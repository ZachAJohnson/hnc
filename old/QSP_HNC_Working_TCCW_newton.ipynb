# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt

from hnc_Ng import  HNC_solver
from qsps import *

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
        
        
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# # Function that sets up HNC QSP

# %%
def set_hnc_onlyion(n_in_per_cc, T, Z, A, Zstar, c_k_guess=None , which_Tij='thermal',
            oz_type='standard', method='kryov', add_bridge=False, bridge='yukawa',yukawa=False,
            pseudopotential=False, r_c=0.6, N_bins = 500, R_max=5):
    
    n_in_AU = n_in_per_cc*1e6 *aB**3
    ri = QSP_HNC.rs_from_n(n_in_AU)
    qsp = QSP_HNC(Z, A, Zstar, T, T, ri, Zstar*n_in_AU, which_Tij=which_Tij, r_c=r_c)

    N_species = 1
    Gamma = np.array(  [[qsp.Γii]])


    names = ["Ion-1", "Electron", ] 
    kappa = 1
    
    rhos = np.array([  3/(4*np.pi)])
    temps = np.array([qsp.Ti])
    masses= np.array([qsp.m_i])
    hnc1 = HNC_solver(N_species, Gamma, rhos, temps, masses ,
                     kappa_multiscale=5, R_max=R_max, N_bins=N_bins, 
                      names=names, dst_type=3, oz_method=oz_type)

    if pseudopotential==True:
        βvei = qsp.βvei_atomic(hnc1.r_array)
    else:
        βvei = qsp.βvei(hnc1.r_array)

    if yukawa:
        βu_r_matrix = np.array([[qsp.βv_Yukawa(hnc1.r_array)]])
    else:
        βu_r_matrix = np.array([[qsp.βvii(hnc1.r_array)]])
        
    if add_bridge:
        if bridge=='ocp':
            βu_r_matrix[0,0] = βu_r_matrix[0,0] - hnc1.Bridge_function_OCP(hnc1.r_array, qsp.Γii)
        elif bridge=='yukawa':
            βu_r_matrix[0,0] = βu_r_matrix[0,0] - hnc1.Bridge_function_Yukawa(hnc1.r_array, qsp.Γii, qsp.get_κ())
    hnc1.set_βu_matrix(βu_r_matrix)
    hnc1.initialize_c_k()
#     print("c asymm: ", hnc1.c_s_k_matrix[1,0]/hnc1.c_s_k_matrix[0,1])
    if c_k_guess is not None:
        for i in range(N_species):
            for j in range(N_species):
                if (c_k_guess[i,j]!=np.zeros(hnc1.N_bins)).all():
#                 if i==j:
                    hnc1.c_k_matrix[i,j] = c_k_guess[i,j]
                    hnc1.c_r_matrix[i,j] = hnc1.FT_k_2_r(hnc1.c_k_matrix[i,j])
                    hnc1.c_s_k_matrix[i,j] = hnc1.c_k_matrix[i,j] + hnc1.βu_l_k_matrix[i,j]
                    hnc1.c_s_r_matrix[i,j] = hnc1.c_r_matrix[i,j] + hnc1.βu_l_r_matrix[i,j]

#     print("c asymm: ", hnc1.c_s_k_matrix[1,0]/hnc1.c_s_k_matrix[0,1])
    hnc1.set_C_matrix()

    return hnc1, qsp

# %%
def set_hnc(n_in_per_cc, T, Z, A, Zstar, c_k_guess=None , which_Tij='thermal',
            oz_type='standard', method='kryov', add_bridge=False, bridge='yukawa',
            pseudopotential=False, r_c=0.6, no_coupling=False, N_bins = 500, R_max=5):
    
    n_in_AU = n_in_per_cc*1e6 *aB**3
    ri = QSP_HNC.rs_from_n(n_in_AU)
    qsp = QSP_HNC(Z, A, Zstar, T, T, ri, Zstar*n_in_AU, which_Tij=which_Tij, r_c=r_c)

    N_species = 2
    Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                        [qsp.Γei,  qsp.Γee]])


    names = ["Ion-1", "Electron", ] 
    kappa = 1
    
    rhos = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
    temps = np.array([qsp.Ti, qsp.Te_c])
    masses= np.array([qsp.m_i, m_e])
    hnc1 = HNC_solver(N_species, Gamma, rhos, temps, masses ,
                     kappa_multiscale=10, R_max=R_max, N_bins=N_bins, 
                      names=names, dst_type=3, oz_method=oz_type)

    if pseudopotential==True:
        βvei = qsp.βvei_atomic(hnc1.r_array)
    else:
        βvei = qsp.βvei(hnc1.r_array)
    βu_r_matrix = np.array([[qsp.βvii(hnc1.r_array), βvei],
                            [βvei, qsp.βvee(hnc1.r_array)]])
    if no_coupling:
        βu_r_matrix[0,1]=0
        βu_r_matrix[1,0]=0
    
    if add_bridge:
        if bridge=='ocp':
            βu_r_matrix[0,0] = βu_r_matrix[0,0] - hnc1.Bridge_function_OCP(hnc1.r_array, qsp.Γii)
        elif bridge=='yukawa':
            βu_r_matrix[0,0] = βu_r_matrix[0,0] - hnc1.Bridge_function_Yukawa(hnc1.r_array, qsp.Γii, qsp.get_κ())
    hnc1.set_βu_matrix(βu_r_matrix)
    hnc1.initialize_c_k()
#     print("c asymm: ", hnc1.c_s_k_matrix[1,0]/hnc1.c_s_k_matrix[0,1])
    if c_k_guess is not None:
        for i in range(N_species):
            for j in range(N_species):
                if (c_k_guess[i,j]!=np.zeros(hnc1.N_bins)).all():
#                 if i==j:
                    hnc1.c_k_matrix[i,j] = c_k_guess[i,j]
                    hnc1.c_r_matrix[i,j] = hnc1.FT_k_2_r(hnc1.c_k_matrix[i,j])
                    hnc1.c_s_k_matrix[i,j] = hnc1.c_k_matrix[i,j] + hnc1.βu_l_k_matrix[i,j]
                    hnc1.c_s_r_matrix[i,j] = hnc1.c_r_matrix[i,j] + hnc1.βu_l_r_matrix[i,j]

#     print("c asymm: ", hnc1.c_s_k_matrix[1,0]/hnc1.c_s_k_matrix[0,1])
    hnc1.set_C_matrix()

    return hnc1, qsp

# %% [markdown]
# ## Load TCCW Cases

# %%
for tccw_case in tccw_cases:
    if 'H' in tccw_case['Case ID']:
        print(tccw_case[' '], tccw_case['Case ID'], " Γii = ",tccw_case['Coupling Constant'])
# Out:
# 0 H1  Γii =  4.689931802
# 6 H2  Γii =  385.7474933
# 7 H3  Γii =  1.505398501
# 14 H11  Γii =  1238.853127
# 15 H21  Γii =  2974.224527
# 16 H31  Γii =  7571.846897
# 26 H12  Γii =  123.8925534
# 27 H22  Γii =  297.4237281
# 28 H32  Γii =  757.1848093
# 38 H13  Γii =  12.40787488
# 39 H23  Γii =  29.74600211
# 40 H33  Γii =  75.71886645
# 50 H14  Γii =  1.296884499
# 51 H24  Γii =  2.985299562
# 52 H34  Γii =  7.572905589
# 62 H15  Γii =  0.197649761
# 63 H25  Γii =  0.33817545
# 64 H35  Γii =  0.762807904
# 74 H16  Γii =  0.001159757

# %%
14700000000./1e9
# Out:
# 14.7

# %%
mixture_file = "/home/zach/plasma/hnc/data/TCCW_single_species_data.csv"
tccw_mixture_data = read_csv(mixture_file)
tccw_cases = [tccw_mixture_data.iloc[n] for n in range(len(tccw_mixture_data))]

case_successes = {}
SVT_case_successes = {}
# R_max = 3
# N_bins = 100
max_attempts=1

tccw_case = tccw_cases[16]
α = 0.1
case_converged=False
case_attempts=0
case_num= tccw_case[' ']
case_id = tccw_case['Case ID']
ni = tccw_case['Number Density [N/cc]']
Te = tccw_case['Temperature [eV]']*eV
Ti = Te
Z = tccw_case['Atomic Number']
Zstar = tccw_case['Zbar (TFDW)']
A = tccw_case['Atomic Weight [a.u.]']
r_s = tccw_case['Wigner-Seitz Radius [cm]']
r_c = tccw_case['Average-Bound Radius [cm]']/r_s
if r_c>1:
    r_c=1e-5
print('\n______________________________\nCase num: {0} Case ID: {1}'.format(case_num, case_id))
print("Te = {0:.3e} eV, n_i = {1:.3e} 1/cc, r_c/r_s = {2:.3f}".format(Te/eV, ni, r_c))
# Out:
# ______________________________
# Case num: 16 Case ID: H31
# Te = 1.000e-02 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.000

# %%
# from scipy.optimize import minimize 

# class c_s_k_fit():
    
#     def __init__(self, fit_function, initial_guess):
#         self.fit_function = fit_function
#         self.guess = initial_guess
#         self.get_vals()
        
#     def err_of_f(self, params):
#         return atom_onlyion.total_err(self.fit_function(params))
    
#     def get_vals(self):
#         sol = minimize(self.err_of_f, self.guess)
#         self.fit_vals = sol.x
#         self.err = sol.fun
    
#     def csk_fit(self):
#         return self.fit_function(self.fit_vals)
        
# def c_s_k_sigmoid_cos_f(params):
#     λ_rate, k_shift, A, κ, r_osc = params
#     k = atom.k_array
#     βu_k = atom_onlyion.βu_k_matrix
#     c_k_initial_guess = -βu_k*1/(1+np.exp(λ_rate*(k-k_shift))) + A*np.exp(-κ*k)*np.cos(2*π*r_osc*k)
#     c_s_k_initial_guess = c_k_initial_guess + atom_onlyion.βu_l_k_matrix
#     return c_s_k_initial_guess

# def c_s_k_sigmoid_f(params):
#     λ_rate, k_shift= params
#     k = atom.k_array
#     βu_k = atom_onlyion.βu_k_matrix
#     c_k_initial_guess = -βu_k*1/(1+np.exp(λ_rate*(k-k_shift)))
#     c_s_k_initial_guess = c_k_initial_guess + atom_onlyion.βu_l_k_matrix
#     return c_s_k_initial_guess

# csk_fit1 = c_s_k_fit(c_s_k_sigmoid_cos_f, (3,2,2e2, 0.5,1/7)) #minimize(c_s_k_initial_guess_f,(1,2,1,1)
# csk_fit2 = c_s_k_fit(c_s_k_sigmoid_f, (3,2))
# csk_fit1.fit_vals, csk_fit1.err
# csk_fit2.fit_vals, csk_fit2.err

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_9092/1012800413.py in <module>
# ----> 1 np.savetxt("./fits/{0}_g_r.txt".format(case_id), np.array([atom.r_array, atom.h_r_matrix[0,0]+1, atom.h_r_matrix[0,1]+1, atom.h_r_matrix[1,1]+1]), header="atom {0} T={1:.1f} eV, r_i={2:.2f}, solve_err={3:.3e}\n r/r_i  gii(r/r_i) gie(r/r_i) gee(r/r_i)".format(case_id, Te/eV, qsp.ri,newton_final_err))
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
# %%time
atom_onlyion, _ = set_hnc_onlyion(ni, Te, Z, A, Zstar, 
                            pseudopotential=True, oz_type='svt',r_c=r_c, 
                            add_bridge=True, bridge='yukawa',yukawa=True, N_bins=1000, R_max=5)
# c_k_initial_guess = -atom_onlyion.βu_k_matrix[0,0]*1/(1+np.exp(2.91575502*(atom_onlyion.k_array-2)))
# atom_onlyion.c_s_k_matrix[0,0] = c_k_initial_guess + atom_onlyion.βu_l_k_matrix[0,0] 
atom_onlyion.c_s_k_matrix[0,0]*=0
atom_onlyion.HNC_solve(alpha_method='fixed', alpha_Picard = 5e-1, tol=1e-8, alpha_Ng=0.1, 
               iters_to_wait=1e3, iters_to_use=2, num_iterations=1e3, verbose=True)

options={'eps':1e-6,'maxfev':10000,'factor':1,'xtol':1e-8} 
newton_kwargs= {'method':'hybr', 'options':options} 
sol = atom_onlyion.HNC_newton_solve( **newton_kwargs)
print("Err: ", atom_onlyion.total_err(sol.x.reshape(1,1,1000)))
# Out:
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=8596.509, Γie=-0.234, Γee=0.239
# r_i=0.305
# r_e=0.307
# r_c=0.000
# θ  =1.88e-05
# 0: Initial condition Total Error: 1.616e+65
# 1: Change in c_r: 2.925e+03, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 1.801e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 2.882e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 1.720e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 1.602e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 3.120e+03, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 2.975e+03, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 2.885e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 2.819e+03, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 2.747e+03, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 2.665e+03, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/plasma/hnc/hnc_Ng.py in HNC_newton_solve(self, **newton_kwargs)
#     490         # sol2 = root(f_to_min, self.c_s_k_matrix, method='krylov' , callback=callback_func, tol=tol, options=options)
#     491         # options={'eps':1e-6,'maxfev':100,'factor':0.1,'xtol':1e-3}
# --> 492         sol2 = root(f_to_min, self.c_s_k_matrix, **newton_kwargs)#method='hybr' , tol=tol, options=options)
#     493         print("\nRoot Finder: ", sol2.success, sol2.message)
#     494         self.c_s_k_matrix = sol2.x.reshape(self.N_species, self.N_species, self.N_bins)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_root.py in root(fun, x0, args, method, jac, tol, callback, options)
#     233
#     234     if meth == 'hybr':
# --> 235         sol = _root_hybr(fun, x0, args=args, jac=jac, **options)
#     236     elif meth == 'lm':
#     237         sol = _root_leastsq(fun, x0, args=args, jac=jac, **options)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     238         if maxfev == 0:
#     239             maxfev = 200 * (n + 1)
# --> 240         retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
#     241                                  ml, mu, epsfcn, factor, diag)
#     242     else:
#
# ~/plasma/hnc/hnc_Ng.py in f_to_min(c_s_k_flat)
#     475         def f_to_min(c_s_k_flat):
#     476             c_s_k_matrix = c_s_k_flat.reshape(self.N_species, self.N_species, self.N_bins)
# --> 477             matrix_to_min = self.get_hnc_oz_matrix(c_s_k_matrix)
#     478             return matrix_to_min.flatten()
#     479
#
# ~/plasma/hnc/hnc_Ng.py in get_hnc_oz_matrix(self, c_s_k_matrix)
#     303         c_k_matrix = c_s_k_matrix - self.βu_l_k_matrix
#     304
# --> 305         γs_k_matrix = self.get_γs_k_matrix(c_s_k_matrix)
#     306         h_k_matrix = c_s_k_matrix  + γs_k_matrix
#     307         h_r_matrix = self.FT_k_2_r_matrix(h_k_matrix)
#
# ~/plasma/hnc/hnc_Ng.py in get_γs_k_matrix(self, c_s_k_matrix)
#     217             γs_k_matrix = self.get_γs_k_matrix_standard(c_s_k_matrix)
#     218         elif self.oz_method in ['svt','SVT']:
# --> 219             γs_k_matrix = self.get_γs_k_matrix_SVT(c_s_k_matrix)
#     220         return γs_k_matrix
#     221
#
# ~/plasma/hnc/hnc_Ng.py in get_γs_k_matrix_SVT(self, c_s_k_matrix)
#     253         γs_k_matrix = np.zeros_like(self.γs_k_matrix)
#     254         for k in range(self.N_bins):
# --> 255             γs_k_matrix[:,:,k]   = solve_sylvester(A[:,:,k], B[:,:,k], C[:,:,k])
#     256             # γs_k_matrix[:,:,k] = solve_continuous_lyapunov(A[:,:,k], C[:,:,k])
#     257         return γs_k_matrix
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_solvers.py in solve_sylvester(a, b, q)
#      83
#      84     # Compute the Schur decomposition form of a
# ---> 85     r, u = schur(a, output='real')
#      86
#      87     # Compute the Schur decomposition of b
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_decomp_schur.py in schur(a, output, lwork, overwrite_a, sort, check_finite)
#     157                              "callable, or one of ('lhp','rhp','iuc','ouc')")
#     158
# --> 159     result = gees(sfunction, a1, lwork=lwork, overwrite_a=overwrite_a,
#     160                   sort_t=sort_t)
#     161
#
# KeyboardInterrupt:

# %%
# Out:
# Err:  3.455505456070031

# %% [markdown]
# Properties of good initial c_k guess
# Polynomial at k<2, then exponential, asymptoting to zero around k=5-20

# %% [markdown]
# # Make atom

# %%
# %%time
# atom, atomqsp = set_hnc(ni, Te, Z, A, Zstar, 
#                             pseudopotential=True, oz_type='svt',r_c=r_c, 
#                             add_bridge=True, bridge='ocp', N_bins=500, R_max=5)
# atom.HNC_solve(alpha_method='fixed', alpha_Picard = 1, tol=1e-8, alpha_Ng=0, 
#                iters_to_wait=1e4, iters_to_use=2, num_iterations=1e3, verbose=True)

# options={'eps':1e-6,'maxfev':10000,'factor':100,'xtol':1e-8} 
# newton_kwargs= {'method':'hybr', 'options':options} 
# sol = atom.HNC_newton_solve( **newton_kwargs)
# Out:
# Root Finder:  True The solution converged.

# %%
# atom_onlyion_answer = atom_onlyion

# %%
# %%time
atom_lowres, atomqsp = set_hnc(ni, Te, Z, A, Zstar, 
                            pseudopotential=True, oz_type='svt',r_c=r_c, 
                            add_bridge=True, bridge='ocp', N_bins=1000, R_max=10)
atom_lowres.c_s_k_matrix[0,0] = 0.5*atom_onlyion.c_s_k_matrix[0,0]
atom_lowres.HNC_solve(alpha_method='fixed', alpha_Picard = 5e-1, tol=1e-3, alpha_Ng=0.1, 
               iters_to_wait=1e4, iters_to_use=5, num_iterations=1e3, verbose=True)

# c_s_k_guess = atom_lowres.c_s_k_matrix.copy()
# Out:
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=861.404, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =1.87e-04
# 0: Initial condition Total Error: 5.292e+01
# 1: Change in c_r: 5.015e-01, HNC Error: 2.366e-02, Total Error: 3.920e+01
# 2: Change in c_r: 3.879e-01, HNC Error: 1.806e-02, Total Error: 3.000e+01
# 3: Change in c_r: 3.203e-01, HNC Error: 1.318e-02, Total Error: 2.375e+01
# 4: Change in c_r: 2.808e-01, HNC Error: 9.700e-03, Total Error: 1.941e+01
# 5: Change in c_r: 2.574e-01, HNC Error: 7.732e-03, Total Error: 1.633e+01
# 6: Change in c_r: 2.426e-01, HNC Error: 6.659e-03, Total Error: 1.407e+01
# 7: Change in c_r: 2.324e-01, HNC Error: 5.880e-03, Total Error: 1.236e+01
# 8: Change in c_r: 2.247e-01, HNC Error: 5.302e-03, Total Error: 1.104e+01
# 9: Change in c_r: 2.187e-01, HNC Error: 5.193e-03, Total Error: 9.987e+00
# 10: Change in c_r: 2.137e-01, HNC Error: 5.650e-03, Total Error: 9.128e+00
# 11: Change in c_r: 2.088e-01, HNC Error: 6.238e-03, Total Error: 8.403e+00
# 12: Change in c_r: 2.031e-01, HNC Error: 6.337e-03, Total Error: 7.776e+00
# 13: Change in c_r: 1.966e-01, HNC Error: 6.234e-03, Total Error: 7.230e+00
# 14: Change in c_r: 1.903e-01, HNC Error: 6.031e-03, Total Error: 6.760e+00
# 15: Change in c_r: 1.856e-01, HNC Error: 4.420e-03, Total Error: 6.363e+00
# 16: Change in c_r: 1.831e-01, HNC Error: 2.476e-03, Total Error: 6.031e+00
# 17: Change in c_r: 1.825e-01, HNC Error: 2.813e-03, Total Error: 5.751e+00
# 18: Change in c_r: 1.831e-01, HNC Error: 3.581e-03, Total Error: 5.507e+00
# 19: Change in c_r: 1.843e-01, HNC Error: 3.631e-03, Total Error: 5.284e+00
# 20: Change in c_r: 1.856e-01, HNC Error: 3.278e-03, Total Error: 5.073e+00
# 21: Change in c_r: 1.867e-01, HNC Error: 3.317e-03, Total Error: 4.871e+00
# 22: Change in c_r: 1.871e-01, HNC Error: 4.808e-03, Total Error: 4.673e+00
# 23: Change in c_r: 1.862e-01, HNC Error: 8.152e-03, Total Error: 4.480e+00
# 24: Change in c_r: 1.832e-01, HNC Error: 1.318e-02, Total Error: 4.290e+00
# 25: Change in c_r: 1.767e-01, HNC Error: 1.788e-02, Total Error: 4.102e+00
# 26: Change in c_r: 1.660e-01, HNC Error: 1.683e-02, Total Error: 3.914e+00
# 27: Change in c_r: 1.524e-01, HNC Error: 4.246e-02, Total Error: 3.723e+00
# 28: Change in c_r: 1.416e-01, HNC Error: 1.021e-01, Total Error: 3.527e+00
# 29: Change in c_r: 1.378e-01, HNC Error: 1.215e-01, Total Error: 3.340e+00
# 30: Change in c_r: 1.380e-01, HNC Error: 9.034e-02, Total Error: 3.182e+00
# 31: Change in c_r: 1.379e-01, HNC Error: 5.215e-02, Total Error: 3.067e+00
# 32: Change in c_r: 1.367e-01, HNC Error: 3.244e-02, Total Error: 2.988e+00
# 33: Change in c_r: 1.351e-01, HNC Error: 2.959e-02, Total Error: 2.932e+00
# 34: Change in c_r: 1.338e-01, HNC Error: 3.091e-02, Total Error: 2.885e+00
# 35: Change in c_r: 1.329e-01, HNC Error: 3.161e-02, Total Error: 2.841e+00
# 36: Change in c_r: 1.322e-01, HNC Error: 3.140e-02, Total Error: 2.796e+00
# 37: Change in c_r: 1.317e-01, HNC Error: 3.059e-02, Total Error: 2.752e+00
# 38: Change in c_r: 1.312e-01, HNC Error: 2.945e-02, Total Error: 2.707e+00
# 39: Change in c_r: 1.309e-01, HNC Error: 2.813e-02, Total Error: 2.662e+00
# 40: Change in c_r: 1.306e-01, HNC Error: 2.674e-02, Total Error: 2.618e+00
# 41: Change in c_r: 1.303e-01, HNC Error: 2.534e-02, Total Error: 2.574e+00
# 42: Change in c_r: 1.301e-01, HNC Error: 2.396e-02, Total Error: 2.531e+00
# 43: Change in c_r: 1.300e-01, HNC Error: 2.262e-02, Total Error: 2.488e+00
# 44: Change in c_r: 1.299e-01, HNC Error: 2.133e-02, Total Error: 2.445e+00
# 45: Change in c_r: 1.298e-01, HNC Error: 2.010e-02, Total Error: 2.403e+00
# 46: Change in c_r: 1.298e-01, HNC Error: 1.892e-02, Total Error: 2.361e+00
# 47: Change in c_r: 1.299e-01, HNC Error: 1.781e-02, Total Error: 2.320e+00
# 48: Change in c_r: 1.300e-01, HNC Error: 1.675e-02, Total Error: 2.279e+00
# 49: Change in c_r: 1.303e-01, HNC Error: 1.576e-02, Total Error: 2.239e+00
# 50: Change in c_r: 1.305e-01, HNC Error: 1.482e-02, Total Error: 2.199e+00
# 51: Change in c_r: 1.309e-01, HNC Error: 1.394e-02, Total Error: 2.160e+00
# 52: Change in c_r: 1.313e-01, HNC Error: 1.312e-02, Total Error: 2.122e+00
# 53: Change in c_r: 1.318e-01, HNC Error: 1.234e-02, Total Error: 2.084e+00
# 54: Change in c_r: 1.323e-01, HNC Error: 1.162e-02, Total Error: 2.046e+00
# 55: Change in c_r: 1.330e-01, HNC Error: 1.095e-02, Total Error: 2.010e+00
# 56: Change in c_r: 1.337e-01, HNC Error: 1.032e-02, Total Error: 1.973e+00
# 57: Change in c_r: 1.345e-01, HNC Error: 9.739e-03, Total Error: 1.938e+00
# 58: Change in c_r: 1.353e-01, HNC Error: 9.196e-03, Total Error: 1.903e+00
# 59: Change in c_r: 1.363e-01, HNC Error: 8.692e-03, Total Error: 1.869e+00
# 60: Change in c_r: 1.373e-01, HNC Error: 8.225e-03, Total Error: 1.836e+00
# 61: Change in c_r: 1.384e-01, HNC Error: 7.790e-03, Total Error: 1.804e+00
# 62: Change in c_r: 1.395e-01, HNC Error: 7.387e-03, Total Error: 1.772e+00
# 63: Change in c_r: 1.408e-01, HNC Error: 7.013e-03, Total Error: 1.741e+00
# 64: Change in c_r: 1.421e-01, HNC Error: 6.664e-03, Total Error: 1.711e+00
# 65: Change in c_r: 1.434e-01, HNC Error: 6.339e-03, Total Error: 1.681e+00
# 66: Change in c_r: 1.448e-01, HNC Error: 6.036e-03, Total Error: 1.652e+00
# 67: Change in c_r: 1.463e-01, HNC Error: 5.753e-03, Total Error: 1.624e+00
# 68: Change in c_r: 1.478e-01, HNC Error: 5.487e-03, Total Error: 1.597e+00
# 69: Change in c_r: 1.494e-01, HNC Error: 5.238e-03, Total Error: 1.570e+00
# 70: Change in c_r: 1.510e-01, HNC Error: 5.004e-03, Total Error: 1.544e+00
# 71: Change in c_r: 1.527e-01, HNC Error: 4.784e-03, Total Error: 1.519e+00
# 72: Change in c_r: 1.543e-01, HNC Error: 4.579e-03, Total Error: 1.495e+00
# 73: Change in c_r: 1.560e-01, HNC Error: 4.394e-03, Total Error: 1.471e+00
# 74: Change in c_r: 1.575e-01, HNC Error: 4.239e-03, Total Error: 1.447e+00
# 75: Change in c_r: 1.590e-01, HNC Error: 4.162e-03, Total Error: 1.424e+00
# 76: Change in c_r: 1.603e-01, HNC Error: 4.341e-03, Total Error: 1.402e+00
# 77: Change in c_r: 1.610e-01, HNC Error: 5.438e-03, Total Error: 1.379e+00
# 78: Change in c_r: 1.607e-01, HNC Error: 9.216e-03, Total Error: 1.356e+00
# 79: Change in c_r: 1.581e-01, HNC Error: 1.888e-02, Total Error: 1.331e+00
# 80: Change in c_r: 1.505e-01, HNC Error: 3.722e-02, Total Error: 1.300e+00
# 81: Change in c_r: 1.335e-01, HNC Error: 3.750e-02, Total Error: 1.256e+00
# 82: Change in c_r: 1.061e-01, HNC Error: 7.127e-01, Total Error: 1.179e+00
# 83: Change in c_r: 1.077e-01, HNC Error: 7.663e+00, Total Error: 1.028e+00
# 84: Change in c_r: 1.831e-01, HNC Error: 3.142e+01, Total Error: 7.829e-01
# 85: Change in c_r: 2.953e-01, HNC Error: 3.060e+01, Total Error: 5.999e-01
# 86: Change in c_r: 4.031e-01, HNC Error: 1.208e-01, Total Error: 5.868e-01
# 87: Change in c_r: 3.106e-01, HNC Error: 2.539e-01, Total Error: 7.900e-01
# 88: Change in c_r: 1.099e-01, HNC Error: 2.192e-01, Total Error: 1.215e+00
# 89: Change in c_r: 1.224e-01, HNC Error: 1.575e+00, Total Error: 1.108e+00
# 90: Change in c_r: 1.449e-01, HNC Error: 2.618e+01, Total Error: 7.427e-01
# 91: Change in c_r: 2.937e-01, HNC Error: 4.644e+01, Total Error: 5.420e-01
# 92: Change in c_r: 4.569e-01, HNC Error: 3.790e-01, Total Error: 6.404e-01
# 93: Change in c_r: 3.217e-01, HNC Error: 2.013e-01, Total Error: 9.009e-01
# 94: Change in c_r: 2.091e-01, HNC Error: 2.052e-01, Total Error: 1.478e+00
# 95: Change in c_r: 1.873e-01, HNC Error: 1.420e+00, Total Error: 1.270e+00
# 96: Change in c_r: 1.207e-01, HNC Error: 4.554e+01, Total Error: 7.955e-01
# 97: Change in c_r: 2.698e-01, HNC Error: 3.763e+02, Total Error: 5.686e-01
# 98: Change in c_r: 5.144e-01, HNC Error: 1.234e+01, Total Error: 1.006e+00
# 99: Change in c_r: 6.241e-01, HNC Error: 2.215e-01, Total Error: 7.775e-01
# 100: Change in c_r: 1.755e-01, HNC Error: 1.191e-01, Total Error: 1.766e+00
# 101: Change in c_r: 3.656e-01, HNC Error: 1.464e-01, Total Error: 1.688e+00
# 102: Change in c_r: 1.921e-01, HNC Error: 6.086e+00, Total Error: 1.223e+00
# 103: Change in c_r: 1.298e-01, HNC Error: 1.389e+02, Total Error: 6.750e-01
# 104: Change in c_r: 3.125e-01, HNC Error: 1.652e+03, Total Error: 7.139e-01
# 105: Change in c_r: 6.145e-01, HNC Error: 1.098e+02, Total Error: 1.451e+00
# 106: Change in c_r: 8.348e-01, HNC Error: 2.213e-01, Total Error: 1.167e+00
# 107: Change in c_r: 1.849e-01, HNC Error: 7.614e-02, Total Error: 2.091e+00
# 108: Change in c_r: 5.006e-01, HNC Error: 1.367e-01, Total Error: 1.983e+00
# 109: Change in c_r: 3.024e-01, HNC Error: 7.568e-01, Total Error: 1.482e+00
# 110: Change in c_r: 1.341e-01, HNC Error: 2.794e+01, Total Error: 9.330e-01
# 111: Change in c_r: 1.809e-01, HNC Error: 3.565e+02, Total Error: 5.243e-01
# 112: Change in c_r: 4.069e-01, HNC Error: 4.591e+02, Total Error: 9.647e-01
# 113: Change in c_r: 6.663e-01, HNC Error: 4.544e-01, Total Error: 1.238e+00
# 114: Change in c_r: 3.082e-01, HNC Error: 1.047e-01, Total Error: 1.247e+00
# 115: Change in c_r: 4.270e-01, HNC Error: 1.462e-01, Total Error: 1.778e+00
# 116: Change in c_r: 2.895e-01, HNC Error: 3.408e-01, Total Error: 1.426e+00
# 117: Change in c_r: 1.317e-01, HNC Error: 1.592e+01, Total Error: 9.133e-01
# 118: Change in c_r: 1.700e-01, HNC Error: 1.292e+02, Total Error: 4.935e-01
# 119: Change in c_r: 3.636e-01, HNC Error: 3.136e+01, Total Error: 7.610e-01
# 120: Change in c_r: 5.041e-01, HNC Error: 3.224e-01, Total Error: 7.356e-01
# 121: Change in c_r: 1.159e-01, HNC Error: 1.502e-01, Total Error: 1.224e+00
# 122: Change in c_r: 2.863e-01, HNC Error: 1.646e-01, Total Error: 1.409e+00
# 123: Change in c_r: 1.616e-01, HNC Error: 3.056e+00, Total Error: 1.044e+00
# 124: Change in c_r: 1.233e-01, HNC Error: 3.096e+01, Total Error: 5.716e-01
# 125: Change in c_r: 2.663e-01, HNC Error: 2.207e+01, Total Error: 5.096e-01
# 126: Change in c_r: 3.947e-01, HNC Error: 3.713e-01, Total Error: 5.920e-01
# 127: Change in c_r: 1.873e-01, HNC Error: 1.981e-01, Total Error: 8.520e-01
# 128: Change in c_r: 1.945e-01, HNC Error: 1.880e-01, Total Error: 1.205e+00
# 129: Change in c_r: 1.363e-01, HNC Error: 1.724e+00, Total Error: 9.540e-01
# 130: Change in c_r: 1.222e-01, HNC Error: 1.267e+01, Total Error: 5.478e-01
# 131: Change in c_r: 2.419e-01, HNC Error: 4.846e+00, Total Error: 4.279e-01
# 132: Change in c_r: 3.123e-01, HNC Error: 3.284e-01, Total Error: 4.505e-01
# 133: Change in c_r: 1.353e-01, HNC Error: 2.311e-01, Total Error: 7.940e-01
# 134: Change in c_r: 1.343e-01, HNC Error: 1.355e-01, Total Error: 1.001e+00
# 135: Change in c_r: 1.013e-01, HNC Error: 1.814e+00, Total Error: 7.726e-01
# 136: Change in c_r: 1.430e-01, HNC Error: 5.021e+00, Total Error: 4.627e-01
# 137: Change in c_r: 2.339e-01, HNC Error: 4.154e-01, Total Error: 3.875e-01
# 138: Change in c_r: 2.247e-01, HNC Error: 2.854e-01, Total Error: 4.633e-01
# 139: Change in c_r: 9.590e-02, HNC Error: 2.305e-01, Total Error: 7.800e-01
# 140: Change in c_r: 9.802e-02, HNC Error: 1.427e-01, Total Error: 8.063e-01
# 141: Change in c_r: 1.042e-01, HNC Error: 1.564e+00, Total Error: 5.901e-01
# 142: Change in c_r: 1.664e-01, HNC Error: 1.098e+00, Total Error: 4.074e-01
# 143: Change in c_r: 2.030e-01, HNC Error: 1.781e-01, Total Error: 3.991e-01
# 144: Change in c_r: 1.439e-01, HNC Error: 2.413e-01, Total Error: 5.632e-01
# 145: Change in c_r: 9.170e-02, HNC Error: 1.337e-01, Total Error: 7.026e-01
# 146: Change in c_r: 9.590e-02, HNC Error: 3.725e-01, Total Error: 6.273e-01
# 147: Change in c_r: 1.296e-01, HNC Error: 6.550e-01, Total Error: 4.767e-01
# 148: Change in c_r: 1.651e-01, HNC Error: 9.684e-02, Total Error: 4.132e-01
# 149: Change in c_r: 1.530e-01, HNC Error: 1.858e-01, Total Error: 4.735e-01
# 150: Change in c_r: 1.111e-01, HNC Error: 1.536e-01, Total Error: 5.821e-01
# 151: Change in c_r: 1.001e-01, HNC Error: 7.971e-02, Total Error: 5.906e-01
# 152: Change in c_r: 1.155e-01, HNC Error: 2.588e-01, Total Error: 5.117e-01
# 153: Change in c_r: 1.384e-01, HNC Error: 1.335e-01, Total Error: 4.482e-01
# 154: Change in c_r: 1.418e-01, HNC Error: 9.639e-02, Total Error: 4.554e-01
# 155: Change in c_r: 1.231e-01, HNC Error: 1.184e-01, Total Error: 5.084e-01
# 156: Change in c_r: 1.099e-01, HNC Error: 6.514e-02, Total Error: 5.341e-01
# 157: Change in c_r: 1.134e-01, HNC Error: 9.414e-02, Total Error: 5.069e-01
# 158: Change in c_r: 1.245e-01, HNC Error: 8.981e-02, Total Error: 4.682e-01
# 159: Change in c_r: 1.295e-01, HNC Error: 6.062e-02, Total Error: 4.576e-01
# 160: Change in c_r: 1.237e-01, HNC Error: 7.695e-02, Total Error: 4.748e-01
# 161: Change in c_r: 1.162e-01, HNC Error: 6.431e-02, Total Error: 4.904e-01
# 162: Change in c_r: 1.151e-01, HNC Error: 5.689e-02, Total Error: 4.846e-01
# 163: Change in c_r: 1.188e-01, HNC Error: 5.976e-02, Total Error: 4.672e-01
# 164: Change in c_r: 1.216e-01, HNC Error: 5.509e-02, Total Error: 4.567e-01
# 165: Change in c_r: 1.204e-01, HNC Error: 5.797e-02, Total Error: 4.582e-01
# 166: Change in c_r: 1.173e-01, HNC Error: 5.680e-02, Total Error: 4.629e-01
# 167: Change in c_r: 1.158e-01, HNC Error: 5.295e-02, Total Error: 4.614e-01
# 168: Change in c_r: 1.164e-01, HNC Error: 5.182e-02, Total Error: 4.543e-01
# 169: Change in c_r: 1.173e-01, HNC Error: 5.135e-02, Total Error: 4.477e-01
# 170: Change in c_r: 1.170e-01, HNC Error: 5.162e-02, Total Error: 4.448e-01
# 171: Change in c_r: 1.159e-01, HNC Error: 5.129e-02, Total Error: 4.439e-01
# 172: Change in c_r: 1.150e-01, HNC Error: 4.996e-02, Total Error: 4.418e-01
# 173: Change in c_r: 1.147e-01, HNC Error: 4.883e-02, Total Error: 4.380e-01
# 174: Change in c_r: 1.146e-01, HNC Error: 4.820e-02, Total Error: 4.337e-01
# 175: Change in c_r: 1.143e-01, HNC Error: 4.782e-02, Total Error: 4.303e-01
# 176: Change in c_r: 1.138e-01, HNC Error: 4.733e-02, Total Error: 4.275e-01
# 177: Change in c_r: 1.132e-01, HNC Error: 4.659e-02, Total Error: 4.246e-01
# 178: Change in c_r: 1.128e-01, HNC Error: 4.580e-02, Total Error: 4.214e-01
# 179: Change in c_r: 1.124e-01, HNC Error: 4.512e-02, Total Error: 4.179e-01
# 180: Change in c_r: 1.120e-01, HNC Error: 4.453e-02, Total Error: 4.145e-01
# 181: Change in c_r: 1.116e-01, HNC Error: 4.393e-02, Total Error: 4.113e-01
# 182: Change in c_r: 1.112e-01, HNC Error: 4.329e-02, Total Error: 4.081e-01
# 183: Change in c_r: 1.108e-01, HNC Error: 4.263e-02, Total Error: 4.049e-01
# 184: Change in c_r: 1.104e-01, HNC Error: 4.198e-02, Total Error: 4.016e-01
# 185: Change in c_r: 1.100e-01, HNC Error: 4.136e-02, Total Error: 3.982e-01
# 186: Change in c_r: 1.096e-01, HNC Error: 4.073e-02, Total Error: 3.949e-01
# 187: Change in c_r: 1.092e-01, HNC Error: 4.011e-02, Total Error: 3.916e-01
# 188: Change in c_r: 1.088e-01, HNC Error: 3.948e-02, Total Error: 3.883e-01
# 189: Change in c_r: 1.084e-01, HNC Error: 3.886e-02, Total Error: 3.850e-01
# 190: Change in c_r: 1.080e-01, HNC Error: 3.823e-02, Total Error: 3.817e-01
# 191: Change in c_r: 1.076e-01, HNC Error: 3.762e-02, Total Error: 3.783e-01
# 192: Change in c_r: 1.072e-01, HNC Error: 3.700e-02, Total Error: 3.750e-01
# 193: Change in c_r: 1.068e-01, HNC Error: 3.638e-02, Total Error: 3.716e-01
# 194: Change in c_r: 1.064e-01, HNC Error: 3.577e-02, Total Error: 3.683e-01
# 195: Change in c_r: 1.060e-01, HNC Error: 3.515e-02, Total Error: 3.649e-01
# 196: Change in c_r: 1.056e-01, HNC Error: 3.454e-02, Total Error: 3.615e-01
# 197: Change in c_r: 1.053e-01, HNC Error: 3.393e-02, Total Error: 3.582e-01
# 198: Change in c_r: 1.049e-01, HNC Error: 3.332e-02, Total Error: 3.548e-01
# 199: Change in c_r: 1.045e-01, HNC Error: 3.272e-02, Total Error: 3.514e-01
# 200: Change in c_r: 1.041e-01, HNC Error: 3.211e-02, Total Error: 3.480e-01
# 201: Change in c_r: 1.038e-01, HNC Error: 3.151e-02, Total Error: 3.447e-01
# 202: Change in c_r: 1.034e-01, HNC Error: 3.090e-02, Total Error: 3.413e-01
# 203: Change in c_r: 1.030e-01, HNC Error: 3.030e-02, Total Error: 3.379e-01
# 204: Change in c_r: 1.027e-01, HNC Error: 2.971e-02, Total Error: 3.345e-01
# 205: Change in c_r: 1.023e-01, HNC Error: 2.911e-02, Total Error: 3.312e-01
# 206: Change in c_r: 1.020e-01, HNC Error: 2.851e-02, Total Error: 3.278e-01
# 207: Change in c_r: 1.016e-01, HNC Error: 2.792e-02, Total Error: 3.245e-01
# 208: Change in c_r: 1.013e-01, HNC Error: 2.733e-02, Total Error: 3.211e-01
# 209: Change in c_r: 1.009e-01, HNC Error: 2.674e-02, Total Error: 3.178e-01
# 210: Change in c_r: 1.006e-01, HNC Error: 2.616e-02, Total Error: 3.144e-01
# 211: Change in c_r: 1.002e-01, HNC Error: 2.558e-02, Total Error: 3.111e-01
# 212: Change in c_r: 9.989e-02, HNC Error: 2.500e-02, Total Error: 3.078e-01
# 213: Change in c_r: 9.955e-02, HNC Error: 2.443e-02, Total Error: 3.046e-01
# 214: Change in c_r: 9.921e-02, HNC Error: 2.386e-02, Total Error: 3.013e-01
# 215: Change in c_r: 9.886e-02, HNC Error: 2.330e-02, Total Error: 2.981e-01
# 216: Change in c_r: 9.851e-02, HNC Error: 2.274e-02, Total Error: 2.949e-01
# 217: Change in c_r: 9.816e-02, HNC Error: 2.219e-02, Total Error: 2.917e-01
# 218: Change in c_r: 9.781e-02, HNC Error: 2.164e-02, Total Error: 2.886e-01
# 219: Change in c_r: 9.745e-02, HNC Error: 2.110e-02, Total Error: 2.855e-01
# 220: Change in c_r: 9.709e-02, HNC Error: 2.057e-02, Total Error: 2.824e-01
# 221: Change in c_r: 9.672e-02, HNC Error: 2.005e-02, Total Error: 2.793e-01
# 222: Change in c_r: 9.635e-02, HNC Error: 1.953e-02, Total Error: 2.763e-01
# 223: Change in c_r: 9.597e-02, HNC Error: 1.903e-02, Total Error: 2.734e-01
# 224: Change in c_r: 9.558e-02, HNC Error: 1.853e-02, Total Error: 2.704e-01
# 225: Change in c_r: 9.519e-02, HNC Error: 1.804e-02, Total Error: 2.675e-01
# 226: Change in c_r: 9.478e-02, HNC Error: 1.756e-02, Total Error: 2.647e-01
# 227: Change in c_r: 9.437e-02, HNC Error: 1.710e-02, Total Error: 2.619e-01
# 228: Change in c_r: 9.395e-02, HNC Error: 1.664e-02, Total Error: 2.591e-01
# 229: Change in c_r: 9.352e-02, HNC Error: 1.620e-02, Total Error: 2.564e-01
# 230: Change in c_r: 9.308e-02, HNC Error: 1.577e-02, Total Error: 2.538e-01
# 231: Change in c_r: 9.264e-02, HNC Error: 1.535e-02, Total Error: 2.511e-01
# 232: Change in c_r: 9.218e-02, HNC Error: 1.494e-02, Total Error: 2.486e-01
# 233: Change in c_r: 9.172e-02, HNC Error: 1.455e-02, Total Error: 2.460e-01
# 234: Change in c_r: 9.125e-02, HNC Error: 1.417e-02, Total Error: 2.435e-01
# 235: Change in c_r: 9.077e-02, HNC Error: 1.380e-02, Total Error: 2.411e-01
# 236: Change in c_r: 9.029e-02, HNC Error: 1.344e-02, Total Error: 2.387e-01
# 237: Change in c_r: 8.981e-02, HNC Error: 1.310e-02, Total Error: 2.363e-01
# 238: Change in c_r: 8.932e-02, HNC Error: 1.277e-02, Total Error: 2.340e-01
# 239: Change in c_r: 8.883e-02, HNC Error: 1.245e-02, Total Error: 2.317e-01
# 240: Change in c_r: 8.834e-02, HNC Error: 1.214e-02, Total Error: 2.295e-01
# 241: Change in c_r: 8.785e-02, HNC Error: 1.184e-02, Total Error: 2.273e-01
# 242: Change in c_r: 8.736e-02, HNC Error: 1.156e-02, Total Error: 2.251e-01
# 243: Change in c_r: 8.688e-02, HNC Error: 1.129e-02, Total Error: 2.230e-01
# 244: Change in c_r: 8.640e-02, HNC Error: 1.102e-02, Total Error: 2.209e-01
# 245: Change in c_r: 8.592e-02, HNC Error: 1.077e-02, Total Error: 2.188e-01
# 246: Change in c_r: 8.545e-02, HNC Error: 1.053e-02, Total Error: 2.167e-01
# 247: Change in c_r: 8.498e-02, HNC Error: 1.030e-02, Total Error: 2.147e-01
# 248: Change in c_r: 8.453e-02, HNC Error: 1.007e-02, Total Error: 2.127e-01
# 249: Change in c_r: 8.408e-02, HNC Error: 9.860e-03, Total Error: 2.108e-01
# 250: Change in c_r: 8.364e-02, HNC Error: 9.653e-03, Total Error: 2.088e-01
# 251: Change in c_r: 8.321e-02, HNC Error: 9.454e-03, Total Error: 2.069e-01
# 252: Change in c_r: 8.279e-02, HNC Error: 9.263e-03, Total Error: 2.051e-01
# 253: Change in c_r: 8.238e-02, HNC Error: 9.079e-03, Total Error: 2.032e-01
# 254: Change in c_r: 8.198e-02, HNC Error: 8.901e-03, Total Error: 2.014e-01
# 255: Change in c_r: 8.160e-02, HNC Error: 8.729e-03, Total Error: 1.996e-01
# 256: Change in c_r: 8.122e-02, HNC Error: 8.563e-03, Total Error: 1.978e-01
# 257: Change in c_r: 8.085e-02, HNC Error: 8.402e-03, Total Error: 1.960e-01
# 258: Change in c_r: 8.050e-02, HNC Error: 8.246e-03, Total Error: 1.943e-01
# 259: Change in c_r: 8.015e-02, HNC Error: 8.095e-03, Total Error: 1.926e-01
# 260: Change in c_r: 7.982e-02, HNC Error: 7.948e-03, Total Error: 1.909e-01
# 261: Change in c_r: 7.949e-02, HNC Error: 7.805e-03, Total Error: 1.893e-01
# 262: Change in c_r: 7.917e-02, HNC Error: 7.666e-03, Total Error: 1.876e-01
# 263: Change in c_r: 7.886e-02, HNC Error: 7.531e-03, Total Error: 1.860e-01
# 264: Change in c_r: 7.856e-02, HNC Error: 7.399e-03, Total Error: 1.845e-01
# 265: Change in c_r: 7.827e-02, HNC Error: 7.270e-03, Total Error: 1.829e-01
# 266: Change in c_r: 7.798e-02, HNC Error: 7.144e-03, Total Error: 1.814e-01
# 267: Change in c_r: 7.769e-02, HNC Error: 7.021e-03, Total Error: 1.799e-01
# 268: Change in c_r: 7.741e-02, HNC Error: 6.901e-03, Total Error: 1.784e-01
# 269: Change in c_r: 7.713e-02, HNC Error: 6.783e-03, Total Error: 1.770e-01
# 270: Change in c_r: 7.686e-02, HNC Error: 6.668e-03, Total Error: 1.756e-01
# 271: Change in c_r: 7.658e-02, HNC Error: 6.556e-03, Total Error: 1.742e-01
# 272: Change in c_r: 7.631e-02, HNC Error: 6.446e-03, Total Error: 1.729e-01
# 273: Change in c_r: 7.604e-02, HNC Error: 6.338e-03, Total Error: 1.715e-01
# 274: Change in c_r: 7.576e-02, HNC Error: 6.233e-03, Total Error: 1.702e-01
# 275: Change in c_r: 7.549e-02, HNC Error: 6.130e-03, Total Error: 1.690e-01
# 276: Change in c_r: 7.522e-02, HNC Error: 6.029e-03, Total Error: 1.677e-01
# 277: Change in c_r: 7.494e-02, HNC Error: 5.930e-03, Total Error: 1.665e-01
# 278: Change in c_r: 7.466e-02, HNC Error: 5.834e-03, Total Error: 1.654e-01
# 279: Change in c_r: 7.438e-02, HNC Error: 5.740e-03, Total Error: 1.642e-01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/plasma/hnc/hnc_Ng.py in HNC_solve(self, alpha_method, num_iterations, tol, iters_to_wait, iters_to_use, alpha_Ng, alpha_Picard, alpha_oz, iters_to_check, verbose)
#     550                 self.c_s_k_matrix = self.Ng_c_s_k(num_to_use=iters_to_use, alpha = alpha_Ng)
#     551
# --> 552             self.set_all_matrices_from_csk(self.c_s_k_matrix)
#     553
#     554             self.h_r_matrix_list.append(self.h_r_matrix.copy())
#
# ~/plasma/hnc/hnc_Ng.py in set_all_matrices_from_csk(self, c_s_k_matrix)
#     329
#     330     def set_all_matrices_from_csk(self, c_s_k_matrix):
# --> 331         c_k_matrix ,c_s_r_matrix ,c_r_matrix ,γs_k_matrix ,γs_r_matrix ,βω_r_matrix ,h_r_matrix ,h_r_matrix ,h_k_matrix = self.get_all_matrices_from_csk(c_s_k_matrix)
#     332         self.c_k_matrix   = c_k_matrix
#     333         self.c_s_r_matrix = c_s_r_matrix
#
# ~/plasma/hnc/hnc_Ng.py in get_all_matrices_from_csk(self, c_s_k_matrix)
#     318         c_s_r_matrix = self.FT_k_2_r_matrix(c_s_k_matrix)
#     319         c_r_matrix   = c_s_r_matrix - self.βu_l_r_matrix
# --> 320         γs_k_matrix = self.get_γs_k_matrix(c_s_k_matrix)                           # 1. c_k, u_l_k -> γ_k   (Definition)
#     321         γs_r_matrix = self.FT_k_2_r_matrix(γs_k_matrix) # γ_k        -> γ_r   (FT)
#     322         βω_r_matrix = self.βu_s_r_matrix - γs_r_matrix   # potential of mean force
#
# ~/plasma/hnc/hnc_Ng.py in get_γs_k_matrix(self, c_s_k_matrix)
#     217             γs_k_matrix = self.get_γs_k_matrix_standard(c_s_k_matrix)
#     218         elif self.oz_method in ['svt','SVT']:
# --> 219             γs_k_matrix = self.get_γs_k_matrix_SVT(c_s_k_matrix)
#     220         return γs_k_matrix
#     221
#
# ~/plasma/hnc/hnc_Ng.py in get_γs_k_matrix_SVT(self, c_s_k_matrix)
#     253         γs_k_matrix = np.zeros_like(self.γs_k_matrix)
#     254         for k in range(self.N_bins):
# --> 255             γs_k_matrix[:,:,k]   = solve_sylvester(A[:,:,k], B[:,:,k], C[:,:,k])
#     256             # γs_k_matrix[:,:,k] = solve_continuous_lyapunov(A[:,:,k], C[:,:,k])
#     257         return γs_k_matrix
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_solvers.py in solve_sylvester(a, b, q)
#      86
#      87     # Compute the Schur decomposition of b
# ---> 88     s, v = schur(b.conj().transpose(), output='real')
#      89
#      90     # Construct f = u'*q*v
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_decomp_schur.py in schur(a, output, lwork, overwrite_a, sort, check_finite)
#     118         raise ValueError("argument must be 'real', or 'complex'")
#     119     if check_finite:
# --> 120         a1 = asarray_chkfinite(a)
#     121     else:
#     122         a1 = asarray(a)
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     624     """
#     625     a = asarray(a, dtype=dtype, order=order)
# --> 626     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
#     627         raise ValueError(
#     628             "array must not contain infs or NaNs")
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims, where)
#      61     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      62     if where is True:
# ---> 63         return umr_all(a, axis, dtype, out, keepdims)
#      64     return umr_all(a, axis, dtype, out, keepdims, where=where)
#      65
#
# KeyboardInterrupt:

# %%
# %%time
options={'eps':1e-6,'maxfev':10000,'factor':1,'xtol':1e-8} 
newton_kwargs= {'method':'hybr', 'options':options} 
sol = atom_lowres.HNC_newton_solve( **newton_kwargs)
print("Err: ", atom_lowres.total_err(sol.x.reshape(2,2,1000)))
# Out:
# Root Finder:  False The number of calls to function has reached maxfev = 10000.
# Err:  0.055395344685129085
# CPU times: user 9min 33s, sys: 229 ms, total: 9min 34s
# Wall time: 9min 33s

# %%
# %%time
options={'eps':1e-6,'maxfev':10000,'factor':100,'xtol':1e-8} 
newton_kwargs= {'method':'hybr', 'options':options} 
sol = atom_lowres.HNC_newton_solve( **newton_kwargs)
print("Err: ", atom_lowres.total_err(sol.x.reshape(2,2,1000)))
# Out:
# Root Finder:  False The number of calls to function has reached maxfev = 10000.
# Err:  0.03866963115089616
# CPU times: user 8min 51s, sys: 135 ms, total: 8min 51s
# Wall time: 8min 51s

# %%
# atom_highres_answer=atom_lowres

# %%
atom = atom_highres_answer
qsp = atomqsp
newton_final_err= 1
np.savetxt("./fits/{0}_g_r.txt".format(case_id), np.array([atom.r_array, atom.h_r_matrix[0,0]+1, atom.h_r_matrix[0,1]+1, atom.h_r_matrix[1,1]+1]).T, header="atom {0} T={1:.1f} eV, r_i={2:.2f}, solve_err={3:.3e}\n r/r_i \t\t\t\t gii(r/r_i) \t\t\t\t gie(r/r_i) \t\t\t\t gee(r/r_i)".format(case_id, Te/eV, qsp.ri,newton_final_err))

# %%
# _,_,_,_,_,_,_,h_r_Ng,_, = atom_lowres.get_all_matrices_from_csk(atom_lowres.Ng_guess_c_s_k)

fig, axs = plt.subplots(2,2, figsize=(16,12))
# axs=np.array([[axs]])

for i in range(2):
        for j in range(2):
            axs[i,j].plot(atom_highres_answer.r_array, atom_lowres.h_r_matrix[i,j])
#             axs[i,j].plot(atom.k_array, atom_onlyion.c_s_k_matrix[i,j],'k-', label='answer')
#             axs[i,j].plot(atom_lowres.k_array, atom_lowres.Ng_guess_c_s_k[i,j],'-',label='Ng guess')
#             axs[i,j].plot(atom_lowres.k_array, atom_lowres.c_s_k_matrix_list[-1][i,j],label='-1')
#             axs[i,j].plot(atom_lowres.k_array, atom_lowres.c_s_k_matrix_list[-2][i,j],label='-2')
            axs[i,j].set_xlim(3e-1,50)
            axs[i,j].set_xscale('log')
# axs[0,0].plot(atom.k_array, atom_onlyion_answer.c_s_k_matrix[0,0],'k--', label='answer')
# axs[0,0].plot(atom_onlyion.k_array, atom_onlyion.Ng_guess_c_s_k[0,0],'--',color=colors[0], label='Ng only ion guess' )
# axs[0,0].plot(atom_onlyion.k_array, atom_onlyion.c_s_k_matrix_list[-1][0,0],'--',color=colors[1] ,label='only ion -1' )
# axs[0,0].plot(atom_onlyion.k_array, atom_onlyion.c_s_k_matrix_list[-2][0,0],'--', color=colors[2],label='only ion -2' )
axs[0,0].plot(atom_onlyion.r_array, atom_onlyion.h_r_matrix[0,0])
axs[0,0].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %%time
atom_lowres.c_s_k_matrix = c_s_k_guess.copy()
options={'eps':1e-6,'maxfev':10000,'factor':100,'xtol':1e-4} 
newton_kwargs= {'method':'hybr', 'options':options} 
sol = atom_lowres.HNC_newton_solve( **newton_kwargs)
# Out:
# /home/zach/plasma/hnc/hnc_Ng.py:309: RuntimeWarning: overflow encountered in exp
#   tot_eqn =  1 + h_r_matrix  - np.exp(-self.βu_s_r_matrix + h_r_matrix - c_s_r_matrix )
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# CPU times: user 7.66 s, sys: 8.08 ms, total: 7.66 s
# Wall time: 7.67 s

# %%
print("Err: ", atom_lowres.total_err(atom_lowres.FT_k_2_r_matrix(sol.x.reshape(2,2,100))))
c_s_k_afterhybr = atom_lowres.c_s_k_matrix.copy()
# Out:
# Err:  0.0182415121650835

# %%
from scipy.interpolate import interp1d
atom_highres, atomqsp = set_hnc(ni, Te, Z, A, Zstar, 
                            pseudopotential=True, oz_type='svt',r_c=r_c, 
                            add_bridge=True, bridge='ocp', N_bins=400, R_max=3)

for i in range(2):
    for j in range(2):
#         atom_highres.c_s_k_matrix[i,j] = interp1d(atom_lowres.k_array, c_s_k_afterhybr[i,j], bounds_error=False, 
#                             fill_value=(c_s_k_afterhybr[i,j,0], 0), kind='quadratic')(atom_highres.k_array)
        atom_highres.c_s_r_matrix[i,j] = interp1d(atom_lowres.r_array, atom_lowres.FT_k_2_r(c_s_k_afterhybr[i,j]), bounds_error=False, 
                            fill_value=(atom_lowres.FT_k_2_r(c_s_k_afterhybr[i,j])[0], 0), kind='quadratic')(atom_highres.r_array)
        atom_highres.c_s_k_matrix[i,j] = atom_highres.FT_k_2_r(atom_highres.c_s_r_matrix[i,j])

# atom_highres.HNC_solve(alpha_method='fixed', alpha_Picard = 1e-3, tol=1e-3, alpha_Ng=1e-10, 
#                iters_to_wait=1e4, num_iterations=1e3)

c_s_k_high_guess = atom_highres.c_s_k_matrix.copy()
print("Guess Err: ", atom_highres.total_err(atom_highres.FT_k_2_r_matrix(c_s_k_high_guess)))
# Out:
# Λei = 0.186
# Λee = 0.263
# Λei adjusted with R = 0.186
# Γii=301.565, Γie=-3.156, Γee=0.580
# r_i=2.667
# r_e=1.517
# r_c=0.199
# θ  =4.59e-02
# Guess Err:  inf

# %%
# %%time
# # atom_highres.c_s_k_matrix = c_s_k_high_guess.copy()
# options={'eps':1e-6,'maxfev':10000,'factor':100,'xtol':1e-4} 
# newton_kwargs= {'method':'hybr', 'options':options} 
# high_sol = atom_highres.HNC_newton_solve( **newton_kwargs)
# print("Err: ", atom_highres.total_err(atom_highres.FT_k_2_r_matrix(high_sol.x.reshape(2,2,400))))
# # c_s_k_afterhigh = atom_highres.c_s_k_matrix.copy()
# c_s_k_afterhigh2 = atom_highres.c_s_k_matrix.copy()

# %%
fig, axs = plt.subplots(2,2, figsize=(16,12))

for i in range(2):
        for j in range(2):
#             axs[i,j].plot(atom_lowres.k_array, atom_lowres.get_hnc_oz_matrix(c_s_k_afterhybr)[i,j],'--',color=colors[0])
#             axs[i,j].plot(atom_highres.k_array, atom_highres.get_hnc_oz_matrix(c_s_k_high_guess)[i,j],'--',color=colors[1])
#             axs[i,j].plot(atom_lowres.k_array, c_s_k_afterhybr[i,j],'.',color=colors[0])
#             axs[i,j].plot(atom_highres.k_array,c_s_k_high_guess[i,j],'-',color=colors[1])
            
#             axs[i,j].plot(atom_lowres.r_array, atom_lowres.get_hnc_oz_matrix(c_s_k_afterhybr)[i,j],'--',color=colors[0])
#             axs[i,j].plot(atom_highres.r_array, atom_highres.get_hnc_oz_matrix(c_s_k_high_guess)[i,j],'--',color=colors[1])
#             axs[i,j].plot(atom_lowres.r_array, c_s_k_afterhybr[i,j],'.',color=colors[0])
            axs[i,j].plot(atom_highres.r_array,  atom_highres.c_s_r_matrix[i,j],'-',color=colors[1])
            
            
            #             axs[i,j].plot(atom_lowres.k_array, sol.x.reshape(2,2,100)[i,j],'-',label='hybr')
#             axs[i,j].plot(atom_lowres.k_array, c_s_k_guess[i,j],'k.',label='Picard')
#             axs[i,j].plot(atom_highres.k_array, c_s_k_high_guess[i,j],'b--',label='Guess')
#             axs[i,j].plot(atom_highres.k_array, c_s_k_afterhigh[i,j],'r--',label='High Res')
#             axs[i,j].plot(atom_highres.k_array, c_s_k_afterhigh2[i,j],'r--',label='High Res')
            
#             axs[i,j].plot(atom_lowres.r_array, atom_lowres.c_s_r_matrix[i,j],label='Al no e')
            
            axs[i,j].tick_params(labelsize=20)
#             axs[i,j].set_xscale('log')
#             axs[i,j].set_xlim(0,50)
            axs[i,j].tick_params(labelsize=20)
            axs[-1,j].set_xlabel(r"$r/r_s $",fontsize=20)
            axs[i,j].set_yscale('symlog',linthresh=0.001)
#             axs[i,j].set_ylim(-10, 1e1)

#         axs[i,0].set_ylabel(r"$c(k)$",fontsize=20)
axs[0,0].legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Al_file = "/home/zach/plasma/datasets/RDFs/Al_1.0eV_rs3_VASP.txt"  # 1 eV
Al_file = '/home/zach/plasma/datasets/RDFs/Al_0.5eV_rs3_KS-MD.txt' # 0.5 eV
Al_data = read_csv(Al_file,header=0, names=['r','g'])

# %%
fig, ax = plt.subplots(figsize=(10,8))
fig.suptitle('Al TCCW Case, 1 eV, rs=3', fontsize=20, y=0.95)

ax.plot(Al_data['r'], Al_data['g'],'ro', label = 'VASP' )
# ax.plot(atom.r_array, atom_one_species.h_r_matrix[0,0] + 1, label='No electrons')
ax.plot(atom_lowres.r_array, atom_lowres.h_r_matrix[0,0] + 1, label='low - SVT Ashcroft Empy Yukawa Bridge')
ax.plot(atom_highres.r_array, atom_highres.h_r_matrix[0,0] + 1,'--.', label='high - SVT Ashcroft Empy Yukawa Bridge')

# ax.plot(atom.r_array, atomSVT.h_r_matrix[0,0] + 1, label='SVT Ashcroft')
# ax.plot(atom.r_array, atomSVT_Yuk.h_r_matrix[0,0] + 1,'--', label='SVT Ashcroft + Yukawa Bridge')
# ax.plot(atom.r_array, atomSVT_OCP.h_r_matrix[0,0] + 1,'--', label='SVT Ashcroft + OCP Bridge')

ax.set_ylabel(r'$g(r)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
ax.tick_params(labelsize=20)
ax.set_xlim(0.5,6)
ax.legend(fontsize=15)

# %% [markdown]
# # βu_eff matching

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
# luke_file = '/home/zach/plasma/atomic_forces/data/Al_T0p5_tab.lammps.PAIR'
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
# luke_r, luke_βV = 1e-10/aB/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_r, luke_βV = 1e-8/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)

# %%
from scipy.optimize import curve_fit

class βu_fit():
    def __init__(self, func, r_array, y_data, initial_guess):
        self.r = r_array
        self.y = y_data
        self.y_vals = curve_fit(func, r_array, y_data, maxfev=int(1e5), p0=initial_guess)
        self.y_fit  = func(r_array, *self.y_vals[0])
        self.err = np.linalg.norm(self.y_fit-self.y)
        print(func.__name__ + " error: {0:.3e} ".format(self.err))

def yukawa_plus(r, a, b, c, d):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d)))

def yukawa_plus_gaussian(r, a ,b ,c, d ,e, f, g):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.exp(-(f-r)**2/g)

def yukawa_plus_cos(r, a ,b ,c, d , h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + h*np.cos((r-i)*j*np.exp(-k*r))*np.exp(-l*r)

def yukawa_plus_gaussian_cos(r, a ,b ,c, d ,e, f, g, h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.cos((r-f)*g*np.exp(-h*r))*np.exp(-i*r) + j*np.exp(-(k-r)**2/l)

# %%
atom = atom_highres

# %%
atom.invert_HNC_OZ([1])
fit1 = βu_fit(yukawa_plus, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[   atomqsp.Γii, atomqsp.get_κ(),2 , 1])
try: 
    fit2 = βu_fit(yukawa_plus_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit1.y_vals[0], 1, 0.01, 1 , 10, 2])
except:
    pass
try:
    fit3 = βu_fit(yukawa_plus_gaussian_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit2.y_vals[0], -1, 1.9, 1])
except:
    pass
# Out:
# yukawa_plus error: 4.442e+01
# yukawa_plus_cos error: 3.221e+01
# /tmp/ipykernel_64608/2646033414.py:19: RuntimeWarning: overflow encountered in exp
#   return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + h*np.cos((r-i)*j*np.exp(-k*r))*np.exp(-l*r)
# /tmp/ipykernel_64608/2646033414.py:19: RuntimeWarning: overflow encountered in multiply
#   return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + h*np.cos((r-i)*j*np.exp(-k*r))*np.exp(-l*r)
# /home/zach/.pyenv/versions/3.9.13/envs/atomic_3.9.13/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:881: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# yukawa_plus_gaussian_cos error: 1.928e+01

# %%
luke_r
# Out:
# 1      0.007092
# 2      0.016484
# 3      0.025875
# 4      0.035267
# 5      0.044658
#          ...
# 601    5.636239
# 602    5.645619
# 603    5.654999
# 604    5.664379
# 605    5.673758
# Name: r [A], Length: 605, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8,6),facecolor='w')
fig.suptitle(r"{0} $T=${1:.1f} eV, $r_i$={2:.2f}".format(case_id, Te/eV, atomqsp.ri), fontsize=20)


yukawa_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array * np.exp(-atom.r_array*atomqsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]
coulomb_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array) [:-1,:-1]

ax.plot(atom.r_array, atom.βu_r_matrix[0,0], 'k--',label='Initial')
ax.plot(atom.r_array, yukawa_matrix[0,0],'k-.', label="Yukawa")

ax.plot(atom.r_array, atom.βueff_r_matrix[0,0],color=colors[0], label='Effective')    
ax.plot(luke_r, luke_βV,'r-', label='Luke Force Match')

ax.set_ylim(np.min([-10, 2*np.min(atom.βueff_r_matrix[0,0])]), np.max([1e3, 2*np.max(atom.βueff_r_matrix[0,0])]))
ax.tick_params(labelsize=20)
ax.set_xlabel(r"$r/r_s$",fontsize=20)
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)

ax.set_xlim(0, 5)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=10)
fig.tight_layout()
