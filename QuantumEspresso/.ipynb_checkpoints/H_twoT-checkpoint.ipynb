# %%
import matplotlib.pyplot as plt
import numpy as np
from pandas import read_csv
import matplotlib as mpl
from cycler import cycler
from scipy.integrate import simpson
from hnc.hnc.constants import *
from hnc.hnc.misc import n_from_rs, rs_from_n, Degeneracy_Parameter, Gamma, Kappa, ThomasFermiZbar

# %%
def Ion_Plasma_Frequency(ni, mi, Zbar):
    ωp = np.sqrt(4 * π *Zbar**2 * ni /mi)
    return ωp

# %% [markdown]
# ### Hydrogen, $T_e = T_i$

# %% [markdown]
# #### TCCW H1 points

# %%
A, Z = 2.014, 1 #  Deuterium
A, Z = 1.00784, 1 # Hydrogen
ρ_gpercc = 1
m_AU = A*amu_to_AU
ni_cc = ρ_gpercc/(m_AU*AU_to_g)
ni_AU = ni_cc*invcc_to_AU
ne_AU = Z*ni_cc*invcc_to_AU
ri = rs_from_n(ni_AU)

Ti_eV, Te_eV  = 2, 2
Ti_AU, Te_AU = Ti_eV*eV_to_AU, Te_eV*eV_to_AU

Zbar = ThomasFermiZbar( Z, ni_AU, Ti_AU)

N_i = 100
L = (N_i/ ni_AU )**(1/3)
Γii = Gamma(Ti_AU, ni_AU, Z)
Γee = Gamma(Te_AU, ne_AU, 1)
κ = Kappa(Te_AU, ni_AU, Zbar)               # screening length
θ = Degeneracy_Parameter(Te_AU, ne_AU)
Γii, Γee, θ, L, Ti_AU*AU_to_K, Te_AU*AU_to_Ry
# Out:
# (9.77547208384342,
#  9.77547208384342,
#  0.07731318329142557,
#  10.413876661597705,
#  23209.050012319647,
#  0.1469973015918493)

# %%
r_array[np.where(g_OCP_array==0.)], ri
# Out:
# (array([0.01311702, 0.01358033, 0.01406002, 0.01455664, 0.01507081,
#         0.01560314, 0.01615427, 0.01672487, 0.01731562, 0.01792724,
#         0.01856046, 0.01921605, 0.0198948 , 0.02059752, 0.02132506,
#         0.0220783 , 0.02285815, 0.02366554, 0.02450145, 0.02536689,
#         0.02626289, 0.02719055, 0.02815097, 0.02914531, 0.03017478,
#         0.03124061, 0.03234408, 0.03348654, 0.03466934, 0.03589393,
#         0.03716177, 0.03847439, 0.03983338, 0.04124036, 0.04269705,
#         0.04420519, 0.0457666 , 0.04738316, 0.04905682, 0.0507896 ,
#         0.05258358, 0.05444093, 0.05636388, 0.05835476, 0.06041595,
#         0.06254996, 0.06475934, 0.06704676, 0.06941497, 0.07186684,
#         0.0744053 , 0.07703344, 0.0797544 , 0.08257147, 0.08548805,
#         0.08850764, 0.0916339 , 0.09487058, 0.09822158, 0.10169095,
#         0.10528286, 0.10900164, 0.11285178, 0.11683792, 0.12096485,
#         0.12523755, 0.12966117, 0.13424104, 0.13898268, 0.1438918 ,
#         0.14897433, 0.15423638, 0.15968429, 0.16532463, 0.1711642 ,
#         0.17721004, 0.18346942, 0.1899499 , 0.19665928, 0.20360565,
#         0.21079738, 0.21824313, 0.22595188, 0.23393292, 0.24219586,
#         0.25075066, 0.25960764, 0.26877746, 0.27827117, 0.28810023,
#         0.29827646, 0.30881213, 0.31971994, 0.33101304, 0.34270503,
#         0.35481001, 0.36734255, 0.38031777, 0.39375129, 0.40765931,
#         0.42205859, 0.43696648, 0.45240094, 0.46838057, 0.48492464,
#         0.50205307, 0.51978651, 0.53814633, 0.55715465, 0.57683438,
#         0.59720923, 0.61830376, 0.64014339, 0.66275444, 0.68616414,
#         0.71040073, 0.73549339, 0.76147237, 0.78836898, 0.81621562,
#         0.84504586, 0.87489444, 0.90579733, 0.93779176, 0.97091629,
#         1.00521084, 1.04071674, 1.07747678, 1.11553524, 1.15493801,
#         1.19573254, 1.23796802, 1.28169533, 1.32696718, 1.3738381 ,
#         1.4223646 , 1.47260514, 1.52462026, 1.57847266, 1.63422723,
#         1.69195114, 1.75171398, 1.81358774]),
#  1.3918194245050366)

# %%
g_OCP_diverge = lambda rstar: 1 - Γii/(rstar+1e-8)*np.exp(-κ*rstar) #rstar=r/ri
g_OCP = lambda r: np.max([0,g_OCP_diverge(r/ri)])
g_OCP = np.vectorize(g_OCP)

fig, ax = plt.subplots(figsize=(8,6))

r_array = np.geomspace(L*1e-3,L, num=200)
g_OCP_array = g_OCP(r_array)
ax.plot(r_array, g_OCP_array)

# %% [markdown]
# ωp_AU = Ion_Plasma_Frequency(ni_AU, m_AU, ThomasFermiZbar(Z, ni_AU, Te_eV*eV_to_AU))
# τp_AU = 2*π/(ωp_AU)
# τp_RAU = τp_AU/2
# dt_over_τp = 0.02
# N_plasma_periods = 20
# print(f"In QE RAU, τp is {τp_RAU} RAU, so {dt_over_τp:0.3f} τp = {τp_RAU*dt_over_τp}")
# print(f"Num steps for {N_plasma_periods} plasma periods: {N_plasma_periods/dt_over_τp}")
