# %%
import numpy as np
import matplotlib.pyplot as plt


from hnc import  HNC_solver
from qsps import *

# %% [markdown]
# # Two Species

# %% [markdown]
# Here we do QSP interactions between electrons and one ion type.
#
# Using $\tilde{r}\equiv r/r_s$, we implement potentials
# \begin{align}
# \beta v_{ee}(\tilde{r}) &=  \frac{\Gamma_{ee}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right) +  \ln2 \exp\left[-\tilde{r}^2 r_s^2/(\pi \Lambda_e^2 \ln 2)\right]\\
# \beta v_{ei}(\tilde{r}) &=  \frac{\Gamma_{ei}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right)\\
# \beta v_{ii}(\tilde{r}) &=  \frac{\Gamma_{ii}}{\tilde{r}}
# \end{align}
# For
# \begin{align}
# \Gamma_{ee}&=\frac{\beta e^2}{r_s}\\
# \Gamma_{ei}&=\frac{\beta Z_i e^2}{r_s}\\
# \Gamma_{ii}&=\frac{\beta Z_i^2 e^2}{r_s}\\
# \end{align}

# %% [markdown]
# Plug into get potentials

# %%
T1=2
T2=2
T3=23
T4=22

# %%
ri = QSP_HNC.rs_from_n(5.01e23*1e6 *aB**3)
# ri = 3
Te = T1*eV 
Ti   = T1*eV 
Z, A = 6,12
Zstar= 3
    
qsp = QSP_HNC(Z, A, Zstar, Te, Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc1 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc1.r_array), qsp.βvei(hnc1.r_array)],
                        [qsp.βvei(hnc1.r_array), qsp.βvee(hnc1.r_array)]])

hnc1.set_βu_matrix(βu_r_matrix)
hnc1.initialize_c_k()
hnc1.set_C_matrix()
hnc1.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 0e-4, h_max=1e4)
# Out:
# Λee = 0.329
# Λei = 0.232
# Γii=331.826, Γie=-1.501, Γee=0.500
# r_i=1.476
# r_e=1.023
# θ  =1.05e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 5.11e+02, OZ: 2.09e-01, HNC: 1.28e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 2.96e+02, OZ: 1.96e-01, HNC: 7.44e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 1.72e+02, OZ: 1.84e-01, HNC: 1.47e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 1.02e+02, OZ: 1.65e-01, HNC: 4.83e+04
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 6.24e+01, OZ: 1.67e-01, HNC: 2.56e-01
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 5: Err in c_r: 8.15e-01, OZ: 3.21e-01, HNC: inf
#  HNC min: [0.5] True Optimization terminated successfully.
# 6: Err in c_r: 4.01e+01, OZ: 1.27e-01, HNC: 4.82e+27
#  HNC min: [0.5] True Optimization terminated successfully.
# 7: Err in c_r: 2.70e+01, OZ: 1.62e-01, HNC: 2.11e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 8: Err in c_r: 2.01e+01, OZ: 1.59e-01, HNC: 7.18e-02
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 9: Err in c_r: 3.57e-01, OZ: 2.95e-01, HNC: inf
#  HNC min: [0.5] True Optimization terminated successfully.
# 10: Err in c_r: 1.60e+01, OZ: 1.43e-01, HNC: 1.21e+34
#  HNC min: [0.5] True Optimization terminated successfully.
# 11: Err in c_r: 1.19e+01, OZ: 1.51e-01, HNC: 2.32e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 12: Err in c_r: 1.09e+01, OZ: 1.55e-01, HNC: 2.26e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 13: Err in c_r: 9.62e+00, OZ: 1.21e-01, HNC: 6.67e+06
#  HNC min: [0.5] True Optimization terminated successfully.
# 14: Err in c_r: 8.28e+00, OZ: 1.24e-01, HNC: 3.94e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 15: Err in c_r: 7.35e+00, OZ: 1.14e-01, HNC: 2.03e+09
#  HNC min: [0.5] True Optimization terminated successfully.
# 16: Err in c_r: 6.30e+00, OZ: 1.42e-01, HNC: 1.82e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 17: Err in c_r: 6.34e+00, OZ: 1.69e-01, HNC: 1.84e+20
#  HNC min: [0.5] True Optimization terminated successfully.
# 18: Err in c_r: 4.75e+00, OZ: 1.40e-01, HNC: 3.12e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 19: Err in c_r: 5.26e+00, OZ: 1.46e-01, HNC: 9.79e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 20: Err in c_r: 5.04e+00, OZ: 1.11e-01, HNC: 1.87e+07
#  HNC min: [0.5] True Optimization terminated successfully.
# 21: Err in c_r: 4.28e+00, OZ: 1.31e-01, HNC: 3.34e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 22: Err in c_r: 4.24e+00, OZ: 1.27e-01, HNC: 2.48e+08
#  HNC min: [0.5] True Optimization terminated successfully.
# 23: Err in c_r: 3.45e+00, OZ: 1.37e-01, HNC: 1.48e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 24: Err in c_r: 3.68e+00, OZ: 1.08e-01, HNC: 6.21e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 25: Err in c_r: 3.30e+00, OZ: 1.12e-01, HNC: 3.35e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 26: Err in c_r: 3.14e+00, OZ: 1.07e-01, HNC: 1.69e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 27: Err in c_r: 2.85e+00, OZ: 1.12e-01, HNC: 7.01e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 28: Err in c_r: 2.81e+00, OZ: 1.07e-01, HNC: 8.63e+01
#  HNC min: [0.5] True Optimization terminated successfully.
# 29: Err in c_r: 2.56e+00, OZ: 1.11e-01, HNC: 6.07e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 30: Err in c_r: 2.53e+00, OZ: 1.06e-01, HNC: 2.64e+01
#  HNC min: [0.5] True Optimization terminated successfully.
# 31: Err in c_r: 2.33e+00, OZ: 1.09e-01, HNC: 8.39e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 32: Err in c_r: 2.29e+00, OZ: 1.06e-01, HNC: 7.65e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 33: Err in c_r: 2.14e+00, OZ: 1.08e-01, HNC: 1.24e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 34: Err in c_r: 2.08e+00, OZ: 1.06e-01, HNC: 2.96e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 35: Err in c_r: 1.97e+00, OZ: 1.07e-01, HNC: 1.39e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 36: Err in c_r: 1.90e+00, OZ: 1.06e-01, HNC: 1.62e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 37: Err in c_r: 1.82e+00, OZ: 1.06e-01, HNC: 1.22e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 38: Err in c_r: 1.75e+00, OZ: 1.06e-01, HNC: 1.13e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 39: Err in c_r: 1.69e+00, OZ: 1.06e-01, HNC: 9.68e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 40: Err in c_r: 1.62e+00, OZ: 1.06e-01, HNC: 8.62e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 41: Err in c_r: 1.57e+00, OZ: 1.06e-01, HNC: 7.66e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 42: Err in c_r: 1.51e+00, OZ: 1.06e-01, HNC: 6.87e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 43: Err in c_r: 1.46e+00, OZ: 1.06e-01, HNC: 6.18e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 44: Err in c_r: 1.41e+00, OZ: 1.07e-01, HNC: 5.59e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 45: Err in c_r: 1.36e+00, OZ: 1.07e-01, HNC: 5.08e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 46: Err in c_r: 1.32e+00, OZ: 1.07e-01, HNC: 4.64e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 47: Err in c_r: 1.28e+00, OZ: 1.07e-01, HNC: 4.25e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 48: Err in c_r: 1.24e+00, OZ: 1.07e-01, HNC: 3.91e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 49: Err in c_r: 1.20e+00, OZ: 1.07e-01, HNC: 3.61e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 50: Err in c_r: 1.17e+00, OZ: 1.07e-01, HNC: 3.34e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 51: Err in c_r: 1.13e+00, OZ: 1.07e-01, HNC: 3.10e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 52: Err in c_r: 1.10e+00, OZ: 1.08e-01, HNC: 2.88e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 53: Err in c_r: 1.07e+00, OZ: 1.08e-01, HNC: 2.69e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 54: Err in c_r: 1.04e+00, OZ: 1.08e-01, HNC: 2.52e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 55: Err in c_r: 1.01e+00, OZ: 1.08e-01, HNC: 2.36e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 56: Err in c_r: 9.85e-01, OZ: 1.08e-01, HNC: 2.22e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 57: Err in c_r: 9.60e-01, OZ: 1.08e-01, HNC: 2.09e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 58: Err in c_r: 9.35e-01, OZ: 1.09e-01, HNC: 1.97e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 59: Err in c_r: 9.11e-01, OZ: 1.09e-01, HNC: 1.86e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 60: Err in c_r: 8.89e-01, OZ: 1.09e-01, HNC: 1.76e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 61: Err in c_r: 8.67e-01, OZ: 1.09e-01, HNC: 1.67e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 62: Err in c_r: 8.46e-01, OZ: 1.10e-01, HNC: 1.58e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 63: Err in c_r: 8.26e-01, OZ: 1.10e-01, HNC: 1.50e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 64: Err in c_r: 8.06e-01, OZ: 1.10e-01, HNC: 1.43e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 65: Err in c_r: 7.87e-01, OZ: 1.10e-01, HNC: 1.36e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 66: Err in c_r: 7.69e-01, OZ: 1.11e-01, HNC: 1.30e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 67: Err in c_r: 7.52e-01, OZ: 1.11e-01, HNC: 1.24e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 68: Err in c_r: 7.35e-01, OZ: 1.11e-01, HNC: 1.19e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 69: Err in c_r: 7.19e-01, OZ: 1.11e-01, HNC: 1.14e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 70: Err in c_r: 7.03e-01, OZ: 1.12e-01, HNC: 1.09e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 71: Err in c_r: 6.88e-01, OZ: 1.12e-01, HNC: 1.04e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 72: Err in c_r: 6.74e-01, OZ: 1.12e-01, HNC: 1.00e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 73: Err in c_r: 6.60e-01, OZ: 1.13e-01, HNC: 9.62e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 74: Err in c_r: 6.46e-01, OZ: 1.13e-01, HNC: 9.25e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 75: Err in c_r: 6.33e-01, OZ: 1.13e-01, HNC: 8.89e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 76: Err in c_r: 6.20e-01, OZ: 1.13e-01, HNC: 8.56e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 77: Err in c_r: 6.07e-01, OZ: 1.14e-01, HNC: 8.24e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 78: Err in c_r: 5.95e-01, OZ: 1.14e-01, HNC: 7.95e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 79: Err in c_r: 5.84e-01, OZ: 1.14e-01, HNC: 7.66e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 80: Err in c_r: 5.72e-01, OZ: 1.15e-01, HNC: 7.39e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 81: Err in c_r: 5.61e-01, OZ: 1.15e-01, HNC: 7.14e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 82: Err in c_r: 5.51e-01, OZ: 1.15e-01, HNC: 6.90e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 83: Err in c_r: 5.40e-01, OZ: 1.16e-01, HNC: 6.67e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 84: Err in c_r: 5.30e-01, OZ: 1.16e-01, HNC: 6.45e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 85: Err in c_r: 5.21e-01, OZ: 1.16e-01, HNC: 6.24e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 86: Err in c_r: 5.11e-01, OZ: 1.17e-01, HNC: 6.05e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 87: Err in c_r: 5.02e-01, OZ: 1.17e-01, HNC: 5.86e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 88: Err in c_r: 4.93e-01, OZ: 1.17e-01, HNC: 5.68e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 89: Err in c_r: 4.84e-01, OZ: 1.18e-01, HNC: 5.51e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 90: Err in c_r: 4.75e-01, OZ: 1.18e-01, HNC: 5.34e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 91: Err in c_r: 4.67e-01, OZ: 1.18e-01, HNC: 5.18e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 92: Err in c_r: 4.59e-01, OZ: 1.19e-01, HNC: 5.03e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 93: Err in c_r: 4.51e-01, OZ: 1.19e-01, HNC: 4.88e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 94: Err in c_r: 4.43e-01, OZ: 1.19e-01, HNC: 4.74e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 95: Err in c_r: 4.36e-01, OZ: 1.20e-01, HNC: 4.61e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 96: Err in c_r: 4.29e-01, OZ: 1.20e-01, HNC: 4.47e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 97: Err in c_r: 4.22e-01, OZ: 1.20e-01, HNC: 4.35e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 98: Err in c_r: 4.15e-01, OZ: 1.21e-01, HNC: 4.23e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 99: Err in c_r: 4.08e-01, OZ: 1.21e-01, HNC: 4.11e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 100: Err in c_r: 4.01e-01, OZ: 1.21e-01, HNC: 4.00e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 101: Err in c_r: 3.95e-01, OZ: 1.22e-01, HNC: 3.90e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 102: Err in c_r: 3.89e-01, OZ: 1.22e-01, HNC: 3.80e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 103: Err in c_r: 3.83e-01, OZ: 1.22e-01, HNC: 3.71e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 104: Err in c_r: 3.77e-01, OZ: 1.23e-01, HNC: 3.62e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 105: Err in c_r: 3.71e-01, OZ: 1.23e-01, HNC: 3.53e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 106: Err in c_r: 3.65e-01, OZ: 1.23e-01, HNC: 3.45e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 107: Err in c_r: 3.59e-01, OZ: 1.24e-01, HNC: 3.37e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 108: Err in c_r: 3.54e-01, OZ: 1.24e-01, HNC: 3.29e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 109: Err in c_r: 3.48e-01, OZ: 1.24e-01, HNC: 3.21e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 110: Err in c_r: 3.43e-01, OZ: 1.25e-01, HNC: 3.14e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 111: Err in c_r: 3.38e-01, OZ: 1.25e-01, HNC: 3.07e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 112: Err in c_r: 3.33e-01, OZ: 1.25e-01, HNC: 2.99e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 113: Err in c_r: 3.28e-01, OZ: 1.26e-01, HNC: 2.92e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 114: Err in c_r: 3.23e-01, OZ: 1.26e-01, HNC: 2.85e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 115: Err in c_r: 3.18e-01, OZ: 1.27e-01, HNC: 2.78e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 116: Err in c_r: 3.13e-01, OZ: 1.27e-01, HNC: 2.72e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 117: Err in c_r: 3.09e-01, OZ: 1.27e-01, HNC: 2.65e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 118: Err in c_r: 3.04e-01, OZ: 1.28e-01, HNC: 2.59e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 119: Err in c_r: 3.00e-01, OZ: 1.28e-01, HNC: 2.52e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 120: Err in c_r: 2.96e-01, OZ: 1.29e-01, HNC: 2.46e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 121: Err in c_r: 2.92e-01, OZ: 1.29e-01, HNC: 2.41e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 122: Err in c_r: 2.88e-01, OZ: 1.29e-01, HNC: 2.35e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 123: Err in c_r: 2.84e-01, OZ: 1.30e-01, HNC: 2.30e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 124: Err in c_r: 2.80e-01, OZ: 1.30e-01, HNC: 2.25e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 125: Err in c_r: 2.76e-01, OZ: 1.30e-01, HNC: 2.20e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 126: Err in c_r: 2.73e-01, OZ: 1.31e-01, HNC: 2.15e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 127: Err in c_r: 2.69e-01, OZ: 1.31e-01, HNC: 2.11e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 128: Err in c_r: 2.65e-01, OZ: 1.31e-01, HNC: 2.07e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 129: Err in c_r: 2.62e-01, OZ: 1.32e-01, HNC: 2.04e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 130: Err in c_r: 2.58e-01, OZ: 1.32e-01, HNC: 2.00e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 131: Err in c_r: 2.55e-01, OZ: 1.32e-01, HNC: 1.97e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 132: Err in c_r: 2.52e-01, OZ: 1.32e-01, HNC: 1.94e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 133: Err in c_r: 2.48e-01, OZ: 1.33e-01, HNC: 1.91e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 134: Err in c_r: 2.45e-01, OZ: 1.33e-01, HNC: 1.88e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 135: Err in c_r: 2.42e-01, OZ: 1.33e-01, HNC: 1.85e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 136: Err in c_r: 2.38e-01, OZ: 1.33e-01, HNC: 1.82e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 137: Err in c_r: 2.35e-01, OZ: 1.34e-01, HNC: 1.80e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 138: Err in c_r: 2.32e-01, OZ: 1.34e-01, HNC: 1.77e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 139: Err in c_r: 2.29e-01, OZ: 1.34e-01, HNC: 1.74e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 140: Err in c_r: 2.26e-01, OZ: 1.35e-01, HNC: 1.72e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 141: Err in c_r: 2.23e-01, OZ: 1.35e-01, HNC: 1.69e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 142: Err in c_r: 2.20e-01, OZ: 1.35e-01, HNC: 1.66e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 143: Err in c_r: 2.17e-01, OZ: 1.36e-01, HNC: 1.63e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 144: Err in c_r: 2.14e-01, OZ: 1.36e-01, HNC: 1.60e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 145: Err in c_r: 2.11e-01, OZ: 1.36e-01, HNC: 1.57e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 146: Err in c_r: 2.09e-01, OZ: 1.37e-01, HNC: 1.54e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 147: Err in c_r: 2.06e-01, OZ: 1.37e-01, HNC: 1.51e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 148: Err in c_r: 2.03e-01, OZ: 1.38e-01, HNC: 1.48e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 149: Err in c_r: 2.01e-01, OZ: 1.38e-01, HNC: 1.45e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 150: Err in c_r: 1.98e-01, OZ: 1.38e-01, HNC: 1.42e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 151: Err in c_r: 1.96e-01, OZ: 1.39e-01, HNC: 1.39e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 152: Err in c_r: 1.93e-01, OZ: 1.39e-01, HNC: 1.36e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 153: Err in c_r: 1.91e-01, OZ: 1.40e-01, HNC: 1.34e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 154: Err in c_r: 1.89e-01, OZ: 1.40e-01, HNC: 1.31e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 155: Err in c_r: 1.87e-01, OZ: 1.41e-01, HNC: 1.28e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 156: Err in c_r: 1.84e-01, OZ: 1.41e-01, HNC: 1.25e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 157: Err in c_r: 1.82e-01, OZ: 1.42e-01, HNC: 1.22e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 158: Err in c_r: 1.80e-01, OZ: 1.42e-01, HNC: 1.20e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 159: Err in c_r: 1.78e-01, OZ: 1.43e-01, HNC: 1.17e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 160: Err in c_r: 1.76e-01, OZ: 1.43e-01, HNC: 1.15e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 161: Err in c_r: 1.74e-01, OZ: 1.44e-01, HNC: 1.12e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 162: Err in c_r: 1.72e-01, OZ: 1.44e-01, HNC: 1.10e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 163: Err in c_r: 1.70e-01, OZ: 1.45e-01, HNC: 1.08e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 164: Err in c_r: 1.69e-01, OZ: 1.45e-01, HNC: 1.06e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 165: Err in c_r: 1.67e-01, OZ: 1.45e-01, HNC: 1.04e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 166: Err in c_r: 1.65e-01, OZ: 1.46e-01, HNC: 1.02e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 167: Err in c_r: 1.63e-01, OZ: 1.46e-01, HNC: 1.01e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 168: Err in c_r: 1.61e-01, OZ: 1.46e-01, HNC: 9.91e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 169: Err in c_r: 1.60e-01, OZ: 1.47e-01, HNC: 9.76e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 170: Err in c_r: 1.58e-01, OZ: 1.47e-01, HNC: 9.63e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 171: Err in c_r: 1.56e-01, OZ: 1.47e-01, HNC: 9.50e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 172: Err in c_r: 1.55e-01, OZ: 1.47e-01, HNC: 9.39e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 173: Err in c_r: 1.53e-01, OZ: 1.48e-01, HNC: 9.28e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 174: Err in c_r: 1.51e-01, OZ: 1.48e-01, HNC: 9.18e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 175: Err in c_r: 1.50e-01, OZ: 1.48e-01, HNC: 9.09e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 176: Err in c_r: 1.48e-01, OZ: 1.48e-01, HNC: 9.01e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 177: Err in c_r: 1.47e-01, OZ: 1.48e-01, HNC: 8.93e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 178: Err in c_r: 1.45e-01, OZ: 1.49e-01, HNC: 8.86e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 179: Err in c_r: 1.44e-01, OZ: 1.49e-01, HNC: 8.79e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 180: Err in c_r: 1.42e-01, OZ: 1.49e-01, HNC: 8.72e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 181: Err in c_r: 1.40e-01, OZ: 1.49e-01, HNC: 8.66e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 182: Err in c_r: 1.39e-01, OZ: 1.49e-01, HNC: 8.61e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 183: Err in c_r: 1.37e-01, OZ: 1.49e-01, HNC: 8.55e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 184: Err in c_r: 1.36e-01, OZ: 1.49e-01, HNC: 8.49e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 185: Err in c_r: 1.34e-01, OZ: 1.49e-01, HNC: 8.44e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 186: Err in c_r: 1.33e-01, OZ: 1.49e-01, HNC: 8.39e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 187: Err in c_r: 1.31e-01, OZ: 1.49e-01, HNC: 8.33e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 188: Err in c_r: 1.30e-01, OZ: 1.50e-01, HNC: 8.28e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 189: Err in c_r: 1.28e-01, OZ: 1.50e-01, HNC: 8.22e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 190: Err in c_r: 1.27e-01, OZ: 1.50e-01, HNC: 8.16e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 191: Err in c_r: 1.25e-01, OZ: 1.50e-01, HNC: 8.10e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 192: Err in c_r: 1.24e-01, OZ: 1.50e-01, HNC: 8.04e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 193: Err in c_r: 1.22e-01, OZ: 1.50e-01, HNC: 7.97e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 194: Err in c_r: 1.21e-01, OZ: 1.50e-01, HNC: 7.90e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 195: Err in c_r: 1.19e-01, OZ: 1.50e-01, HNC: 7.83e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 196: Err in c_r: 1.18e-01, OZ: 1.50e-01, HNC: 7.76e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 197: Err in c_r: 1.17e-01, OZ: 1.51e-01, HNC: 7.68e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 198: Err in c_r: 1.15e-01, OZ: 1.51e-01, HNC: 7.60e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 199: Err in c_r: 1.14e-01, OZ: 1.51e-01, HNC: 7.52e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 200: Err in c_r: 1.13e-01, OZ: 1.51e-01, HNC: 7.43e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 201: Err in c_r: 1.11e-01, OZ: 1.51e-01, HNC: 7.35e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 202: Err in c_r: 1.10e-01, OZ: 1.52e-01, HNC: 7.26e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 203: Err in c_r: 1.09e-01, OZ: 1.52e-01, HNC: 7.16e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 204: Err in c_r: 1.07e-01, OZ: 1.52e-01, HNC: 7.07e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 205: Err in c_r: 1.06e-01, OZ: 1.52e-01, HNC: 6.97e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 206: Err in c_r: 1.05e-01, OZ: 1.53e-01, HNC: 6.87e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 207: Err in c_r: 1.04e-01, OZ: 1.53e-01, HNC: 6.77e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 208: Err in c_r: 1.02e-01, OZ: 1.53e-01, HNC: 6.67e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 209: Err in c_r: 1.01e-01, OZ: 1.54e-01, HNC: 6.57e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 210: Err in c_r: 1.00e-01, OZ: 1.54e-01, HNC: 6.47e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 211: Err in c_r: 9.88e-02, OZ: 1.54e-01, HNC: 6.36e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 212: Err in c_r: 9.77e-02, OZ: 1.55e-01, HNC: 6.26e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 213: Err in c_r: 9.66e-02, OZ: 1.55e-01, HNC: 6.15e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 214: Err in c_r: 9.55e-02, OZ: 1.56e-01, HNC: 6.05e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 215: Err in c_r: 9.45e-02, OZ: 1.56e-01, HNC: 5.94e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 216: Err in c_r: 9.34e-02, OZ: 1.57e-01, HNC: 5.84e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 217: Err in c_r: 9.24e-02, OZ: 1.57e-01, HNC: 5.73e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 218: Err in c_r: 9.14e-02, OZ: 1.57e-01, HNC: 5.63e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 219: Err in c_r: 9.04e-02, OZ: 1.58e-01, HNC: 5.52e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 220: Err in c_r: 8.95e-02, OZ: 1.58e-01, HNC: 5.42e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 221: Err in c_r: 8.85e-02, OZ: 1.59e-01, HNC: 5.32e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 222: Err in c_r: 8.76e-02, OZ: 1.59e-01, HNC: 5.22e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 223: Err in c_r: 8.67e-02, OZ: 1.60e-01, HNC: 5.13e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 224: Err in c_r: 8.59e-02, OZ: 1.60e-01, HNC: 5.03e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 225: Err in c_r: 8.50e-02, OZ: 1.61e-01, HNC: 4.93e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 226: Err in c_r: 8.41e-02, OZ: 1.61e-01, HNC: 4.84e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 227: Err in c_r: 8.33e-02, OZ: 1.61e-01, HNC: 4.75e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 228: Err in c_r: 8.25e-02, OZ: 1.62e-01, HNC: 4.66e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 229: Err in c_r: 8.17e-02, OZ: 1.62e-01, HNC: 4.58e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 230: Err in c_r: 8.09e-02, OZ: 1.63e-01, HNC: 4.49e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 231: Err in c_r: 8.02e-02, OZ: 1.63e-01, HNC: 4.41e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 232: Err in c_r: 7.94e-02, OZ: 1.64e-01, HNC: 4.33e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 233: Err in c_r: 7.87e-02, OZ: 1.64e-01, HNC: 4.25e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 234: Err in c_r: 7.80e-02, OZ: 1.65e-01, HNC: 4.18e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 235: Err in c_r: 7.73e-02, OZ: 1.65e-01, HNC: 4.10e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 236: Err in c_r: 7.66e-02, OZ: 1.65e-01, HNC: 4.03e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 237: Err in c_r: 7.59e-02, OZ: 1.66e-01, HNC: 3.96e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 238: Err in c_r: 7.52e-02, OZ: 1.66e-01, HNC: 3.90e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 239: Err in c_r: 7.46e-02, OZ: 1.67e-01, HNC: 3.83e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 240: Err in c_r: 7.39e-02, OZ: 1.67e-01, HNC: 3.77e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 241: Err in c_r: 7.33e-02, OZ: 1.67e-01, HNC: 3.71e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 242: Err in c_r: 7.27e-02, OZ: 1.68e-01, HNC: 3.65e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 243: Err in c_r: 7.21e-02, OZ: 1.68e-01, HNC: 3.59e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 244: Err in c_r: 7.15e-02, OZ: 1.68e-01, HNC: 3.54e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 245: Err in c_r: 7.09e-02, OZ: 1.69e-01, HNC: 3.48e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 246: Err in c_r: 7.03e-02, OZ: 1.69e-01, HNC: 3.43e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 247: Err in c_r: 6.97e-02, OZ: 1.69e-01, HNC: 3.38e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 248: Err in c_r: 6.91e-02, OZ: 1.70e-01, HNC: 3.33e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 249: Err in c_r: 6.86e-02, OZ: 1.70e-01, HNC: 3.29e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 250: Err in c_r: 6.80e-02, OZ: 1.70e-01, HNC: 3.24e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 251: Err in c_r: 6.75e-02, OZ: 1.71e-01, HNC: 3.20e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 252: Err in c_r: 6.70e-02, OZ: 1.71e-01, HNC: 3.16e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 253: Err in c_r: 6.64e-02, OZ: 1.71e-01, HNC: 3.12e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 254: Err in c_r: 6.59e-02, OZ: 1.71e-01, HNC: 3.08e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 255: Err in c_r: 6.54e-02, OZ: 1.72e-01, HNC: 3.04e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 256: Err in c_r: 6.49e-02, OZ: 1.72e-01, HNC: 3.00e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 257: Err in c_r: 6.44e-02, OZ: 1.72e-01, HNC: 2.97e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 258: Err in c_r: 6.39e-02, OZ: 1.72e-01, HNC: 2.94e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 259: Err in c_r: 6.34e-02, OZ: 1.73e-01, HNC: 2.90e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 260: Err in c_r: 6.29e-02, OZ: 1.73e-01, HNC: 2.87e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 261: Err in c_r: 6.24e-02, OZ: 1.73e-01, HNC: 2.84e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 262: Err in c_r: 6.19e-02, OZ: 1.73e-01, HNC: 2.81e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 263: Err in c_r: 6.14e-02, OZ: 1.74e-01, HNC: 2.78e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 264: Err in c_r: 6.10e-02, OZ: 1.74e-01, HNC: 2.76e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 265: Err in c_r: 6.05e-02, OZ: 1.74e-01, HNC: 2.73e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 266: Err in c_r: 6.00e-02, OZ: 1.74e-01, HNC: 2.71e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 267: Err in c_r: 5.96e-02, OZ: 1.74e-01, HNC: 2.68e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 268: Err in c_r: 5.91e-02, OZ: 1.74e-01, HNC: 2.66e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 269: Err in c_r: 5.87e-02, OZ: 1.75e-01, HNC: 2.63e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 270: Err in c_r: 5.82e-02, OZ: 1.75e-01, HNC: 2.61e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 271: Err in c_r: 5.78e-02, OZ: 1.75e-01, HNC: 2.59e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 272: Err in c_r: 5.73e-02, OZ: 1.75e-01, HNC: 2.57e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 273: Err in c_r: 5.69e-02, OZ: 1.75e-01, HNC: 2.55e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 274: Err in c_r: 5.64e-02, OZ: 1.75e-01, HNC: 2.53e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 275: Err in c_r: 5.60e-02, OZ: 1.75e-01, HNC: 2.51e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 276: Err in c_r: 5.56e-02, OZ: 1.76e-01, HNC: 2.50e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 277: Err in c_r: 5.51e-02, OZ: 1.76e-01, HNC: 2.48e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 278: Err in c_r: 5.47e-02, OZ: 1.76e-01, HNC: 2.46e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 279: Err in c_r: 5.43e-02, OZ: 1.76e-01, HNC: 2.45e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 280: Err in c_r: 5.38e-02, OZ: 1.76e-01, HNC: 2.43e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 281: Err in c_r: 5.34e-02, OZ: 1.76e-01, HNC: 2.42e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 282: Err in c_r: 5.30e-02, OZ: 1.76e-01, HNC: 2.40e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 283: Err in c_r: 5.26e-02, OZ: 1.76e-01, HNC: 2.39e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 284: Err in c_r: 5.22e-02, OZ: 1.76e-01, HNC: 2.38e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 285: Err in c_r: 5.17e-02, OZ: 1.76e-01, HNC: 2.36e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 286: Err in c_r: 5.13e-02, OZ: 1.76e-01, HNC: 2.35e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 287: Err in c_r: 5.09e-02, OZ: 1.76e-01, HNC: 2.34e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 288: Err in c_r: 5.05e-02, OZ: 1.76e-01, HNC: 2.33e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 289: Err in c_r: 5.01e-02, OZ: 1.77e-01, HNC: 2.31e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 290: Err in c_r: 4.97e-02, OZ: 1.77e-01, HNC: 2.30e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 291: Err in c_r: 4.93e-02, OZ: 1.77e-01, HNC: 2.29e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 292: Err in c_r: 4.89e-02, OZ: 1.77e-01, HNC: 2.28e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 293: Err in c_r: 4.85e-02, OZ: 1.77e-01, HNC: 2.27e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 294: Err in c_r: 4.81e-02, OZ: 1.77e-01, HNC: 2.26e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 295: Err in c_r: 4.77e-02, OZ: 1.77e-01, HNC: 2.25e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 296: Err in c_r: 4.73e-02, OZ: 1.77e-01, HNC: 2.24e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 297: Err in c_r: 4.69e-02, OZ: 1.77e-01, HNC: 2.23e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 298: Err in c_r: 4.65e-02, OZ: 1.77e-01, HNC: 2.22e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 299: Err in c_r: 4.61e-02, OZ: 1.77e-01, HNC: 2.21e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 300: Err in c_r: 4.57e-02, OZ: 1.77e-01, HNC: 2.20e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 301: Err in c_r: 4.53e-02, OZ: 1.77e-01, HNC: 2.20e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 302: Err in c_r: 4.49e-02, OZ: 1.77e-01, HNC: 2.19e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 303: Err in c_r: 4.45e-02, OZ: 1.77e-01, HNC: 2.18e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 304: Err in c_r: 4.41e-02, OZ: 1.77e-01, HNC: 2.17e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 305: Err in c_r: 4.37e-02, OZ: 1.77e-01, HNC: 2.16e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 306: Err in c_r: 4.33e-02, OZ: 1.77e-01, HNC: 2.15e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 307: Err in c_r: 4.30e-02, OZ: 1.77e-01, HNC: 2.14e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 308: Err in c_r: 4.26e-02, OZ: 1.77e-01, HNC: 2.13e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 309: Err in c_r: 4.22e-02, OZ: 1.77e-01, HNC: 2.12e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 310: Err in c_r: 4.18e-02, OZ: 1.77e-01, HNC: 2.12e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 311: Err in c_r: 4.14e-02, OZ: 1.76e-01, HNC: 2.11e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 312: Err in c_r: 4.10e-02, OZ: 1.76e-01, HNC: 2.10e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 313: Err in c_r: 4.07e-02, OZ: 1.76e-01, HNC: 2.09e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 314: Err in c_r: 4.03e-02, OZ: 1.76e-01, HNC: 2.08e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 315: Err in c_r: 3.99e-02, OZ: 1.76e-01, HNC: 2.07e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 316: Err in c_r: 3.95e-02, OZ: 1.76e-01, HNC: 2.06e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 317: Err in c_r: 3.92e-02, OZ: 1.76e-01, HNC: 2.05e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 318: Err in c_r: 3.88e-02, OZ: 1.76e-01, HNC: 2.04e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 319: Err in c_r: 3.84e-02, OZ: 1.76e-01, HNC: 2.03e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 320: Err in c_r: 3.81e-02, OZ: 1.76e-01, HNC: 2.02e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 321: Err in c_r: 3.77e-02, OZ: 1.76e-01, HNC: 2.01e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 322: Err in c_r: 3.73e-02, OZ: 1.76e-01, HNC: 2.01e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 323: Err in c_r: 3.70e-02, OZ: 1.76e-01, HNC: 2.00e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 324: Err in c_r: 3.66e-02, OZ: 1.76e-01, HNC: 1.99e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 325: Err in c_r: 3.63e-02, OZ: 1.76e-01, HNC: 1.97e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 326: Err in c_r: 3.59e-02, OZ: 1.76e-01, HNC: 1.96e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 327: Err in c_r: 3.55e-02, OZ: 1.76e-01, HNC: 1.95e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 328: Err in c_r: 3.52e-02, OZ: 1.76e-01, HNC: 1.94e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 329: Err in c_r: 3.48e-02, OZ: 1.76e-01, HNC: 1.93e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 330: Err in c_r: 3.45e-02, OZ: 1.76e-01, HNC: 1.92e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 331: Err in c_r: 3.41e-02, OZ: 1.76e-01, HNC: 1.91e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 332: Err in c_r: 3.38e-02, OZ: 1.76e-01, HNC: 1.90e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 333: Err in c_r: 3.35e-02, OZ: 1.76e-01, HNC: 1.89e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 334: Err in c_r: 3.31e-02, OZ: 1.76e-01, HNC: 1.88e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 335: Err in c_r: 3.28e-02, OZ: 1.76e-01, HNC: 1.86e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 336: Err in c_r: 3.24e-02, OZ: 1.76e-01, HNC: 1.85e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 337: Err in c_r: 3.21e-02, OZ: 1.76e-01, HNC: 1.84e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 338: Err in c_r: 3.18e-02, OZ: 1.75e-01, HNC: 1.83e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 339: Err in c_r: 3.14e-02, OZ: 1.75e-01, HNC: 1.82e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 340: Err in c_r: 3.11e-02, OZ: 1.75e-01, HNC: 1.80e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 341: Err in c_r: 3.08e-02, OZ: 1.75e-01, HNC: 1.79e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 342: Err in c_r: 3.05e-02, OZ: 1.75e-01, HNC: 1.78e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 343: Err in c_r: 3.01e-02, OZ: 1.75e-01, HNC: 1.77e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 344: Err in c_r: 2.98e-02, OZ: 1.75e-01, HNC: 1.75e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 345: Err in c_r: 2.95e-02, OZ: 1.75e-01, HNC: 1.74e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 346: Err in c_r: 2.92e-02, OZ: 1.75e-01, HNC: 1.73e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 347: Err in c_r: 2.89e-02, OZ: 1.75e-01, HNC: 1.71e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 348: Err in c_r: 2.86e-02, OZ: 1.75e-01, HNC: 1.70e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 349: Err in c_r: 2.83e-02, OZ: 1.75e-01, HNC: 1.69e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 350: Err in c_r: 2.80e-02, OZ: 1.75e-01, HNC: 1.67e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 351: Err in c_r: 2.77e-02, OZ: 1.75e-01, HNC: 1.66e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 352: Err in c_r: 2.74e-02, OZ: 1.75e-01, HNC: 1.65e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 353: Err in c_r: 2.71e-02, OZ: 1.75e-01, HNC: 1.63e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 354: Err in c_r: 2.68e-02, OZ: 1.75e-01, HNC: 1.62e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 355: Err in c_r: 2.65e-02, OZ: 1.75e-01, HNC: 1.61e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 356: Err in c_r: 2.62e-02, OZ: 1.75e-01, HNC: 1.59e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 357: Err in c_r: 2.59e-02, OZ: 1.75e-01, HNC: 1.58e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 358: Err in c_r: 2.56e-02, OZ: 1.75e-01, HNC: 1.56e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 359: Err in c_r: 2.53e-02, OZ: 1.75e-01, HNC: 1.55e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 360: Err in c_r: 2.50e-02, OZ: 1.75e-01, HNC: 1.54e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 361: Err in c_r: 2.48e-02, OZ: 1.75e-01, HNC: 1.52e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 362: Err in c_r: 2.45e-02, OZ: 1.75e-01, HNC: 1.51e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 363: Err in c_r: 2.42e-02, OZ: 1.75e-01, HNC: 1.49e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 364: Err in c_r: 2.40e-02, OZ: 1.75e-01, HNC: 1.48e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 365: Err in c_r: 2.37e-02, OZ: 1.75e-01, HNC: 1.47e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 366: Err in c_r: 2.34e-02, OZ: 1.75e-01, HNC: 1.45e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 367: Err in c_r: 2.32e-02, OZ: 1.75e-01, HNC: 1.44e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 368: Err in c_r: 2.29e-02, OZ: 1.75e-01, HNC: 1.42e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 369: Err in c_r: 2.26e-02, OZ: 1.75e-01, HNC: 1.41e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 370: Err in c_r: 2.24e-02, OZ: 1.75e-01, HNC: 1.40e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 371: Err in c_r: 2.21e-02, OZ: 1.75e-01, HNC: 1.38e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 372: Err in c_r: 2.19e-02, OZ: 1.75e-01, HNC: 1.37e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 373: Err in c_r: 2.16e-02, OZ: 1.75e-01, HNC: 1.35e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 374: Err in c_r: 2.14e-02, OZ: 1.75e-01, HNC: 1.34e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 375: Err in c_r: 2.12e-02, OZ: 1.75e-01, HNC: 1.33e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 376: Err in c_r: 2.09e-02, OZ: 1.75e-01, HNC: 1.31e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 377: Err in c_r: 2.07e-02, OZ: 1.75e-01, HNC: 1.30e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 378: Err in c_r: 2.05e-02, OZ: 1.75e-01, HNC: 1.29e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 379: Err in c_r: 2.02e-02, OZ: 1.75e-01, HNC: 1.27e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 380: Err in c_r: 2.00e-02, OZ: 1.75e-01, HNC: 1.26e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 381: Err in c_r: 1.98e-02, OZ: 1.76e-01, HNC: 1.25e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 382: Err in c_r: 1.95e-02, OZ: 1.76e-01, HNC: 1.23e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 383: Err in c_r: 1.93e-02, OZ: 1.76e-01, HNC: 1.22e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 384: Err in c_r: 1.91e-02, OZ: 1.76e-01, HNC: 1.21e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 385: Err in c_r: 1.89e-02, OZ: 1.76e-01, HNC: 1.19e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 386: Err in c_r: 1.87e-02, OZ: 1.76e-01, HNC: 1.18e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 387: Err in c_r: 1.85e-02, OZ: 1.76e-01, HNC: 1.17e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 388: Err in c_r: 1.83e-02, OZ: 1.76e-01, HNC: 1.15e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 389: Err in c_r: 1.80e-02, OZ: 1.76e-01, HNC: 1.14e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 390: Err in c_r: 1.78e-02, OZ: 1.76e-01, HNC: 1.13e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 391: Err in c_r: 1.76e-02, OZ: 1.76e-01, HNC: 1.12e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 392: Err in c_r: 1.74e-02, OZ: 1.76e-01, HNC: 1.10e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 393: Err in c_r: 1.72e-02, OZ: 1.76e-01, HNC: 1.09e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 394: Err in c_r: 1.70e-02, OZ: 1.76e-01, HNC: 1.08e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 395: Err in c_r: 1.69e-02, OZ: 1.76e-01, HNC: 1.07e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 396: Err in c_r: 1.67e-02, OZ: 1.76e-01, HNC: 1.05e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 397: Err in c_r: 1.65e-02, OZ: 1.76e-01, HNC: 1.04e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 398: Err in c_r: 1.63e-02, OZ: 1.76e-01, HNC: 1.03e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 399: Err in c_r: 1.61e-02, OZ: 1.76e-01, HNC: 1.02e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 400: Err in c_r: 1.59e-02, OZ: 1.76e-01, HNC: 1.01e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 401: Err in c_r: 1.57e-02, OZ: 1.76e-01, HNC: 9.95e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 402: Err in c_r: 1.56e-02, OZ: 1.76e-01, HNC: 9.84e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 403: Err in c_r: 1.54e-02, OZ: 1.77e-01, HNC: 9.72e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 404: Err in c_r: 1.52e-02, OZ: 1.77e-01, HNC: 9.61e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 405: Err in c_r: 1.50e-02, OZ: 1.77e-01, HNC: 9.50e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 406: Err in c_r: 1.49e-02, OZ: 1.77e-01, HNC: 9.39e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 407: Err in c_r: 1.47e-02, OZ: 1.77e-01, HNC: 9.28e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 408: Err in c_r: 1.45e-02, OZ: 1.77e-01, HNC: 9.17e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 409: Err in c_r: 1.44e-02, OZ: 1.77e-01, HNC: 9.06e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 410: Err in c_r: 1.42e-02, OZ: 1.77e-01, HNC: 8.96e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 411: Err in c_r: 1.41e-02, OZ: 1.77e-01, HNC: 8.85e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 412: Err in c_r: 1.39e-02, OZ: 1.77e-01, HNC: 8.75e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 413: Err in c_r: 1.37e-02, OZ: 1.77e-01, HNC: 8.65e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 414: Err in c_r: 1.36e-02, OZ: 1.77e-01, HNC: 8.54e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 415: Err in c_r: 1.34e-02, OZ: 1.77e-01, HNC: 8.44e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 416: Err in c_r: 1.33e-02, OZ: 1.77e-01, HNC: 8.34e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 417: Err in c_r: 1.31e-02, OZ: 1.77e-01, HNC: 8.25e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 418: Err in c_r: 1.30e-02, OZ: 1.77e-01, HNC: 8.15e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 419: Err in c_r: 1.28e-02, OZ: 1.77e-01, HNC: 8.05e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 420: Err in c_r: 1.27e-02, OZ: 1.77e-01, HNC: 7.96e-04
# ...
# 860: Err in c_r: 1.72e-04, OZ: 1.86e-01, HNC: 9.21e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 861: Err in c_r: 1.70e-04, OZ: 1.86e-01, HNC: 9.12e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 862: Err in c_r: 1.68e-04, OZ: 1.86e-01, HNC: 9.04e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 863: Err in c_r: 1.67e-04, OZ: 1.86e-01, HNC: 8.95e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 864: Err in c_r: 1.65e-04, OZ: 1.86e-01, HNC: 8.87e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 865: Err in c_r: 1.64e-04, OZ: 1.86e-01, HNC: 8.79e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 866: Err in c_r: 1.62e-04, OZ: 1.86e-01, HNC: 8.71e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 867: Err in c_r: 1.61e-04, OZ: 1.86e-01, HNC: 8.63e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 868: Err in c_r: 1.59e-04, OZ: 1.86e-01, HNC: 8.55e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 869: Err in c_r: 1.58e-04, OZ: 1.86e-01, HNC: 8.47e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 870: Err in c_r: 1.56e-04, OZ: 1.86e-01, HNC: 8.39e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 871: Err in c_r: 1.55e-04, OZ: 1.86e-01, HNC: 8.31e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 872: Err in c_r: 1.53e-04, OZ: 1.86e-01, HNC: 8.23e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 873: Err in c_r: 1.52e-04, OZ: 1.86e-01, HNC: 8.16e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 874: Err in c_r: 1.51e-04, OZ: 1.86e-01, HNC: 8.08e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 875: Err in c_r: 1.49e-04, OZ: 1.86e-01, HNC: 8.01e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 876: Err in c_r: 1.48e-04, OZ: 1.86e-01, HNC: 7.93e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 877: Err in c_r: 1.46e-04, OZ: 1.86e-01, HNC: 7.86e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 878: Err in c_r: 1.45e-04, OZ: 1.86e-01, HNC: 7.79e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 879: Err in c_r: 1.44e-04, OZ: 1.86e-01, HNC: 7.71e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 880: Err in c_r: 1.42e-04, OZ: 1.86e-01, HNC: 7.64e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 881: Err in c_r: 1.41e-04, OZ: 1.86e-01, HNC: 7.57e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 882: Err in c_r: 1.40e-04, OZ: 1.86e-01, HNC: 7.50e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 883: Err in c_r: 1.39e-04, OZ: 1.86e-01, HNC: 7.43e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 884: Err in c_r: 1.37e-04, OZ: 1.86e-01, HNC: 7.36e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 885: Err in c_r: 1.36e-04, OZ: 1.86e-01, HNC: 7.29e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 886: Err in c_r: 1.35e-04, OZ: 1.86e-01, HNC: 7.23e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 887: Err in c_r: 1.33e-04, OZ: 1.86e-01, HNC: 7.16e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 888: Err in c_r: 1.32e-04, OZ: 1.86e-01, HNC: 7.09e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 889: Err in c_r: 1.31e-04, OZ: 1.86e-01, HNC: 7.03e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 890: Err in c_r: 1.30e-04, OZ: 1.86e-01, HNC: 6.96e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 891: Err in c_r: 1.29e-04, OZ: 1.86e-01, HNC: 6.90e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 892: Err in c_r: 1.27e-04, OZ: 1.86e-01, HNC: 6.83e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 893: Err in c_r: 1.26e-04, OZ: 1.86e-01, HNC: 6.77e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 894: Err in c_r: 1.25e-04, OZ: 1.86e-01, HNC: 6.71e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 895: Err in c_r: 1.24e-04, OZ: 1.86e-01, HNC: 6.64e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 896: Err in c_r: 1.23e-04, OZ: 1.86e-01, HNC: 6.58e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 897: Err in c_r: 1.22e-04, OZ: 1.86e-01, HNC: 6.52e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 898: Err in c_r: 1.20e-04, OZ: 1.86e-01, HNC: 6.46e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 899: Err in c_r: 1.19e-04, OZ: 1.86e-01, HNC: 6.40e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 900: Err in c_r: 1.18e-04, OZ: 1.86e-01, HNC: 6.34e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 901: Err in c_r: 1.17e-04, OZ: 1.86e-01, HNC: 6.28e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 902: Err in c_r: 1.16e-04, OZ: 1.86e-01, HNC: 6.23e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 903: Err in c_r: 1.15e-04, OZ: 1.86e-01, HNC: 6.17e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 904: Err in c_r: 1.14e-04, OZ: 1.86e-01, HNC: 6.11e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 905: Err in c_r: 1.13e-04, OZ: 1.86e-01, HNC: 6.05e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 906: Err in c_r: 1.12e-04, OZ: 1.86e-01, HNC: 6.00e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 907: Err in c_r: 1.11e-04, OZ: 1.86e-01, HNC: 5.94e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 908: Err in c_r: 1.10e-04, OZ: 1.86e-01, HNC: 5.89e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 909: Err in c_r: 1.09e-04, OZ: 1.86e-01, HNC: 5.83e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 910: Err in c_r: 1.08e-04, OZ: 1.86e-01, HNC: 5.78e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 911: Err in c_r: 1.07e-04, OZ: 1.86e-01, HNC: 5.72e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 912: Err in c_r: 1.06e-04, OZ: 1.86e-01, HNC: 5.67e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 913: Err in c_r: 1.05e-04, OZ: 1.86e-01, HNC: 5.62e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 914: Err in c_r: 1.04e-04, OZ: 1.86e-01, HNC: 5.57e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 915: Err in c_r: 1.03e-04, OZ: 1.86e-01, HNC: 5.52e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 916: Err in c_r: 1.02e-04, OZ: 1.86e-01, HNC: 5.46e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 917: Err in c_r: 1.01e-04, OZ: 1.86e-01, HNC: 5.41e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 918: Err in c_r: 1.00e-04, OZ: 1.86e-01, HNC: 5.36e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 919: Err in c_r: 9.91e-05, OZ: 1.86e-01, HNC: 5.31e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 920: Err in c_r: 9.82e-05, OZ: 1.86e-01, HNC: 5.26e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 921: Err in c_r: 9.73e-05, OZ: 1.86e-01, HNC: 5.22e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 922: Err in c_r: 9.64e-05, OZ: 1.86e-01, HNC: 5.17e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 923: Err in c_r: 9.55e-05, OZ: 1.86e-01, HNC: 5.12e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 924: Err in c_r: 9.46e-05, OZ: 1.86e-01, HNC: 5.07e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 925: Err in c_r: 9.38e-05, OZ: 1.86e-01, HNC: 5.03e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 926: Err in c_r: 9.29e-05, OZ: 1.86e-01, HNC: 4.98e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 927: Err in c_r: 9.20e-05, OZ: 1.86e-01, HNC: 4.93e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 928: Err in c_r: 9.12e-05, OZ: 1.86e-01, HNC: 4.89e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 929: Err in c_r: 9.03e-05, OZ: 1.86e-01, HNC: 4.84e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 930: Err in c_r: 8.95e-05, OZ: 1.86e-01, HNC: 4.80e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 931: Err in c_r: 8.87e-05, OZ: 1.86e-01, HNC: 4.75e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 932: Err in c_r: 8.79e-05, OZ: 1.86e-01, HNC: 4.71e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 933: Err in c_r: 8.71e-05, OZ: 1.86e-01, HNC: 4.67e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 934: Err in c_r: 8.62e-05, OZ: 1.86e-01, HNC: 4.62e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 935: Err in c_r: 8.55e-05, OZ: 1.86e-01, HNC: 4.58e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 936: Err in c_r: 8.47e-05, OZ: 1.86e-01, HNC: 4.54e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 937: Err in c_r: 8.39e-05, OZ: 1.86e-01, HNC: 4.49e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 938: Err in c_r: 8.31e-05, OZ: 1.86e-01, HNC: 4.45e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 939: Err in c_r: 8.23e-05, OZ: 1.86e-01, HNC: 4.41e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 940: Err in c_r: 8.16e-05, OZ: 1.86e-01, HNC: 4.37e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 941: Err in c_r: 8.08e-05, OZ: 1.86e-01, HNC: 4.33e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 942: Err in c_r: 8.01e-05, OZ: 1.86e-01, HNC: 4.29e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 943: Err in c_r: 7.93e-05, OZ: 1.86e-01, HNC: 4.25e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 944: Err in c_r: 7.86e-05, OZ: 1.86e-01, HNC: 4.21e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 945: Err in c_r: 7.79e-05, OZ: 1.86e-01, HNC: 4.17e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 946: Err in c_r: 7.72e-05, OZ: 1.86e-01, HNC: 4.13e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 947: Err in c_r: 7.64e-05, OZ: 1.86e-01, HNC: 4.10e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 948: Err in c_r: 7.57e-05, OZ: 1.86e-01, HNC: 4.06e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 949: Err in c_r: 7.50e-05, OZ: 1.86e-01, HNC: 4.02e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 950: Err in c_r: 7.43e-05, OZ: 1.86e-01, HNC: 3.98e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 951: Err in c_r: 7.37e-05, OZ: 1.86e-01, HNC: 3.95e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 952: Err in c_r: 7.30e-05, OZ: 1.86e-01, HNC: 3.91e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 953: Err in c_r: 7.23e-05, OZ: 1.86e-01, HNC: 3.87e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 954: Err in c_r: 7.16e-05, OZ: 1.86e-01, HNC: 3.84e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 955: Err in c_r: 7.10e-05, OZ: 1.86e-01, HNC: 3.80e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 956: Err in c_r: 7.03e-05, OZ: 1.86e-01, HNC: 3.77e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 957: Err in c_r: 6.97e-05, OZ: 1.86e-01, HNC: 3.73e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 958: Err in c_r: 6.90e-05, OZ: 1.86e-01, HNC: 3.70e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 959: Err in c_r: 6.84e-05, OZ: 1.86e-01, HNC: 3.66e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 960: Err in c_r: 6.78e-05, OZ: 1.86e-01, HNC: 3.63e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 961: Err in c_r: 6.71e-05, OZ: 1.86e-01, HNC: 3.60e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 962: Err in c_r: 6.65e-05, OZ: 1.86e-01, HNC: 3.56e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 963: Err in c_r: 6.59e-05, OZ: 1.86e-01, HNC: 3.53e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 964: Err in c_r: 6.53e-05, OZ: 1.86e-01, HNC: 3.50e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 965: Err in c_r: 6.47e-05, OZ: 1.86e-01, HNC: 3.46e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 966: Err in c_r: 6.41e-05, OZ: 1.86e-01, HNC: 3.43e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 967: Err in c_r: 6.35e-05, OZ: 1.86e-01, HNC: 3.40e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 968: Err in c_r: 6.29e-05, OZ: 1.86e-01, HNC: 3.37e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 969: Err in c_r: 6.23e-05, OZ: 1.86e-01, HNC: 3.34e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 970: Err in c_r: 6.18e-05, OZ: 1.86e-01, HNC: 3.31e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 971: Err in c_r: 6.12e-05, OZ: 1.86e-01, HNC: 3.28e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 972: Err in c_r: 6.06e-05, OZ: 1.86e-01, HNC: 3.25e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 973: Err in c_r: 6.01e-05, OZ: 1.86e-01, HNC: 3.22e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 974: Err in c_r: 5.95e-05, OZ: 1.86e-01, HNC: 3.19e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 975: Err in c_r: 5.90e-05, OZ: 1.86e-01, HNC: 3.16e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 976: Err in c_r: 5.84e-05, OZ: 1.86e-01, HNC: 3.13e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 977: Err in c_r: 5.79e-05, OZ: 1.86e-01, HNC: 3.10e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 978: Err in c_r: 5.73e-05, OZ: 1.86e-01, HNC: 3.07e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 979: Err in c_r: 5.68e-05, OZ: 1.86e-01, HNC: 3.04e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 980: Err in c_r: 5.63e-05, OZ: 1.86e-01, HNC: 3.01e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 981: Err in c_r: 5.58e-05, OZ: 1.86e-01, HNC: 2.99e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 982: Err in c_r: 5.52e-05, OZ: 1.86e-01, HNC: 2.96e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 983: Err in c_r: 5.47e-05, OZ: 1.86e-01, HNC: 2.93e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 984: Err in c_r: 5.42e-05, OZ: 1.86e-01, HNC: 2.90e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 985: Err in c_r: 5.37e-05, OZ: 1.86e-01, HNC: 2.88e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 986: Err in c_r: 5.32e-05, OZ: 1.86e-01, HNC: 2.85e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 987: Err in c_r: 5.27e-05, OZ: 1.86e-01, HNC: 2.82e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 988: Err in c_r: 5.23e-05, OZ: 1.86e-01, HNC: 2.80e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 989: Err in c_r: 5.18e-05, OZ: 1.86e-01, HNC: 2.77e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 990: Err in c_r: 5.13e-05, OZ: 1.86e-01, HNC: 2.75e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 991: Err in c_r: 5.08e-05, OZ: 1.86e-01, HNC: 2.72e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 992: Err in c_r: 5.03e-05, OZ: 1.86e-01, HNC: 2.70e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 993: Err in c_r: 4.99e-05, OZ: 1.86e-01, HNC: 2.67e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 994: Err in c_r: 4.94e-05, OZ: 1.86e-01, HNC: 2.65e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 995: Err in c_r: 4.90e-05, OZ: 1.86e-01, HNC: 2.62e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 996: Err in c_r: 4.85e-05, OZ: 1.86e-01, HNC: 2.60e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 997: Err in c_r: 4.81e-05, OZ: 1.86e-01, HNC: 2.57e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 998: Err in c_r: 4.76e-05, OZ: 1.86e-01, HNC: 2.55e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 999: Err in c_r: 4.72e-05, OZ: 1.86e-01, HNC: 2.53e-06
# Warning: HNC_solver did not converge within the specified number of iterations.

# %%
hnc1.plot_species_convergence_g(n_slices= int(len(hnc1.h_list)/1)  )
hnc1.plot_species_convergence_c(n_slices= int(len(hnc1.h_list)/1)  )

# %% [markdown]
# # New Temperature HNC

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T2*eV 
Ti   = T2*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc2 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc2.r_array), qsp.βvei(hnc2.r_array)],
                        [qsp.βvei(hnc2.r_array), qsp.βvee(hnc2.r_array)]])

hnc2.set_βu_matrix(βu_r_matrix)
hnc2.initialize_c_k()
hnc2.set_C_matrix()
hnc2.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
# Out:
# Λee = 0.193
# Λei = 0.174
# Γii=3.401, Γie=-1.712, Γee=0.350
# r_i=3.000
# r_e=2.080
# θ  =2.07e+00
# Λee = 0.186
# Λei = 0.171
# Γii=3.401, Γie=-1.657, Γee=0.328
# r_i=3.000
# r_e=2.080
# θ  =2.24e+00
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 0: Err in c_r: 5.92e-01, OZ: 4.97e-01, HNC: inf
# /home/zach/plasma/hnc/hnc.py:296: RuntimeWarning: overflow encountered in exp
#   hnc_eqn = - 1 - self.h_r_matrix   + np.exp( -self.βu_s_r_matrix + self.h_r_matrix - c_s_r_matrix )
# /home/zach/plasma/hnc/hnc.py:362: RuntimeWarning: overflow encountered in exp
#   hnc_err = np.linalg.norm(- 1 - self.h_r_matrix   + np.exp( -self.βu_r_matrix + self.h_r_matrix - self.c_r_matrix ))/np.sqrt(self.N_bins*self.N_species**2)
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 1: Err in c_r: 5.68e+00, OZ: 1.54e+00, HNC: inf
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 7.09e+00, OZ: 6.34e-01, HNC: 1.46e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 3.68e+00, OZ: 4.69e-01, HNC: 4.05e-01
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 4: Err in c_r: 3.97e+01, OZ: 3.41e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 5: Err in c_r: 3.19e+01, OZ: 4.78e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 6: Err in c_r: 5.29e+01, OZ: 3.86e+02, HNC: inf
# /home/zach/plasma/hnc/hnc.py:342: RuntimeWarning: overflow encountered in exp
#   self.h_r_matrix = -1 + np.exp(self.γs_r_matrix - self.βu_s_r_matrix) # 2. γ_r,u_s_r  -> h_r   (HNC)
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 7: Err in c_r: 8.42e+01, OZ: 5.59e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 8: Err in c_r: 9.56e+01, OZ: 4.93e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 9: Err in c_r: 2.72e+02, OZ: 5.31e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 10: Err in c_r: 1.04e+03, OZ: 6.55e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 11: Err in c_r: 1.93e+02, OZ: 5.07e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 12: Err in c_r: 1.14e+02, OZ: 2.57e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 13: Err in c_r: 3.96e+02, OZ: 5.01e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 14: Err in c_r: 4.71e+03, OZ: 9.63e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 15: Err in c_r: 3.35e+02, OZ: 5.47e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 16: Err in c_r: 1.67e+02, OZ: 3.35e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 17: Err in c_r: 5.20e+02, OZ: 4.35e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 18: Err in c_r: 1.96e+02, OZ: 3.27e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 19: Err in c_r: 1.00e+03, OZ: 6.02e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 20: Err in c_r: 1.85e+02, OZ: 2.13e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 21: Err in c_r: 4.30e+02, OZ: 4.78e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 22: Err in c_r: 6.80e+03, OZ: 7.47e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 23: Err in c_r: 7.37e+02, OZ: 5.29e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 24: Err in c_r: 1.93e+02, OZ: 2.43e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 25: Err in c_r: 2.85e+03, OZ: 5.85e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 26: Err in c_r: 1.34e+02, OZ: 1.29e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 27: Err in c_r: 6.74e+02, OZ: 3.95e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 28: Err in c_r: 2.25e+02, OZ: 2.41e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 29: Err in c_r: 2.38e+03, OZ: 6.71e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 30: Err in c_r: 1.11e+02, OZ: 1.49e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 31: Err in c_r: 3.89e+02, OZ: 3.52e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 32: Err in c_r: 1.43e+03, OZ: 4.87e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 33: Err in c_r: 6.24e+02, OZ: 3.92e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 34: Err in c_r: 7.83e+02, OZ: 3.22e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 35: Err in c_r: 5.73e+02, OZ: 4.36e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 36: Err in c_r: 1.82e+02, OZ: 6.84e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 37: Err in c_r: 5.50e+02, OZ: 3.79e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 38: Err in c_r: 1.35e+03, OZ: 4.90e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 39: Err in c_r: 3.95e+02, OZ: 2.43e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 40: Err in c_r: 4.20e+02, OZ: 1.19e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 41: Err in c_r: 4.41e+02, OZ: 2.82e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 42: Err in c_r: 8.61e+02, OZ: 4.62e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 43: Err in c_r: 3.20e+02, OZ: 1.66e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 44: Err in c_r: 7.38e+02, OZ: 2.40e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 45: Err in c_r: 7.81e+02, OZ: 4.00e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 46: Err in c_r: 8.38e+02, OZ: 3.90e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 47: Err in c_r: 2.12e+03, OZ: 5.23e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 48: Err in c_r: 4.16e+02, OZ: 1.03e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 49: Err in c_r: 3.54e+02, OZ: 2.88e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 50: Err in c_r: 2.73e+03, OZ: 6.30e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 51: Err in c_r: 2.08e+02, OZ: 5.65e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 52: Err in c_r: 1.46e+02, OZ: 2.49e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 53: Err in c_r: 2.10e+02, OZ: 1.99e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 54: Err in c_r: 5.75e+03, OZ: 6.50e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 55: Err in c_r: 5.15e+02, OZ: 3.74e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 56: Err in c_r: 2.66e+03, OZ: 6.04e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 57: Err in c_r: 3.28e+02, OZ: 1.73e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 58: Err in c_r: 1.35e+04, OZ: 1.13e+03, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 59: Err in c_r: 1.92e+02, OZ: 1.71e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 60: Err in c_r: 2.00e+02, OZ: 1.82e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 61: Err in c_r: 1.90e+02, OZ: 1.76e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 62: Err in c_r: 1.85e+02, OZ: 3.77e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 63: Err in c_r: 9.31e+02, OZ: 3.32e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 64: Err in c_r: 2.02e+02, OZ: 1.47e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 65: Err in c_r: 1.87e+02, OZ: 1.67e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 66: Err in c_r: 1.93e+02, OZ: 1.38e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 67: Err in c_r: 1.95e+02, OZ: 2.21e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 68: Err in c_r: 2.31e+02, OZ: 3.14e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 69: Err in c_r: 2.16e+02, OZ: 1.99e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 70: Err in c_r: 4.60e+03, OZ: 8.44e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 71: Err in c_r: 1.87e+02, OZ: 1.61e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 72: Err in c_r: 1.73e+02, OZ: 2.09e+01, HNC: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 37
#      35 hnc2.initialize_c_k()
#      36 hnc2.set_C_matrix()
# ---> 37 hnc2.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
#
# File ~/plasma/hnc/hnc.py:339, in HNC_solver.HNC_solve(self, h_max, alpha_method, alpha_Picard, alpha_oz)
#     335 self.h_list, self.c_list = [], []
#     336 while not converged and iteration < self.num_iterations:
#     337     # Compute matrices in k-space using OZ equation
#     338     # if iteration>=0:
# --> 339     self.set_γs_k_matrix()                           # 1. c_k, u_l_k -> γ_k   (Definition)
#     340     self.γs_r_matrix = self.FT_k_2_r_matrix(self.γs_k_matrix) # γ_k        -> γ_r   (FT)
#     341     self.βω_r_matrix = self.βu_s_r_matrix - self.γs_r_matrix   # potential of mean force
#
# File ~/plasma/hnc/hnc.py:201, in HNC_solver.set_γs_k_matrix(self)
#     196 def set_γs_k_matrix(self):
#     197     """
#     198     invert N_species x N_species  matrix equation to get γ_k = h_k - c_k
#     199     γs_k = (I-C)^-1 (C c_k_s - u_s_k)
#     200     """
# --> 201     self.γs_k_matrix = self.get_γs_k_matrix(self.c_s_k_matrix, self.C_matrix)
#
# File ~/plasma/hnc/hnc.py:208, in HNC_solver.get_γs_k_matrix(self, c_s_k_matrix, C_matrix)
#     203 def get_γs_k_matrix(self, c_s_k_matrix, C_matrix):
#     204     """
#     205     invert N_species x N_species  matrix equation to get γ_k = h_k - c_k
#     206     γs_k = (I-C)^-1 (C c_k_s - u_s_k)
#     207     """
# --> 208     denominator = self.invert_matrix(self.I[:,:,np.newaxis] - C_matrix)
#     209     numerator   = self.A_times_B(C_matrix, c_s_k_matrix ) -  self.βu_l_k_matrix
#     210     γs_k_matrix = self.A_times_B(denominator, numerator )
#
# File ~/plasma/hnc/hnc.py:223, in HNC_solver.invert_matrix(self, A_matrix)
#     220 A_inverse = np.zeros_like(A_matrix)#np.linalg.inv(A_matrix)
#     222 for k_index in range(self.N_bins):
# --> 223     A_inverse[:,:, k_index] = np.linalg.inv(A_matrix[:,:,k_index])
#     225 return A_inverse
#
# File <__array_function__ internals>:180, in inv(*args, **kwargs)
#
# File ~/.pyenv/versions/3.9.13/envs/atomic_3.9.13/lib/python3.9/site-packages/numpy/linalg/linalg.py:553, in inv(a)
#     551 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
#     552 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
# --> 553 return wrap(ainv.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
hnc2.plot_species_convergence_g(n_slices= int(len(hnc2.h_list)/1)  )
hnc2.plot_species_convergence_c(n_slices= int(len(hnc2.h_list)/1)  )

# %% [markdown]
# # Extrapolate

# %%
fig, axs = plt.subplots(ncols=N_species, nrows=N_species, figsize=(15,8))

T3 = 25
c_s_r_new = (hnc2.c_s_r_matrix - hnc1.c_s_r_matrix)/(T2-T1)*(T3 - T2) + hnc2.c_s_r_matrix

for i in range(N_species):
    for j in range(N_species):
        axs[i,j].plot(hnc1.r_array, hnc1.c_s_r_matrix[i,j],'-',label="T1")
        axs[i,j].plot(hnc2.r_array, hnc2.c_s_r_matrix[i,j],'-', label="T2")
        axs[i,j].plot(hnc2.r_array, c_s_r_new[i,j] ,'--', label="T_proj")
        axs[i,j].set_yscale('symlog',linthresh=1)
        axs[i,j].set_xscale('log')
        axs[i,j].legend()

# %% [markdown]
# # New Temp

# %%
c_s_r_new = hnc1.c_s_r_matrix

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T3*eV 
Ti   = T3*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc3 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc3.r_array), qsp.βvei(hnc3.r_array)],
                        [qsp.βvei(hnc3.r_array), qsp.βvee(hnc3.r_array)]])

hnc3.set_βu_matrix(βu_r_matrix)

hnc3.c_s_r_matrix[:,:,:] = c_s_r_new
hnc3.c_s_k_matrix = hnc3.FT_r_2_k_matrix(hnc3.c_s_r_matrix)
hnc3.c_r_matrix = hnc3.c_s_k_matrix - hnc3.βu_l_k_matrix
hnc3.set_C_matrix()
hnc3.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
# Out:
# Λee = 0.196
# Λei = 0.176
# Γii=3.549, Γie=-1.744, Γee=0.363
# r_i=3.000
# r_e=2.080
# θ  =1.99e+00
# Λee = 0.189
# Λei = 0.173
# Γii=3.549, Γie=-1.683, Γee=0.338
# r_i=3.000
# r_e=2.080
# θ  =2.16e+00
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 0: Err in c_r: 5.08e+01, OZ: 3.54e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 1: Err in c_r: 4.17e+01, OZ: 3.35e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 2: Err in c_r: 8.15e+01, OZ: 4.16e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 3: Err in c_r: 1.15e+02, OZ: 3.97e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 4: Err in c_r: 2.64e+01, OZ: 4.96e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 5: Err in c_r: 1.79e+02, OZ: 3.47e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 6: Err in c_r: 4.74e+02, OZ: 4.35e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 7: Err in c_r: 7.11e+01, OZ: 2.26e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 8: Err in c_r: 6.80e+01, OZ: 2.88e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 9: Err in c_r: 1.78e+02, OZ: 5.39e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 10: Err in c_r: 1.15e+02, OZ: 3.42e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 11: Err in c_r: 1.68e+02, OZ: 4.50e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 12: Err in c_r: 2.70e+02, OZ: 4.48e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 13: Err in c_r: 2.69e+02, OZ: 4.43e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 14: Err in c_r: 3.30e+02, OZ: 4.71e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 15: Err in c_r: 2.69e+02, OZ: 4.80e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 16: Err in c_r: 3.05e+02, OZ: 3.80e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 17: Err in c_r: 4.55e+02, OZ: 4.60e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 18: Err in c_r: 3.50e+02, OZ: 3.71e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 19: Err in c_r: 2.01e+03, OZ: 6.25e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 20: Err in c_r: 1.14e+02, OZ: 9.36e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 21: Err in c_r: 7.55e+02, OZ: 5.91e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 22: Err in c_r: 1.44e+02, OZ: 1.08e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 23: Err in c_r: 5.02e+02, OZ: 5.99e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 24: Err in c_r: 1.44e+02, OZ: 1.67e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 25: Err in c_r: 3.35e+02, OZ: 4.00e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 26: Err in c_r: 2.64e+02, OZ: 3.46e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 27: Err in c_r: 7.13e+02, OZ: 4.36e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 28: Err in c_r: 3.84e+02, OZ: 3.53e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 29: Err in c_r: 4.36e+02, OZ: 4.11e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 30: Err in c_r: 3.17e+02, OZ: 2.87e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 31: Err in c_r: 1.05e+03, OZ: 5.01e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 32: Err in c_r: 3.78e+02, OZ: 3.02e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 33: Err in c_r: 6.04e+02, OZ: 4.70e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 34: Err in c_r: 4.35e+02, OZ: 2.66e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 35: Err in c_r: 4.57e+02, OZ: 3.20e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 36: Err in c_r: 2.51e+03, OZ: 5.82e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 37: Err in c_r: 5.77e+03, OZ: 7.00e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 38: Err in c_r: 4.01e+02, OZ: 2.30e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 39: Err in c_r: 1.49e+02, OZ: 2.64e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 40: Err in c_r: 1.32e+04, OZ: 8.32e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 41: Err in c_r: 1.47e+02, OZ: 5.79e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 42: Err in c_r: 2.74e+02, OZ: 4.49e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 43: Err in c_r: 9.63e+02, OZ: 4.39e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 44: Err in c_r: 2.73e+02, OZ: 1.35e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 45: Err in c_r: 1.73e+03, OZ: 5.27e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 46: Err in c_r: 1.68e+03, OZ: 5.78e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 47: Err in c_r: 2.96e+02, OZ: 1.80e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 48: Err in c_r: 6.44e+02, OZ: 2.33e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 49: Err in c_r: 4.07e+02, OZ: 2.73e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 50: Err in c_r: 3.51e+03, OZ: 6.21e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 51: Err in c_r: 4.33e+02, OZ: 2.81e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 52: Err in c_r: 4.41e+02, OZ: 2.90e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 53: Err in c_r: 3.54e+02, OZ: 2.73e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 54: Err in c_r: 7.92e+02, OZ: 3.63e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 55: Err in c_r: 4.53e+02, OZ: 2.71e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 56: Err in c_r: 5.25e+02, OZ: 3.54e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 57: Err in c_r: 7.89e+02, OZ: 4.06e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 58: Err in c_r: 1.45e+03, OZ: 5.17e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 59: Err in c_r: 3.50e+02, OZ: 7.28e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 60: Err in c_r: 2.90e+02, OZ: 1.30e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 61: Err in c_r: 2.22e+02, OZ: 1.08e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 62: Err in c_r: 3.40e+02, OZ: 1.51e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 63: Err in c_r: 3.07e+02, OZ: 9.47e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 64: Err in c_r: 1.93e+02, OZ: 2.05e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 65: Err in c_r: 2.47e+02, OZ: 7.11e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 66: Err in c_r: 5.26e+02, OZ: 1.89e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 67: Err in c_r: 5.81e+02, OZ: 2.85e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 68: Err in c_r: 6.04e+02, OZ: 2.70e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 69: Err in c_r: 7.21e+02, OZ: 3.09e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 70: Err in c_r: 3.94e+02, OZ: 2.42e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 71: Err in c_r: 5.32e+02, OZ: 1.92e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 72: Err in c_r: 7.19e+02, OZ: 1.64e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 73: Err in c_r: 2.11e+02, OZ: 2.63e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 74: Err in c_r: 2.44e+02, OZ: 7.44e+01, HNC: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [15], line 40
#      38 hnc3.c_r_matrix = hnc3.c_s_k_matrix - hnc3.βu_l_k_matrix
#      39 hnc3.set_C_matrix()
# ---> 40 hnc3.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
#
# File ~/plasma/hnc/hnc.py:349, in HNC_solver.HNC_solve(self, h_max, alpha_method, alpha_Picard, alpha_oz)
#     347 # Update h_r, c_r_matrix
#     348 old_c_s_r_matrix = self.c_s_r_matrix.copy()
# --> 349 self.c_s_r_matrix = self.c_s_updater(old_c_s_r_matrix, new_c_s_r_matrix, method = alpha_method, alpha_Picard = alpha_Picard, alpha_oz = alpha_oz )
#     351 self.c_s_k_matrix = self.FT_r_2_k_matrix(self.c_s_r_matrix)  # FT
#     353 self.c_r_matrix = self.c_s_r_matrix  - self.βu_l_r_matrix # 4. c_s, u_l   -> c_r_k (Definition)
#
# File ~/plasma/hnc/hnc.py:246, in HNC_solver.c_s_updater(self, c_s_r_old, c_s_r_new, method, alpha_Picard, alpha_oz)
#     243     c_s_r_oz = self.FT_k_2_r_matrix(self.A_times_B(I_plus_h_rho_inverse, self.h_k_matrix))
#     245 if method=='best':
# --> 246     c_s_r = self.c_s_find_best_alpha(c_s_r_old, c_s_r_new, c_s_r_oz)
#     247 elif method=='fixed':
#     248     c_s_r = alpha_Picard*c_s_r_new + (1-alpha_Picard)*c_s_r_old
#
# File ~/plasma/hnc/hnc.py:272, in HNC_solver.c_s_find_best_alpha(self, c_s_r_old, c_s_r_new, c_s_r_oz)
#     270 method='Nelder-Mead'
#     271 tol=1e-8
# --> 272 res = minimize(c_err_1, [0.01], bounds=[(1e-5,0.5)], tol=tol, options={'maxiter':int(1e2)}, method=method) #, constraints=constraints, method='COBYLA')#bounds=[(ε, 1-ε),(ε, 1-ε),(ε, 1-ε)]
#     273 α_best = res.x
#     274 print(" HNC min:", res.x, res.success, res.message)
#
# File ~/.pyenv/versions/3.9.13/envs/atomic_3.9.13/lib/python3.9/site-packages/scipy/optimize/_minimize.py:687, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     684     bounds = standardize_bounds(bounds, x0, meth)
#     686 if meth == 'nelder-mead':
# --> 687     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     688                                **options)
#     689 elif meth == 'powell':
#     690     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/.pyenv/versions/3.9.13/envs/atomic_3.9.13/lib/python3.9/site-packages/scipy/optimize/_optimize.py:848, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     845                     if bounds is not None:
#     846                         sim[j] = np.clip(
#     847                             sim[j], lower_bound, upper_bound)
# --> 848                     fsim[j] = func(sim[j])
#     849     iterations += 1
#     850 except _MaxFuncCallError:
#
# File ~/.pyenv/versions/3.9.13/envs/atomic_3.9.13/lib/python3.9/site-packages/scipy/optimize/_optimize.py:496, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     494 ncalls[0] += 1
#     495 # A copy of x is sent to the user function (gh13740)
# --> 496 fx = function(np.copy(x), *(wrapper_args + args))
#     497 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     498 # backwards-compatibility, also allow np.array([1.3]),
#     499 # np.array([[1.3]]) etc.
#     500 if not np.isscalar(fx):
#
# File ~/plasma/hnc/hnc.py:258, in HNC_solver.c_s_find_best_alpha.<locals>.c_err_1(α)
#     256 def c_err_1(α):
#     257     c_s = α*c_s_r_new + (1-α)*c_s_r_old
# --> 258     err = self.total_err(c_s)
#     259     # print("HNC α: {0:.1e}, c_err: {1:.1e} ".format(float(α), err))
#     260     return err
#
# File ~/plasma/hnc/hnc.py:296, in HNC_solver.total_err(self, c_s_r_matrix)
#     286 # oz_eqn = -self.h_k_matrix + c_k_matrix  + self.A_times_B(c_k_matrix, self.h_k_matrix*self.rho[:,np.newaxis,np.newaxis])
#     287 # C_matrix = self.rho[np.newaxis,:,np.newaxis] * c_k_matrix
#     288 # oz_eqn = -self.h_k_matrix + c_k_matrix  + self.get_γs_k_matrix(c_k_matrix, C_matrix)+ self.βu_l_k_matrix
#    (...)
#     293 # oz_err=0
#     294 # oz_err = np.linalg.norm(oz_eqn) /np.sqrt(self.N_bins*self.N_species**2)
#     295 oz_err = 0
# --> 296 hnc_eqn = - 1 - self.h_r_matrix   + np.exp( -self.βu_s_r_matrix + self.h_r_matrix - c_s_r_matrix )
#     297 # hnc_err = np.linalg.norm(np.where( hnc_eqn>1e5, 1e5 ,hnc_eqn) )/np.sqrt(self.N_bins*self.N_species**2)
#     298 hnc_err = np.linalg.norm(hnc_eqn)/np.sqrt(self.N_bins*self.N_species**2)
#
# KeyboardInterrupt:

# %%
hnc3.plot_species_convergence_g(n_slices= int(len(hnc3.h_list)/1)  )
hnc3.plot_species_convergence_c(n_slices= int(len(hnc3.h_list)/1)  )

# %% [markdown]
# # Extrapolate Again!

# %%
fig, axs = plt.subplots(ncols=N_species, nrows=N_species, figsize=(15,8))

c_s_r_new = (hnc2.c_s_r_matrix - hnc3.c_s_r_matrix )/(T2-T3)*(T4 - T3) + hnc3.c_s_r_matrix

for i in range(N_species):
    for j in range(N_species):
        axs[i,j].plot(hnc1.r_array, hnc1.c_s_r_matrix[i,j],'-',label="T1")
        axs[i,j].plot(hnc2.r_array, hnc2.c_s_r_matrix[i,j],'-',label="T2")
        axs[i,j].plot(hnc3.r_array, hnc3.c_s_r_matrix[i,j],'-', label="T3")
        axs[i,j].plot(hnc3.r_array, c_s_r_new[i,j] ,'--', label="T_proj")
        axs[i,j].set_yscale('symlog',linthresh=1)
        axs[i,j].set_xscale('log')
        axs[i,j].legend()

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T4*eV 
Ti   = T4*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc4 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc4.r_array), qsp.βvei(hnc4.r_array)],
                        [qsp.βvei(hnc4.r_array), qsp.βvee(hnc4.r_array)]])

hnc4.set_βu_matrix(βu_r_matrix)

hnc4.c_s_r_matrix[:,:,:] = c_s_r_new
hnc4.c_s_k_matrix = hnc4.FT_r_2_k_matrix(hnc4.c_s_r_matrix)
hnc4.c_r_matrix = hnc4.c_s_k_matrix - hnc4.βu_l_k_matrix
hnc4.set_C_matrix()
hnc4.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)

# %%
hnc4.plot_species_convergence_g(n_slices= int(len(hnc4.h_list)/1)  )
hnc4.plot_species_convergence_c(n_slices= int(len(hnc4.h_list)/1)  )
