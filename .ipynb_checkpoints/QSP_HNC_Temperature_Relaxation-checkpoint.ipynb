# %%
import numpy as np
import matplotlib.pyplot as plt


from hnc import  HNC_solver
from qsps import *

# %% [markdown]
# # Two Species

# %% [markdown]
# Here we do QSP interactions between electrons and one ion type.
#
# Using $\tilde{r}\equiv r/r_s$, we implement potentials
# \begin{align}
# \beta v_{ee}(\tilde{r}) &=  \frac{\Gamma_{ee}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right) +  \ln2 \exp\left[-\tilde{r}^2 r_s^2/(\pi \Lambda_e^2 \ln 2)\right]\\
# \beta v_{ei}(\tilde{r}) &=  \frac{\Gamma_{ei}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right)\\
# \beta v_{ii}(\tilde{r}) &=  \frac{\Gamma_{ii}}{\tilde{r}}
# \end{align}
# For
# \begin{align}
# \Gamma_{ee}&=\frac{\beta e^2}{r_s}\\
# \Gamma_{ei}&=\frac{\beta Z_i e^2}{r_s}\\
# \Gamma_{ii}&=\frac{\beta Z_i^2 e^2}{r_s}\\
# \end{align}

# %% [markdown]
# Plug into get potentials

# %%
T1=25
T2=24
T3=23
T4=22

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T1*eV 
Ti   = T1*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc1 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc1.r_array), qsp.βvei(hnc1.r_array)],
                        [qsp.βvei(hnc1.r_array), qsp.βvee(hnc1.r_array)]])

hnc1.set_βu_matrix(βu_r_matrix)
hnc1.initialize_c_k()
hnc1.set_C_matrix()
hnc1.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
# Out:
# Λee = 0.196
# Λei = 0.139
# Γii=3.265, Γie=-1.088, Γee=0.363
# r_i=3.000
# r_e=2.080
# Λee = 0.189
# Λei = 0.134
# Γii=3.265, Γie=-1.014, Γee=0.338
# r_i=3.000
# r_e=2.080
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 7.10e+00, OZ: 1.01e-01, HNC: 9.78e+30
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 3.20e+00, OZ: 9.90e-02, HNC: 8.12e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 1.87e+00, OZ: 1.03e-01, HNC: 1.75e+09
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 1.36e+00, OZ: 1.07e-01, HNC: 6.02e+10
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 1.10e+00, OZ: 1.11e-01, HNC: 1.86e+10
#  HNC min: [0.5] True Optimization terminated successfully.
# 5: Err in c_r: 8.26e-01, OZ: 1.14e-01, HNC: 1.66e+08
#  HNC min: [0.5] True Optimization terminated successfully.
# 6: Err in c_r: 5.10e-01, OZ: 1.16e-01, HNC: 2.59e+05
#  HNC min: [0.5] True Optimization terminated successfully.
# 7: Err in c_r: 2.34e-01, OZ: 1.16e-01, HNC: 7.68e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 8: Err in c_r: 5.54e-02, OZ: 1.16e-01, HNC: 1.08e+01
#  HNC min: [0.5] True Optimization terminated successfully.
# 9: Err in c_r: 6.94e-02, OZ: 1.16e-01, HNC: 5.06e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 10: Err in c_r: 1.10e-01, OZ: 1.15e-01, HNC: 6.49e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 11: Err in c_r: 1.10e-01, OZ: 1.15e-01, HNC: 6.42e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 12: Err in c_r: 8.30e-02, OZ: 1.15e-01, HNC: 5.67e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 13: Err in c_r: 4.76e-02, OZ: 1.15e-01, HNC: 4.14e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 14: Err in c_r: 1.73e-02, OZ: 1.15e-01, HNC: 1.83e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 15: Err in c_r: 7.23e-03, OZ: 1.15e-01, HNC: 5.53e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 16: Err in c_r: 1.41e-02, OZ: 1.15e-01, HNC: 1.93e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 17: Err in c_r: 1.44e-02, OZ: 1.15e-01, HNC: 2.07e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 18: Err in c_r: 1.04e-02, OZ: 1.15e-01, HNC: 1.46e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 19: Err in c_r: 5.26e-03, OZ: 1.15e-01, HNC: 7.02e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 20: Err in c_r: 1.27e-03, OZ: 1.15e-01, HNC: 1.10e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 21: Err in c_r: 2.05e-03, OZ: 1.15e-01, HNC: 2.37e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 22: Err in c_r: 2.96e-03, OZ: 1.15e-01, HNC: 3.64e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 23: Err in c_r: 2.72e-03, OZ: 1.15e-01, HNC: 3.41e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 24: Err in c_r: 1.89e-03, OZ: 1.15e-01, HNC: 2.40e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 25: Err in c_r: 9.40e-04, OZ: 1.15e-01, HNC: 1.20e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 26: Err in c_r: 2.33e-04, OZ: 1.15e-01, HNC: 2.12e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 27: Err in c_r: 3.40e-04, OZ: 1.15e-01, HNC: 3.92e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 28: Err in c_r: 4.86e-04, OZ: 1.15e-01, HNC: 6.14e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 29: Err in c_r: 4.42e-04, OZ: 1.15e-01, HNC: 5.68e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 30: Err in c_r: 3.00e-04, OZ: 1.15e-01, HNC: 3.87e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 31: Err in c_r: 1.43e-04, OZ: 1.15e-01, HNC: 1.83e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 32: Err in c_r: 3.28e-05, OZ: 1.15e-01, HNC: 2.17e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 33: Err in c_r: 6.23e-05, OZ: 1.15e-01, HNC: 7.35e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 34: Err in c_r: 8.35e-05, OZ: 1.15e-01, HNC: 1.05e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 35: Err in c_r: 7.37e-05, OZ: 1.15e-01, HNC: 9.44e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 36: Err in c_r: 4.87e-05, OZ: 1.15e-01, HNC: 6.28e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 37: Err in c_r: 2.23e-05, OZ: 1.15e-01, HNC: 2.84e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 38: Err in c_r: 5.04e-06, OZ: 1.15e-01, HNC: 1.97e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 39: Err in c_r: 1.11e-05, OZ: 1.15e-01, HNC: 1.33e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 40: Err in c_r: 1.42e-05, OZ: 1.15e-01, HNC: 1.80e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 41: Err in c_r: 1.22e-05, OZ: 1.15e-01, HNC: 1.57e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 42: Err in c_r: 7.86e-06, OZ: 1.15e-01, HNC: 1.01e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 43: Err in c_r: 3.44e-06, OZ: 1.15e-01, HNC: 4.36e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 44: Err in c_r: 8.23e-07, OZ: 1.15e-01, HNC: 1.39e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 45: Err in c_r: 1.98e-06, OZ: 1.15e-01, HNC: 2.39e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 46: Err in c_r: 2.41e-06, OZ: 1.15e-01, HNC: 3.06e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 47: Err in c_r: 2.02e-06, OZ: 1.15e-01, HNC: 2.59e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 48: Err in c_r: 1.27e-06, OZ: 1.15e-01, HNC: 1.63e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 49: Err in c_r: 5.27e-07, OZ: 1.15e-01, HNC: 6.63e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 50: Err in c_r: 1.45e-07, OZ: 1.15e-01, HNC: 5.42e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 51: Err in c_r: 3.50e-07, OZ: 1.15e-01, HNC: 4.27e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 52: Err in c_r: 4.08e-07, OZ: 1.15e-01, HNC: 5.18e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 53: Err in c_r: 3.33e-07, OZ: 1.15e-01, HNC: 4.28e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 54: Err in c_r: 2.03e-07, OZ: 1.15e-01, HNC: 2.62e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 55: Err in c_r: 8.02e-08, OZ: 1.15e-01, HNC: 1.00e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 56: Err in c_r: 2.67e-08, OZ: 1.15e-01, HNC: 1.66e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 57: Err in c_r: 6.16e-08, OZ: 1.15e-01, HNC: 7.56e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 58: Err in c_r: 6.89e-08, OZ: 1.15e-01, HNC: 8.76e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 59: Err in c_r: 5.48e-08, OZ: 1.15e-01, HNC: 7.05e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 60: Err in c_r: 3.25e-08, OZ: 1.15e-01, HNC: 4.19e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 61: Err in c_r: 1.21e-08, OZ: 1.15e-01, HNC: 1.49e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 62: Err in c_r: 5.05e-09, OZ: 1.15e-01, HNC: 4.06e-07

# %%
hnc1.plot_species_convergence_g(n_slices= int(len(hnc1.h_list)/1)  )
hnc1.plot_species_convergence_c(n_slices= int(len(hnc1.h_list)/1)  )

# %%
hnc1.plot_g_vs_murillo(gmax=3)
hnc1.plot_g_vs_murillo()

# %% [markdown]
# # New Temperature HNC

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T2*eV 
Ti   = T2*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc2 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc2.r_array), qsp.βvei(hnc2.r_array)],
                        [qsp.βvei(hnc2.r_array), qsp.βvee(hnc2.r_array)]])

hnc2.set_βu_matrix(βu_r_matrix)
hnc2.initialize_c_k()
hnc2.set_C_matrix()
hnc2.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
# Out:
# Λee = 0.200
# Λei = 0.142
# Γii=3.401, Γie=-1.134, Γee=0.378
# r_i=3.000
# r_e=2.080
# Λee = 0.193
# Λei = 0.136
# Γii=3.401, Γie=-1.050, Γee=0.350
# r_i=3.000
# r_e=2.080
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 7.37e+00, OZ: 1.01e-01, HNC: 7.74e+31
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 3.32e+00, OZ: 9.94e-02, HNC: 2.06e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 1.95e+00, OZ: 1.04e-01, HNC: 3.66e+09
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 1.43e+00, OZ: 1.08e-01, HNC: 2.55e+11
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 1.19e+00, OZ: 1.12e-01, HNC: 1.33e+11
#  HNC min: [0.5] True Optimization terminated successfully.
# 5: Err in c_r: 9.29e-01, OZ: 1.16e-01, HNC: 1.61e+09
#  HNC min: [0.5] True Optimization terminated successfully.
# 6: Err in c_r: 6.17e-01, OZ: 1.18e-01, HNC: 2.83e+06
#  HNC min: [0.5] True Optimization terminated successfully.
# 7: Err in c_r: 3.51e-01, OZ: 1.18e-01, HNC: 1.04e+04
#  HNC min: [0.5] True Optimization terminated successfully.
# 8: Err in c_r: 1.82e-01, OZ: 1.18e-01, HNC: 3.03e+02
#  HNC min: [0.5] True Optimization terminated successfully.
# 9: Err in c_r: 8.33e-02, OZ: 1.18e-01, HNC: 3.28e+01
#  HNC min: [0.5] True Optimization terminated successfully.
# 10: Err in c_r: 2.82e-02, OZ: 1.18e-01, HNC: 2.32e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 11: Err in c_r: 5.16e-02, OZ: 1.17e-01, HNC: 4.54e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 12: Err in c_r: 7.89e-02, OZ: 1.17e-01, HNC: 6.18e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 13: Err in c_r: 8.75e-02, OZ: 1.17e-01, HNC: 6.48e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 14: Err in c_r: 8.03e-02, OZ: 1.17e-01, HNC: 6.20e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 15: Err in c_r: 6.42e-02, OZ: 1.17e-01, HNC: 5.52e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 16: Err in c_r: 4.57e-02, OZ: 1.17e-01, HNC: 4.52e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 17: Err in c_r: 2.92e-02, OZ: 1.17e-01, HNC: 3.31e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 18: Err in c_r: 1.67e-02, OZ: 1.17e-01, HNC: 2.13e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 19: Err in c_r: 8.56e-03, OZ: 1.17e-01, HNC: 1.18e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 20: Err in c_r: 3.95e-03, OZ: 1.17e-01, HNC: 5.70e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 21: Err in c_r: 1.79e-03, OZ: 1.17e-01, HNC: 2.60e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 22: Err in c_r: 1.03e-03, OZ: 1.17e-01, HNC: 1.54e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 23: Err in c_r: 1.02e-03, OZ: 1.17e-01, HNC: 1.52e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 24: Err in c_r: 1.27e-03, OZ: 1.17e-01, HNC: 1.83e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 25: Err in c_r: 1.45e-03, OZ: 1.17e-01, HNC: 2.06e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 26: Err in c_r: 1.45e-03, OZ: 1.17e-01, HNC: 2.05e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 27: Err in c_r: 1.29e-03, OZ: 1.17e-01, HNC: 1.83e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 28: Err in c_r: 1.03e-03, OZ: 1.17e-01, HNC: 1.47e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 29: Err in c_r: 7.35e-04, OZ: 1.17e-01, HNC: 1.06e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 30: Err in c_r: 4.69e-04, OZ: 1.17e-01, HNC: 6.85e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 31: Err in c_r: 2.59e-04, OZ: 1.17e-01, HNC: 3.82e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 32: Err in c_r: 1.16e-04, OZ: 1.17e-01, HNC: 1.70e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 33: Err in c_r: 3.83e-05, OZ: 1.17e-01, HNC: 4.45e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 34: Err in c_r: 2.73e-05, OZ: 1.17e-01, HNC: 2.05e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 35: Err in c_r: 2.97e-05, OZ: 1.17e-01, HNC: 3.54e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 36: Err in c_r: 2.15e-05, OZ: 1.17e-01, HNC: 2.77e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 37: Err in c_r: 9.33e-06, OZ: 1.17e-01, HNC: 1.15e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 38: Err in c_r: 5.03e-06, OZ: 1.17e-01, HNC: 4.24e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 39: Err in c_r: 1.12e-05, OZ: 1.17e-01, HNC: 1.48e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 40: Err in c_r: 1.41e-05, OZ: 1.17e-01, HNC: 1.95e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 41: Err in c_r: 1.37e-05, OZ: 1.17e-01, HNC: 1.93e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 42: Err in c_r: 1.12e-05, OZ: 1.17e-01, HNC: 1.60e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 43: Err in c_r: 7.91e-06, OZ: 1.17e-01, HNC: 1.14e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 44: Err in c_r: 4.74e-06, OZ: 1.17e-01, HNC: 6.91e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 45: Err in c_r: 2.25e-06, OZ: 1.17e-01, HNC: 3.28e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 46: Err in c_r: 7.20e-07, OZ: 1.17e-01, HNC: 8.39e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 47: Err in c_r: 6.30e-07, OZ: 1.17e-01, HNC: 5.81e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 48: Err in c_r: 8.42e-07, OZ: 1.17e-01, HNC: 1.07e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 49: Err in c_r: 7.66e-07, OZ: 1.17e-01, HNC: 1.04e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 50: Err in c_r: 5.32e-07, OZ: 1.17e-01, HNC: 7.43e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 51: Err in c_r: 2.72e-07, OZ: 1.17e-01, HNC: 3.81e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 52: Err in c_r: 8.09e-08, OZ: 1.17e-01, HNC: 7.59e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 53: Err in c_r: 1.15e-07, OZ: 1.17e-01, HNC: 1.32e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 54: Err in c_r: 1.69e-07, OZ: 1.17e-01, HNC: 2.27e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 55: Err in c_r: 1.72e-07, OZ: 1.17e-01, HNC: 2.39e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 56: Err in c_r: 1.41e-07, OZ: 1.17e-01, HNC: 2.00e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 57: Err in c_r: 9.73e-08, OZ: 1.17e-01, HNC: 1.40e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 58: Err in c_r: 5.47e-08, OZ: 1.17e-01, HNC: 7.93e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 59: Err in c_r: 2.22e-08, OZ: 1.17e-01, HNC: 3.13e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 60: Err in c_r: 8.24e-09, OZ: 1.17e-01, HNC: 3.14e-07

# %%
hnc2.plot_species_convergence_g(n_slices= int(len(hnc2.h_list)/1)  )
hnc2.plot_species_convergence_c(n_slices= int(len(hnc2.h_list)/1)  )

# %% [markdown]
# # Extrapolate

# %%
fig, axs = plt.subplots(ncols=N_species, nrows=N_species, figsize=(15,8))

T3 = 25
c_s_r_new = (hnc2.c_s_r_matrix - hnc1.c_s_r_matrix)/(T2-T1)*(T3 - T2) + hnc2.c_s_r_matrix

for i in range(N_species):
    for j in range(N_species):
        axs[i,j].plot(hnc1.r_array, hnc1.c_s_r_matrix[i,j],'-',label="T1")
        axs[i,j].plot(hnc2.r_array, hnc2.c_s_r_matrix[i,j],'-', label="T2")
        axs[i,j].plot(hnc2.r_array, c_s_r_new[i,j] ,'--', label="T_proj")
        axs[i,j].set_yscale('symlog',linthresh=1)
        axs[i,j].set_xscale('log')
        axs[i,j].legend()

# %% [markdown]
# # New Temp

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T3*eV 
Ti   = T3*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc3 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc3.r_array), qsp.βvei(hnc3.r_array)],
                        [qsp.βvei(hnc3.r_array), qsp.βvee(hnc3.r_array)]])

hnc3.set_βu_matrix(βu_r_matrix)

hnc3.c_s_r_matrix[:,:,:] = c_s_r_new
hnc3.c_s_k_matrix = hnc3.FT_r_2_k_matrix(hnc3.c_s_r_matrix)
hnc3.c_r_matrix = hnc3.c_s_k_matrix - hnc3.βu_l_k_matrix
hnc3.set_C_matrix()
hnc3.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
# Out:
# Λee = 0.196
# Λei = 0.139
# Γii=3.265, Γie=-1.088, Γee=0.363
# r_i=3.000
# r_e=2.080
# Λee = 0.189
# Λei = 0.134
# Γii=3.265, Γie=-1.014, Γee=0.338
# r_i=3.000
# r_e=2.080
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 2.88e+00, OZ: 5.85e-01, HNC: 3.74e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 1.94e+00, OZ: 1.19e-01, HNC: 3.57e+25
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 1.16e+00, OZ: 1.20e-01, HNC: 6.11e+11
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 6.51e-01, OZ: 1.20e-01, HNC: 6.58e+06
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 2.54e-01, OZ: 1.19e-01, HNC: 1.15e+03
#  HNC min: [0.5] True Optimization terminated successfully.
# 5: Err in c_r: 6.38e-02, OZ: 1.18e-01, HNC: 2.68e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 6: Err in c_r: 1.48e-01, OZ: 1.17e-01, HNC: 7.62e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 7: Err in c_r: 2.25e-01, OZ: 1.15e-01, HNC: 8.09e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 8: Err in c_r: 2.41e-01, OZ: 1.15e-01, HNC: 7.89e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 9: Err in c_r: 2.01e-01, OZ: 1.14e-01, HNC: 7.51e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 10: Err in c_r: 1.33e-01, OZ: 1.14e-01, HNC: 6.76e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 11: Err in c_r: 6.59e-02, OZ: 1.15e-01, HNC: 5.04e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 12: Err in c_r: 1.97e-02, OZ: 1.15e-01, HNC: 1.96e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 13: Err in c_r: 1.37e-02, OZ: 1.15e-01, HNC: 1.30e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 14: Err in c_r: 1.92e-02, OZ: 1.15e-01, HNC: 2.69e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 15: Err in c_r: 1.58e-02, OZ: 1.15e-01, HNC: 2.25e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 16: Err in c_r: 8.53e-03, OZ: 1.15e-01, HNC: 1.14e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 17: Err in c_r: 2.07e-03, OZ: 1.15e-01, HNC: 1.64e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 18: Err in c_r: 3.67e-03, OZ: 1.15e-01, HNC: 4.30e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 19: Err in c_r: 5.47e-03, OZ: 1.15e-01, HNC: 6.65e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 20: Err in c_r: 5.22e-03, OZ: 1.15e-01, HNC: 6.42e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 21: Err in c_r: 3.79e-03, OZ: 1.15e-01, HNC: 4.74e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 22: Err in c_r: 2.05e-03, OZ: 1.15e-01, HNC: 2.61e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 23: Err in c_r: 6.38e-04, OZ: 1.15e-01, HNC: 7.39e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 24: Err in c_r: 4.76e-04, OZ: 1.15e-01, HNC: 4.90e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 25: Err in c_r: 8.15e-04, OZ: 1.15e-01, HNC: 1.02e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 26: Err in c_r: 8.00e-04, OZ: 1.15e-01, HNC: 1.03e-01
#  HNC min: [0.5] True Optimization terminated successfully.
# 27: Err in c_r: 5.77e-04, OZ: 1.15e-01, HNC: 7.46e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 28: Err in c_r: 3.01e-04, OZ: 1.15e-01, HNC: 3.87e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 29: Err in c_r: 8.16e-05, OZ: 1.15e-01, HNC: 8.51e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 30: Err in c_r: 9.34e-05, OZ: 1.15e-01, HNC: 1.05e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 31: Err in c_r: 1.44e-04, OZ: 1.15e-01, HNC: 1.80e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 32: Err in c_r: 1.35e-04, OZ: 1.15e-01, HNC: 1.73e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 33: Err in c_r: 9.51e-05, OZ: 1.15e-01, HNC: 1.22e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 34: Err in c_r: 4.79e-05, OZ: 1.15e-01, HNC: 6.14e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 35: Err in c_r: 1.20e-05, OZ: 1.15e-01, HNC: 1.13e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 36: Err in c_r: 1.69e-05, OZ: 1.15e-01, HNC: 1.94e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 37: Err in c_r: 2.46e-05, OZ: 1.15e-01, HNC: 3.09e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 38: Err in c_r: 2.25e-05, OZ: 1.15e-01, HNC: 2.88e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 39: Err in c_r: 1.54e-05, OZ: 1.15e-01, HNC: 1.99e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 40: Err in c_r: 7.48e-06, OZ: 1.15e-01, HNC: 9.56e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 41: Err in c_r: 1.75e-06, OZ: 1.15e-01, HNC: 1.32e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 42: Err in c_r: 3.07e-06, OZ: 1.15e-01, HNC: 3.59e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 43: Err in c_r: 4.20e-06, OZ: 1.15e-01, HNC: 5.30e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 44: Err in c_r: 3.74e-06, OZ: 1.15e-01, HNC: 4.80e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 45: Err in c_r: 2.50e-06, OZ: 1.15e-01, HNC: 3.22e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 46: Err in c_r: 1.16e-06, OZ: 1.15e-01, HNC: 1.48e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 47: Err in c_r: 2.62e-07, OZ: 1.15e-01, HNC: 1.31e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 48: Err in c_r: 5.51e-07, OZ: 1.15e-01, HNC: 6.55e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 49: Err in c_r: 7.15e-07, OZ: 1.15e-01, HNC: 9.04e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 50: Err in c_r: 6.21e-07, OZ: 1.15e-01, HNC: 7.96e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 51: Err in c_r: 4.04e-07, OZ: 1.15e-01, HNC: 5.21e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 52: Err in c_r: 1.80e-07, OZ: 1.15e-01, HNC: 2.28e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 53: Err in c_r: 4.17e-08, OZ: 1.15e-01, HNC: 8.98e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 54: Err in c_r: 9.82e-08, OZ: 1.15e-01, HNC: 1.18e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 55: Err in c_r: 1.22e-07, OZ: 1.15e-01, HNC: 1.54e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 56: Err in c_r: 1.03e-07, OZ: 1.15e-01, HNC: 1.32e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 57: Err in c_r: 6.51e-08, OZ: 1.15e-01, HNC: 8.39e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 58: Err in c_r: 2.76e-08, OZ: 1.15e-01, HNC: 3.49e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 59: Err in c_r: 7.14e-09, OZ: 1.15e-01, HNC: 1.95e-07

# %%
hnc3.plot_species_convergence_g(n_slices= int(len(hnc3.h_list)/1)  )
hnc3.plot_species_convergence_c(n_slices= int(len(hnc3.h_list)/1)  )

# %% [markdown]
# # Extrapolate Again!

# %%
fig, axs = plt.subplots(ncols=N_species, nrows=N_species, figsize=(15,8))

c_s_r_new = (hnc2.c_s_r_matrix - hnc3.c_s_r_matrix )/(T2-T3)*(T4 - T3) + hnc3.c_s_r_matrix

for i in range(N_species):
    for j in range(N_species):
        axs[i,j].plot(hnc1.r_array, hnc1.c_s_r_matrix[i,j],'-',label="T1")
        axs[i,j].plot(hnc2.r_array, hnc2.c_s_r_matrix[i,j],'-',label="T2")
        axs[i,j].plot(hnc3.r_array, hnc3.c_s_r_matrix[i,j],'-', label="T3")
        axs[i,j].plot(hnc3.r_array, c_s_r_new[i,j] ,'--', label="T_proj")
        axs[i,j].set_yscale('symlog',linthresh=1)
        axs[i,j].set_xscale('log')
        axs[i,j].legend()

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ri = 3
Te_c = T4*eV 
Ti   = T4*eV 
Z, A = 13, 27
Zstar= 3
# "Classical-Map  Hypernetted  Chain  Calculations  for  DensePlasmas"R. Bredow1∗, Th. Bornath1, W.-D. Kraeft1, M.W.C. Dharma-wardana2,andR. Redmer1
# Tq  = 1/5*qsp.E_F 


def make_Te(Te_c, Tq):
    Te  = np.sqrt(Tq**2 + Te_c**2)
    return Te
    
qsp = QSP_HNC(Z, A, Zstar, Te_c, Ti, ri)
Tq = qsp.E_F/(1.594 - 0.3160*np.sqrt(qsp.re) + 0.0240*qsp.re)
qsp = QSP_HNC(Z, A, Zstar, make_Te(Te_c, Tq), Ti, ri)

N_species = 2
Gamma = np.array(  [[qsp.Γii,  qsp.Γei],
                    [qsp.Γei,  qsp.Γee]])


names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc4 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-8,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=5, N_bins=1000, names=names, dst_type=3)

βu_r_matrix = np.array([[qsp.βvii(hnc4.r_array), qsp.βvei(hnc4.r_array)],
                        [qsp.βvei(hnc4.r_array), qsp.βvee(hnc4.r_array)]])

hnc4.set_βu_matrix(βu_r_matrix)

hnc4.c_s_r_matrix[:,:,:] = c_s_r_new
hnc4.c_s_k_matrix = hnc4.FT_r_2_k_matrix(hnc4.c_s_r_matrix)
hnc4.c_r_matrix = hnc4.c_s_k_matrix - hnc4.βu_l_k_matrix
hnc4.set_C_matrix()
hnc4.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
# Out:
# Λee = 0.209
# Λei = 0.148
# Γii=3.710, Γie=-1.237, Γee=0.412
# r_i=3.000
# r_e=2.080
# Λee = 0.200
# Λei = 0.141
# Γii=3.710, Γie=-1.131, Γee=0.377
# r_i=3.000
# r_e=2.080
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 4.05e+00, OZ: 5.97e-01, HNC: 3.20e+00
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 2.14e+00, OZ: 1.24e-01, HNC: 6.83e+27
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 1.54e+00, OZ: 1.26e-01, HNC: 3.70e+15
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 1.29e+00, OZ: 1.28e-01, HNC: 1.77e+13
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 1.72e+00, OZ: 1.31e-01, HNC: 2.11e+17
#  HNC min: [0.5] True Optimization terminated successfully.
# 5: Err in c_r: 5.38e+00, OZ: 1.40e-01, HNC: 3.06e+53
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 6: Err in c_r: 3.16e+00, OZ: 1.41e-01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 7: Err in c_r: 8.41e+00, OZ: 1.56e-01, HNC: inf
# /home/zach/plasma/hnc/hnc.py:296: RuntimeWarning: overflow encountered in exp
#   hnc_eqn = - 1 - self.h_r_matrix   + np.exp( -self.βu_s_r_matrix + self.h_r_matrix - c_s_r_matrix )
# /home/zach/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py:863: RuntimeWarning: invalid value encountered in subtract
#   np.max(np.abs(fsim[0] - fsim[1:])) <= fatol):
# /home/zach/plasma/hnc/hnc.py:362: RuntimeWarning: overflow encountered in exp
#   hnc_err = np.linalg.norm(- 1 - self.h_r_matrix   + np.exp( -self.βu_r_matrix + self.h_r_matrix - self.c_r_matrix ))/np.sqrt(self.N_bins*self.N_species**2)
# /home/zach/plasma/hnc/hnc.py:342: RuntimeWarning: overflow encountered in exp
#   self.h_r_matrix = -1 + np.exp(self.γs_r_matrix - self.βu_s_r_matrix) # 2. γ_r,u_s_r  -> h_r   (HNC)
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 8: Err in c_r: 1.30e+01, OZ: 2.69e-01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 9: Err in c_r: 5.85e+01, OZ: 3.62e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 10: Err in c_r: 5.84e+01, OZ: 4.01e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 11: Err in c_r: 5.58e+01, OZ: 2.51e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 12: Err in c_r: 1.47e+02, OZ: 5.25e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 13: Err in c_r: 1.98e+02, OZ: 5.08e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 14: Err in c_r: 1.06e+02, OZ: 4.38e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 15: Err in c_r: 3.81e+02, OZ: 5.34e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 16: Err in c_r: 1.20e+03, OZ: 5.79e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 17: Err in c_r: 1.35e+02, OZ: 3.52e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 18: Err in c_r: 6.75e+03, OZ: 6.80e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 19: Err in c_r: 1.41e+02, OZ: 3.66e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 20: Err in c_r: 5.12e+02, OZ: 5.56e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 21: Err in c_r: 2.79e+03, OZ: 8.11e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 22: Err in c_r: 2.45e+02, OZ: 3.69e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 23: Err in c_r: 3.55e+02, OZ: 4.48e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 24: Err in c_r: 1.79e+02, OZ: 6.39e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 25: Err in c_r: 8.30e+01, OZ: 2.42e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 26: Err in c_r: 1.22e+02, OZ: 2.11e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 27: Err in c_r: 3.39e+02, OZ: 3.18e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 28: Err in c_r: 1.84e+02, OZ: 3.29e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 29: Err in c_r: 2.47e+02, OZ: 2.99e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 30: Err in c_r: 2.94e+03, OZ: 6.31e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 31: Err in c_r: 2.31e+02, OZ: 1.50e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 32: Err in c_r: 4.94e+02, OZ: 5.16e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 33: Err in c_r: 3.75e+02, OZ: 2.75e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 34: Err in c_r: 2.93e+02, OZ: 2.21e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 35: Err in c_r: 4.94e+02, OZ: 3.46e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 36: Err in c_r: 3.79e+02, OZ: 3.34e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 37: Err in c_r: 1.74e+03, OZ: 5.96e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 38: Err in c_r: 2.56e+02, OZ: 1.41e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 39: Err in c_r: 7.60e+03, OZ: 8.26e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 40: Err in c_r: 5.68e+02, OZ: 4.12e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 41: Err in c_r: 2.25e+03, OZ: 5.33e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 42: Err in c_r: 6.66e+03, OZ: 7.05e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 43: Err in c_r: 1.38e+02, OZ: 1.80e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 44: Err in c_r: 2.33e+02, OZ: 2.33e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 45: Err in c_r: 2.42e+02, OZ: 1.91e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 46: Err in c_r: 2.61e+03, OZ: 5.51e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 47: Err in c_r: 2.60e+02, OZ: 3.79e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 48: Err in c_r: 3.24e+02, OZ: 5.77e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 49: Err in c_r: 1.70e+02, OZ: 6.43e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 50: Err in c_r: 3.05e+02, OZ: 2.02e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 51: Err in c_r: 3.98e+02, OZ: 1.58e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 52: Err in c_r: 4.96e+02, OZ: 2.44e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 53: Err in c_r: 4.30e+02, OZ: 3.13e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 54: Err in c_r: 2.25e+02, OZ: 3.47e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 55: Err in c_r: 1.98e+02, OZ: 2.66e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 56: Err in c_r: 2.02e+02, OZ: 4.55e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 57: Err in c_r: 2.66e+02, OZ: 1.37e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 58: Err in c_r: 5.83e+02, OZ: 2.83e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 59: Err in c_r: 9.58e+02, OZ: 4.00e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 60: Err in c_r: 5.52e+02, OZ: 3.01e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 61: Err in c_r: 3.80e+02, OZ: 2.48e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 62: Err in c_r: 1.74e+04, OZ: 8.77e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 63: Err in c_r: 1.33e+02, OZ: 4.66e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 64: Err in c_r: 2.11e+02, OZ: 1.90e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 65: Err in c_r: 4.61e+02, OZ: 2.21e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 66: Err in c_r: 1.58e+03, OZ: 5.75e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 67: Err in c_r: 6.40e+02, OZ: 4.85e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 68: Err in c_r: 2.84e+02, OZ: 2.67e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 69: Err in c_r: 5.75e+02, OZ: 2.23e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 70: Err in c_r: 2.75e+02, OZ: 1.01e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 71: Err in c_r: 1.50e+03, OZ: 4.37e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 72: Err in c_r: 1.14e+03, OZ: 3.95e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 73: Err in c_r: 2.82e+02, OZ: 6.66e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 74: Err in c_r: 2.72e+03, OZ: 4.86e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 75: Err in c_r: 5.15e+02, OZ: 2.74e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 76: Err in c_r: 3.73e+03, OZ: 6.06e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 77: Err in c_r: 1.82e+02, OZ: 2.66e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 78: Err in c_r: 2.27e+02, OZ: 1.57e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 79: Err in c_r: 2.32e+02, OZ: 1.79e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 80: Err in c_r: 2.18e+02, OZ: 1.68e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 81: Err in c_r: 2.01e+02, OZ: 1.82e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 82: Err in c_r: 2.05e+02, OZ: 2.03e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 83: Err in c_r: 2.14e+02, OZ: 6.05e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 84: Err in c_r: 2.76e+02, OZ: 2.44e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 85: Err in c_r: 1.85e+02, OZ: 1.63e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 86: Err in c_r: 1.84e+02, OZ: 1.35e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 87: Err in c_r: 8.69e+02, OZ: 7.44e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 88: Err in c_r: 5.31e+02, OZ: 1.69e+02, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 89: Err in c_r: 2.03e+02, OZ: 1.36e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 90: Err in c_r: 1.92e+02, OZ: 1.25e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 91: Err in c_r: 1.87e+02, OZ: 1.33e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 92: Err in c_r: 1.85e+02, OZ: 1.46e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 93: Err in c_r: 1.86e+02, OZ: 1.40e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 94: Err in c_r: 1.63e+02, OZ: 1.49e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 95: Err in c_r: 1.69e+02, OZ: 1.74e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 96: Err in c_r: 2.75e+02, OZ: 3.52e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 97: Err in c_r: 1.79e+02, OZ: 2.00e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 98: Err in c_r: 2.14e+02, OZ: 3.85e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 99: Err in c_r: 1.78e+02, OZ: 2.26e+01, HNC: inf
#  HNC min: [0.01] False Maximum number of iterations has been exceeded.
# 100: Err in c_r: 1.85e+02, OZ: 2.28e+01, HNC: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_34108/914170617.py in <module>
#      38 hnc4.c_r_matrix = hnc4.c_s_k_matrix - hnc4.βu_l_k_matrix
#      39 hnc4.set_C_matrix()
# ---> 40 hnc4.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
#
# ~/plasma/hnc/hnc.py in HNC_solve(self, h_max, alpha_method, alpha_Picard, alpha_oz)
#     347             # Update h_r, c_r_matrix
#     348             old_c_s_r_matrix = self.c_s_r_matrix.copy()
# --> 349             self.c_s_r_matrix = self.c_s_updater(old_c_s_r_matrix, new_c_s_r_matrix, method = alpha_method, alpha_Picard = alpha_Picard, alpha_oz = alpha_oz )
#     350
#     351             self.c_s_k_matrix = self.FT_r_2_k_matrix(self.c_s_r_matrix)  # FT
#
# ~/plasma/hnc/hnc.py in c_s_updater(self, c_s_r_old, c_s_r_new, method, alpha_Picard, alpha_oz)
#     240         if method=='best' or alpha_oz > 0.0:
#     241             # c_s_r_oz =  self.FT_k_2_r_matrix(self.h_k_matrix  - self.γs_k_matrix)
# --> 242             I_plus_h_rho_inverse = self.invert_matrix(self.I[:,:,np.newaxis] + self.h_k_matrix*self.rho[:,np.newaxis,np.newaxis])
#     243             c_s_r_oz = self.FT_k_2_r_matrix(self.A_times_B(I_plus_h_rho_inverse, self.h_k_matrix))
#     244
#
# ~/plasma/hnc/hnc.py in invert_matrix(self, A_matrix)
#     221
#     222         for k_index in range(self.N_bins):
# --> 223             A_inverse[:,:, k_index] = np.linalg.inv(A_matrix[:,:,k_index])
#     224
#     225         return A_inverse
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py in inv(a)
#     550     signature = 'D->D' if isComplexType(t) else 'd->d'
#     551     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553     return wrap(ainv.astype(result_t, copy=False))
#     554
#
# KeyboardInterrupt:
