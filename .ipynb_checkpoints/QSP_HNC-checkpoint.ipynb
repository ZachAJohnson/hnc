# %%
import numpy as np
import matplotlib.pyplot as plt


from hnc_n_multiscale import  HNC_solver

# %% [markdown]
# # Two Species

# %% [markdown]
# Here we do QSP interactions between electrons and one ion type.
#
# Using $\tilde{r}\equiv r/r_s$, we implement potentials
# \begin{align}
# \beta v_{ee}(\tilde{r}) &=  \frac{\Gamma_{ee}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right) +  \ln2 \exp\left[-\tilde{r}^2 r_s^2/(\pi \Lambda_e^2 \ln 2)\right]\\
# \beta v_{ei}(\tilde{r}) &=  \frac{\Gamma_{ei}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right)\\
# \beta v_{ii}(\tilde{r}) &=  \frac{\Gamma_{ii}}{\tilde{r}}
# \end{align}
# For
# \begin{align}
# \Gamma_{ee}&=\frac{\beta e^2}{r_s}\\
# \Gamma_{ei}&=\frac{\beta Z_i e^2}{r_s}\\
# \Gamma_{ii}&=\frac{\beta Z_i^2 e^2}{r_s}\\
# \end{align}

# %% [markdown]
# Define physical constants

# %% [markdown]
# # Check ALL Tei stuff

# %%
m_e = 1
m_p = 1833.274
eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
Kelvin = 8.61732814974493e-5*eV #Similarly, 1 Kelvin = 3.167e-6... in natural units 
aB = 5.29177210903e-11 # Bohr radius in m

π = np.pi
# [AU]
# ni = 6e20*1e6*aB**3
# ri = (4/3*π*ni)**(-1/3)

ri=3
ni = (4/3*π*ri**3)**-1

Te   = 0.8*eV 
Ti   = 0.8*eV 

βe   = 1/Te
βi   = 1/Ti

Zstar = 4#

A = 18
m_i = m_p*A
μ_ei = m_i*m_e/(m_e+m_i) #reduced mass
Tie = μ_ei * (Te/m_e + Ti/m_i) #thermal velocity defined Tei
βie = 1/Tie

ne = Zstar*ni
re = (4/3*π*ne)**(-1/3)

lambda_TF = np.sqrt( Te / (4*np.pi*ne)  )

Λe  = np.sqrt(  βie*2*π /m_e )
Λe_star  = Λe/ri
print("Λee = {0:.3f}".format(Λe_star))
Γee = βe/ri 
Γei = -Zstar*βie/ri
Γii = Zstar**2*βi/ri 

E_F = 1/(2*m_e) * (3*π**2 * ne)**(2/3)
θ   = Te/E_F

print("Γii={0:.1f}, Γie={1:.1f}, Γee={2:.1f} ".format(Γii, Γei, Γee))
print("r_i={0:.1f}".format(ri))
print("r_e={0:.1f}".format(re))
print("θ  ={0:.2e}".format(θ))

def βv_Yukawa(r):
    return Γii/r * np.exp(-r*ri/lambda_TF)
# Out:
# Λee = 4.873
# Γii=181.4, Γie=-45.3, Γee=11.3
# r_i=3.0
# r_e=1.9
# θ  =5.70e-02

# %% [markdown]
# ##### Load MM Data

# %%
# from pandas import read_csv

# r_ie, gie = np.array(read_csv("~/plasma/MM_HNC/gie.out", delim_whitespace=True)).T
# r_ee, gee = np.array(read_csv("~/plasma/MM_HNC/gee.out", delim_whitespace=True)).T
# r_ii, gii = np.array(read_csv("~/plasma/MM_HNC/gii.out", delim_whitespace=True)).T

# data_to_compare = [gie,gee,gii]
# data_to_compare = ["~/plasma/MM_HNC/gie.out","~/plasma/MM_HNC/gee.out","~/plasma/MM_HNC/gii.out"]
# data_names=['MM ie', "MM ee", 'MM ii' ]

# %% [markdown]
# Plug into get potentials

# %%
from scipy.special import erfc

# Build Components for QSP's

def βv_Deutsch(Γ, r):
    return Γ/r* ( 1 -  np.exp(-np.sqrt(2)*π*r/Λe_star) )

# Kelbg looks really weird??
def βv_Kelbg(Γ,r):
    return Γ/r*( 1 - np.exp(-2*π*r**2/Λe_star**2)+ np.sqrt(2)*π*r/Λe_star*erfc(np.sqrt(2*π)*r/Λe_star))

def βv_Pauli(r):
    return  np.log(2) * np.exp(-4*π* r**2 /( Λe_star**2))


######### Build Actual QSP's

def βvee(r):
    return βv_Kelbg(Γee,r) + βv_Pauli(r)

def βvei(r):
    return βv_Kelbg(Γei,r)

# def βvei_atomic(r):
#     r_c = 3/5 #3/5 r_s in linear n_b(r) model
#     return np.heaviside(r - r_c,0.5) * βvei(r)

def βvii(r):
    return Γii/r 

fig, ax = plt.subplots(figsize=(8,6),facecolor='w')

xs = np.geomspace(1e-2,10)
ax.plot(βv_Deutsch(1,xs),label='Deutsch')
ax.plot(βv_Kelbg(1,xs),label='Kelbg')
ax.plot(βv_Pauli(xs),label='Pauli')
ax.set_yscale('log')
ax.set_ylim(1e-1,1e2)
ax.legend()

# %% [markdown]
# First, we initialize the hnc

# %%
N_species = 2
Gamma = np.array(  [[Γii,  Γei],
                    [Γei,  Γee]])


# Gamma = np.array(  [[50,  10],
#                     [10,  10]])

names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc2 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-6,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=10, N_bins=1000, names=names, dst_type=3)

# %%
βu_r_matrix = np.array([[βvii(hnc2.r_array), βvei(hnc2.r_array)],
                        [βvei(hnc2.r_array), βvee(hnc2.r_array)]])

hnc2.set_βu_matrix(βu_r_matrix)
hnc2.initialize_c_k()
hnc2.set_C_matrix()

# %%
hnc2.plot_βu_all_species()
# Out:
# /home/zach/plasma/hnc/hnc_n_multiscale.py:473: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim(0,10)

# %%
hnc2.HNC_solve(alpha=0.1, h_max=1e4)
# Out:
# 0: Err in c_r: 358.973
# 1: Err in c_r: 331.516
# 2: Err in c_r: 306.045
# 3: Err in c_r: 282.441
# 4: Err in c_r: 260.589
# 5: Err in c_r: 240.377
# 6: Err in c_r: 221.698
# 7: Err in c_r: 204.449
# 8: Err in c_r: 188.534
# 9: Err in c_r: 173.858
# 10: Err in c_r: 160.334
# 11: Err in c_r: 147.878
# 12: Err in c_r: 136.413
# 13: Err in c_r: 125.864
# 14: Err in c_r: 116.163
# 15: Err in c_r: 107.245
# 16: Err in c_r: 99.049
# 17: Err in c_r: 91.520
# 18: Err in c_r: 84.606
# 19: Err in c_r: 78.257
# 20: Err in c_r: 72.429
# 118: Err in c_r: 3.060
# 119: Err in c_r: 3.023
# 120: Err in c_r: 2.987
# 121: Err in c_r: 2.951
# 122: Err in c_r: 2.917
# 123: Err in c_r: 2.883
# 124: Err in c_r: 2.849
# 125: Err in c_r: 2.816
# 126: Err in c_r: 2.784
# 127: Err in c_r: 2.753
# 128: Err in c_r: 2.722
# 129: Err in c_r: 2.691
# 130: Err in c_r: 2.661
# 131: Err in c_r: 2.632
# 132: Err in c_r: 2.603
# 133: Err in c_r: 2.575
# 134: Err in c_r: 2.547
# 135: Err in c_r: 2.520
# 136: Err in c_r: 2.493
# 137: Err in c_r: 2.467
# 138: Err in c_r: 2.441
# 139: Err in c_r: 2.416
# 140: Err in c_r: 2.391
# 141: Err in c_r: 2.366
# 142: Err in c_r: 2.342
# 143: Err in c_r: 2.318
# 144: Err in c_r: 2.295
# 145: Err in c_r: 2.272
# 146: Err in c_r: 2.249
# 147: Err in c_r: 2.227
# 148: Err in c_r: 2.205
# 149: Err in c_r: 2.183
# 150: Err in c_r: 2.162
# 151: Err in c_r: 2.141
# 152: Err in c_r: 2.121
# 153: Err in c_r: 2.101
# 154: Err in c_r: 2.081
# 155: Err in c_r: 2.061
# 156: Err in c_r: 2.042
# 157: Err in c_r: 2.023
# 158: Err in c_r: 2.004
# 159: Err in c_r: 1.985
# 160: Err in c_r: 1.967
# 161: Err in c_r: 1.949
# 162: Err in c_r: 1.932
# 163: Err in c_r: 1.914
# 164: Err in c_r: 1.897
# 165: Err in c_r: 1.880
# 166: Err in c_r: 1.864
# 167: Err in c_r: 1.847
# 168: Err in c_r: 1.831
# 169: Err in c_r: 1.815
# 170: Err in c_r: 1.799
# 171: Err in c_r: 1.784
# 172: Err in c_r: 1.768
# 173: Err in c_r: 1.753
# 174: Err in c_r: 1.738
# 175: Err in c_r: 1.724
# 176: Err in c_r: 1.709
# 177: Err in c_r: 1.695
# 178: Err in c_r: 1.681
# 179: Err in c_r: 1.667
# 180: Err in c_r: 1.653
# 181: Err in c_r: 1.639
# 182: Err in c_r: 1.626
# 183: Err in c_r: 1.613
# 184: Err in c_r: 1.600
# 185: Err in c_r: 1.587
# 186: Err in c_r: 1.574
# 187: Err in c_r: 1.561
# 188: Err in c_r: 1.549
# 189: Err in c_r: 1.537
# 190: Err in c_r: 1.525
# 191: Err in c_r: 1.513
# 192: Err in c_r: 1.501
# 193: Err in c_r: 1.489
# 194: Err in c_r: 1.478
# 195: Err in c_r: 1.466
# 196: Err in c_r: 1.455
# 197: Err in c_r: 1.444
# 198: Err in c_r: 1.433
# 199: Err in c_r: 1.422
# 200: Err in c_r: 1.411
# 201: Err in c_r: 1.401
# 202: Err in c_r: 1.390
# 203: Err in c_r: 1.380
# 204: Err in c_r: 1.370
# 205: Err in c_r: 1.360
# 206: Err in c_r: 1.350
# 207: Err in c_r: 1.340
# 208: Err in c_r: 1.330
# 209: Err in c_r: 1.320
# 210: Err in c_r: 1.311
# 211: Err in c_r: 1.301
# 212: Err in c_r: 1.292
# 213: Err in c_r: 1.283
# 214: Err in c_r: 1.274
# 215: Err in c_r: 1.265
# 216: Err in c_r: 1.256
# 217: Err in c_r: 1.247
# 218: Err in c_r: 1.238
# 219: Err in c_r: 1.229
# 220: Err in c_r: 1.221
# 221: Err in c_r: 1.212
# 222: Err in c_r: 1.204
# 223: Err in c_r: 1.196
# 224: Err in c_r: 1.187
# 225: Err in c_r: 1.179
# 226: Err in c_r: 1.171
# 227: Err in c_r: 1.163
# 228: Err in c_r: 1.156
# 229: Err in c_r: 1.148
# 230: Err in c_r: 1.140
# 231: Err in c_r: 1.132
# 232: Err in c_r: 1.125
# 233: Err in c_r: 1.117
# 234: Err in c_r: 1.110
# 235: Err in c_r: 1.103
# 236: Err in c_r: 1.095
# 237: Err in c_r: 1.088
# 238: Err in c_r: 1.081
# 239: Err in c_r: 1.074
# 240: Err in c_r: 1.067
# 241: Err in c_r: 1.060
# 242: Err in c_r: 1.053
# 243: Err in c_r: 1.047
# 244: Err in c_r: 1.040
# 245: Err in c_r: 1.033
# 246: Err in c_r: 1.027
# 247: Err in c_r: 1.020
# 248: Err in c_r: 1.014
# 249: Err in c_r: 1.007
# 250: Err in c_r: 1.001
# 251: Err in c_r: 0.995
# 252: Err in c_r: 0.988
# 253: Err in c_r: 0.982
# 254: Err in c_r: 0.976
# 255: Err in c_r: 0.970
# 256: Err in c_r: 0.964
# 257: Err in c_r: 0.958
# 258: Err in c_r: 0.952
# 259: Err in c_r: 0.946
# 260: Err in c_r: 0.941
# 261: Err in c_r: 0.935
# 262: Err in c_r: 0.929
# 263: Err in c_r: 0.924
# 264: Err in c_r: 0.918
# 265: Err in c_r: 0.913
# 266: Err in c_r: 0.907
# 267: Err in c_r: 0.902
# 268: Err in c_r: 0.896
# 269: Err in c_r: 0.891
# 270: Err in c_r: 0.886
# 271: Err in c_r: 0.880
# 272: Err in c_r: 0.875
# 273: Err in c_r: 0.870
# 274: Err in c_r: 0.865
# 275: Err in c_r: 0.860
# 276: Err in c_r: 0.855
# 277: Err in c_r: 0.850
# 278: Err in c_r: 0.845
# 279: Err in c_r: 0.840
# 280: Err in c_r: 0.835
# 281: Err in c_r: 0.830
# 282: Err in c_r: 0.826
# 283: Err in c_r: 0.821
# 284: Err in c_r: 0.816
# 285: Err in c_r: 0.811
# 286: Err in c_r: 0.807
# 287: Err in c_r: 0.802
# 288: Err in c_r: 0.798
# 289: Err in c_r: 0.793
# 290: Err in c_r: 0.789
# 291: Err in c_r: 0.784
# 292: Err in c_r: 0.780
# 293: Err in c_r: 0.776
# 294: Err in c_r: 0.771
# 295: Err in c_r: 0.767
# 296: Err in c_r: 0.763
# 297: Err in c_r: 0.758
# 298: Err in c_r: 0.754
# 299: Err in c_r: 0.750
# 300: Err in c_r: 0.746
# 301: Err in c_r: 0.742
# 302: Err in c_r: 0.738
# 303: Err in c_r: 0.734
# 304: Err in c_r: 0.730
# 305: Err in c_r: 0.726
# 306: Err in c_r: 0.722
# 307: Err in c_r: 0.718
# 308: Err in c_r: 0.714
# 309: Err in c_r: 0.710
# 310: Err in c_r: 0.706
# 504: Err in c_r: 0.289
# 505: Err in c_r: 0.288
# 506: Err in c_r: 0.286
# 507: Err in c_r: 0.285
# 508: Err in c_r: 0.284
# 509: Err in c_r: 0.283
# 510: Err in c_r: 0.282
# 511: Err in c_r: 0.281
# 512: Err in c_r: 0.280
# 513: Err in c_r: 0.278
# 514: Err in c_r: 0.277
# 515: Err in c_r: 0.276
# 516: Err in c_r: 0.275
# 517: Err in c_r: 0.274
# 518: Err in c_r: 0.273
# 519: Err in c_r: 0.272
# 520: Err in c_r: 0.271
# 521: Err in c_r: 0.270
# 522: Err in c_r: 0.268
# 523: Err in c_r: 0.267
# 524: Err in c_r: 0.266
# 525: Err in c_r: 0.265
# 526: Err in c_r: 0.264
# 527: Err in c_r: 0.263
# 528: Err in c_r: 0.262
# 529: Err in c_r: 0.261
# 530: Err in c_r: 0.260
# 531: Err in c_r: 0.259
# 532: Err in c_r: 0.258
# 533: Err in c_r: 0.257
# 534: Err in c_r: 0.256
# 535: Err in c_r: 0.255
# 536: Err in c_r: 0.254
# 537: Err in c_r: 0.253
# 538: Err in c_r: 0.252
# 539: Err in c_r: 0.251
# 540: Err in c_r: 0.250
# 541: Err in c_r: 0.249
# 542: Err in c_r: 0.248
# 543: Err in c_r: 0.247
# 544: Err in c_r: 0.246
# 545: Err in c_r: 0.245
# 546: Err in c_r: 0.244
# 547: Err in c_r: 0.243
# 548: Err in c_r: 0.242
# 549: Err in c_r: 0.241
# 550: Err in c_r: 0.240
# 551: Err in c_r: 0.239
# 552: Err in c_r: 0.238
# 553: Err in c_r: 0.237
# 554: Err in c_r: 0.236
# 555: Err in c_r: 0.235
# 556: Err in c_r: 0.235
# 557: Err in c_r: 0.234
# 558: Err in c_r: 0.233
# 559: Err in c_r: 0.232
# 560: Err in c_r: 0.231
# 561: Err in c_r: 0.230
# 562: Err in c_r: 0.229
# 563: Err in c_r: 0.228
# 564: Err in c_r: 0.227
# 565: Err in c_r: 0.226
# 566: Err in c_r: 0.226
# 567: Err in c_r: 0.225
# 568: Err in c_r: 0.224
# 569: Err in c_r: 0.223
# 570: Err in c_r: 0.222
# 571: Err in c_r: 0.221
# 572: Err in c_r: 0.220
# 573: Err in c_r: 0.219
# 574: Err in c_r: 0.219
# 575: Err in c_r: 0.218
# 576: Err in c_r: 0.217
# 577: Err in c_r: 0.216
# 578: Err in c_r: 0.215
# 579: Err in c_r: 0.214
# 580: Err in c_r: 0.214
# 581: Err in c_r: 0.213
# 582: Err in c_r: 0.212
# 583: Err in c_r: 0.211
# 584: Err in c_r: 0.210
# 585: Err in c_r: 0.210
# 586: Err in c_r: 0.209
# 587: Err in c_r: 0.208
# 588: Err in c_r: 0.207
# 589: Err in c_r: 0.206
# 590: Err in c_r: 0.206
# 591: Err in c_r: 0.205
# 592: Err in c_r: 0.204
# 593: Err in c_r: 0.203
# 594: Err in c_r: 0.202
# 595: Err in c_r: 0.202
# 596: Err in c_r: 0.201
# 597: Err in c_r: 0.200
# 598: Err in c_r: 0.199
# 599: Err in c_r: 0.199
# 600: Err in c_r: 0.198
# 601: Err in c_r: 0.197
# 602: Err in c_r: 0.196
# 603: Err in c_r: 0.196
# 604: Err in c_r: 0.195
# 605: Err in c_r: 0.194
# 606: Err in c_r: 0.193
# 607: Err in c_r: 0.193
# 608: Err in c_r: 0.192
# 609: Err in c_r: 0.191
# 610: Err in c_r: 0.190
# 611: Err in c_r: 0.190
# 612: Err in c_r: 0.189
# 613: Err in c_r: 0.188
# 614: Err in c_r: 0.188
# 615: Err in c_r: 0.187
# 616: Err in c_r: 0.186
# 617: Err in c_r: 0.186
# 618: Err in c_r: 0.185
# 619: Err in c_r: 0.184
# 620: Err in c_r: 0.183
# 621: Err in c_r: 0.183
# 622: Err in c_r: 0.182
# 623: Err in c_r: 0.181
# 624: Err in c_r: 0.181
# 625: Err in c_r: 0.180
# 626: Err in c_r: 0.179
# 627: Err in c_r: 0.179
# 628: Err in c_r: 0.178
# 629: Err in c_r: 0.177
# 630: Err in c_r: 0.177
# 631: Err in c_r: 0.176
# 632: Err in c_r: 0.175
# 633: Err in c_r: 0.175
# 634: Err in c_r: 0.174
# 635: Err in c_r: 0.173
# 636: Err in c_r: 0.173
# 637: Err in c_r: 0.172
# 638: Err in c_r: 0.171
# 639: Err in c_r: 0.171
# 640: Err in c_r: 0.170
# 641: Err in c_r: 0.170
# 642: Err in c_r: 0.169
# 643: Err in c_r: 0.168
# 644: Err in c_r: 0.168
# 645: Err in c_r: 0.167
# 646: Err in c_r: 0.166
# 647: Err in c_r: 0.166
# 648: Err in c_r: 0.165
# 649: Err in c_r: 0.165
# 650: Err in c_r: 0.164
# 651: Err in c_r: 0.163
# 652: Err in c_r: 0.163
# 653: Err in c_r: 0.162
# 654: Err in c_r: 0.162
# 655: Err in c_r: 0.161
# 656: Err in c_r: 0.160
# 657: Err in c_r: 0.160
# 658: Err in c_r: 0.159
# 659: Err in c_r: 0.159
# 660: Err in c_r: 0.158
# 661: Err in c_r: 0.157
# 662: Err in c_r: 0.157
# 663: Err in c_r: 0.156
# 664: Err in c_r: 0.156
# 665: Err in c_r: 0.155
# 666: Err in c_r: 0.155
# 667: Err in c_r: 0.154
# 668: Err in c_r: 0.153
# 669: Err in c_r: 0.153
# 670: Err in c_r: 0.152
# 671: Err in c_r: 0.152
# 672: Err in c_r: 0.151
# 673: Err in c_r: 0.151
# 674: Err in c_r: 0.150
# 675: Err in c_r: 0.150
# 676: Err in c_r: 0.149
# 677: Err in c_r: 0.148
# 678: Err in c_r: 0.148
# 679: Err in c_r: 0.147
# 680: Err in c_r: 0.147
# 681: Err in c_r: 0.146
# 682: Err in c_r: 0.146
# 683: Err in c_r: 0.145
# 684: Err in c_r: 0.145
# 685: Err in c_r: 0.144
# 686: Err in c_r: 0.144
# 687: Err in c_r: 0.143
# 688: Err in c_r: 0.143
# 689: Err in c_r: 0.142
# 690: Err in c_r: 0.142
# 691: Err in c_r: 0.141
# 692: Err in c_r: 0.141
# 693: Err in c_r: 0.140
# 694: Err in c_r: 0.140
# 695: Err in c_r: 0.139
# 696: Err in c_r: 0.139
# 697: Err in c_r: 0.138
# 698: Err in c_r: 0.138
# 699: Err in c_r: 0.137
# 700: Err in c_r: 0.137
# 701: Err in c_r: 0.136
# 702: Err in c_r: 0.136
# 703: Err in c_r: 0.135
# 704: Err in c_r: 0.135
# 705: Err in c_r: 0.134
# 706: Err in c_r: 0.134
# 707: Err in c_r: 0.133
# 708: Err in c_r: 0.133
# 709: Err in c_r: 0.132
# 710: Err in c_r: 0.132
# 711: Err in c_r: 0.131
# 712: Err in c_r: 0.131
# 713: Err in c_r: 0.130
# 714: Err in c_r: 0.130
# 715: Err in c_r: 0.129
# 716: Err in c_r: 0.129
# 717: Err in c_r: 0.128
# 718: Err in c_r: 0.128
# 719: Err in c_r: 0.128
# 720: Err in c_r: 0.127
# 721: Err in c_r: 0.127
# 722: Err in c_r: 0.126
# 723: Err in c_r: 0.126
# 724: Err in c_r: 0.125
# 725: Err in c_r: 0.125
# 726: Err in c_r: 0.124
# 727: Err in c_r: 0.124
# 728: Err in c_r: 0.123
# 729: Err in c_r: 0.123
# 730: Err in c_r: 0.123
# 731: Err in c_r: 0.122
# 732: Err in c_r: 0.122
# 733: Err in c_r: 0.121
# 734: Err in c_r: 0.121
# 735: Err in c_r: 0.120
# 736: Err in c_r: 0.120
# 737: Err in c_r: 0.120
# 738: Err in c_r: 0.119
# 739: Err in c_r: 0.119
# 740: Err in c_r: 0.118
# 741: Err in c_r: 0.118
# 742: Err in c_r: 0.117
# 743: Err in c_r: 0.117
# 744: Err in c_r: 0.117
# 745: Err in c_r: 0.116
# 746: Err in c_r: 0.116
# 747: Err in c_r: 0.115
# 748: Err in c_r: 0.115
# 749: Err in c_r: 0.115
# 750: Err in c_r: 0.114
# 751: Err in c_r: 0.114
# 752: Err in c_r: 0.113
# 753: Err in c_r: 0.113
# 754: Err in c_r: 0.113
# 755: Err in c_r: 0.112
# 756: Err in c_r: 0.112
# 757: Err in c_r: 0.111
# 758: Err in c_r: 0.111
# 759: Err in c_r: 0.111
# 760: Err in c_r: 0.110
# 761: Err in c_r: 0.110
# 762: Err in c_r: 0.109
# 763: Err in c_r: 0.109
# 764: Err in c_r: 0.109
# 765: Err in c_r: 0.108
# 766: Err in c_r: 0.108
# 767: Err in c_r: 0.108
# 768: Err in c_r: 0.107
# 769: Err in c_r: 0.107
# 770: Err in c_r: 0.106
# 771: Err in c_r: 0.106
# 772: Err in c_r: 0.106
# 773: Err in c_r: 0.105
# 774: Err in c_r: 0.105
# 775: Err in c_r: 0.105
# 776: Err in c_r: 0.104
# 777: Err in c_r: 0.104
# 778: Err in c_r: 0.103
# 779: Err in c_r: 0.103
# 780: Err in c_r: 0.103
# 781: Err in c_r: 0.102
# 782: Err in c_r: 0.102
# 783: Err in c_r: 0.102
# 784: Err in c_r: 0.101
# 785: Err in c_r: 0.101
# 786: Err in c_r: 0.101
# 787: Err in c_r: 0.100
# 788: Err in c_r: 0.100
# 789: Err in c_r: 0.100
# 790: Err in c_r: 0.099
# 791: Err in c_r: 0.099
# 792: Err in c_r: 0.098
# 793: Err in c_r: 0.098
# 794: Err in c_r: 0.098
# 795: Err in c_r: 0.097
# 796: Err in c_r: 0.097
# 797: Err in c_r: 0.097
# 798: Err in c_r: 0.096
# 799: Err in c_r: 0.096
# 800: Err in c_r: 0.096
# 801: Err in c_r: 0.095
# 802: Err in c_r: 0.095
# 803: Err in c_r: 0.095
# 804: Err in c_r: 0.094
# 805: Err in c_r: 0.094
# 806: Err in c_r: 0.094
# 807: Err in c_r: 0.093
# 808: Err in c_r: 0.093
# 809: Err in c_r: 0.093
# 810: Err in c_r: 0.092
# 811: Err in c_r: 0.092
# 812: Err in c_r: 0.092
# 813: Err in c_r: 0.092
# 814: Err in c_r: 0.091
# 815: Err in c_r: 0.091
# 816: Err in c_r: 0.091
# 817: Err in c_r: 0.090
# 818: Err in c_r: 0.090
# 819: Err in c_r: 0.090
# 820: Err in c_r: 0.089
# 821: Err in c_r: 0.089
# 822: Err in c_r: 0.089
# 823: Err in c_r: 0.088
# 824: Err in c_r: 0.088
# 825: Err in c_r: 0.088
# 826: Err in c_r: 0.087
# 827: Err in c_r: 0.087
# 828: Err in c_r: 0.087
# 829: Err in c_r: 0.087
# 830: Err in c_r: 0.086
# 831: Err in c_r: 0.086
# 832: Err in c_r: 0.086
# 833: Err in c_r: 0.085
# 834: Err in c_r: 0.085
# 835: Err in c_r: 0.085
# 836: Err in c_r: 0.085
# 837: Err in c_r: 0.084
# 838: Err in c_r: 0.084
# 839: Err in c_r: 0.084
# 840: Err in c_r: 0.083
# 841: Err in c_r: 0.083
# 842: Err in c_r: 0.083
# 843: Err in c_r: 0.083
# 844: Err in c_r: 0.082
# 845: Err in c_r: 0.082
# 846: Err in c_r: 0.082
# 847: Err in c_r: 0.081
# 848: Err in c_r: 0.081
# 849: Err in c_r: 0.081
# 850: Err in c_r: 0.081
# 851: Err in c_r: 0.080
# 852: Err in c_r: 0.080
# 853: Err in c_r: 0.080
# 854: Err in c_r: 0.079
# 855: Err in c_r: 0.079
# 856: Err in c_r: 0.079
# 857: Err in c_r: 0.079
# 858: Err in c_r: 0.078
# 859: Err in c_r: 0.078
# 860: Err in c_r: 0.078
# 861: Err in c_r: 0.078
# 862: Err in c_r: 0.077
# 863: Err in c_r: 0.077
# 864: Err in c_r: 0.077
# 865: Err in c_r: 0.076
# 866: Err in c_r: 0.076
# 867: Err in c_r: 0.076
# 868: Err in c_r: 0.076
# 869: Err in c_r: 0.075
# 870: Err in c_r: 0.075
# 871: Err in c_r: 0.075
# 872: Err in c_r: 0.075
# 873: Err in c_r: 0.074
# 874: Err in c_r: 0.074
# 875: Err in c_r: 0.074
# 876: Err in c_r: 0.074
# 877: Err in c_r: 0.073
# 878: Err in c_r: 0.073
# 879: Err in c_r: 0.073
# 880: Err in c_r: 0.073
# 881: Err in c_r: 0.072
# 882: Err in c_r: 0.072
# 883: Err in c_r: 0.072
# 884: Err in c_r: 0.072
# 885: Err in c_r: 0.071
# 886: Err in c_r: 0.071
# 887: Err in c_r: 0.071
# 888: Err in c_r: 0.071
# 889: Err in c_r: 0.070
# 890: Err in c_r: 0.070
# 987: Err in c_r: 0.051
# 988: Err in c_r: 0.050
# 989: Err in c_r: 0.050
# 990: Err in c_r: 0.050
# 991: Err in c_r: 0.050
# 992: Err in c_r: 0.050
# 993: Err in c_r: 0.050
# 994: Err in c_r: 0.049
# 995: Err in c_r: 0.049
# 996: Err in c_r: 0.049
# 997: Err in c_r: 0.049
# 998: Err in c_r: 0.049
# 999: Err in c_r: 0.049
# Warning: HNC_solver did not converge within the specified number of iterations.

# %%
hnc2.plot_g_all_species()
hnc2.plot_g_all_species(gmax=3)#data_to_compare=['/home/zach/plasma/atomic_forces/data/RDF/Al_1.0eV_rs3_KS-MD.txt'], data_names=['KS MD'], gmax=3)
hnc2.plot_species((1,1))

# %% [markdown]
# # Effective Potentials

# %%
hnc2.invert_HNC(1)

# %%
fig, ax = plt.subplots()

ax.plot(hnc2.r_array, 1+hnc2.heff_r_matrix[0,0],label= 'h')
ax.plot(hnc2.r_array, hnc2.ceff_r_matrix[0,0],label='c')
ax.plot(hnc2.r_array,np.log(1+hnc2.heff_r_matrix)[0,0],label='log(1+h)')
ax.set_yscale('symlog',linthresh=1e-5)
ax.set_xlim(1e-1,2)
# ax.set_xscale('log')
ax.legend()
# Out:
# /tmp/ipykernel_133669/3332355128.py:5: RuntimeWarning: divide by zero encountered in log
#   ax.plot(hnc2.r_array,np.log(1+hnc2.heff_r_matrix)[0,0],label='log(1+h)')

# %%
hnc2.βωeff_r_matrix
# Out:
# array([[[ 9.59516959e+02,  4.70132566e+02,  3.07052152e+02,
#           2.25563132e+02,  1.76721178e+02,  1.44209936e+02,
#           1.21035367e+02,  1.03699382e+02,  9.02577458e+01,
#           7.95432466e+01,  7.08125921e+01,  6.35698557e+01,
#           5.74714028e+01,  5.22715567e+01,  4.77899930e+01,
#           4.38913538e+01,  4.04720533e+01,  3.74514759e+01,
#           3.47659502e+01,  3.23645280e+01,  3.02059663e+01,
#           2.82565298e+01,  2.64883656e+01,  2.48782818e+01,
#           2.34068191e+01,  2.20575350e+01,  2.08164463e+01,
#           1.96715907e+01,  1.86126791e+01,  1.76308158e+01,
#           1.67182741e+01,  1.58683126e+01,  1.50750256e+01,
#           1.43332191e+01,  1.36383086e+01,  1.29862334e+01,
#           1.23733851e+01,  1.17965473e+01,  1.12528444e+01,
#           1.07396984e+01,  1.02547920e+01,  9.79603658e+00,
#           9.36154513e+00,  8.94960883e+00,  8.55867659e+00,
#           8.18733745e+00,  7.83430517e+00,  7.49840483e+00,
#           7.17856106e+00,  6.87378772e+00,  6.58317882e+00,
#           6.30590050e+00,  6.04118393e+00,  5.78831907e+00,
#           5.54664906e+00,  5.31556526e+00,  5.09450284e+00,
#           4.88293682e+00,  4.68037852e+00,  4.48637242e+00,
#           4.30049327e+00,  4.12234356e+00,  3.95155120e+00,
#           3.78776745e+00,  3.63066501e+00,  3.47993633e+00,
#           3.33529209e+00,  3.19645976e+00,  3.06318234e+00,
#           2.93521722e+00,  2.81233510e+00,  2.69431904e+00,
#           2.58096360e+00,  2.47207398e+00,  2.36746536e+00,
#           1.66294439e-11,  1.48823503e-11,  1.31980660e-11,
#           1.15757576e-11,  1.00146559e-11,  8.51381857e-12,
#           7.07265927e-12,  5.68918038e-12,  4.36385047e-12,
#           3.09510042e-12,  1.88094668e-12,  7.20927590e-13,
#          -3.86144567e-13, -1.44149451e-12, -2.44640377e-12,
#          -3.40267524e-12, -4.31099118e-12, -5.17281849e-12,
#          -5.98939638e-12, -6.76252912e-12, -7.49304507e-12,
#          -8.18312131e-12, -8.83307902e-12, -9.44523771e-12,
#          -1.00204257e-11, -1.05601235e-11, -1.10655781e-11,
#          -1.15388298e-11, -1.19800645e-11, -1.23909511e-11,
#          -1.27737834e-11, -1.31289432e-11, -1.34577206e-11,
#          -1.37622678e-11, -1.40423925e-11, -1.43007089e-11,
#          -1.45372479e-11, -1.47540987e-11, -1.49515847e-11,
#          -1.51315354e-11, -1.52944879e-11, -1.54414946e-11,
#          -1.55742285e-11, -1.56928622e-11, -1.57988059e-11,
#          -1.58927036e-11, -1.59753499e-11, -1.60482224e-11,
#          -1.61115597e-11, -1.61661113e-11, -1.62129841e-11,
#          -1.62524819e-11, -1.62851594e-11, -1.63120022e-11,
#          -1.63332146e-11, -1.63495708e-11, -1.63614782e-11,
#          -1.63694120e-11, -1.63735436e-11, -1.63746379e-11,
#          -1.63725526e-11, -1.63680877e-11, -1.63607878e-11,
#          -1.63517297e-11, -1.63401400e-11, -1.63267777e-11,
#          -1.63112042e-11]]])

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
luke_r,luke_βV = 1e-10/aB/ri*luke_data['r [A]'], 1/(T/eV)*luke_data['V [eV]']
luke_r[165], luke_βV[165]
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_133669/1805172397.py in <module>
#       4
#       5 luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
# ----> 6 luke_r,luke_βV = 1e-10/aB/rs*luke_data['r [A]'], 1/(T/eV)*luke_data['V [eV]']
#       7 luke_r[165], luke_βV[165]
#       8 luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)
#
# NameError: name 'T' is not defined

# %%
fig, ax = plt.subplots(figsize=(10,6),facecolor='w')
fig.suptitle(r"$T=${0:.1f} eV, $r_i$={1:.2f}".format(T/eV,ri), fontsize=20)

ax.plot(luke_r, luke_βV,'k--', label="Luke Force Match")
ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0],'k-', label="Effective")
ax.plot(hnc2.r_array, hnc2.βu_r_matrix[0,0], label="Initial")
ax.plot(hnc2.r_array, βv_Yukawa(hnc2.r_array),label="Yukawa")
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
ax.set_ylim(-1,1e4)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=15)

# %% [markdown]
# # Check!

# %%
# N_species = 1
# Gamma = np.array(  [[1]])
# names = ["Ion Effective"] 
# kappa = 1
# rho = np.array([3/(4*np.pi)])
# hnc_check = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-3, kappa_multiscale=10,
#                        rho = rho, num_iterations=int(1e3), R_max=10, N_bins=1000, names=names)

# hnc_luke = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-3, kappa_multiscale=10,
#                        rho = rho, num_iterations=int(1e4), R_max=10, N_bins=1000, names=names)

# # check
# βu_r_matrix = np.nan_to_num( hnc2.βueff_r_matrix,nan = -np.log(1.e-16), posinf=-np.log(1e-16) ).copy()
# hnc_check.set_βu_matrix(βu_r_matrix)
# hnc_check.HNC_solve(alpha=1)

# # luke
# # βu_r_matrix[0,0]=luke_βV_function(hnc2.r_array)
# # hnc_luke.set_βu_matrix(βu_r_matrix)
# # hnc_luke.HNC_solve(alpha=1)

# %%
# np.savetxt("example_veff_1eV_rs_3aBohr.txt", np.array([hnc_check.r_array, hnc_check.βu_r_matrix[0,0]]).T,header="r/r_s,   beta v_ii^eff   (both unitless)",delimiter=', ' )

# %%
# hnc_check.plot_g_all_species()

# %%
# fig, ax = plt.subplots(figsize=(10,6))

# ax.plot(hnc2.r_array, hnc2.h_r_matrix[0,0]+1,'.', label="Two Actual Species")
# ax.plot(hnc_check.r_array, hnc_check.h_r_matrix[0,0]+1,'-', label="One Effective Species")
# ax.plot(hnc_luke.r_array, hnc_luke.h_r_matrix[0,0]+1,'-', label="Luke HNC with Force Matched V")
# ax.set_ylabel(r'$g(r/r_s)$',fontsize=20)
# ax.set_xlabel(r'$r/r_s$',fontsize=20)
# ax.set_ylim(-0.1,3)
# ax.set_xlim(0,5)
# ax.tick_params(labelsize=15)
# ax.legend(fontsize=15)

# %% [markdown]
# # Curve Fitting

# %%
from scipy.optimize import curve_fit

def yukawa_fit(r, Γ, κ,p):
    return  Γ/r*np.exp(-κ*r)

def yukawa_remaining_fit(r,a,b,c,d):
    return 1/(a+b*np.exp(c*(hnc2.r_array-d)))

def LJ_fit(r, a,b,m,n):
    return  1/(a*r**m + b/r**n) #+ v0

def yukawa_friedel_fit(r, Γ, κ1, a,κ2, k,  δ, v0):
    return  Γ/r*np.exp(-κ1*r) + a/r**3*np.exp(-κ2*r)*np.cos(k*r+δ) + v0

def yukawa_plus_fit(r, Γ, κ1, a,b,c):
    return  Γ/r*np.exp(-κ1*r)/(1+np.exp(b*(hnc2.r_array-c)))
# last_inf_index = int(np.argwhere(np.isinf(hnc2.βueff_r_matrix[0,0]))[-1] )

y_vals = curve_fit(yukawa_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0])
y_fit_data  = yukawa_fit(hnc2.r_array, y_vals[0][0],y_vals[0][1],y_vals[0][2])

y_remaining_vals = curve_fit(yukawa_remaining_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0]/y_fit_data)
y_remaining_fit_data  = yukawa_remaining_fit(hnc2.r_array, y_remaining_vals[0][0],y_remaining_vals[0][1],y_remaining_vals[0][2],y_remaining_vals[0][3])


# LJ_vals = curve_fit(LJ_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0],maxfev=int(1e5))
# yf_vals= curve_fit(yukawa_friedel_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0],maxfev=int(1e5))
# yp_vals= curve_fit(yukawa_plus_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0],maxfev=int(1e3))

# %%
y_vals[0], y_remaining_vals[0]

# %%
fig, ax = plt.subplots(figsize=(10,6))

g_data = hnc2.h_r_matrix[0,0] + 1

# LJ_fit_data  = LJ_fit(hnc2.r_array, LJ_vals[0][0],LJ_vals[0][1],LJ_vals[0][2],LJ_vals[0][3])
# yf_fit_data = yukawa_friedel_fit(hnc2.r_array, yf_vals[0][0],yf_vals[0][1],yf_vals[0][2],yf_vals[0][3],yf_vals[0][4],yf_vals[0][5],yf_vals[0][6])
yp_fit_data = yukawa_plus_fit(hnc2.r_array, yp_vals[0][0],yp_vals[0][1],yp_vals[0][2],yp_vals[0][3],yp_vals[0][4])


ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0],'k-', label="Effective")
# ax.plot(hnc2.r_array, y_fit_data*y_remaining_fit_data,'--', label="Yukawa Fit")
ax.plot(hnc2.r_array, 81.87504124/hnc2.r_array*np.exp(-0.99115223*hnc2.r_array)/(0.92620556+0.7351028*np.exp(1.72217623*(hnc2.r_array-1.75197859))),'--', label="Fit")
# ax.plot(hnc2.r_array[1:], hnc2.βueff_r_matrix[0,0][1:]-hnc2.βueff_r_matrix[0,0][:-1],'k-', label="Effective")
# ax.plot(hnc2.r_array[1:], (y_fit_data*y_remaining_fit_data)[1:]-(y_fit_data*y_remaining_fit_data)[:-1],'--', label="Yukawa Fit")

# ax.plot(hnc2.r_array, LJ_fit_data,'--', label="Yukawa Fit")
# ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0]-y_fit_data*y_remaining_fit_data,'.', label="Yukawa Fit Ratio")
 
# ax.plot(hnc2.r_array,y_remaining_fit_data,'.', label="Yukawa Remaining Fit")

# ax.plot(hnc2.r_array, yf_fit_data,'.', label="Yukawa-Friedel Fit")
# ax.plot(hnc2.r_array, yp_fit_data,'.', label="Yukawa-Plus Fit")
# ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0]/yp_fit_data,'.', label="Yukawa-Plus Fit Ratio")
# ax.plot(hnc2.r_array, 1/(1+np.exp(3*(hnc2.r_array-2.5))),'.', label="Yukawa-Friedel Fit")

ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
# ax.set_ylim(-2,2)
ax.set_yscale('symlog',linthresh=1e-1)
ax.set_xlim(0,10)
ax.tick_params(labelsize=15)
ax.legend(fontsize=15)

# %%
from scipy.interpolate import RBFInterpolator



RBFInterpolator(hnc2.r_array, hnc2.βueff_r_matrix[0,0]/y_fit_data)
