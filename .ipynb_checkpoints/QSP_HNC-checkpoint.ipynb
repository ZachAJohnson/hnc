# %%
import numpy as np
import matplotlib.pyplot as plt

from hnc_n_multiscale import  HNC_solver

# %% [markdown]
# # Two Species

# %% [markdown]
# Here we do QSP interactions between electrons and one ion type.
#
# Using $\tilde{r}\equiv r/r_s$, we implement potentials
# \begin{align}
# \beta v_{ee}(\tilde{r}) &=  \frac{\Gamma_{ee}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right) +  \ln2 \exp\left[-\tilde{r}^2 r_s^2/(\pi \Lambda_e^2 \ln 2)\right]\\
# \beta v_{ei}(\tilde{r}) &=  \frac{\Gamma_{ei}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right)\\
# \beta v_{ii}(\tilde{r}) &=  \frac{\Gamma_{ii}}{\tilde{r}}
# \end{align}
# For
# \begin{align}
# \Gamma_{ee}&=\frac{\beta e^2}{r_s}\\
# \Gamma_{ei}&=\frac{\beta Z_i e^2}{r_s}\\
# \Gamma_{ii}&=\frac{\beta Z_i^2 e^2}{r_s}\\
# \end{align}

# %% [markdown]
# Define physical constants

# %%
# k_B = 1.380649e-23  # Boltzmann constant [J/K]
# hbar=  6.62607015e-34 # Planck [J/s]
eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
Kelvin = 8.61732814974493e-5*eV #Similarly, 1 Kelvin = 3.167e-6... in natural units 
aB = 5.29177210903e-11 # Bohr radius in m

π = np.pi
# [AU]
ni = 5.01e23*1e6
# rs = (4/3*π*ni)**(-1/3)/aB
rs  = 3
T   = 1*eV 
Zstar=3#

ne = Zstar*(4/3*np.pi*rs**3)**(-1)
lambda_TF = np.sqrt( T / (4*np.pi*ne)  )

β   = 1/T
m_e = 1

Λe  = np.sqrt(  β*2*π /m_e )
Λe_star  = np.sqrt(  β*2*π /m_e )/rs
print("Λee = {0:.3f}".format(Λe_star))
Γee = β/rs 
Γei = -Zstar*β/rs 
Γii = Zstar**2*β/rs 
print("Γii={0:.1f}, Γie={1:.1f}, Γee={2:.1f} ".format(Γee, Γei, Γii))
print("r_s={0:.1f}".format(rs))

def βv_Yukawa(r):
    return Γii/r * np.exp(-r*rs/lambda_TF)
# Out:
# Λee = 4.358
# Γii=9.1, Γie=-27.2, Γee=81.6
# r_s=3.0

# %% [markdown]
# ##### Load MM Data

# %%
# from pandas import read_csv

# r_ie, gie = np.array(read_csv("~/plasma/MM_HNC/gie.out", delim_whitespace=True)).T
# r_ee, gee = np.array(read_csv("~/plasma/MM_HNC/gee.out", delim_whitespace=True)).T
# r_ii, gii = np.array(read_csv("~/plasma/MM_HNC/gii.out", delim_whitespace=True)).T

# data_to_compare = [gie,gee,gii]
# data_to_compare = ["~/plasma/MM_HNC/gie.out","~/plasma/MM_HNC/gee.out","~/plasma/MM_HNC/gii.out"]
# data_names=['MM ie', "MM ee", 'MM ii' ]

# %% [markdown]
# Plug into get potentials

# %%
from scipy.special import erfc

# Build Components for QSP's

def βv_Deutsch(Γ, r):
    return Γ/r*  np.exp(-2*π*r/Λe_star)

# Kelbg looks really weird??
def βv_Kelbg(Γ,r):
    return Γ/r*( 1 - np.exp(-2*π*r**2/Λe_star**2)+ np.sqrt(2)*π*r/Λe_star*erfc(np.sqrt(2*π)*r/Λe_star))

def βv_Pauli(r):
    return  np.log(2) * np.exp(-4*π* r**2 /( Λe_star**2))


######### Build Actual QSP's

def βvee(r):
    return βv_Kelbg(Γee,r) + βv_Pauli(r)

def βvei(r):
    return βv_Kelbg(Γei,r)

# def βvei_atomic(r):
#     r_c = 3/5 #3/5 r_s in linear n_b(r) model
#     return np.heaviside(r - r_c,0.5) * βvei(r)

def βvii(r):
    return Γii/r

# %% [markdown]
# First, we initialize the hnc

# %%
N_species = 2
Gamma = np.array(  [[Γii,  Γei],
                    [Γei,  Γee]])


# Gamma = np.array(  [[50,  10],
#                     [10,  10]])

names = ["Ion-1", "Electron", ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi) ])
hnc2 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-6,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1e3), 
                 R_max=10, N_bins=1000, names=names, dst_type=3)

# %%
βu_r_matrix = np.array([[βvii(hnc2.r_array), βvei(hnc2.r_array)],
                        [βvei(hnc2.r_array), βvee(hnc2.r_array)]])

hnc2.set_βu_matrix(βu_r_matrix)
hnc2.initialize_c_k()
hnc2.set_C_matrix()

# %%
hnc2.plot_βu_all_species()
# Out:
# /home/zach/plasma/hnc/hnc_n_multiscale.py:475: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set_xlim(0,10)

# %%
hnc2.HNC_solve(alpha=0.001, h_max=5e2)
# Out:
# 0: Err in c_r: 178.048
# 1: Err in c_r: 28.127
# 2: Err in c_r: 10.641
# 3: Err in c_r: 5.995
# 4: Err in c_r: 4.069
# 5: Err in c_r: 3.093
# 6: Err in c_r: 2.426
# 7: Err in c_r: 1.994
# 8: Err in c_r: 1.647
# 9: Err in c_r: 1.404
# 10: Err in c_r: 1.202
# 11: Err in c_r: 1.046
# 12: Err in c_r: 0.917
# 13: Err in c_r: 0.810
# 14: Err in c_r: 0.721
# 15: Err in c_r: 0.645
# 16: Err in c_r: 0.579
# 17: Err in c_r: 0.523
# 18: Err in c_r: 0.474
# 19: Err in c_r: 0.430
# 20: Err in c_r: 0.392
# 21: Err in c_r: 0.358
# 22: Err in c_r: 0.328
# 23: Err in c_r: 0.300
# 24: Err in c_r: 0.276
# 25: Err in c_r: 0.254
# 26: Err in c_r: 0.234
# 27: Err in c_r: 0.216
# 28: Err in c_r: 0.199
# 29: Err in c_r: 0.184
# 30: Err in c_r: 0.170
# 31: Err in c_r: 0.158
# 32: Err in c_r: 0.146
# 33: Err in c_r: 0.135
# 34: Err in c_r: 0.126
# 35: Err in c_r: 0.117
# 36: Err in c_r: 0.108
# 37: Err in c_r: 0.101
# 38: Err in c_r: 0.094
# 39: Err in c_r: 0.087
# 40: Err in c_r: 0.081
# 41: Err in c_r: 0.076
# 42: Err in c_r: 0.070
# 43: Err in c_r: 0.066
# 44: Err in c_r: 0.061
# 45: Err in c_r: 0.057
# 46: Err in c_r: 0.053
# 47: Err in c_r: 0.050
# 48: Err in c_r: 0.046
# 49: Err in c_r: 0.043
# 50: Err in c_r: 0.040
# 51: Err in c_r: 0.038
# 52: Err in c_r: 0.035
# 53: Err in c_r: 0.033
# 54: Err in c_r: 0.031
# 55: Err in c_r: 0.029
# 56: Err in c_r: 0.027
# 57: Err in c_r: 0.025
# 58: Err in c_r: 0.023
# 59: Err in c_r: 0.022
# 60: Err in c_r: 0.020
# 61: Err in c_r: 0.019
# 62: Err in c_r: 0.018
# 63: Err in c_r: 0.017
# 64: Err in c_r: 0.016
# 65: Err in c_r: 0.015
# 66: Err in c_r: 0.014
# 67: Err in c_r: 0.013
# 68: Err in c_r: 0.012
# 69: Err in c_r: 0.011
# 70: Err in c_r: 0.010
# 71: Err in c_r: 0.010
# 72: Err in c_r: 0.009
# 73: Err in c_r: 0.009
# 74: Err in c_r: 0.008
# 75: Err in c_r: 0.007
# 76: Err in c_r: 0.007
# 77: Err in c_r: 0.007
# 78: Err in c_r: 0.006
# 79: Err in c_r: 0.006
# 80: Err in c_r: 0.005
# 81: Err in c_r: 0.005
# 82: Err in c_r: 0.005
# 83: Err in c_r: 0.004
# 84: Err in c_r: 0.004
# 85: Err in c_r: 0.004
# 86: Err in c_r: 0.004
# 87: Err in c_r: 0.003
# 88: Err in c_r: 0.003
# 89: Err in c_r: 0.003
# 90: Err in c_r: 0.003
# 91: Err in c_r: 0.003
# 92: Err in c_r: 0.002
# 93: Err in c_r: 0.002
# 94: Err in c_r: 0.002
# 95: Err in c_r: 0.002
# 96: Err in c_r: 0.002
# 97: Err in c_r: 0.002
# 98: Err in c_r: 0.002
# 99: Err in c_r: 0.002
# 100: Err in c_r: 0.001
# 101: Err in c_r: 0.001
# 102: Err in c_r: 0.001
# 103: Err in c_r: 0.001
# 104: Err in c_r: 0.001
# 105: Err in c_r: 0.001
# 106: Err in c_r: 0.001
# 107: Err in c_r: 0.001
# 108: Err in c_r: 0.001
# 109: Err in c_r: 0.001
# 110: Err in c_r: 0.001
# 111: Err in c_r: 0.001
# 112: Err in c_r: 0.001
# 113: Err in c_r: 0.001
# 114: Err in c_r: 0.001
# 115: Err in c_r: 0.001
# 116: Err in c_r: 0.000
# 117: Err in c_r: 0.000
# 118: Err in c_r: 0.000
# 119: Err in c_r: 0.000
# 120: Err in c_r: 0.000
# 121: Err in c_r: 0.000
# 122: Err in c_r: 0.000
# 123: Err in c_r: 0.000
# 124: Err in c_r: 0.000
# 125: Err in c_r: 0.000
# 126: Err in c_r: 0.000
# 127: Err in c_r: 0.000
# 128: Err in c_r: 0.000
# 129: Err in c_r: 0.000
# 130: Err in c_r: 0.000
# 131: Err in c_r: 0.000
# 132: Err in c_r: 0.000
# 133: Err in c_r: 0.000
# 134: Err in c_r: 0.000
# 135: Err in c_r: 0.000
# 136: Err in c_r: 0.000
# 137: Err in c_r: 0.000
# 138: Err in c_r: 0.000
# 139: Err in c_r: 0.000
# 140: Err in c_r: 0.000
# 141: Err in c_r: 0.000
# 142: Err in c_r: 0.000
# 143: Err in c_r: 0.000
# 144: Err in c_r: 0.000
# 145: Err in c_r: 0.000
# 146: Err in c_r: 0.000
# 147: Err in c_r: 0.000
# 148: Err in c_r: 0.000
# 149: Err in c_r: 0.000
# 150: Err in c_r: 0.000
# 151: Err in c_r: 0.000
# 152: Err in c_r: 0.000
# 153: Err in c_r: 0.000
# 154: Err in c_r: 0.000
# 155: Err in c_r: 0.000
# 156: Err in c_r: 0.000
# 157: Err in c_r: 0.000
# 158: Err in c_r: 0.000
# 159: Err in c_r: 0.000
# 160: Err in c_r: 0.000
# 161: Err in c_r: 0.000
# 162: Err in c_r: 0.000
# 163: Err in c_r: 0.000
# 164: Err in c_r: 0.000
# 165: Err in c_r: 0.000
# 166: Err in c_r: 0.000
# 167: Err in c_r: 0.000
# 168: Err in c_r: 0.000
# 169: Err in c_r: 0.000
# 170: Err in c_r: 0.000
# 171: Err in c_r: 0.000
# 172: Err in c_r: 0.000
# 173: Err in c_r: 0.000
# 174: Err in c_r: 0.000
# 175: Err in c_r: 0.000
# 176: Err in c_r: 0.000
# 177: Err in c_r: 0.000
# 178: Err in c_r: 0.000
# 179: Err in c_r: 0.000
# 180: Err in c_r: 0.000
# 181: Err in c_r: 0.000
# 182: Err in c_r: 0.000
# 183: Err in c_r: 0.000
# 184: Err in c_r: 0.000
# 185: Err in c_r: 0.000
# 186: Err in c_r: 0.000
# 187: Err in c_r: 0.000
# 188: Err in c_r: 0.000
# 189: Err in c_r: 0.000
# 190: Err in c_r: 0.000
# 191: Err in c_r: 0.000
# 192: Err in c_r: 0.000
# 193: Err in c_r: 0.000
# 194: Err in c_r: 0.000
# 195: Err in c_r: 0.000
# 196: Err in c_r: 0.000
# 197: Err in c_r: 0.000
# 198: Err in c_r: 0.000
# 199: Err in c_r: 0.000
# 200: Err in c_r: 0.000
# 201: Err in c_r: 0.000
# 202: Err in c_r: 0.000
# 203: Err in c_r: 0.000
# 204: Err in c_r: 0.000
# 205: Err in c_r: 0.000
# 206: Err in c_r: 0.000
# 207: Err in c_r: 0.000
# 208: Err in c_r: 0.000
# 209: Err in c_r: 0.000
# 210: Err in c_r: 0.000

# %%
hnc2.plot_g_all_species()
hnc2.plot_g_all_species(data_to_compare=['/home/zach/plasma/atomic_forces/data/RDF/Al_1.0eV_rs3_KS-MD.txt'], data_names=['KS MD'], gmax=3)
hnc2.plot_species((1,1))

# %% [markdown]
# # Effective Potentials

# %%
hnc2.invert_HNC(1)
# Out:
# /home/zach/plasma/hnc/hnc_n_multiscale.py:345: RuntimeWarning: divide by zero encountered in log
#   self.βueff_r_matrix[ieff,jeff]   = self.heff_r_matrix[ieff,jeff] - self.ceff_r_matrix[ieff,jeff] - np.log(1+self.heff_r_matrix[ieff,jeff]) #  h_r, c_r -> βu_r

# %%
fig, ax = plt.subplots()

ax.plot(hnc2.r_array, 1+hnc2.heff_r_matrix[0,0],label= 'h')
ax.plot(hnc2.r_array, hnc2.ceff_r_matrix[0,0],label='c')
ax.plot(hnc2.r_array,np.log(1+hnc2.heff_r_matrix)[0,0],label='log(1+h)')
ax.set_yscale('symlog',linthresh=1e-5)
ax.set_xlim(1e-1,2)
# ax.set_xscale('log')
ax.legend()
# Out:
# /tmp/ipykernel_27165/3332355128.py:5: RuntimeWarning: divide by zero encountered in log
#   ax.plot(hnc2.r_array,np.log(1+hnc2.heff_r_matrix)[0,0],label='log(1+h)')

# %%
(T/eV)
# Out:
# 1.0

# %%
2.180719*1e-10/aB/rs
# Out:
# 1.3736538882559282

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
luke_r,luke_βV = 1e-10/aB/rs*luke_data['r [A]'], 1/(T/eV)*luke_data['V [eV]']
luke_r[165], luke_βV[165]
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)

# %%
fig, ax = plt.subplots(figsize=(10,6),facecolor='w')
fig.suptitle(r"$T=${0:.1f} eV, $r_s$={1:.2f}".format(T/eV,rs), fontsize=20)

ax.plot(luke_r, luke_βV,'k--', label="Luke Force Match")
ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0],'k-', label="Effective")
ax.plot(hnc2.r_array, hnc2.βu_r_matrix[0,0], label="Initial")
ax.plot(hnc2.r_array, βv_Yukawa(hnc2.r_array),label="Yukawa")
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
ax.set_ylim(-1,1e2)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=15)

# %% [markdown]
# # Check!

# %%
# N_species = 1
# Gamma = np.array(  [[1]])
# names = ["Ion Effective"] 
# kappa = 1
# rho = np.array([3/(4*np.pi)])
# hnc_check = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-3, kappa_multiscale=10,
#                        rho = rho, num_iterations=int(1e3), R_max=10, N_bins=1000, names=names)

# hnc_luke = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-3, kappa_multiscale=10,
#                        rho = rho, num_iterations=int(1e4), R_max=10, N_bins=1000, names=names)

# # check
# βu_r_matrix = np.nan_to_num( hnc2.βueff_r_matrix,nan = -np.log(1.e-16), posinf=-np.log(1e-16) ).copy()
# hnc_check.set_βu_matrix(βu_r_matrix)
# hnc_check.HNC_solve(alpha=1)

# # luke
# # βu_r_matrix[0,0]=luke_βV_function(hnc2.r_array)
# # hnc_luke.set_βu_matrix(βu_r_matrix)
# # hnc_luke.HNC_solve(alpha=1)

# %%
# np.savetxt("example_veff_1eV_rs_3aBohr.txt", np.array([hnc_check.r_array, hnc_check.βu_r_matrix[0,0]]).T,header="r/r_s,   beta v_ii^eff   (both unitless)",delimiter=', ' )

# %%
# hnc_check.plot_g_all_species()

# %%
# fig, ax = plt.subplots(figsize=(10,6))

# ax.plot(hnc2.r_array, hnc2.h_r_matrix[0,0]+1,'.', label="Two Actual Species")
# ax.plot(hnc_check.r_array, hnc_check.h_r_matrix[0,0]+1,'-', label="One Effective Species")
# ax.plot(hnc_luke.r_array, hnc_luke.h_r_matrix[0,0]+1,'-', label="Luke HNC with Force Matched V")
# ax.set_ylabel(r'$g(r/r_s)$',fontsize=20)
# ax.set_xlabel(r'$r/r_s$',fontsize=20)
# ax.set_ylim(-0.1,3)
# ax.set_xlim(0,5)
# ax.tick_params(labelsize=15)
# ax.legend(fontsize=15)

# %% [markdown]
# # Curve Fitting

# %%
int(np.argwhere(np.isinf(hnc2.βueff_r_matrix[0,0]))[-1] )
# Out:
# 64

# %%
from scipy.optimize import curve_fit

def yukawa_fit(r, Γ, κ,p):
    return  Γ/r*np.exp(-κ*r)

def LJ_fit(r, a,b,m,n):
    return  1/(a*r**m + b/r**n)

def yukawa_friedel_fit(r, Γ, κ1, a,κ2, k,  δ,p ):
    return  Γ/r*np.exp(-κ1*r) + a/r**p*np.exp(-κ2*r)*np.cos(k*r+δ)

last_inf_index = int(np.argwhere(np.isinf(hnc2.βueff_r_matrix[0,0]))[-1] )

y_vals = curve_fit(yukawa_fit, hnc2.r_array[last_inf_index+1:], hnc2.βueff_r_matrix[0,0][last_inf_index+1:])
LJ_vals = curve_fit(LJ_fit, hnc2.r_array[last_inf_index+1:], hnc2.βueff_r_matrix[0,0][last_inf_index+1:])
yf_vals= curve_fit(yukawa_friedel_fit, hnc2.r_array[last_inf_index+1:], hnc2.βueff_r_matrix[0,0][last_inf_index+1:])
# Out:
# /home/zach/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py:906: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_27165/862545280.py in <module>
#      14 y_vals = curve_fit(yukawa_fit, hnc2.r_array[last_inf_index+1:], hnc2.βueff_r_matrix[0,0][last_inf_index+1:])
#      15 LJ_vals = curve_fit(LJ_fit, hnc2.r_array[last_inf_index+1:], hnc2.βueff_r_matrix[0,0][last_inf_index+1:])
# ---> 16 yf_vals= curve_fit(yukawa_friedel_fit, hnc2.r_array[last_inf_index+1:], hnc2.βueff_r_matrix[0,0][last_inf_index+1:])
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     862         cost = np.sum(infodict['fvec'] ** 2)
#     863         if ier not in [1, 2, 3, 4]:
# --> 864             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     865     else:
#     866         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 1600.

# %%
LJ_vals[0]

# %%
fig, ax = plt.subplots(figsize=(10,6))

g_data = hnc2.h_r_matrix[0,0] + 1

y_fit_data  = yukawa_fit(hnc2.r_array, y_vals[0][0],y_vals[0][1],y_vals[0][2])
LJ_fit_data  = LJ_fit(hnc2.r_array, LJ_vals[0][0],LJ_vals[0][1],LJ_vals[0][2],LJ_vals[0][3])
yf_fit_data = yukawa_friedel_fit(hnc2.r_array, yf_vals[0][0],yf_vals[0][1],yf_vals[0][2],yf_vals[0][3],yf_vals[0][4],yf_vals[0][5],yf_vals[0][6])


ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0],'k-', label="Effective")
ax.plot(hnc2.r_array, y_fit_data,'--', label="LJ Fit")
ax.plot(hnc2.r_array, LJ_fit_data,'--', label="Yukawa Fit")
# ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0]/y_fit,'.', label="Yukawa Fit")

ax.plot(hnc2.r_array, yf_fit,'.', label="Yukawa-Friedel Fit")

ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
# ax.set_ylim(-2,3)
ax.set_yscale('symlog',linthresh=1e-2)
ax.set_xlim(0,10)
ax.tick_params(labelsize=15)
ax.legend(fontsize=15)
