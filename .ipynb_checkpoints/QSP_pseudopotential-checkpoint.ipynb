# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from hnc_pseudopotential import  HNC_solver

# %% [markdown]
# # Two Species

# %% [markdown]
# Here we do QSP interactions between electrons and one ion type.
#
# Using $\tilde{r}\equiv r/r_s$, we implement potentials
# \begin{align}
# \beta v_{ee}(\tilde{r}) &=  \frac{\Gamma_{ee}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right) +  \ln2 \exp\left[-\tilde{r}^2 r_s^2/(\pi \Lambda_e^2 \ln 2)\right]\\
# \beta v_{ei}(\tilde{r}) &=  \frac{\Gamma_{ei}}{\tilde{r}}\left( 1- \exp[-\tilde{r} r_s/\Lambda_e]\right)\\
# \beta v_{ii}(\tilde{r}) &=  \frac{\Gamma_{ii}}{\tilde{r}}
# \end{align}
# For
# \begin{align}
# \Gamma_{ee}&=\frac{\beta e^2}{r_s}\\
# \Gamma_{ei}&=\frac{\beta Z_i e^2}{r_s}\\
# \Gamma_{ii}&=\frac{\beta Z_i^2 e^2}{r_s}\\
# \end{align}

# %% [markdown]
# Define physical constants

# %% [markdown]
# # Check ALL Tei stuff

# %%
m_e = 1
m_p = 1833.274
eV = 0.0367512 # So 4 eV = 4 * 0.036.. in natural units
Kelvin = 8.61732814974493e-5*eV #Similarly, 1 Kelvin = 3.167e-6... in natural units 
aB = 5.29177210903e-11 # Bohr radius in m

π = np.pi
# [AU]
# ni = 6e20*1e6*aB**3
# ri = (4/3*π*ni)**(-1/3)

ri=3
ni = (4/3*π*ri**3)**-1

Te   = 1*eV 
Ti   = 1*eV 

βe   = 1/Te
βi   = 1/Ti

Zstar = 4#

Z, A = 13, 27
m_i = m_p*A
μ_ei = m_i*m_e/(m_e+m_i) #reduced mass
Tie = μ_ei * (Te/m_e + Ti/m_i) #thermal velocity defined Tei
βie = 1/Tie

ne = Zstar*ni
re = (4/3*π*ne)**(-1/3)

E_F = 1/(2*m_e) * (3*π**2 * ne)**(2/3)
v_F = np.sqrt(2*E_F/m_e)
θ   = Te/E_F

lambda_TF = np.sqrt( Te / (4*np.pi*ne)  )

Λe   = np.sqrt(  βe*2*π /m_e )
Λeff = np.sqrt(6*π) / np.sqrt( 3*Te/m_e + 0.6*v_F**2)/m_e

Λe_star  = Λeff/ri
print("Λee = {0:.3f}".format(Λe_star))
Γee = βe/ri 
Γei = -Zstar*βie/ri
Γii = Zstar**2*βi/ri 


print("Γii={0:.1f}, Γie={1:.1f}, Γee={2:.1f} ".format(Γii, Γei, Γee))
print("r_i={0:.1f}".format(ri))
print("r_e={0:.1f}".format(re))
print("θ  ={0:.2e}".format(θ))

def βv_Yukawa(r):
    return Γii/r * np.exp(-r*ri/lambda_TF)
# Out:
# Λee = 1.695
# Γii=145.1, Γie=-36.3, Γee=9.1
# r_i=3.0
# r_e=1.9
# θ  =7.13e-02

# %% [markdown]
# Plug into get potentials

# %%
from scipy.special import erfc

# Build Components for QSP's

def βv_Deutsch(Γ, r):
    return Γ/r* ( 1 -  np.exp(-np.sqrt(2)*π*r/Λe_star) )

# Kelbg looks really weird??
def βv_Kelbg(Γ,r):
    return Γ/r*( 1 - np.exp(-2*π*r**2/Λe_star**2)+ np.sqrt(2)*π*r/Λe_star*erfc(np.sqrt(2*π)*r/Λe_star))

def βv_Pauli(r):
    return  np.log(2) * np.exp(-4*π* r**2 /( Λe_star**2))


######### Build Actual QSP's

def βvee(r):
    return βv_Kelbg(Γee,r) + βv_Pauli(r)

def βvei(r):
    return βv_Kelbg(Γei,r)

# def βvei_atomic(r):
#     r_c = 3/5 #3/5 r_s in linear n_b(r) model
#     return np.heaviside(r - r_c,0.5) * βvei(r)

def βvii(r):
    return Γii/r 

fig, ax = plt.subplots(figsize=(8,6),facecolor='w')

xs = np.geomspace(1e-2,10)
ax.plot(βv_Deutsch(1,xs),label='Deutsch')
ax.plot(βv_Kelbg(1,xs),label='Kelbg')
ax.plot(βv_Pauli(xs),label='Pauli')
ax.set_yscale('log')
ax.set_ylim(1e-1,1e2)
ax.legend()

# %% [markdown]
# First, we initialize the hnc

# %%
from scipy.interpolate import interp1d
N_species = 3
Gamma = np.array(  [[Γii,  Γei, Γee],
                    [Γei,  Γee, Γee],
                    [Γee,  Γee, Γee]])


N_bins = 1000

names = ["Ion", "Free electrons", "Bound electrons" ] 
kappa = 1
rho = np.array([  3/(4*np.pi), Zstar*3/(4*np.pi), (Z - Zstar)*3/(4*np.pi) ])
hnc2 = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-6,
                 kappa_multiscale=1, rho = rho, num_iterations=int(1000), 
                 R_max=10, N_bins=N_bins, names=names, dst_type=3,
                 fixed_h_species=[(0,2),(2,0)])

### add fixed h/g
hnc2.fixed_h_r_matrix = np.zeros((N_species,  N_species, N_bins))

file="/home/zach/plasma/atomic_forces/average_atom/data/Al_NPA_TFD_R3.0e+01_rs3.0e+00_T1.0e+00eV_Zstar4.7.dat"
AA_data = pd.read_csv(file, header=2, delim_whitespace=True)
r_AA = AA_data['r[AU]']/ri
nf_AA = AA_data['nf[AU]']*ri**3
nb_AA = AA_data['nb[AU]']*ri**3
hnc2.fixed_h_r_matrix[0,2] = interp1d(r_AA, nb_AA)(hnc2.r_array)
hnc2.fixed_h_r_matrix[2,0] = hnc2.fixed_h_r_matrix[0,2]

# %%
βu_r_matrix = np.array([[βvii(hnc2.r_array), βvei(hnc2.r_array), βvee(hnc2.r_array)],
                        [βvei(hnc2.r_array), βvee(hnc2.r_array), βvee(hnc2.r_array)],
                        [βvee(hnc2.r_array), βvee(hnc2.r_array), βvee(hnc2.r_array)]])

hnc2.set_βu_matrix(βu_r_matrix)
hnc2.initialize_c_k()
hnc2.set_C_matrix()

# %%
hnc2.plot_βu_all_species()
# Out:
# /home/zach/plasma/hnc/hnc_n_multiscale.py:491: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   
# 104: Err in c_r: 3.897
# 105: Err in c_r: 3.841
# 106: Err in c_r: 3.786
# 107: Err in c_r: 3.732
# 108: Err in c_r: 3.679
# 109: Err in c_r: 3.628
# 110: Err in c_r: 3.578
# 111: Err in c_r: 3.529
# 112: Err in c_r: 3.481
# 113: Err in c_r: 3.435
# 114: Err in c_r: 3.389
# 115: Err in c_r: 3.344
# 116: Err in c_r: 3.301
# 117: Err in c_r: 3.258
# 118: Err in c_r: 3.216
# 119: Err in c_r: 3.175
# 120: Err in c_r: 3.135
# 121: Err in c_r: 3.096
# 122: Err in c_r: 3.058
# 123: Err in c_r: 3.020
# 124: Err in c_r: 2.983
# 125: Err in c_r: 2.947
# 126: Err in c_r: 2.912
# 127: Err in c_r: 2.877
# 128: Err in c_r: 2.843
# 129: Err in c_r: 2.810
# 130: Err in c_r: 2.777
# 131: Err in c_r: 2.745
# 132: Err in c_r: 2.714
# 133: Err in c_r: 2.683
# 134: Err in c_r: 2.652
# 135: Err in c_r: 2.623
# 136: Err in c_r: 2.593
# 137: Err in c_r: 2.565
# 138: Err in c_r: 2.536
# 139: Err in c_r: 2.509
# 140: Err in c_r: 2.481
# 141: Err in c_r: 2.455
# 142: Err in c_r: 2.428
# 143: Err in c_r: 2.403
# 144: Err in c_r: 2.377
# 145: Err in c_r: 2.352
# 146: Err in c_r: 2.328
# 147: Err in c_r: 2.304
# 148: Err in c_r: 2.280
# 149: Err in c_r: 2.257
# 150: Err in c_r: 2.234
# 151: Err in c_r: 2.211
# 152: Err in c_r: 2.189
# 153: Err in c_r: 2.167
# 154: Err in c_r: 2.146
# 155: Err in c_r: 2.124
# 156: Err in c_r: 2.104
# 157: Err in c_r: 2.083
# 158: Err in c_r: 2.063
# 159: Err in c_r: 2.043
# 160: Err in c_r: 2.023
# 161: Err in c_r: 2.004
# 162: Err in c_r: 1.985
# 163: Err in c_r: 1.966
# 164: Err in c_r: 1.948
# 165: Err in c_r: 1.930
# 166: Err in c_r: 1.912
# 167: Err in c_r: 1.894
# 168: Err in c_r: 1.877
# 169: Err in c_r: 1.860
# 170: Err in c_r: 1.843
# 171: Err in c_r: 1.826
# 172: Err in c_r: 1.810
# 173: Err in c_r: 1.794
# 174: Err in c_r: 1.778
# 175: Err in c_r: 1.762
# 176: Err in c_r: 1.747
# 177: Err in c_r: 1.731
# 178: Err in c_r: 1.716
# 179: Err in c_r: 1.701
# 180: Err in c_r: 1.687
# 181: Err in c_r: 1.672
# 182: Err in c_r: 1.658
# 183: Err in c_r: 1.644
# 184: Err in c_r: 1.630
# 185: Err in c_r: 1.616
# 186: Err in c_r: 1.603
# 187: Err in c_r: 1.589
# 188: Err in c_r: 1.576
# 189: Err in c_r: 1.563
# 190: Err in c_r: 1.550
# 191: Err in c_r: 1.538
# 192: Err in c_r: 1.525
# 193: Err in c_r: 1.513
# 194: Err in c_r: 1.500
# 195: Err in c_r: 1.488
# 196: Err in c_r: 1.476
# 197: Err in c_r: 1.465
# 198: Err in c_r: 1.453
# 199: Err in c_r: 1.442
# 200: Err in c_r: 1.430
# 201: Err in c_r: 1.419
# 202: Err in c_r: 1.408
# 203: Err in c_r: 1.397
# 204: Err in c_r: 1.386
# 205: Err in c_r: 1.376
# 206: Err in c_r: 1.365
# 207: Err in c_r: 1.355
# 208: Err in c_r: 1.344
# 209: Err in c_r: 1.334
# 210: Err in c_r: 1.324
# 211: Err in c_r: 1.314
# 212: Err in c_r: 1.304
# 213: Err in c_r: 1.294
# 214: Err in c_r: 1.285
# 215: Err in c_r: 1.275
# 216: Err in c_r: 1.266
# 217: Err in c_r: 1.257
# 218: Err in c_r: 1.247
# 219: Err in c_r: 1.238
# 220: Err in c_r: 1.229
# 221: Err in c_r: 1.220
# 222: Err in c_r: 1.212
# 223: Err in c_r: 1.203
# 224: Err in c_r: 1.194
# 225: Err in c_r: 1.186
# 226: Err in c_r: 1.177
# 227: Err in c_r: 1.169
# 228: Err in c_r: 1.161
# 229: Err in c_r: 1.153
# 230: Err in c_r: 1.145
# 231: Err in c_r: 1.137
# 232: Err in c_r: 1.129
# 233: Err in c_r: 1.121
# 234: Err in c_r: 1.113
# 235: Err in c_r: 1.106
# 236: Err in c_r: 1.098
# 237: Err in c_r: 1.091
# 238: Err in c_r: 1.083
# 239: Err in c_r: 1.076
# 240: Err in c_r: 1.069
# 241: Err in c_r: 1.061
# 242: Err in c_r: 1.054
# 243: Err in c_r: 1.047
# 244: Err in c_r: 1.040
# 245: Err in c_r: 1.033
# 246: Err in c_r: 1.026
# 247: Err in c_r: 1.020
# 248: Err in c_r: 1.013
# 249: Err in c_r: 1.006
# 250: Err in c_r: 1.000
# 251: Err in c_r: 0.993
# 252: Err in c_r: 0.987
# 253: Err in c_r: 0.980
# 254: Err in c_r: 0.974
# 255: Err in c_r: 0.968
# 256: Err in c_r: 0.962
# 257: Err in c_r: 0.956
# 258: Err in c_r: 0.949
# 259: Err in c_r: 0.943
# 260: Err in c_r: 0.938
# 261: Err in c_r: 0.932
# 262: Err in c_r: 0.926
# 263: Err in c_r: 0.920
# 264: Err in c_r: 0.914
# 265: Err in c_r: 0.909
# 266: Err in c_r: 0.903
# 267: Err in c_r: 0.897
# 268: Err in c_r: 0.892
# 269: Err in c_r: 0.886
# 270: Err in c_r: 0.881
# 271: Err in c_r: 0.875
# 272: Err in c_r: 0.870
# 273: Err in c_r: 0.865
# 274: Err in c_r: 0.860
# 275: Err in c_r: 0.854
# 276: Err in c_r: 0.849
# 277: Err in c_r: 0.844
# 278: Err in c_r: 0.839
# 279: Err in c_r: 0.834
# 280: Err in c_r: 0.829
# 281: Err in c_r: 0.824
# 282: Err in c_r: 0.819
# 283: Err in c_r: 0.815
# 284: Err in c_r: 0.810
# 285: Err in c_r: 0.805
# 286: Err in c_r: 0.800
# 287: Err in c_r: 0.796
# 288: Err in c_r: 0.791
# 289: Err in c_r: 0.787
# 290: Err in c_r: 0.782
# 291: Err in c_r: 0.778
# 292: Err in c_r: 0.773
# 293: Err in c_r: 0.769
# 294: Err in c_r: 0.764
# 295: Err in c_r: 0.760
# 296: Err in c_r: 0.756
# 489: Err in c_r: 0.318
# 490: Err in c_r: 0.317
# 491: Err in c_r: 0.316
# 492: Err in c_r: 0.315
# 493: Err in c_r: 0.313
# 494: Err in c_r: 0.312
# 495: Err in c_r: 0.311
# 496: Err in c_r: 0.310
# 497: Err in c_r: 0.309
# 498: Err in c_r: 0.308
# 499: Err in c_r: 0.307
# 500: Err in c_r: 0.306
# 501: Err in c_r: 0.304
# 502: Err in c_r: 0.303
# 503: Err in c_r: 0.302
# 504: Err in c_r: 0.301
# 505: Err in c_r: 0.300
# 506: Err in c_r: 0.299
# 507: Err in c_r: 0.298
# 508: Err in c_r: 0.297
# 509: Err in c_r: 0.296
# 510: Err in c_r: 0.295
# 511: Err in c_r: 0.294
# 512: Err in c_r: 0.293
# 513: Err in c_r: 0.292
# 514: Err in c_r: 0.291
# 515: Err in c_r: 0.290
# 516: Err in c_r: 0.289
# 517: Err in c_r: 0.288
# 518: Err in c_r: 0.287
# 519: Err in c_r: 0.286
# 520: Err in c_r: 0.285
# 521: Err in c_r: 0.284
# 522: Err in c_r: 0.283
# 523: Err in c_r: 0.282
# 524: Err in c_r: 0.281
# 525: Err in c_r: 0.280
# 526: Err in c_r: 0.279
# 527: Err in c_r: 0.278
# 528: Err in c_r: 0.277
# 529: Err in c_r: 0.276
# 530: Err in c_r: 0.275
# 531: Err in c_r: 0.274
# 532: Err in c_r: 0.273
# 533: Err in c_r: 0.272
# 534: Err in c_r: 0.271
# 535: Err in c_r: 0.270
# 536: Err in c_r: 0.269
# 537: Err in c_r: 0.268
# 538: Err in c_r: 0.267
# 539: Err in c_r: 0.267
# 540: Err in c_r: 0.266
# 541: Err in c_r: 0.265
# 542: Err in c_r: 0.264
# 543: Err in c_r: 0.263
# 544: Err in c_r: 0.262
# 545: Err in c_r: 0.261
# 546: Err in c_r: 0.260
# 547: Err in c_r: 0.259
# 548: Err in c_r: 0.259
# 549: Err in c_r: 0.258
# 550: Err in c_r: 0.257
# 551: Err in c_r: 0.256
# 552: Err in c_r: 0.255
# 553: Err in c_r: 0.254
# 554: Err in c_r: 0.253
# 555: Err in c_r: 0.253
# 556: Err in c_r: 0.252
# 557: Err in c_r: 0.251
# 558: Err in c_r: 0.250
# 559: Err in c_r: 0.249
# 560: Err in c_r: 0.248
# 561: Err in c_r: 0.247
# 562: Err in c_r: 0.247
# 563: Err in c_r: 0.246
# 564: Err in c_r: 0.245
# 565: Err in c_r: 0.244
# 566: Err in c_r: 0.243
# 567: Err in c_r: 0.243
# 568: Err in c_r: 0.242
# 569: Err in c_r: 0.241
# 570: Err in c_r: 0.240
# 571: Err in c_r: 0.239
# 572: Err in c_r: 0.239
# 573: Err in c_r: 0.238
# 574: Err in c_r: 0.237
# 575: Err in c_r: 0.236
# 576: Err in c_r: 0.236
# 577: Err in c_r: 0.235
# 578: Err in c_r: 0.234
# 579: Err in c_r: 0.233
# 580: Err in c_r: 0.232
# 581: Err in c_r: 0.232
# 582: Err in c_r: 0.231
# 583: Err in c_r: 0.230
# 584: Err in c_r: 0.229
# 585: Err in c_r: 0.229
# 586: Err in c_r: 0.228
# 587: Err in c_r: 0.227
# 588: Err in c_r: 0.227
# 589: Err in c_r: 0.226
# 590: Err in c_r: 0.225
# 591: Err in c_r: 0.224
# 592: Err in c_r: 0.224
# 593: Err in c_r: 0.223
# 594: Err in c_r: 0.222
# 595: Err in c_r: 0.221
# 596: Err in c_r: 0.221
# 597: Err in c_r: 0.220
# 598: Err in c_r: 0.219
# 599: Err in c_r: 0.219
# 600: Err in c_r: 0.218
# 601: Err in c_r: 0.217
# 602: Err in c_r: 0.217
# 603: Err in c_r: 0.216
# 604: Err in c_r: 0.215
# 605: Err in c_r: 0.215
# 606: Err in c_r: 0.214
# 607: Err in c_r: 0.213
# 608: Err in c_r: 0.212
# 609: Err in c_r: 0.212
# 610: Err in c_r: 0.211
# 611: Err in c_r: 0.210
# 612: Err in c_r: 0.210
# 613: Err in c_r: 0.209
# 614: Err in c_r: 0.208
# 615: Err in c_r: 0.208
# 616: Err in c_r: 0.207
# 617: Err in c_r: 0.207
# 618: Err in c_r: 0.206
# 619: Err in c_r: 0.205
# 620: Err in c_r: 0.205
# 621: Err in c_r: 0.204
# 622: Err in c_r: 0.203
# 623: Err in c_r: 0.203
# 624: Err in c_r: 0.202
# 625: Err in c_r: 0.201
# 626: Err in c_r: 0.201
# 627: Err in c_r: 0.200
# 628: Err in c_r: 0.200
# 629: Err in c_r: 0.199
# 630: Err in c_r: 0.198
# 631: Err in c_r: 0.198
# 632: Err in c_r: 0.197
# 633: Err in c_r: 0.196
# 634: Err in c_r: 0.196
# 635: Err in c_r: 0.195
# 636: Err in c_r: 0.195
# 637: Err in c_r: 0.194
# 638: Err in c_r: 0.193
# 639: Err in c_r: 0.193
# 640: Err in c_r: 0.192
# 641: Err in c_r: 0.192
# 642: Err in c_r: 0.191
# 643: Err in c_r: 0.190
# 644: Err in c_r: 0.190
# 645: Err in c_r: 0.189
# 646: Err in c_r: 0.189
# 647: Err in c_r: 0.188
# 648: Err in c_r: 0.188
# 649: Err in c_r: 0.187
# 650: Err in c_r: 0.186
# 651: Err in c_r: 0.186
# 652: Err in c_r: 0.185
# 653: Err in c_r: 0.185
# 654: Err in c_r: 0.184
# 655: Err in c_r: 0.184
# 656: Err in c_r: 0.183
# 657: Err in c_r: 0.183
# 658: Err in c_r: 0.182
# 659: Err in c_r: 0.181
# 660: Err in c_r: 0.181
# 661: Err in c_r: 0.180
# 662: Err in c_r: 0.180
# 663: Err in c_r: 0.179
# 664: Err in c_r: 0.179
# 665: Err in c_r: 0.178
# 666: Err in c_r: 0.178
# 667: Err in c_r: 0.177
# 668: Err in c_r: 0.177
# 669: Err in c_r: 0.176
# 670: Err in c_r: 0.175
# 671: Err in c_r: 0.175
# 672: Err in c_r: 0.174
# 673: Err in c_r: 0.174
# 674: Err in c_r: 0.173
# 675: Err in c_r: 0.173
# 676: Err in c_r: 0.172
# 677: Err in c_r: 0.172
# 678: Err in c_r: 0.171
# 679: Err in c_r: 0.171
# 680: Err in c_r: 0.170
# 681: Err in c_r: 0.170
# 682: Err in c_r: 0.169
# 683: Err in c_r: 0.169
# 684: Err in c_r: 0.168
# 685: Err in c_r: 0.168
# 686: Err in c_r: 0.167
# 687: Err in c_r: 0.167
# 688: Err in c_r: 0.166
# 689: Err in c_r: 0.166
# 690: Err in c_r: 0.165
# 691: Err in c_r: 0.165
# 692: Err in c_r: 0.164
# 693: Err in c_r: 0.164
# 694: Err in c_r: 0.163
# 695: Err in c_r: 0.163
# 696: Err in c_r: 0.162
# 697: Err in c_r: 0.162
# 698: Err in c_r: 0.161
# 699: Err in c_r: 0.161
# 700: Err in c_r: 0.161
# 701: Err in c_r: 0.160
# 702: Err in c_r: 0.160
# 703: Err in c_r: 0.159
# 704: Err in c_r: 0.159
# 705: Err in c_r: 0.158
# 706: Err in c_r: 0.158
# 707: Err in c_r: 0.157
# 708: Err in c_r: 0.157
# 709: Err in c_r: 0.156
# 710: Err in c_r: 0.156
# 711: Err in c_r: 0.155
# 712: Err in c_r: 0.155
# 713: Err in c_r: 0.155
# 714: Err in c_r: 0.154
# 715: Err in c_r: 0.154
# 716: Err in c_r: 0.153
# 717: Err in c_r: 0.153
# 718: Err in c_r: 0.152
# 719: Err in c_r: 0.152
# 720: Err in c_r: 0.151
# 721: Err in c_r: 0.151
# 722: Err in c_r: 0.151
# 723: Err in c_r: 0.150
# 724: Err in c_r: 0.150
# 725: Err in c_r: 0.149
# 726: Err in c_r: 0.149
# 727: Err in c_r: 0.148
# 728: Err in c_r: 0.148
# 729: Err in c_r: 0.148
# 730: Err in c_r: 0.147
# 731: Err in c_r: 0.147
# 732: Err in c_r: 0.146
# 733: Err in c_r: 0.146
# 734: Err in c_r: 0.145
# 735: Err in c_r: 0.145
# 736: Err in c_r: 0.145
# 737: Err in c_r: 0.144
# 738: Err in c_r: 0.144
# 739: Err in c_r: 0.143
# 740: Err in c_r: 0.143
# 741: Err in c_r: 0.143
# 742: Err in c_r: 0.142
# 743: Err in c_r: 0.142
# 744: Err in c_r: 0.141
# 745: Err in c_r: 0.141
# 746: Err in c_r: 0.141
# 747: Err in c_r: 0.140
# 748: Err in c_r: 0.140
# 749: Err in c_r: 0.139
# 750: Err in c_r: 0.139
# 751: Err in c_r: 0.139
# 752: Err in c_r: 0.138
# 753: Err in c_r: 0.138
# 754: Err in c_r: 0.137
# 755: Err in c_r: 0.137
# 756: Err in c_r: 0.137
# 757: Err in c_r: 0.136
# 758: Err in c_r: 0.136
# 759: Err in c_r: 0.135
# 760: Err in c_r: 0.135
# 761: Err in c_r: 0.135
# 762: Err in c_r: 0.134
# 763: Err in c_r: 0.134
# 764: Err in c_r: 0.134
# 765: Err in c_r: 0.133
# 766: Err in c_r: 0.133
# 767: Err in c_r: 0.132
# 768: Err in c_r: 0.132
# 769: Err in c_r: 0.132
# 770: Err in c_r: 0.131
# 771: Err in c_r: 0.131
# 772: Err in c_r: 0.131
# 773: Err in c_r: 0.130
# 774: Err in c_r: 0.130
# 775: Err in c_r: 0.129
# 776: Err in c_r: 0.129
# 777: Err in c_r: 0.129
# 778: Err in c_r: 0.128
# 779: Err in c_r: 0.128
# 780: Err in c_r: 0.128
# 781: Err in c_r: 0.127
# 782: Err in c_r: 0.127
# 783: Err in c_r: 0.127
# 784: Err in c_r: 0.126
# 785: Err in c_r: 0.126
# 786: Err in c_r: 0.126
# 787: Err in c_r: 0.125
# 788: Err in c_r: 0.125
# 789: Err in c_r: 0.125
# 790: Err in c_r: 0.124
# 791: Err in c_r: 0.124
# 792: Err in c_r: 0.123
# 793: Err in c_r: 0.123
# 794: Err in c_r: 0.123
# 795: Err in c_r: 0.122
# 796: Err in c_r: 0.122
# 797: Err in c_r: 0.122
# 798: Err in c_r: 0.121
# 799: Err in c_r: 0.121
# 800: Err in c_r: 0.121
# 801: Err in c_r: 0.120
# 802: Err in c_r: 0.120
# 803: Err in c_r: 0.120
# 804: Err in c_r: 0.119
# 805: Err in c_r: 0.119
# 806: Err in c_r: 0.119
# 807: Err in c_r: 0.118
# 808: Err in c_r: 0.118
# 809: Err in c_r: 0.118
# 810: Err in c_r: 0.118
# 811: Err in c_r: 0.117
# 812: Err in c_r: 0.117
# 813: Err in c_r: 0.117
# 814: Err in c_r: 0.116
# 815: Err in c_r: 0.116
# 816: Err in c_r: 0.116
# 817: Err in c_r: 0.115
# 818: Err in c_r: 0.115
# 819: Err in c_r: 0.115
# 820: Err in c_r: 0.114
# 821: Err in c_r: 0.114
# 822: Err in c_r: 0.114
# 823: Err in c_r: 0.113
# 824: Err in c_r: 0.113
# 825: Err in c_r: 0.113
# 826: Err in c_r: 0.112
# 827: Err in c_r: 0.112
# 828: Err in c_r: 0.112
# 829: Err in c_r: 0.112
# 830: Err in c_r: 0.111
# 831: Err in c_r: 0.111
# 832: Err in c_r: 0.111
# 833: Err in c_r: 0.110
# 834: Err in c_r: 0.110
# 835: Err in c_r: 0.110
# 836: Err in c_r: 0.109
# 837: Err in c_r: 0.109
# 838: Err in c_r: 0.109
# 839: Err in c_r: 0.109
# 840: Err in c_r: 0.108
# 841: Err in c_r: 0.108
# 842: Err in c_r: 0.108
# 843: Err in c_r: 0.107
# 844: Err in c_r: 0.107
# 845: Err in c_r: 0.107
# 846: Err in c_r: 0.107
# 847: Err in c_r: 0.106
# 848: Err in c_r: 0.106
# 849: Err in c_r: 0.106
# 850: Err in c_r: 0.105
# 851: Err in c_r: 0.105
# 852: Err in c_r: 0.105
# 853: Err in c_r: 0.105
# 854: Err in c_r: 0.104
# 855: Err in c_r: 0.104
# 856: Err in c_r: 0.104
# 857: Err in c_r: 0.103
# 858: Err in c_r: 0.103
# 859: Err in c_r: 0.103
# 860: Err in c_r: 0.103
# 861: Err in c_r: 0.102
# 862: Err in c_r: 0.102
# 863: Err in c_r: 0.102
# 864: Err in c_r: 0.102
# 865: Err in c_r: 0.101
# 866: Err in c_r: 0.101
# 867: Err in c_r: 0.101
# 868: Err in c_r: 0.100
# 869: Err in c_r: 0.100
# 870: Err in c_r: 0.100
# 871: Err in c_r: 0.100
# 872: Err in c_r: 0.099
# 873: Err in c_r: 0.099
# 874: Err in c_r: 0.099
# 875: Err in c_r: 0.099
# 876: Err in c_r: 0.098
# 877: Err in c_r: 0.098
# 878: Err in c_r: 0.098
# 879: Err in c_r: 0.098
# 880: Err in c_r: 0.097
# 881: Err in c_r: 0.097
# 882: Err in c_r: 0.097
# 883: Err in c_r: 0.097
# 884: Err in c_r: 0.096
# 885: Err in c_r: 0.096
# 886: Err in c_r: 0.096
# 887: Err in c_r: 0.096
# 888: Err in c_r: 0.095
# 889: Err in c_r: 0.095
# 890: Err in c_r: 0.095
# 891: Err in c_r: 0.095
# 892: Err in c_r: 0.094
# 893: Err in c_r: 0.094
# 894: Err in c_r: 0.094
# 895: Err in c_r: 0.094
# 896: Err in c_r: 0.093
# 897: Err in c_r: 0.093
# 898: Err in c_r: 0.093
# 899: Err in c_r: 0.093
# 900: Err in c_r: 0.092
# 901: Err in c_r: 0.092
# 902: Err in c_r: 0.092
# 903: Err in c_r: 0.092
# 904: Err in c_r: 0.091
# 905: Err in c_r: 0.091
# 906: Err in c_r: 0.091
# 907: Err in c_r: 0.091
# 908: Err in c_r: 0.090
# 909: Err in c_r: 0.090
# 910: Err in c_r: 0.090
# 911: Err in c_r: 0.090
# 912: Err in c_r: 0.089
# 913: Err in c_r: 0.089
# 914: Err in c_r: 0.089
# 915: Err in c_r: 0.089
# 916: Err in c_r: 0.089
# 917: Err in c_r: 0.088
# 918: Err in c_r: 0.088
# 919: Err in c_r: 0.088
# 920: Err in c_r: 0.088
# 921: Err in c_r: 0.087
# 922: Err in c_r: 0.087
# 923: Err in c_r: 0.087
# 924: Err in c_r: 0.087
# 925: Err in c_r: 0.086
# 926: Err in c_r: 0.086
# 927: Err in c_r: 0.086
# 928: Err in c_r: 0.086
# 929: Err in c_r: 0.086
# 930: Err in c_r: 0.085
# 931: Err in c_r: 0.085
# 932: Err in c_r: 0.085
# 933: Err in c_r: 0.085
# 934: Err in c_r: 0.084
# 935: Err in c_r: 0.084
# 936: Err in c_r: 0.084
# 937: Err in c_r: 0.084
# 938: Err in c_r: 0.084
# 939: Err in c_r: 0.083
# 940: Err in c_r: 0.083
# 941: Err in c_r: 0.083
# 942: Err in c_r: 0.083
# 943: Err in c_r: 0.083
# 944: Err in c_r: 0.082
# 945: Err in c_r: 0.082
# 946: Err in c_r: 0.082
# 947: Err in c_r: 0.082
# 948: Err in c_r: 0.081
# 949: Err in c_r: 0.081
# 950: Err in c_r: 0.081
# 951: Err in c_r: 0.081
# 952: Err in c_r: 0.081
# 953: Err in c_r: 0.080
# 954: Err in c_r: 0.080
# 955: Err in c_r: 0.080
# 956: Err in c_r: 0.080
# 957: Err in c_r: 0.080
# 958: Err in c_r: 0.079
# 959: Err in c_r: 0.079
# 960: Err in c_r: 0.079
# 961: Err in c_r: 0.079
# 962: Err in c_r: 0.079
# 963: Err in c_r: 0.078
# 964: Err in c_r: 0.078
# 965: Err in c_r: 0.078
# 966: Err in c_r: 0.078
# 967: Err in c_r: 0.078
# 968: Err in c_r: 0.077
# 969: Err in c_r: 0.077
# 970: Err in c_r: 0.077
# 971: Err in c_r: 0.077
# 972: Err in c_r: 0.077
# 973: Err in c_r: 0.076
# 974: Err in c_r: 0.076
# 975: Err in c_r: 0.076
# 976: Err in c_r: 0.076
# 977: Err in c_r: 0.076
# 978: Err in c_r: 0.075
# 979: Err in c_r: 0.075
# 980: Err in c_r: 0.075
# 981: Err in c_r: 0.075
# 982: Err in c_r: 0.075
# 983: Err in c_r: 0.075
# 984: Err in c_r: 0.074
# 985: Err in c_r: 0.074
# 986: Err in c_r: 0.074
# 987: Err in c_r: 0.074
# 988: Err in c_r: 0.074
# 989: Err in c_r: 0.073
# 990: Err in c_r: 0.073
# 991: Err in c_r: 0.073
# 992: Err in c_r: 0.073
# 993: Err in c_r: 0.073
# 994: Err in c_r: 0.072
# 995: Err in c_r: 0.072
# 996: Err in c_r: 0.072
# 997: Err in c_r: 0.072
# 998: Err in c_r: 0.072
# 999: Err in c_r: 0.072
# Warning: HNC_solver did not converge within the specified number of iterations.

# %%
hnc2.plot_species_convergence()

# %%
hnc2.plot_g_all_species()
hnc2.plot_g_all_species(gmax=3)#data_to_compare=['/home/zach/plasma/atomic_forces/data/RDF/Al_1.0eV_rs3_KS-MD.txt'], data_names=['KS MD'], gmax=3)
hnc2.plot_species((1,1))

# %%
asdas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_71978/2594026724.py in <module>
# ----> 1 asdas
#
# NameError: name 'asdas' is not defined

# %% [markdown]
# # Effective Potentials

# %%
hnc2.invert_HNC(1)

# %%
fig, ax = plt.subplots()

ax.plot(hnc2.r_array, 1+hnc2.heff_r_matrix[0,0],label= 'h')
ax.plot(hnc2.r_array, hnc2.ceff_r_matrix[0,0],label='c')
ax.plot(hnc2.r_array,np.log(1+hnc2.heff_r_matrix)[0,0],label='log(1+h)')
ax.set_yscale('symlog',linthresh=1e-5)
ax.set_xlim(1e-1,2)
# ax.set_xscale('log')
ax.legend()

# %%
hnc2.βωeff_r_matrix

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
luke_r,luke_βV = 1e-10/aB/ri*luke_data['r [A]'], 1/(T/eV)*luke_data['V [eV]']
luke_r[165], luke_βV[165]
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)

# %%
fig, ax = plt.subplots(figsize=(10,6),facecolor='w')
fig.suptitle(r"$T=${0:.1f} eV, $r_i$={1:.2f}".format(T/eV,ri), fontsize=20)

ax.plot(luke_r, luke_βV,'k--', label="Luke Force Match")
ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0],'k-', label="Effective")
ax.plot(hnc2.r_array, hnc2.βu_r_matrix[0,0], label="Initial")
ax.plot(hnc2.r_array, βv_Yukawa(hnc2.r_array),label="Yukawa")
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
ax.set_ylim(-1,1e4)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=15)

# %% [markdown]
# # Check!

# %%
# N_species = 1
# Gamma = np.array(  [[1]])
# names = ["Ion Effective"] 
# kappa = 1
# rho = np.array([3/(4*np.pi)])
# hnc_check = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-3, kappa_multiscale=10,
#                        rho = rho, num_iterations=int(1e3), R_max=10, N_bins=1000, names=names)

# hnc_luke = HNC_solver(N_species, Gamma=Gamma, kappa=kappa, tol=1e-3, kappa_multiscale=10,
#                        rho = rho, num_iterations=int(1e4), R_max=10, N_bins=1000, names=names)

# # check
# βu_r_matrix = np.nan_to_num( hnc2.βueff_r_matrix,nan = -np.log(1.e-16), posinf=-np.log(1e-16) ).copy()
# hnc_check.set_βu_matrix(βu_r_matrix)
# hnc_check.HNC_solve(alpha=1)

# # luke
# # βu_r_matrix[0,0]=luke_βV_function(hnc2.r_array)
# # hnc_luke.set_βu_matrix(βu_r_matrix)
# # hnc_luke.HNC_solve(alpha=1)

# %%
# np.savetxt("example_veff_1eV_rs_3aBohr.txt", np.array([hnc_check.r_array, hnc_check.βu_r_matrix[0,0]]).T,header="r/r_s,   beta v_ii^eff   (both unitless)",delimiter=', ' )

# %%
# hnc_check.plot_g_all_species()

# %%
# fig, ax = plt.subplots(figsize=(10,6))

# ax.plot(hnc2.r_array, hnc2.h_r_matrix[0,0]+1,'.', label="Two Actual Species")
# ax.plot(hnc_check.r_array, hnc_check.h_r_matrix[0,0]+1,'-', label="One Effective Species")
# ax.plot(hnc_luke.r_array, hnc_luke.h_r_matrix[0,0]+1,'-', label="Luke HNC with Force Matched V")
# ax.set_ylabel(r'$g(r/r_s)$',fontsize=20)
# ax.set_xlabel(r'$r/r_s$',fontsize=20)
# ax.set_ylim(-0.1,3)
# ax.set_xlim(0,5)
# ax.tick_params(labelsize=15)
# ax.legend(fontsize=15)

# %% [markdown]
# # Curve Fitting

# %%
from scipy.optimize import curve_fit

def yukawa_fit(r, Γ, κ,p):
    return  Γ/r*np.exp(-κ*r)

def yukawa_remaining_fit(r,a,b,c,d):
    return 1/(a+b*np.exp(c*(hnc2.r_array-d)))

def LJ_fit(r, a,b,m,n):
    return  1/(a*r**m + b/r**n) #+ v0

def yukawa_friedel_fit(r, Γ, κ1, a,κ2, k,  δ, v0):
    return  Γ/r*np.exp(-κ1*r) + a/r**3*np.exp(-κ2*r)*np.cos(k*r+δ) + v0

def yukawa_plus_fit(r, Γ, κ1, a,b,c):
    return  Γ/r*np.exp(-κ1*r)/(1+np.exp(b*(hnc2.r_array-c)))
# last_inf_index = int(np.argwhere(np.isinf(hnc2.βueff_r_matrix[0,0]))[-1] )

y_vals = curve_fit(yukawa_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0])
y_fit_data  = yukawa_fit(hnc2.r_array, y_vals[0][0],y_vals[0][1],y_vals[0][2])

y_remaining_vals = curve_fit(yukawa_remaining_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0]/y_fit_data)
y_remaining_fit_data  = yukawa_remaining_fit(hnc2.r_array, y_remaining_vals[0][0],y_remaining_vals[0][1],y_remaining_vals[0][2],y_remaining_vals[0][3])


# LJ_vals = curve_fit(LJ_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0],maxfev=int(1e5))
# yf_vals= curve_fit(yukawa_friedel_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0],maxfev=int(1e5))
# yp_vals= curve_fit(yukawa_plus_fit, hnc2.r_array, hnc2.βueff_r_matrix[0,0],maxfev=int(1e3))

# %%
y_vals[0], y_remaining_vals[0]

# %%
fig, ax = plt.subplots(figsize=(10,6))

g_data = hnc2.h_r_matrix[0,0] + 1

# LJ_fit_data  = LJ_fit(hnc2.r_array, LJ_vals[0][0],LJ_vals[0][1],LJ_vals[0][2],LJ_vals[0][3])
# yf_fit_data = yukawa_friedel_fit(hnc2.r_array, yf_vals[0][0],yf_vals[0][1],yf_vals[0][2],yf_vals[0][3],yf_vals[0][4],yf_vals[0][5],yf_vals[0][6])
yp_fit_data = yukawa_plus_fit(hnc2.r_array, yp_vals[0][0],yp_vals[0][1],yp_vals[0][2],yp_vals[0][3],yp_vals[0][4])


ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0],'k-', label="Effective")
# ax.plot(hnc2.r_array, y_fit_data*y_remaining_fit_data,'--', label="Yukawa Fit")
ax.plot(hnc2.r_array, 81.87504124/hnc2.r_array*np.exp(-0.99115223*hnc2.r_array)/(0.92620556+0.7351028*np.exp(1.72217623*(hnc2.r_array-1.75197859))),'--', label="Fit")
# ax.plot(hnc2.r_array[1:], hnc2.βueff_r_matrix[0,0][1:]-hnc2.βueff_r_matrix[0,0][:-1],'k-', label="Effective")
# ax.plot(hnc2.r_array[1:], (y_fit_data*y_remaining_fit_data)[1:]-(y_fit_data*y_remaining_fit_data)[:-1],'--', label="Yukawa Fit")

# ax.plot(hnc2.r_array, LJ_fit_data,'--', label="Yukawa Fit")
# ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0]-y_fit_data*y_remaining_fit_data,'.', label="Yukawa Fit Ratio")
 
# ax.plot(hnc2.r_array,y_remaining_fit_data,'.', label="Yukawa Remaining Fit")

# ax.plot(hnc2.r_array, yf_fit_data,'.', label="Yukawa-Friedel Fit")
# ax.plot(hnc2.r_array, yp_fit_data,'.', label="Yukawa-Plus Fit")
# ax.plot(hnc2.r_array, hnc2.βueff_r_matrix[0,0]/yp_fit_data,'.', label="Yukawa-Plus Fit Ratio")
# ax.plot(hnc2.r_array, 1/(1+np.exp(3*(hnc2.r_array-2.5))),'.', label="Yukawa-Friedel Fit")

ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
# ax.set_ylim(-2,2)
ax.set_yscale('symlog',linthresh=1e-1)
ax.set_xlim(0,10)
ax.tick_params(labelsize=15)
ax.legend(fontsize=15)

# %%
from scipy.interpolate import RBFInterpolator



RBFInterpolator(hnc2.r_array, hnc2.βueff_r_matrix[0,0]/y_fit_data)
