# %%
import numpy as np
import matplotlib.pyplot as plt


# from hnc_custom_screeningOZ_multiscale import  HNC_solver
from hnc_Ng import  HNC_solver
from qsps import *

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
        
        
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
def set_hnc_onlyion(n_in_per_cc, T, Z, A, Zstar, c_k_guess=None , which_Tij='thermal',
            oz_type='standard', method='kryov', add_bridge=False, bridge='yukawa',
            pseudopotential=False, r_c=0.6, no_coupling=False, N_bins = 500, R_max=5):
    
    n_in_AU = n_in_per_cc*1e6 *aB**3
    ri = QSP_HNC.rs_from_n(n_in_AU)
    qsp = QSP_HNC(Z, A, Zstar, T, T, ri, Zstar*n_in_AU, which_Tij=which_Tij, r_c=r_c)

    N_species = 1
    Gamma = np.array(  [[qsp.Γii]])


    names = ["Ion-1", "Electron", ] 
    kappa = 1
    
    rhos = np.array([  3/(4*np.pi)])
    temps = np.array([qsp.Ti])
    masses= np.array([qsp.m_i])
    hnc1 = HNC_solver(N_species, Gamma, rhos, temps, masses ,
                     kappa_multiscale=5, R_max=R_max, N_bins=N_bins, 
                      names=names, dst_type=3, oz_method=oz_type)

    if pseudopotential==True:
        βvei = qsp.βvei_atomic(hnc1.r_array)
    else:
        βvei = qsp.βvei(hnc1.r_array)
    βu_r_matrix = np.array([[qsp.βvii(hnc1.r_array)]])
    if no_coupling:
        βu_r_matrix[0,1]=0
        βu_r_matrix[1,0]=0
    
    if add_bridge:
        if bridge=='ocp':
            βu_r_matrix[0,0] = βu_r_matrix[0,0] - hnc1.Bridge_function_OCP(hnc1.r_array, qsp.Γii)
        elif bridge=='yukawa':
            βu_r_matrix[0,0] = βu_r_matrix[0,0] - hnc1.Bridge_function_Yukawa(hnc1.r_array, qsp.Γii, qsp.get_κ())
    hnc1.set_βu_matrix(βu_r_matrix)
    hnc1.initialize_c_k()
#     print("c asymm: ", hnc1.c_s_k_matrix[1,0]/hnc1.c_s_k_matrix[0,1])
    if c_k_guess is not None:
        for i in range(N_species):
            for j in range(N_species):
                if (c_k_guess[i,j]!=np.zeros(hnc1.N_bins)).all():
#                 if i==j:
                    hnc1.c_k_matrix[i,j] = c_k_guess[i,j]
                    hnc1.c_r_matrix[i,j] = hnc1.FT_k_2_r(hnc1.c_k_matrix[i,j])
                    hnc1.c_s_k_matrix[i,j] = hnc1.c_k_matrix[i,j] + hnc1.βu_l_k_matrix[i,j]
                    hnc1.c_s_r_matrix[i,j] = hnc1.c_r_matrix[i,j] + hnc1.βu_l_r_matrix[i,j]

#     print("c asymm: ", hnc1.c_s_k_matrix[1,0]/hnc1.c_s_k_matrix[0,1])
    hnc1.set_C_matrix()

    return hnc1, qsp

# %% [markdown]
# # Priority 1

# %% [markdown]
# ## atom

# %%
mixture_file = "/home/zach/plasma/hnc/data/TCCW_single_species_data.csv"
tccw_mixture_data = read_csv(mixture_file)
tccw_cases = [tccw_mixture_data.iloc[n] for n in range(len(tccw_mixture_data))]

for tccw_case in tccw_cases:
    if 'H' in tccw_case['Case ID']:
        print(tccw_case[' '], tccw_case['Case ID'], " Γii = ",tccw_case['Coupling Constant'])
# Out:
# 0 H1  Γii =  4.689931802
# 6 H2  Γii =  385.7474933
# 7 H3  Γii =  1.505398501
# 14 H11  Γii =  1238.853127
# 15 H21  Γii =  2974.224527
# 16 H31  Γii =  7571.846897
# 26 H12  Γii =  123.8925534
# 27 H22  Γii =  297.4237281
# 28 H32  Γii =  757.1848093
# 38 H13  Γii =  12.40787488
# 39 H23  Γii =  29.74600211
# 40 H33  Γii =  75.71886645
# 50 H14  Γii =  1.296884499
# 51 H24  Γii =  2.985299562
# 52 H34  Γii =  7.572905589
# 62 H15  Γii =  0.197649761
# 63 H25  Γii =  0.33817545
# 64 H35  Γii =  0.762807904
# 74 H16  Γii =  0.001159757

# %%
case_successes = {}
SVT_case_successes = {}
R_max = 10
N_bins = 500
max_attempts=1

tccw_case = tccw_cases[28]
α = 0.1
case_converged=False
case_attempts=0
case_num= tccw_case[' ']
case_id = tccw_case['Case ID']
ni = tccw_case['Number Density [N/cc]']
Te = tccw_case['Temperature [eV]']*eV
Ti = Te
Z = tccw_case['Atomic Number']
Zstar = tccw_case['Zbar (TFDW)']
A = tccw_case['Atomic Weight [a.u.]']
r_s = tccw_case['Wigner-Seitz Radius [cm]']
r_c = tccw_case['Average-Bound Radius [cm]']/r_s

print('\n______________________________\nCase num: {0} Case ID: {1}'.format(case_num, case_id))
print("Te = {0:.3e} eV, n_i = {1:.3e} 1/cc, r_c/r_s = {2:.3f}".format(Te/eV, ni, r_c))
# Out:
# ______________________________
# Case num: 28 Case ID: H32
# Te = 1.000e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525

# %%
c_k_matrix_list = []
h_k_matrix_list = []
atom_list = []
T_max = 7*Te
Te_list = np.linspace(Te, T_max, num=10)[::-1]

for index, Te_annealed in enumerate(Te_list):
    print("\nIndex ", index,":")
    print("__________________________\nTe = {0:.3e} eV, n_i = {1:.3e} 1/cc, r_c/r_s = {2:.3f}".format(Te_annealed/eV, ni, r_c))
    atom, qsp = set_hnc_onlyion(ni, Te_annealed, Z, A, Zstar, 
                            pseudopotential=True, oz_type='svt',r_c=r_c, 
                            add_bridge=True, bridge='ocp')

#     if index>0:
#         atom.h_k_matrix = h_k_matrix_list[-1].copy()#(h_k_matrix_list[-1]-h_k_matrix_list[-2])/(Te_list[index-1]-Te_list[index-])
#         atom.c_s_k_matrix  = atom.invert_SVT(atom.h_k_matrix, -atom.βu_s_k_matrix)
#         alpha_Picard = 1e-3
#     if index>1:
#         atom.h_k_matrix = h_k_matrix_list[-1] + (Te_annealed-Te_list[index-1])*(h_k_matrix_list[-1]-h_k_matrix_list[-2])/(Te_list[index-1]-Te_list[index-2])
#         atom.c_s_k_matrix  = atom.invert_SVT(atom.h_k_matrix, -atom.βu_s_k_matrix)
#         alpha_Picard = 1e-3
    atom.c_s_k_matrix*=0
    atom.HNC_solve(alpha_method='fixed', alpha_Picard = 0.5, tol=1e-8, alpha_Ng=0.1, 
               iters_to_wait=1e4, iters_to_use=2, num_iterations=1e3, verbose=True)

    options={'eps':1e-6,'maxfev':10000,'factor':1,'xtol':1e-8} 
    newton_kwargs= {'method':'hybr', 'options':options} 
    sol = atom.HNC_newton_solve( **newton_kwargs)
    print("Err: ", atom.total_err(sol.x.reshape(1,1,500)))

    #     if atom.newton_succeed==False:
#         break
    atom_list.append(atom)
    c_k_matrix_list.append(atom.c_k_matrix.copy())
    h_k_matrix_list.append(atom.h_k_matrix.copy())
# Out:
# Index  0 :
#
# __________________________
# Te = 7.000e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=123.058, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =1.31e-03
# 0: Initial condition Total Error: 5.125e+02
# 1: Change in c_r: 4.503e-01, HNC Error: 1.492e-02, Total Error: 3.027e+02
# 2: Change in c_r: 4.227e-01, HNC Error: 1.399e-02, Total Error: 1.795e+02
# 3: Change in c_r: 4.028e-01, HNC Error: 1.634e-01, Total Error: 1.084e+02
# 4: Change in c_r: 3.913e-01, HNC Error: 1.112e+00, Total Error: 6.774e+01
# 5: Change in c_r: 3.876e-01, HNC Error: 2.812e+00, Total Error: 4.441e+01
# 6: Change in c_r: 3.861e-01, HNC Error: 3.673e+00, Total Error: 3.081e+01
# 7: Change in c_r: 3.835e-01, HNC Error: 4.149e+00, Total Error: 2.267e+01
# 8: Change in c_r: 3.808e-01, HNC Error: 3.954e+00, Total Error: 1.761e+01
# 9: Change in c_r: 3.774e-01, HNC Error: 3.462e+00, Total Error: 1.431e+01
# 10: Change in c_r: 3.737e-01, HNC Error: 2.870e+00, Total Error: 1.203e+01
# 11: Change in c_r: 3.696e-01, HNC Error: 2.331e+00, Total Error: 1.038e+01
# 12: Change in c_r: 3.653e-01, HNC Error: 1.882e+00, Total Error: 9.128e+00
# 13: Change in c_r: 3.610e-01, HNC Error: 1.526e+00, Total Error: 8.137e+00
# 14: Change in c_r: 3.566e-01, HNC Error: 1.248e+00, Total Error: 7.330e+00
# 15: Change in c_r: 3.522e-01, HNC Error: 1.032e+00, Total Error: 6.657e+00
# 16: Change in c_r: 3.478e-01, HNC Error: 8.627e-01, Total Error: 6.088e+00
# 17: Change in c_r: 3.434e-01, HNC Error: 7.293e-01, Total Error: 5.598e+00
# 18: Change in c_r: 3.390e-01, HNC Error: 6.230e-01, Total Error: 5.173e+00
# 19: Change in c_r: 3.345e-01, HNC Error: 5.373e-01, Total Error: 4.800e+00
# 20: Change in c_r: 3.300e-01, HNC Error: 4.674e-01, Total Error: 4.471e+00
# Γii=152.013, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =1.06e-03
# 0: Initial condition Total Error: 1.392e+01
# 1: Change in c_r: 9.057e+01, HNC Error: 6.681e+14, Total Error: 1.064e+01
# 2: Change in c_r: 6.061e+00, HNC Error: 2.069e-01, Total Error: 7.417e+00
# 3: Change in c_r: 6.669e+00, HNC Error: 2.030e-01, Total Error: 1.204e+01
# 4: Change in c_r: 5.691e+00, HNC Error: 4.353e-01, Total Error: 1.044e+01
# 5: Change in c_r: 4.284e+00, HNC Error: 7.219e+01, Total Error: 7.643e+00
# 6: Change in c_r: 2.517e+00, HNC Error: 2.339e+05, Total Error: 2.668e+00
# 7: Change in c_r: 7.683e-01, HNC Error: inf, Total Error: 4.656e+04
# 8: Change in c_r: 8.333e+02, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 3.929e+03, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 3.158e+03, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 4.429e+03, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  5
# Final iter:11, Total Error: 2.668e+00
#
# Root Finder:  True The solution converged.
# Err:  2.348272383694718e-08
# Index  3 :
#
# __________________________
# Te = 5.000e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=172.281, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =9.37e-04
# 0: Initial condition Total Error: inf
# 1: Change in c_r: 3.522e+03, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 1.333e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 3.973e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 4.046e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 2.717e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 2.499e+03, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 2.041e+03, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 1.174e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 6.576e+02, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 5.779e+02, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 2.377e+03, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Err:  inf
# Index  4 :
#
# __________________________
# Te = 4.333e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=198.786, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =8.12e-04
# /home/zach/plasma/hnc/hnc_Ng.py:498: RuntimeWarning: overflow encountered in exp
#   self.h_r_matrix = -1 + np.exp(self.γs_r_matrix - self.βu_s_r_matrix)
# 0: Initial condition Total Error: inf
# 1: Change in c_r: 9.578e+02, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 4.524e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 3.572e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 4.072e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 3.193e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 2.498e+03, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 2.589e+03, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 1.872e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 8.876e+02, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 6.890e+02, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 4.818e+02, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Err:  inf
# Index  5 :
#
# __________________________
# Te = 3.667e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=234.928, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =6.87e-04
# 0: Initial condition Total Error: inf
# 1: Change in c_r: 1.610e+03, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 4.501e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 3.551e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 4.131e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 1.906e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 2.888e+03, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 3.363e+03, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 1.715e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 1.938e+03, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 1.976e+03, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 8.422e+02, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Err:  inf
# Index  6 :
#
# __________________________
# Te = 3.000e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=287.135, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =5.62e-04
# 0: Initial condition Total Error: inf
# 1: Change in c_r: 6.217e+02, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 3.916e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 3.571e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 2.832e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 1.630e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 8.676e+02, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 3.570e+02, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 1.011e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 2.330e+03, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 1.167e+03, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 4.867e+02, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
# Err:  inf
# Index  7 :
#
# __________________________
# Te = 2.333e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=369.173, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =4.37e-04
# 0: Initial condition Total Error: inf
# 1: Change in c_r: 6.820e+02, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 4.357e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 3.885e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 3.844e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 2.210e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 1.411e+03, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 2.005e+03, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 1.088e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 3.085e+03, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 1.386e+03, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 6.867e+02, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
# Err:  inf
# Index  8 :
#
# __________________________
# Te = 1.667e-01 eV, n_i = 5.700e+25 1/cc, r_c/r_s = 0.525
# Λei = 0.353
# Λee = 0.500
# Λei adjusted with R = 0.353
# Γii=516.843, Γie=-0.235, Γee=0.239
# r_i=0.305
# r_e=0.306
# r_c=0.525
# θ  =3.12e-04
# 0: Initial condition Total Error: inf
# 1: Change in c_r: 1.265e+02, HNC Error: inf, Total Error: inf
# 2: Change in c_r: 3.799e+03, HNC Error: inf, Total Error: inf
# 3: Change in c_r: 3.095e+03, HNC Error: inf, Total Error: inf
# 4: Change in c_r: 2.729e+03, HNC Error: inf, Total Error: inf
# 5: Change in c_r: 1.079e+03, HNC Error: inf, Total Error: inf
# 6: Change in c_r: 1.008e+03, HNC Error: inf, Total Error: inf
# 7: Change in c_r: 3.565e+03, HNC Error: inf, Total Error: inf
# 8: Change in c_r: 1.359e+03, HNC Error: inf, Total Error: inf
# 9: Change in c_r: 1.162e+03, HNC Error: inf, Total Error: inf
# 10: Change in c_r: 5.787e+02, HNC Error: inf, Total Error: inf
# 11: Change in c_r: 4.978e+02, HNC Error: inf, Total Error: inf
# QUIT: Total error infinite.
# Exiting, reverting to best index so far:  0
# Final iter:11, Total Error: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_11560/2501209035.py in <module>
#      26     options={'eps':1e-6,'maxfev':10000,'factor':1,'xtol':1e-8}
#      27     newton_kwargs= {'method':'hybr', 'options':options}
# ---> 28     sol = atom.HNC_newton_solve( **newton_kwargs)
#      29     print("Err: ", atom.total_err(sol.x.reshape(1,1,500)))
#      30
#
# ~/plasma/hnc/hnc_Ng.py in HNC_newton_solve(self, **newton_kwargs)
#     490         # sol2 = root(f_to_min, self.c_s_k_matrix, method='krylov' , callback=callback_func, tol=tol, options=options)
#     491         # options={'eps':1e-6,'maxfev':100,'factor':0.1,'xtol':1e-3}
# --> 492         sol2 = root(f_to_min, self.c_s_k_matrix, **newton_kwargs)#method='hybr' , tol=tol, options=options)
#     493         print("\nRoot Finder: ", sol2.success, sol2.message)
#     494         self.c_s_k_matrix = sol2.x.reshape(self.N_species, self.N_species, self.N_bins)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_root.py in root(fun, x0, args, method, jac, tol, callback, options)
#     233
#     234     if meth == 'hybr':
# --> 235         sol = _root_hybr(fun, x0, args=args, jac=jac, **options)
#     236     elif meth == 'lm':
#     237         sol = _root_leastsq(fun, x0, args=args, jac=jac, **options)
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minpack_py.py in _root_hybr(func, x0, args, jac, col_deriv, xtol, maxfev, band, eps, factor, diag, **unknown_options)
#     238         if maxfev == 0:
#     239             maxfev = 200 * (n + 1)
# --> 240         retval = _minpack._hybrd(func, x0, args, 1, xtol, maxfev,
#     241                                  ml, mu, epsfcn, factor, diag)
#     242     else:
#
# ~/plasma/hnc/hnc_Ng.py in f_to_min(c_s_k_flat)
#     475         def f_to_min(c_s_k_flat):
#     476             c_s_k_matrix = c_s_k_flat.reshape(self.N_species, self.N_species, self.N_bins)
# --> 477             matrix_to_min = self.get_hnc_oz_matrix(c_s_k_matrix)
#     478             return matrix_to_min.flatten()
#     479
#
# ~/plasma/hnc/hnc_Ng.py in get_hnc_oz_matrix(self, c_s_k_matrix)
#     303         c_k_matrix = c_s_k_matrix - self.βu_l_k_matrix
#     304
# --> 305         γs_k_matrix = self.get_γs_k_matrix(c_s_k_matrix)
#     306         h_k_matrix = c_s_k_matrix  + γs_k_matrix
#     307         h_r_matrix = self.FT_k_2_r_matrix(h_k_matrix)
#
# ~/plasma/hnc/hnc_Ng.py in get_γs_k_matrix(self, c_s_k_matrix)
#     217             γs_k_matrix = self.get_γs_k_matrix_standard(c_s_k_matrix)
#     218         elif self.oz_method in ['svt','SVT']:
# --> 219             γs_k_matrix = self.get_γs_k_matrix_SVT(c_s_k_matrix)
#     220         return γs_k_matrix
#     221
#
# ~/plasma/hnc/hnc_Ng.py in get_γs_k_matrix_SVT(self, c_s_k_matrix)
#     253         γs_k_matrix = np.zeros_like(self.γs_k_matrix)
#     254         for k in range(self.N_bins):
# --> 255             γs_k_matrix[:,:,k]   = solve_sylvester(A[:,:,k], B[:,:,k], C[:,:,k])
#     256             # γs_k_matrix[:,:,k] = solve_continuous_lyapunov(A[:,:,k], C[:,:,k])
#     257         return γs_k_matrix
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_solvers.py in solve_sylvester(a, b, q)
#      86
#      87     # Compute the Schur decomposition of b
# ---> 88     s, v = schur(b.conj().transpose(), output='real')
#      89
#      90     # Construct f = u'*q*v
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/linalg/_decomp_schur.py in schur(a, output, lwork, overwrite_a, sort, check_finite)
#     136         # get optimal work array
#     137         result = gees(lambda x: None, a1, lwork=-1)
# --> 138         lwork = result[-2][0].real.astype(numpy.int_)
#     139
#     140     if sort is None:
#
# KeyboardInterrupt:

# %%
h_k_matrix_list

# %%
fig, axs = plt.subplots(2,2, figsize=(16,12))




for i in range(2):
        for j in range(2):
            
#             axs[i,j].plot(atom_list[0].k_array, atom_list[0].c_k_matrix[i,j])
#             axs[i,j].plot(atom_test.k_array, atom_test.c_k_matrix[i,j],'--')
            for k in range(10):
                axs[i,j].plot(atom_list[0].k_array, h_k_matrix_list[k][i,j])
#                 axs[i,j].plot(atom_test.k_array, atom_test.c_s_k_matrix[i,j],'--')
            
#             axs[i,j].plot(atom_list[0].k_array, atom_list[0].h_k_matrix[i,j])
#             axs[i,j].plot(atom_list[1].k_array, atom_list[1].h_k_matrix[i,j])
#             axs[i,j].plot(atom_test.k_array, atom_test.h_k_matrix[i,j],'--')

#             axs[i,j].plot(atom_list[0].r_array, atom_list[0].h_r_matrix[i,j])
#             axs[i,j].plot(atom_list[1].r_array, atom_list[1].h_r_matrix[i,j],'--')
#             axs[i,j].plot(atom_test.r_array, atom_test.h_r_matrix[i,j],'--')

            axs[i,j].tick_params(labelsize=20)
#             axs[i,j].set_xscale('log')
            axs[i,j].set_xlim(0,50)
            axs[i,j].tick_params(labelsize=20)
            axs[-1,j].set_xlabel(r"$r/r_s $",fontsize=20)
#             axs[i,j].set_yscale('symlog',linthresh=0.1)
#             axs[i,j].set_ylim(-10, 1e1)

#         axs[i,0].set_ylabel(r"$c(k)$",fontsize=20)

# %%
atom.plot_species_convergence_g(n_slices= int(len(atom.h_r_matrix_list)/1)  )

# %%
atom.plot_species_convergence_c(n_slices= int(len(atom.h_r_matrix_list)/10)  )

# %%
# fig, ax = plt.subplots(1,1, figsize=(8,6))


# ρ_e = [ np.sum(((h_r_matrix[0,1]+1)*atom.r_array**2)*atom.del_r) for h_r_matrix in atom.h_r_matrix_list]
# ρ_i = [ np.sum(((h_r_matrix[0,0]+1)*atom.r_array**2)*atom.del_r) for h_r_matrix in atom.h_r_matrix_list]

# ρ_e_normal = [ np.sum(((h_r_matrix[0,1]+1)*atom.r_array**2)*atom.del_r) for h_r_matrix in atom_normal.h_r_matrix_list]
# ρ_i_normal = [ np.sum(((h_r_matrix[0,0]+1)*atom.r_array**2)*atom.del_r) for h_r_matrix in atom_normal.h_r_matrix_list]

# # ax.plot(ρ_e ,label=r'$\rho_e$')#, color=color)
# # ax.plot(ρ_i,  '--', label=r'$\rho_i$')#,color=color)
# ax.plot(ρ_e_normal ,label=r'$\rho_e$')#, color=color)
# ax.plot(ρ_i_normal,  '--', label=r'$\rho_i$')#,color=color)
# ax2 = ax.twinx()
# ax2.plot(atom.u_ex_list,'-k')
# ax2.plot(atom_normal.u_ex_list,'--k')

# # ax.set_ylim(8.75,9.2)
# ax2.set_ylim(-1.5,.1)
# ax.legend()

# %%
atom.plot_species_convergence_ck(n_slices= int(len(atom.h_r_matrix_list)/1)  )

# %%
atom.plot_species_convergence_g(n_slices= int(len(atom.h_r_matrix_list)/1)  )
atom.plot_species_convergence_c(n_slices= int(len(atom.h_r_matrix_list)/1)  )

# %%
Al_file = "/home/zach/plasma/datasets/RDFs/Al_1.0eV_rs3_VASP.txt"  # 1 eV
Al_file = '/home/zach/plasma/datasets/RDFs/Al_0.5eV_rs3_KS-MD.txt' # 0.5 eV
Al_data = read_csv(Al_file,header=0, names=['r','g'])

# %%
Te_list[2]/eV

# %%
fig, ax = plt.subplots(figsize=(10,8))
fig.suptitle('Al TCCW Case, 1 eV, rs=3', fontsize=20, y=0.95)

ax.plot(Al_data['r'], Al_data['g'],'ro', label = 'VASP' )
# ax.plot(atom.r_array, atom_one_species.h_r_matrix[0,0] + 1, label='No electrons')
ax.plot(atom.r_array, atom.h_r_matrix[0,0] + 1, label='SVT Ashcroft Empy Yukawa Bridge')
# ax.plot(atom.r_array, atomSVT.h_r_matrix[0,0] + 1, label='SVT Ashcroft')
# ax.plot(atom.r_array, atomSVT_Yuk.h_r_matrix[0,0] + 1,'--', label='SVT Ashcroft + Yukawa Bridge')
# ax.plot(atom.r_array, atomSVT_OCP.h_r_matrix[0,0] + 1,'--', label='SVT Ashcroft + OCP Bridge')

ax.set_ylabel(r'$g(r)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)
ax.tick_params(labelsize=20)
ax.set_xlim(0.5,4)
ax.legend(fontsize=15)

# %% [markdown]
# # βu_eff matching

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
# luke_file = '/home/zach/plasma/atomic_forces/data/Al_T0p5_tab.lammps.PAIR'
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
# luke_r, luke_βV = 1e-10/aB/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_r, luke_βV = 1e-8/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)

# %%
from scipy.optimize import curve_fit

class βu_fit():
    def __init__(self, func, r_array, y_data, initial_guess):
        self.r = r_array
        self.y = y_data
        self.y_vals = curve_fit(func, r_array, y_data, maxfev=int(1e5), p0=initial_guess)
        self.y_fit  = func(r_array, *self.y_vals[0])
        self.err = np.linalg.norm(self.y_fit-self.y)
        print(func.__name__ + " error: {0:.3e} ".format(self.err))

def yukawa_plus(r, a, b, c, d):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d)))

def yukawa_plus_gaussian(r, a ,b ,c, d ,e, f, g):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.exp(-(f-r)**2/g)

def yukawa_plus_cos(r, a ,b ,c, d , h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + h*np.cos((r-i)*j*np.exp(-k*r))*np.exp(-l*r)

def yukawa_plus_gaussian_cos(r, a ,b ,c, d ,e, f, g, h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.cos((r-f)*g*np.exp(-h*r))*np.exp(-i*r) + j*np.exp(-(k-r)**2/l)

# %%
atom.invert_HNC([1])
fit1 = βu_fit(yukawa_plus, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[   atomqsp.Γii, atomqsp.get_κ(),2 , 1])
try: 
    fit2 = βu_fit(yukawa_plus_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit1.y_vals[0], 1, 0.01, 1 , 10, 2])
except:
    pass
try:
    fit3 = βu_fit(yukawa_plus_gaussian_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit2.y_vals[0], -1, 1.9, 1])
except:
    pass

# %%
luke_r

# %%
fig, ax = plt.subplots(figsize=(8,6),facecolor='w')
fig.suptitle(r"{0} $T=${1:.1f} eV, $r_i$={2:.2f}".format(case_id, Te/eV, atomqsp.ri), fontsize=20)


yukawa_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array * np.exp(-atom.r_array*atomqsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]
coulomb_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array) [:-1,:-1]

ax.plot(atom.r_array, atom.βu_r_matrix[0,0], 'k--',label='Initial')
ax.plot(atom.r_array, yukawa_matrix[0,0],'k-.', label="Yukawa")

ax.plot(atom.r_array, atom.βueff_r_matrix[0,0],color=colors[0], label='Effective')    
ax.plot(luke_r, luke_βV,'r-', label='Luke Force Match')

ax.set_ylim(np.min([-10, 2*np.min(atom.βueff_r_matrix[0,0])]), np.max([1e3, 2*np.max(atom.βueff_r_matrix[0,0])]))
ax.tick_params(labelsize=20)
ax.set_xlabel(r"$r/r_s$",fontsize=20)
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)

ax.set_xlim(0, R_max)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=10)
fig.tight_layout()
