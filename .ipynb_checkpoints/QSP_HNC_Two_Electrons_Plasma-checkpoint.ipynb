# %%
import numpy as np
import matplotlib.pyplot as plt

from CMEP import CMEP_Atom
from hnc import  HNC_solver
from qsps import *

from pandas import read_csv

eV = 0.0367512

# %%
# ri = QSP_HNC.rs_from_n(6.03e30*aB**3)
ni_cc = 1e22
Te_eV = 5.56
Te_AU = Te_eV*eV 
Ti_eV = Te_eV

Z, A = 4,9
Zbar= 2.105

atom = CMEP_Atom(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar,
             βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':False}, 
             qsp_options= {'r_c':0.0},
             hnc_options= {'kappa_multiscale':10, 'R_max':5,'N_bins':500,'oz_method':'svt'},
             hnc_solve_options={'alpha_Picard':1})
# atom.run_hnc()
print("T/EF = ", atom.qsp.Ti/atom.qsp.E_F)
# Out:
# Te_in_eV: 5.560
# Ti_in_eV: 5.560
# T/EF =  2.00013194113309

# %%
from atomic_forces.atomOFDFT.python.physics import ThomasFermi
from scipy.optimize import root

def find_η(Te, ne):
    """
    Gets chemical potential in [AU] that gives density ne at temperature Te
    """
    f_to_min = lambda η: ThomasFermi.n_TF(Te, η)-ne # η = βμ in ideal gas, no potential case
    
    root_and_info = root(f_to_min, 0.4,tol=1e-4)

    η = root_and_info['x'][0]
    return η

def h_ee_ID(ne, T, r, η):
    sin_arg = np.sqrt(2*T*m_e)*r
    t_max = np.max([1/sin_arg, η ])
    
    t = np.linspace(0,t_max, num=10000) 
    dt = t[1]-t[0]
    κ = 3*(2*T*m_e) / (atom.qsp.k_F**3 * r)  * np.sum(dt* t*np.sin(sin_arg*t) /(1+np.exp(t**2-η) )  )
#     h_ee = -0.5*κ**2
    h_ee = -κ**2
    return h_ee
    

η = find_η(Te_AU, atom.qsp.ne )
h_ee_ID_explicit = np.array([h_ee_ID(atom.qsp.ne, Te_AU, r*atom.qsp.ri, η ) for r in atom.hnc.r_array])
h_ee_ID_explicit
# Out:
# /tmp/ipykernel_5798/58252760.py:21: RuntimeWarning: overflow encountered in exp
#   κ = 3*(2*T*m_e) / (atom.qsp.k_F**3 * r)  * np.sum(dt* t*np.sin(sin_arg*t) /(1+np.exp(t**2-η) )  )
# array([-9.99366734e-01, -9.97469817e-01, -9.94316200e-01, -9.89917696e-01,
#        -9.84290742e-01, -9.77456295e-01, -9.69439303e-01, -9.60252080e-01,
#        -9.49735475e-01, -9.37069140e-01, -9.20325180e-01, -8.96828205e-01,
#        -8.64257961e-01, -8.21666184e-01, -7.69811346e-01, -7.10822252e-01,
#        -6.47537036e-01, -5.82857778e-01, -5.19302824e-01, -4.58789347e-01,
#        -4.02596450e-01, -3.51436895e-01, -3.05576097e-01, -2.64957815e-01,
#        -2.29315023e-01, -1.98257793e-01, -1.71337709e-01, -1.48092001e-01,
#        -1.28071749e-01, -1.10858380e-01, -9.60720101e-02, -8.33744022e-02,
#        -7.24685333e-02, -6.30962016e-02, -5.50346121e-02, -4.80925590e-02,
#        -4.21065808e-02, -3.69373097e-02, -3.24661298e-02, -2.85921902e-02,
#        -2.52297832e-02, -2.23060687e-02, -1.97591185e-02, -1.75362453e-02,
#        -1.55925822e-02, -1.38898792e-02, -1.23954859e-02, -1.10814929e-02,
#        -9.92400818e-03, -8.90254652e-03, -7.99951570e-03, -7.19978276e-03,
#        -6.49030839e-03, -5.85983806e-03, -5.29864116e-03, -4.79829018e-03,
#        -4.35147372e-03, -3.95183783e-03, -3.59385131e-03, -3.27269105e-03,
#        -2.98414443e-03, -2.72452594e-03, -2.49060607e-03, -2.27955027e-03,
#        -2.08886680e-03, -1.91636185e-03, -1.76010092e-03, -1.61837569e-03,
#        -1.48967525e-03, -1.37266143e-03, -1.26614730e-03, -1.16907866e-03,
#        -1.08051784e-03, -9.99629748e-04, -9.25669646e-04, -8.57972499e-04,
#        -7.95943700e-04, -7.39050939e-04, -6.86817091e-04, -6.38813982e-04,
#        -5.94656908e-04, -5.53999823e-04, -5.16531100e-04, -4.81969790e-04,
#        -4.50062328e-04, -4.20579615e-04, -3.93314441e-04, -3.68079196e-04,
#        -3.44703845e-04, -3.23034128e-04, -3.02929957e-04, -2.84263996e-04,
#        -2.66920383e-04, -2.50793608e-04, -2.35787491e-04, -2.21814285e-04,
#        -2.08793864e-04, -1.96652996e-04, -1.85324697e-04, -1.74747643e-04,
#        -1.64865649e-04, -1.55627193e-04, -1.46984996e-04, -1.38895634e-04,
#        -1.31319200e-04, -1.24218982e-04, -1.17561192e-04, -1.11314704e-04,
#        -1.05450826e-04, -9.99430911e-05, -9.47670685e-05, -8.99001899e-05,
#        -8.53215950e-05, -8.10119888e-05, -7.69535130e-05, -7.31296282e-05,
#        -6.95250070e-05, -6.61254362e-05, -6.29177280e-05, -5.98896388e-05,
#        -5.70297945e-05, -5.43276228e-05, -5.17732912e-05, -4.93576499e-05,
#        -4.70721795e-05, -4.49089438e-05, -4.28605451e-05, -4.09200849e-05,
#        -3.90811258e-05, -3.73376587e-05, -3.56840705e-05, -3.41151160e-05,
#        -3.26258909e-05, -3.12118078e-05, -2.98685734e-05, -2.85921681e-05,
#        -2.73788261e-05, -2.62250186e-05, -2.51274368e-05, -2.40829767e-05,
#        -2.30887259e-05, -2.21419496e-05, -2.12400795e-05, -2.03807020e-05,
#        -1.95615484e-05, -1.87804850e-05, -1.80355044e-05, -1.73247173e-05,
#        -1.66463446e-05, -1.59987108e-05, -1.53802368e-05, -1.47894340e-05,
#        -1.42248988e-05, -1.36853070e-05, -1.31694088e-05, -1.26760245e-05,
#        -1.22040397e-05, -1.17524019e-05, -1.13201161e-05, -1.09062419e-05,
#        -1.05098896e-05, -1.01302179e-05, -9.76643030e-06, -9.41777290e-06,
#        -9.08353173e-06, -8.76303047e-06, -8.45562823e-06, -8.16071750e-06,
#        -7.87772228e-06, -7.60609619e-06, -7.34532088e-06, -7.09490439e-06,
#        -6.85437966e-06, -6.62330320e-06, -6.40125370e-06, -6.18783087e-06,
#        -5.98265423e-06, -5.78536208e-06, -5.59561043e-06, -5.41307207e-06,
#        -5.23743567e-06, -5.06840490e-06, -4.90569765e-06, -4.74904531e-06,
#        -4.59819198e-06, -4.45289389e-06, -4.31291869e-06, -4.17804493e-06,
#        -4.04806143e-06, -3.92276680e-06, -3.80196892e-06, -3.68548448e-06,
#        -3.57313851e-06, -3.46476398e-06, -3.36020141e-06, -3.25929847e-06,
#        -3.16190965e-06, -3.06789589e-06, -2.97712431e-06, -2.88946787e-06,
#        -2.80480509e-06, -2.72301979e-06, -2.64400085e-06, -2.56764193e-06,
#        -2.49384128e-06, -2.42250149e-06, -2.35352931e-06, -2.28683543e-06,
#        -2.22233432e-06, -2.15994405e-06, -2.09958609e-06, -2.04118520e-06,
#        -1.98466925e-06, -1.92996908e-06, -1.87701838e-06, -1.82575355e-06,
#        -1.77611356e-06, -1.72803987e-06, -1.68147629e-06, -1.63636889e-06,
#        -1.59266590e-06, -1.55031760e-06, -1.50927625e-06, -1.46949599e-06,
#        -1.43093275e-06, -1.39354420e-06, -1.35728966e-06, -1.32213000e-06,
#        -1.28802763e-06, -1.25494640e-06, -1.22285153e-06, -1.19170957e-06,
#        -1.16148835e-06, -1.13215691e-06, -1.10368546e-06, -1.07604531e-06,
#        -1.04920887e-06, -1.02314954e-06, -9.97841743e-07, -9.73260814e-07,
#        -9.49383009e-07, -9.26185452e-07, -9.03646097e-07, -8.81743701e-07,
#        -8.60457785e-07, -8.39768611e-07, -8.19657148e-07, -8.00105042e-07,
#        -7.81094595e-07, -7.62608736e-07, -7.44630993e-07, -7.27145479e-07,
#        -7.10136857e-07, -6.93590331e-07, -6.77491615e-07, -6.61826921e-07,
#        -6.46582932e-07, -6.31746794e-07, -6.17306089e-07, -6.03248824e-07,
#        -5.89563414e-07, -5.76238664e-07, -5.63263759e-07, -5.50628246e-07,
#        -5.38322022e-07, -5.26335321e-07, -5.14658701e-07, -5.03283034e-07,
#        -4.92199491e-07, -4.81399535e-07, -4.70874907e-07, -4.60617619e-07,
#        -4.50619942e-07, -4.40874397e-07, -4.31373746e-07, -4.22110986e-07,
#        -4.13079335e-07, -4.04272230e-07, -3.95683318e-07, -3.87306443e-07,
#        -3.79135649e-07, -3.71165163e-07, -3.63389395e-07, -3.55802931e-07,
#        -3.48400524e-07, -3.41177090e-07, -3.34127704e-07, -3.27247591e-07,
#        -3.20532123e-07, -3.13976816e-07, -3.07577320e-07, -3.01329418e-07,
#        -2.95229023e-07, -2.89272170e-07, -2.83455012e-07, -2.77773820e-07,
#        -2.72224976e-07, -2.66804969e-07, -2.61510393e-07, -2.56337943e-07,
#        -2.51284411e-07, -2.46346684e-07, -2.41521741e-07, -2.36806647e-07,
#        -2.32198556e-07, -2.27694701e-07, -2.23292399e-07, -2.18989041e-07,
#        -2.14782095e-07, -2.10669101e-07, -2.06647670e-07, -2.02715481e-07,
#        -1.98870278e-07, -1.95109869e-07, -1.91432126e-07, -1.87834979e-07,
#        -1.84316415e-07, -1.80874481e-07, -1.77507275e-07, -1.74212949e-07,
#        -1.70989707e-07, -1.67835802e-07, -1.64749535e-07, -1.61729253e-07,
#        -1.58773351e-07, -1.55880265e-07, -1.53048475e-07, -1.50276500e-07,
#        -1.47562903e-07, -1.44906283e-07, -1.42305276e-07, -1.39758558e-07,
#        -1.37264837e-07, -1.34822857e-07, -1.32431395e-07, -1.30089260e-07,
#        -1.27795294e-07, -1.25548368e-07, -1.23347383e-07, -1.21191270e-07,
#        -1.19078985e-07, -1.17009515e-07, -1.14981870e-07, -1.12995088e-07,
#        -1.11048230e-07, -1.09140382e-07, -1.07270654e-07, -1.05438178e-07,
#        -1.03642109e-07, -1.01881622e-07, -1.00155915e-07, -9.84642039e-08,
#        -9.68057265e-08, -9.51797388e-08, -9.35855156e-08, -9.20223499e-08,
#        -9.04895524e-08, -8.89864508e-08, -8.75123896e-08, -8.60667295e-08,
#        -8.46488472e-08, -8.32581343e-08, -8.18939977e-08, -8.05558588e-08,
#        -7.92431529e-08, -7.79553292e-08, -7.66918505e-08, -7.54521921e-08,
#        -7.42358425e-08, -7.30423022e-08, -7.18710838e-08, -7.07217116e-08,
#        -6.95937213e-08, -6.84866596e-08, -6.74000840e-08, -6.63335625e-08,
#        -6.52866733e-08, -6.42590046e-08, -6.32501542e-08, -6.22597296e-08,
#        -6.12873471e-08, -6.03326322e-08, -5.93952190e-08, -5.84747503e-08,
#        -5.75708771e-08, -5.66832582e-08, -5.58115606e-08, -5.49554588e-08,
#        -5.41146348e-08, -5.32887779e-08, -5.24775845e-08, -5.16807578e-08,
#        -5.08980078e-08, -5.01290512e-08, -4.93736108e-08, -4.86314159e-08,
#        -4.79022018e-08, -4.71857098e-08, -4.64816869e-08, -4.57898857e-08,
#        -4.51100645e-08, -4.44419867e-08, -4.37854212e-08, -4.31401419e-08,
#        -4.25059275e-08, -4.18825619e-08, -4.12698335e-08, -4.06675355e-08,
#        -4.00754654e-08, -3.94934253e-08, -3.89212214e-08, -3.83586644e-08,
#        -3.78055688e-08, -3.72617533e-08, -3.67270403e-08, -3.62012562e-08,
#        -3.56842310e-08, -3.51757984e-08, -3.46757957e-08, -3.41840634e-08,
#        -3.37004457e-08, -3.32247899e-08, -3.27569465e-08, -3.22967694e-08,
#        -3.18441153e-08, -3.13988440e-08, -3.09608182e-08, -3.05299035e-08,
#        -3.01059684e-08, -2.96888839e-08, -2.92785238e-08, -2.88747646e-08,
#        -2.84774852e-08, -2.80865671e-08, -2.77018941e-08, -2.73233525e-08,
#        -2.69508308e-08, -2.65842200e-08, -2.62234131e-08, -2.58683054e-08,
#        -2.55187942e-08, -2.51747789e-08, -2.48361611e-08, -2.45028442e-08,
#        -2.41747335e-08, -2.38517365e-08, -2.35337621e-08, -2.32207214e-08,
#        -2.29125271e-08, -2.26090936e-08, -2.23103371e-08, -2.20161754e-08,
#        -2.17265280e-08, -2.14413157e-08, -2.11604613e-08, -2.08838888e-08,
#        -2.06115237e-08, -2.03432931e-08, -2.00791255e-08, -1.98189506e-08,
#        -1.95626996e-08, -1.93103051e-08, -1.90617008e-08, -1.88168220e-08,
#        -1.85756049e-08, -1.83379870e-08, -1.81039073e-08, -1.78733055e-08,
#        -1.76461228e-08, -1.74223014e-08, -1.72017845e-08, -1.69845166e-08,
#        -1.67704429e-08, -1.65595101e-08, -1.63516656e-08, -1.61468577e-08,
#        -1.59450359e-08, -1.57461505e-08, -1.55501529e-08, -1.53569952e-08,
#        -1.51666305e-08, -1.49790128e-08, -1.47940968e-08, -1.46118381e-08,
#        -1.44321933e-08, -1.42551196e-08, -1.40805750e-08, -1.39085183e-08,
#        -1.37389092e-08, -1.35717078e-08, -1.34068752e-08, -1.32443731e-08,
#        -1.30841640e-08, -1.29262110e-08, -1.27704778e-08, -1.26169288e-08,
#        -1.24655292e-08, -1.23162446e-08, -1.21690412e-08, -1.20238862e-08])

# %%
t = np.linspace(0,100, num=1000) 
k = np.linspace(0,100, num=1000)
dt = t[1]-t[0]
dk = k[1]-k[0]
print("ne==", 2*4*π * (2*m_e*Te_AU)**(3/2) /(2*π)**3 * np.sum( dt* t**2 /(1+np.exp( t**2-η) )  ) )
print("ne==", 2*4*π /(2*π)**3 * np.sum( dk* k**2 /(1+np.exp( 1/(2*Te_AU*m_e)* k**2-η)) ) ) 
print("ne_TF == ", ThomasFermi.n_TF(Te_AU, η))
# Out:
# ne== 0.0031192879140600153
# ne== 0.0031192879140600153
# ne_TF ==  0.0031192881765616503
# /tmp/ipykernel_5798/2071180337.py:5: RuntimeWarning: overflow encountered in exp
#   print("ne==", 2*4*π * (2*m_e*Te_AU)**(3/2) /(2*π)**3 * np.sum( dt* t**2 /(1+np.exp( t**2-η) )  ) )
# /tmp/ipykernel_5798/2071180337.py:6: RuntimeWarning: overflow encountered in exp
#   print("ne==", 2*4*π /(2*π)**3 * np.sum( dk* k**2 /(1+np.exp( 1/(2*Te_AU*m_e)* k**2-η)) ) )

# %%
f_of_k = 1/(  1+np.exp((atom.hnc.k_array/atom.qsp.ri)**2/(2*m_e*Te_AU) - η) )
# h_ee_ID_DST = -0.5* qsp.ri**-6*atom.hnc.FT_k_2_r(f_of_k)**2/(0.5*qsp.ne)**2
h_ee_ID_DST = - atom.qsp.ri**-6*atom.hnc.FT_k_2_r(f_of_k)**2/(0.5*atom.qsp.ne)**2
h_ee_ID_DST
# Out:
# /tmp/ipykernel_5798/1473901977.py:1: RuntimeWarning: overflow encountered in exp
#   f_of_k = 1/(  1+np.exp((atom.hnc.k_array/atom.qsp.ri)**2/(2*m_e*Te_AU) - η) )
# array([-9.99366734e-01, -9.97469817e-01, -9.94316200e-01, -9.89917696e-01,
#        -9.84290742e-01, -9.77456296e-01, -9.69439708e-01, -9.60270568e-01,
#        -9.49982519e-01, -9.38613060e-01, -9.26203315e-01, -9.12797789e-01,
#        -8.98444108e-01, -8.83192733e-01, -8.67096672e-01, -8.50211176e-01,
#        -8.32593423e-01, -8.14302205e-01, -7.95397600e-01, -7.75940650e-01,
#        -7.55993042e-01, -7.35616783e-01, -7.14873889e-01, -6.93826081e-01,
#        -6.72534485e-01, -6.51059354e-01, -6.29459791e-01, -6.07793499e-01,
#        -5.86116537e-01, -5.64483104e-01, -5.42945336e-01, -5.21553118e-01,
#        -5.00353928e-01, -4.79392692e-01, -4.58711665e-01, -4.38350330e-01,
#        -4.18345320e-01, -3.98730359e-01, -3.79536225e-01, -3.60790733e-01,
#        -3.42518733e-01, -3.24742129e-01, -3.07479918e-01, -2.90748236e-01,
#        -2.74560430e-01, -2.58927133e-01, -2.43856360e-01, -2.29353609e-01,
#        -2.15421974e-01, -2.02062268e-01, -1.89273149e-01, -1.77051253e-01,
#        -1.65391335e-01, -1.54286408e-01, -1.43727886e-01, -1.33705729e-01,
#        -1.24208582e-01, -1.15223925e-01, -1.06738206e-01, -9.87369768e-02,
#        -9.12050318e-02, -8.41265300e-02, -7.74851205e-02, -7.12640587e-02,
#        -6.54463169e-02, -6.00146891e-02, -5.49518879e-02, -5.02406354e-02,
#        -4.58637467e-02, -4.18042055e-02, -3.80452343e-02, -3.45703556e-02,
#        -3.13634476e-02, -2.84087924e-02, -2.56911181e-02, -2.31956342e-02,
#        -2.09080614e-02, -1.88146551e-02, -1.69022246e-02, -1.51581461e-02,
#        -1.35703717e-02, -1.21274341e-02, -1.08184470e-02, -9.63310225e-03,
#        -8.56166369e-03, -7.59495809e-03, -6.72436364e-03, -5.94179615e-03,
#        -5.23969352e-03, -4.61099851e-03, -4.04914028e-03, -3.54801495e-03,
#        -3.10196527e-03, -2.70575987e-03, -2.35457207e-03, -2.04395858e-03,
#        -1.76983824e-03, -1.52847089e-03, -1.31643655e-03, -1.13061507e-03,
#        -9.68166200e-04, -8.26510384e-04, -7.03310130e-04, -5.96452160e-04,
#        -5.04030315e-04, -4.24329273e-04, -3.55809088e-04, -2.97090566e-04,
#        -2.46941485e-04, -2.04263656e-04, -1.68080799e-04, -1.37527245e-04,
#        -1.11837415e-04, -9.03360731e-05, -7.24293110e-05, -5.75962409e-05,
#        -4.53813620e-05, -3.53875666e-05, -2.72697504e-05, -2.07289931e-05,
#        -1.55072718e-05, -1.13826744e-05, -8.16507697e-06, -5.69225165e-06,
#        -3.82637320e-06, -2.45089190e-06, -1.46774319e-06, -7.94865387e-07,
#        -3.63998268e-07, -1.18736987e-07, -1.28173108e-08, -8.60977253e-09,
#        -7.58018638e-08, -1.90248934e-07, -3.32975953e-07, -4.89313730e-07,
#        -6.48154553e-07, -8.01313541e-07, -9.42983231e-07, -1.06927010e-06,
#        -1.17780282e-06, -1.26740312e-06, -1.33781090e-06, -1.38945644e-06,
#        -1.42327306e-06, -1.44054441e-06, -1.44278141e-06, -1.43162420e-06,
#        -1.40876531e-06, -1.37589048e-06, -1.33463425e-06, -1.28654763e-06,
#        -1.23307585e-06, -1.17554396e-06, -1.11514901e-06, -1.05295719e-06,
#        -9.89904896e-07, -9.26802769e-07, -8.64341820e-07, -8.03101104e-07,
#        -7.43556326e-07, -6.86089003e-07, -6.30995810e-07, -5.78497874e-07,
#        -5.28749805e-07, -4.81848320e-07, -4.37840353e-07, -3.96730590e-07,
#        -3.58488385e-07, -3.23054036e-07, -2.90344435e-07, -2.60258092e-07,
#        -2.32679564e-07, -2.07483325e-07, -1.84537109e-07, -1.63704766e-07,
#        -1.44848674e-07, -1.27831751e-07, -1.12519101e-07, -9.87793476e-08,
#        -8.64856736e-08, -7.55166190e-08, -6.57566630e-08, -5.70966204e-08,
#        -4.94338824e-08, -4.26725249e-08, -3.67233078e-08, -3.15035858e-08,
#        -2.69371464e-08, -2.29539929e-08, -1.94900842e-08, -1.64870435e-08,
#        -1.38918459e-08, -1.16564928e-08, -9.73768065e-09, -8.09646916e-09,
#        -6.69795392e-09, -5.51094723e-09, -4.50766981e-09, -3.66345574e-09,
#        -2.95647212e-09, -2.36745451e-09, -1.87945888e-09, -1.47763019e-09,
#        -1.14898776e-09, -8.82227014e-10, -6.67537298e-10, -4.96435090e-10,
#        -3.61611970e-10, -2.56796564e-10, -1.76629648e-10, -1.16551571e-10,
#        -7.27011409e-11, -4.18251271e-11, -2.11975358e-11, -8.54785898e-12,
#        -1.99751263e-12, -3.72499811e-15, -1.31017432e-12, -4.90371772e-12,
#        -9.97659715e-12, -1.58935521e-11, -2.21633129e-11, -2.84139894e-11,
#        -3.43719148e-11, -3.98435376e-11, -4.46999995e-11, -4.88640654e-11,
#        -5.22991098e-11, -5.49998914e-11, -5.69848784e-11, -5.82899104e-11,
#        -5.89630109e-11, -5.90601816e-11, -5.86420333e-11, -5.77711244e-11,
#        -5.65098949e-11, -5.49190976e-11, -5.30566426e-11, -5.09767808e-11,
#        -4.87295652e-11, -4.63605346e-11, -4.39105757e-11, -4.14159235e-11,
#        -3.89082690e-11, -3.64149455e-11, -3.39591733e-11, -3.15603418e-11,
#        -2.92343165e-11, -2.69937572e-11, -2.48484389e-11, -2.28055671e-11,
#        -2.08700833e-11, -1.90449553e-11, -1.73314496e-11, -1.57293853e-11,
#        -1.42373666e-11, -1.28529945e-11, -1.15730582e-11, -1.03937056e-11,
#        -9.31059463e-12, -8.31902586e-12, -7.41405793e-12, -6.59060681e-12,
#        -5.84353031e-12, -5.16769913e-12, -4.55805575e-12, -4.00966238e-12,
#        -3.51773927e-12, -3.07769451e-12, -2.68514620e-12, -2.33593837e-12,
#        -2.02615112e-12, -1.75210616e-12, -1.51036830e-12, -1.29774370e-12,
#        -1.11127533e-12, -9.48236379e-13, -8.06121845e-13, -6.82638946e-13,
#        -5.75696530e-13, -4.83393891e-13, -4.04009196e-13, -3.35987771e-13,
#        -2.77930408e-13, -2.28581843e-13, -1.86819527e-13, -1.51642785e-13,
#        -1.22162423e-13, -9.75908442e-14, -7.72327084e-14, -6.04761552e-14,
#        -4.67845996e-14, -3.56891043e-14, -2.67813184e-14, -1.97069714e-14,
#        -1.41599028e-14, -9.87660529e-15, -6.63125760e-15, -4.23121909e-15,
#        -2.51295873e-15, -1.33838978e-15, -5.91581480e-16, -1.75819514e-16,
#        -1.09874684e-17, -3.12426599e-17, -1.82960600e-16, -4.22923729e-16,
#        -7.16731367e-16, -1.03740924e-15, -1.36419839e-15, -1.68150469e-15,
#        -1.97799163e-15, -2.24580058e-15, -2.47988360e-15, -2.67743598e-15,
#        -2.83741594e-15, -2.96014102e-15, -3.04695094e-15, -3.09992847e-15,
#        -3.12167011e-15, -3.11509983e-15, -3.08331944e-15, -3.02949026e-15,
#        -2.95674120e-15, -2.86809891e-15, -2.76643655e-15, -2.65443771e-15,
#        -2.53457292e-15, -2.40908624e-15, -2.27998994e-15, -2.14906552e-15,
#        -2.01786968e-15, -1.88774383e-15, -1.75982636e-15, -1.63506662e-15,
#        -1.51424005e-15, -1.39796379e-15, -1.28671244e-15, -1.18083357e-15,
#        -1.08056270e-15, -9.86037560e-16, -8.97311534e-16, -8.14366143e-16,
#        -7.37122541e-16, -6.65451991e-16, -5.99185341e-16, -5.38121496e-16,
#        -4.82034941e-16, -4.30682359e-16, -3.83808398e-16, -3.41150639e-16,
#        -3.02443837e-16, -2.67423498e-16, -2.35828848e-16, -2.07405259e-16,
#        -1.81906193e-16, -1.59094717e-16, -1.38744643e-16, -1.20641337e-16,
#        -1.04582254e-16, -9.03772296e-17, -7.78485645e-17, -6.68309484e-17,
#        -5.71712387e-17, -4.87281323e-17, -4.13717461e-17, -3.49831325e-17,
#        -2.94537455e-17, -2.46848714e-17, -2.05870423e-17, -1.70794377e-17,
#        -1.40892869e-17, -1.15512795e-17, -9.40698976e-18, -7.60431885e-18,
#        -6.09696060e-18, -4.84389185e-18, -3.80889051e-18, -2.96008170e-18,
#        -2.26951322e-18, -1.71276026e-18, -1.26855897e-18, -9.18468508e-19,
#        -6.46560452e-19, -4.39134820e-19, -2.84461089e-19, -1.72543213e-19,
#        -9.49069886e-20, -4.44085119e-20, -1.50621963e-20, -1.88687244e-21,
#        -7.68629780e-22, -8.33899483e-21, -2.18671246e-20, -3.91647750e-20,
#        -5.85028336e-20, -7.85383221e-20, -9.82507910e-20, -1.16887155e-19,
#        -1.33914059e-19, -1.48976943e-19, -1.61865029e-19, -1.72481567e-19,
#        -1.80818701e-19, -1.86936302e-19, -1.90944412e-19, -1.92988668e-19,
#        -1.93238378e-19, -1.91876928e-19, -1.89094020e-19, -1.85079618e-19,
#        -1.80019333e-19, -1.74090865e-19, -1.67461512e-19, -1.60286430e-19,
#        -1.52707583e-19, -1.44853185e-19, -1.36837596e-19, -1.28761514e-19,
#        -1.20712453e-19, -1.12765376e-19, -1.04983493e-19, -9.74190847e-20,
#        -9.01144422e-20, -8.31028100e-20, -7.64092742e-20, -7.00517233e-20,
#        -6.40416703e-20, -5.83851176e-20, -5.30833232e-20, -4.81335090e-20,
#        -4.35295416e-20, -3.92625131e-20, -3.53212864e-20, -3.16929989e-20,
#        -2.83634630e-20, -2.53175641e-20, -2.25395744e-20, -2.00134441e-20,
#        -1.77230266e-20, -1.56522971e-20, -1.37855106e-20, -1.21073284e-20,
#        -1.06029494e-20, -9.25816288e-21, -8.05943618e-21, -6.99394402e-21,
#        -6.04960236e-21, -5.21507644e-21, -4.47978623e-21, -3.83390170e-21,
#        -3.26832047e-21, -2.77465026e-21, -2.34518533e-21, -1.97286897e-21,
#        -1.65126871e-21, -1.37453668e-21, -1.13737549e-21, -9.35000595e-22,
#        -7.63109504e-22, -6.17838126e-22, -4.95733222e-22, -3.93715972e-22,
#        -3.09050759e-22, -2.39314366e-22, -1.82368170e-22, -1.36330289e-22,
#        -9.95507293e-23, -7.05875091e-23, -4.81856910e-23, -3.12567436e-23,
#        -1.88598973e-23, -1.01860143e-23, -4.54198337e-24, -1.33653956e-24,
#        -6.80639282e-26, -3.13059677e-25, -1.71608443e-24, -3.98061957e-24,
#        -6.86098796e-24, -1.01552362e-23, -1.36986110e-23, -1.73581162e-23,
#        -2.10276142e-23, -2.46232471e-23, -2.80801880e-23, -3.13489089e-23,
#        -3.43925254e-23, -3.71844304e-23, -3.97064160e-23, -4.19463900e-23,
#        -4.38975318e-23, -4.55565884e-23, -4.69230007e-23, -4.79981007e-23,
#        -4.87845037e-23, -4.92853495e-23, -4.95041538e-23, -4.94444850e-23])

# %% [markdown]
# # Compare to
# ### "Simple Classical Mapping of the Spin-Polarized Quantum Electron Gas: Distribution Functions and Local-Field Corrections" - Dharma-Wardana

# %%
def get_β_cP(h_r): #Pauli potential
    h_k = atom.hnc.FT_r_2_k(h_r)

    I_plus_h_rho_inverse = 1/(1 + 0.5*h_k*atom.hnc.rho[0])
    c_k = I_plus_h_rho_inverse * h_k
    c_r = atom.hnc.FT_k_2_r(c_k)

    # Approximate with HNC
    β_cP   = h_r - c_r -np.log(h_r+1)
    return β_cP

β_cP_DST = get_β_cP(h_ee_ID_DST)
β_cP_explicit = get_β_cP(h_ee_ID_explicit)

# %%
DW_gee_T0_data = read_csv("/home/zach/plasma/datasets/RDFs/gee_T=2EF.txt",delim_whitespace=True, header=1)
DW_βP_T0_data = read_csv("/home/zach/plasma/datasets/RDFs/βPee_T=2EF.txt",delim_whitespace=True, header=1)

# %%
fig, ax = plt.subplots(figsize=(4,6))

ax.plot(atom.hnc.r_array*atom.qsp.k_F*atom.qsp.ri, β_cP_DST, label=r'$\beta P$ DST')
ax.plot(atom.hnc.r_array*atom.qsp.k_F*atom.qsp.ri, β_cP_explicit, label=r'$\beta P$ Explicit')
ax.plot(atom.hnc.r_array, atom.qsp.βv_Pauli(atom.hnc.r_array, atom.qsp.Λee),label=r'$\beta P$ Standard')
ax.plot(DW_βP_T0_data['rkF'], DW_βP_T0_data['βP_ee'],'k.')
ax2 = ax.twinx()
ax2.plot(atom.hnc.r_array*atom.qsp.k_F*atom.qsp.ri, h_ee_ID_DST +1,'k-.')
ax2.plot(atom.hnc.r_array*atom.qsp.k_F*atom.qsp.ri, h_ee_ID_explicit +1,'k--')
ax2.plot(DW_gee_T0_data['rkF'], DW_gee_T0_data['gee'],'kx')
# ax2.plot(atom.hnc.r_array*atom.qsp.k_F*atom.qsp.ri, h_ee_ID_explicit+1)
# ax.set_xscale('log')

ax2.set_ylim(0,1.25)
ax.set_ylim(0,1.25)
ax.set_xlim(0,5)
ax.set_xlim(0,5)
ax.set_xlabel(r"$r k_F$",fontsize=20)
ax.set_ylabel(r"$\beta P $",fontsize=20)
ax2.set_ylabel(r"$g_{ii} $",fontsize=20)
ax.tick_params(labelsize=14)
ax2.tick_params(labelsize=14)
ax.legend(fontsize=12)

# %% [markdown]
# # Invert HNC

# %%
# def get_β_cP(h_r): #Pauli potential
#     h_r_matrix = np.array([[h_r, 0*h_r],[0*h_r, h_r]])
#     h_k_matrix = atom.hnc.FT_r_2_k_matrix(h_r_matrix)
#     rho_matrix = 0.5*np.array([atom.hnc.rho[1], atom.hnc.rho[1]])
    
#     I_plus_h_rho_inverse = atom.hnc.invert_matrix(atom.hnc.I[:,:,np.newaxis] + h_k_matrix*rho_matrix[:,np.newaxis,np.newaxis])#1/(1 + h_k*atom.hnc.rho[0])
#     c_k = atom.hnc.A_times_B(  I_plus_h_rho_inverse, h_k_matrix)
#     c_r = atom.hnc.FT_k_2_r_matrix(c_k)

#     # Approximate with HNC
#     β_cP   = h_r - c_r -np.log(h_r+1)
#     return β_cP

# β_cP_DST = get_β_cP(h_ee_ID_DST)
# # β_cP_explicit = get_β_cP(h_ee_ID_explicit)

# %%
fig, ax = plt.subplots()

ax.plot(atom.hnc.r_array, β_cP_DST, label='DST')
ax.plot(atom.hnc.r_array, β_cP_explicit,label='explicit')
ax.plot(atom.hnc.r_array, qsp.βv_Pauli(atom.hnc.r_array, qsp.Λee),label=r'$\beta P_1$')
Λee_test = 1/np.sqrt(2*π*(m_e/2)*atom.qsp.Te_c )/atom.qsp.ri 
ax.plot(atom.hnc.r_array, np.log(2)*np.exp(-np.log(2)*atom.hnc.r_array**2/(π*Λee_test**2)),label=r'$\beta P_2$'  )
ax.plot(atom.hnc.r_array, np.log(2)*np.exp(-atom.hnc.r_array**2/(π*np.log(2)*Λee_test**2)),label=r'$\beta P_3$'  )
# ax.set_yscale('log')
ax.set_xscale('log')

# ax.set_ylim(1e-1,1e0)
ax.set_ylabel(r'$\beta P$')
ax.set_xlabel(r'$r/r_i$')
ax.legend()

# %%
from scipy.special import erfc

def Slater_S(Γ):
    ymax = 100
    ymin = 0.01*π*np.sqrt(Γ*qsp.re)
    N = int(ymax/ymin)
    print(N)
    y = np.linspace(0,1e2,num=N)
    dy = y[1]-y[0]
    return -4* np.sqrt(π*Γ*qsp.re) * np.sum(dy* np.exp(-y**2)*y/(1 - np.exp(π*np.sqrt(Γ*qsp.re)/y )  ) )

def β_cΔ(Γ, x): 
    """
    x=r/r_e   
    """
    a = np.sqrt(qsp.re/Γ)
    γ = -np.sqrt(π*Γ*qsp.re)/np.log(Slater_S(Γ))
#     return Γ/x*( 1 - np.exp(-a**2*x**2) + np.sqrt(π)*a*x *erfc(a*x))
    return Γ/x*( 1 - np.exp(-a**2*x**2) + np.sqrt(π)*a*x/γ *erfc(γ*a*x))
    
def Γc():
    Γ = 1/(qsp.Te*qsp.re)
    ωp = np.sqrt(4*π*qsp.ne/m_e)
    return 2*Γ*qsp.Te * np.tanh(ωp/(2*qsp.Te))/( ωp  )

# %%
fig, ax = plt.subplots()

ax.plot(atom.hnc.r_array, β_cΔ(Γc(), atom.hnc.r_array*qsp.ri/qsp.re ),label= "Dufty")
ax.plot(atom.hnc.r_array, qsp.βv_Kelbg(qsp.Γee, atom.hnc.r_array, qsp.Λee), label='Kelbg')
ax.plot(atom.hnc.r_array, qsp.βv_Deutsch(qsp.Γee, atom.hnc.r_array, qsp.Λee),label='Deutsch')
# ax.plot(atom.hnc.r_array, qsp.βv_Kelbg(Γc(), atom.hnc.r_array, qsp.Λee))
ax.legend()
# Out:
# 1710
# /tmp/ipykernel_7200/3922971775.py:10: RuntimeWarning: divide by zero encountered in divide
#   return -4* np.sqrt(π*Γ*qsp.re) * np.sum(dy* np.exp(-y**2)*y/(1 - np.exp(π*np.sqrt(Γ*qsp.re)/y )  ) )

# %%
np.savetxt("βvee.txt",np.array([atom.hnc.r_array, β_cP_DST + β_cΔ(Γc(), atom.hnc.r_array*qsp.ri/qsp.re )]).T)
# Out:
# 1710
# /tmp/ipykernel_42832/3922971775.py:10: RuntimeWarning: divide by zero encountered in divide
#   return -4* np.sqrt(π*Γ*qsp.re) * np.sum(dy* np.exp(-y**2)*y/(1 - np.exp(π*np.sqrt(Γ*qsp.re)/y )  ) )

# %%
βu_r_matrix = np.array([[β_cP_DST + β_cΔ(Γc(), atom.hnc.r_array*qsp.ri/qsp.re ) ]])

atom.hnc.set_βu_matrix(βu_r_matrix)
atom.hnc.initialize_c_k()
atom.hnc.set_C_matrix()
atom.hnc.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
h_r_DST = atom.hnc.h_r_matrix[0,0]

βu_r_matrix = np.array([[β_cP_explicit + β_cΔ(Γc(), atom.hnc.r_array*qsp.ri/qsp.re ) ]])

atom.hnc.set_βu_matrix(βu_r_matrix)
atom.hnc.initialize_c_k()
atom.hnc.set_C_matrix()
atom.hnc.HNC_solve(alpha_method='best', alpha_Picard = 1e-2, alpha_oz = 1e-4, h_max=1e4)
h_r_explicit = atom.hnc.h_r_matrix[0,0]
# Out:
# 1710
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 7.19e-02, OZ: 1.01e-01, HNC: 1.88e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 4.28e-02, OZ: 1.04e-01, HNC: 9.86e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 2.55e-02, OZ: 1.06e-01, HNC: 5.58e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 1.53e-02, OZ: 1.07e-01, HNC: 3.30e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 9.24e-03, OZ: 1.08e-01, HNC: 2.00e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 5: Err in c_r: 5.63e-03, OZ: 1.08e-01, HNC: 1.24e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 6: Err in c_r: 3.45e-03, OZ: 1.08e-01, HNC: 7.72e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 7: Err in c_r: 2.13e-03, OZ: 1.09e-01, HNC: 4.87e-04
# /tmp/ipykernel_42832/3922971775.py:10: RuntimeWarning: divide by zero encountered in divide
#   return -4* np.sqrt(π*Γ*qsp.re) * np.sum(dy* np.exp(-y**2)*y/(1 - np.exp(π*np.sqrt(Γ*qsp.re)/y )  ) )
#  HNC min: [0.5] True Optimization terminated successfully.
# 8: Err in c_r: 1.33e-03, OZ: 1.09e-01, HNC: 3.09e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 9: Err in c_r: 8.34e-04, OZ: 1.09e-01, HNC: 1.97e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 10: Err in c_r: 5.25e-04, OZ: 1.09e-01, HNC: 1.26e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 11: Err in c_r: 3.33e-04, OZ: 1.09e-01, HNC: 8.06e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 12: Err in c_r: 2.11e-04, OZ: 1.09e-01, HNC: 5.17e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 13: Err in c_r: 1.35e-04, OZ: 1.09e-01, HNC: 3.33e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 14: Err in c_r: 8.62e-05, OZ: 1.09e-01, HNC: 2.14e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 15: Err in c_r: 5.52e-05, OZ: 1.09e-01, HNC: 1.38e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 16: Err in c_r: 3.54e-05, OZ: 1.09e-01, HNC: 8.89e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 17: Err in c_r: 2.28e-05, OZ: 1.09e-01, HNC: 5.73e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 18: Err in c_r: 1.47e-05, OZ: 1.09e-01, HNC: 3.70e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 19: Err in c_r: 9.43e-06, OZ: 1.09e-01, HNC: 2.39e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 20: Err in c_r: 6.08e-06, OZ: 1.09e-01, HNC: 1.54e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 21: Err in c_r: 3.92e-06, OZ: 1.09e-01, HNC: 9.95e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 22: Err in c_r: 2.53e-06, OZ: 1.09e-01, HNC: 6.43e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 23: Err in c_r: 1.63e-06, OZ: 1.09e-01, HNC: 4.15e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 24: Err in c_r: 1.05e-06, OZ: 1.09e-01, HNC: 2.68e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 25: Err in c_r: 6.80e-07, OZ: 1.09e-01, HNC: 1.73e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 26: Err in c_r: 4.39e-07, OZ: 1.09e-01, HNC: 1.12e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 27: Err in c_r: 2.83e-07, OZ: 1.09e-01, HNC: 7.23e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 28: Err in c_r: 1.83e-07, OZ: 1.09e-01, HNC: 4.67e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 29: Err in c_r: 1.18e-07, OZ: 1.09e-01, HNC: 3.02e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 30: Err in c_r: 7.64e-08, OZ: 1.09e-01, HNC: 1.95e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 31: Err in c_r: 4.93e-08, OZ: 1.09e-01, HNC: 1.26e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 32: Err in c_r: 3.19e-08, OZ: 1.09e-01, HNC: 8.14e-09
#  HNC min: [0.5] True Optimization terminated successfully.
# 33: Err in c_r: 2.06e-08, OZ: 1.09e-01, HNC: 5.26e-09
#  HNC min: [0.5] True Optimization terminated successfully.
# 34: Err in c_r: 1.33e-08, OZ: 1.09e-01, HNC: 3.40e-09
#  HNC min: [0.5] True Optimization terminated successfully.
# 35: Err in c_r: 8.60e-09, OZ: 1.09e-01, HNC: 2.20e-09
# 1710
#  HNC min: [0.5] True Optimization terminated successfully.
# 0: Err in c_r: 7.70e-02, OZ: 1.00e-01, HNC: 1.79e-02
#  HNC min: [0.5] True Optimization terminated successfully.
# 1: Err in c_r: 4.38e-02, OZ: 1.03e-01, HNC: 9.02e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 2: Err in c_r: 2.49e-02, OZ: 1.04e-01, HNC: 4.91e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 3: Err in c_r: 1.42e-02, OZ: 1.05e-01, HNC: 2.79e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 4: Err in c_r: 8.13e-03, OZ: 1.06e-01, HNC: 1.63e-03
#  HNC min: [0.5] True Optimization terminated successfully.
# 5: Err in c_r: 4.69e-03, OZ: 1.06e-01, HNC: 9.67e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 6: Err in c_r: 2.73e-03, OZ: 1.06e-01, HNC: 5.80e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 7: Err in c_r: 1.60e-03, OZ: 1.06e-01, HNC: 3.51e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 8: Err in c_r: 9.47e-04, OZ: 1.06e-01, HNC: 2.14e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 9: Err in c_r: 5.64e-04, OZ: 1.07e-01, HNC: 1.31e-04
#  HNC min: [0.5] True Optimization terminated successfully.
# 10: Err in c_r: 3.38e-04, OZ: 1.07e-01, HNC: 8.04e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 11: Err in c_r: 2.04e-04, OZ: 1.07e-01, HNC: 4.95e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 12: Err in c_r: 1.23e-04, OZ: 1.07e-01, HNC: 3.06e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 13: Err in c_r: 7.52e-05, OZ: 1.07e-01, HNC: 1.89e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 14: Err in c_r: 4.59e-05, OZ: 1.07e-01, HNC: 1.17e-05
#  HNC min: [0.5] True Optimization terminated successfully.
# 15: Err in c_r: 2.81e-05, OZ: 1.07e-01, HNC: 7.25e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 16: Err in c_r: 1.73e-05, OZ: 1.07e-01, HNC: 4.50e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 17: Err in c_r: 1.07e-05, OZ: 1.07e-01, HNC: 2.79e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 18: Err in c_r: 6.57e-06, OZ: 1.07e-01, HNC: 1.73e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 19: Err in c_r: 4.06e-06, OZ: 1.07e-01, HNC: 1.08e-06
#  HNC min: [0.5] True Optimization terminated successfully.
# 20: Err in c_r: 2.51e-06, OZ: 1.07e-01, HNC: 6.70e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 21: Err in c_r: 1.56e-06, OZ: 1.07e-01, HNC: 4.17e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 22: Err in c_r: 9.66e-07, OZ: 1.07e-01, HNC: 2.59e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 23: Err in c_r: 5.99e-07, OZ: 1.07e-01, HNC: 1.61e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 24: Err in c_r: 3.72e-07, OZ: 1.07e-01, HNC: 1.00e-07
#  HNC min: [0.5] True Optimization terminated successfully.
# 25: Err in c_r: 2.31e-07, OZ: 1.07e-01, HNC: 6.24e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 26: Err in c_r: 1.44e-07, OZ: 1.07e-01, HNC: 3.89e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 27: Err in c_r: 8.93e-08, OZ: 1.07e-01, HNC: 2.42e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 28: Err in c_r: 5.56e-08, OZ: 1.07e-01, HNC: 1.51e-08
#  HNC min: [0.5] True Optimization terminated successfully.
# 29: Err in c_r: 3.46e-08, OZ: 1.07e-01, HNC: 9.37e-09
#  HNC min: [0.5] True Optimization terminated successfully.
# 30: Err in c_r: 2.15e-08, OZ: 1.07e-01, HNC: 5.84e-09
#  HNC min: [0.5] True Optimization terminated successfully.
# 31: Err in c_r: 1.34e-08, OZ: 1.07e-01, HNC: 3.63e-09
#  HNC min: [0.5] True Optimization terminated successfully.
# 32: Err in c_r: 8.33e-09, OZ: 1.07e-01, HNC: 2.26e-09

# %%
fig, ax = plt.subplots()
DD_data_rs1_t1 = np.array([[0.015915119363395226, 0.22208955223880597],
[0.16710875331564987, 0.2740298507462687 ],
[0.42572944297082227, 0.4298507462686567 ],
[0.7519893899204244, 0.6698507462686567 ],
[1.0145888594164456, 0.8202985074626866 ],
[1.3647214854111407, 0.9223880597014925 ],
[1.9456233421750664, 0.9779104477611941 ],
[2.944297082228117, 1.0011940298507462  ]]).T

DD_data_rs40_t8 = np.array([[0.09767441860465116, 0.002628120893561104 ],
[0.3697674418604651, 0.02759526938239159  ],
[0.5895348837209302, 0.16294349540078845  ],
[0.8093023255813954, 0.4231274638633377  ],
[1.0186046511627906, 0.6649145860709593  ],
[1.1651162790697673, 0.7936925098554534  ],
[1.3813953488372093, 0.9132720105124836  ],
[1.744186046511628, 0.9894875164257556  ],
[2.644186046511628, 1.0052562417871223  ]]).T

DD_data_rs1_t0p0625 = np.array([[0.015810276679841896, 0.2360060514372163],
[0.2292490118577075, 0.291981845688351   ],  
[0.6600790513833992, 0.4962178517397882  ],  
[1.0434782608695652, 0.708018154311649   ], 
[1.4584980237154148, 0.897125567322239   ],  
[1.7549407114624505, 0.9697428139183056  ], 
[2.276679841897233, 1.0030257186081695   ],
[2.7786561264822134, 1.0030257186081695  ], 
[3.0948616600790513, 1.0030257186081695  ]]).T

ax.plot(atom.hnc.r_array, h_r_DST+1,'-', label='dst')
ax.plot(atom.hnc.r_array, h_r_explicit+1,'--',label='explicit')
# ax.plot(DD_data_rs1_t1[0],DD_data_rs1_t1[1],'k.',label='data')
# ax.plot(DD_data_rs40_t8[0],DD_data_rs40_t8[1],'k.',label='data')
ax.plot(DD_data_rs1_t0p0625[0],DD_data_rs1_t0p0625[1],'k.',label='data')
ax.legend()
ax.set_xlim(0,5)
ax.set_ylim(0,1.5)
# Out:
# (0.0, 1.5)
