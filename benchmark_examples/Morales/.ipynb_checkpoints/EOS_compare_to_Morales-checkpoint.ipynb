# %% [markdown]
# # Integral Equation Model Comparisons
# Purpose of this notebook is to EOS calculations for comparisons to CEIMC EOS Hydrogen paper and atoMEC
#
# [https://journals.aps.org/pre/abstract/10.1103/PhysRevE.81.021202](https://journals.aps.org/pre/abstract/10.1103/PhysRevE.81.021202)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

from hnc.hnc.PIE import Plasma_of_Ions_and_Electrons as PLASMA

from hnc.hnc.constants import *
from hnc.hnc.misc import n_from_rs, rs_from_n

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
                
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# ModuleNotFoundError: No module named 'mendeleev'
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %% [markdown]
# #### Load Morales CEIMC Data

# %%
CEIMC_file = "Morales_EOS_CEIMC.dat"
CEIMC_df = read_csv(CEIMC_file, delim_whitespace=True, header=4)
CEIMC_EAU  = CEIMC_df['E[AU]']
CEIMC_rs  = CEIMC_df['rs']
CEIMC_PGPa = CEIMC_df['P[GPa]']
CEIMC_TK   = CEIMC_df['T[K]']
CEIMC_PMbar =  1e-2*CEIMC_PGPa
CEIMC_TeV = CEIMC_TK/eV_to_K

# %%
CEIMC_df
# Out:
#      T[K]  ρ[g/cm3]    rs    E[AU]  P[GPa]
# 0    2000     2.329  1.05  −0.3846    1576
# 1    3000     2.329  1.05  −0.3777    1607
# 2    4000     2.329  1.05  −0.3707    1640
# 3    6000     2.329  1.05  −0.3569    1701
# 4    8000     2.329  1.05  −0.3458    1753
# 5   10000     2.329  1.05  −0.3316    1814
# 6    2000     2.026  1.10  −0.4170    1157
# 7    3000     2.026  1.10  −0.4097    1190
# 8    4000     2.026  1.10  −0.4026    1219
# 9    6000     2.026  1.10  −0.3898    1270
# 10   8000     2.026  1.10  −0.3777    1315
# 11  10000     2.026  1.10  −0.3660    1362
# 12   2000     1.773  1.15  −0.4419     861
# 13   3000     1.773  1.15  −0.4356     883
# 14   4000     1.773  1.15  −0.4285     911
# 15   6000     1.773  1.15  −0.4151     956
# 16   8000     1.773  1.15  −0.4018    1003
# 17  10000     1.773  1.15  −0.3891    1048
# 18   2000     1.380  1.25  −0.4790     482
# 19   3000     1.380  1.25  −0.4721     501
# 20   4000     1.380  1.25  −0.4673     514
# 21   6000     1.380  1.25  −0.4549     553
# 22   8000     1.380  1.25  −0.4419     588
# 23  10000     1.380  1.25  −0.4324     616
# 24   2000     0.983  1.40  −0.5117     213
# 25   3000     0.983  1.40  −0.5057     220
# 26   4000     0.983  1.40  −0.4993     232
# 27   6000     0.983  1.40  −0.4869     256
# 28   8000     0.983  1.40  −0.4767     275
# 29  10000     0.983  1.40  −0.4674     295
# 30   2000     0.724  1.55  −0.5330     111
# 31   3000     0.724  1.55  −0.5230     105
# 32   4000     0.724  1.55  −0.5157     116
# 33   6000     0.724  1.55  −0.5027     134
# 34   8000     0.724  1.55  −0.4938     143
# 35  10000     0.724  1.55  −0.4831     162

# %% [markdown]
# #### Load Morales BOMD Data

# %%
BOMD_file = "Morales_EOS_BOMD.dat"
BOMD_df = read_csv(BOMD_file, delim_whitespace=True, header=4)
BOMD_EAU  = BOMD_df['E[AU]']
BOMD_rs  = BOMD_df['rs']
BOMD_PGPa = BOMD_df['P[GPa]']
BOMD_TK   = BOMD_df['T[K]']
BOMD_PMbar =  1e-2*BOMD_PGPa
BOMD_TeV = BOMD_TK/eV_to_K

# %%
BOMD_df
# Out:
#      T[K]  ρ[g/cm3]    rs     E[AU]  P[GPa]
# 0    4000     2.329  1.05  −0.37438  1635.4
# 1    6000     2.329  1.05   −0.3610  1701.0
# 2    8000     2.329  1.05   −0.3484  1762.4
# 3   10000     2.329  1.05   −0.3360  1823.0
# 4    4000     2.026  1.10   −0.4059  1218.7
# 5    6000     2.026  1.10   −0.3927  1276.1
# 6    8000     2.026  1.10   −0.3804  1328.8
# 7   10000     2.026  1.10   −0.3690  1378.0
# 8    4000     1.773  1.15  −0.43137   916.5
# 9    6000     1.773  1.15  −0.41883   964.8
# 10   8000     1.773  1.15  −0.40686  1010.1
# 11  10000     1.773  1.15  −0.39542  1053.8
# 12   4000     1.380  1.25  −0.46886   528.0
# 13   6000     1.380  1.25  −0.45675   565.1
# 14   8000     1.380  1.25   −0.4451   600.4
# 15  10000     1.380  1.25   −0.4344   633.2
# 16   4000     0.983  1.40  −0.50203   241.9
# 17   6000     0.983  1.40   −0.4905   267.0
# 18   8000     0.983  1.40   −0.4796   291.6
# 19  10000     0.983  1.40   −0.4692   315.0

# %% [markdown]
# #### Load atoMEC data

# %%
atoMEC_file = "atoMEC_H_pressures.dat"
atoMEC_df = read_csv(atoMEC_file, delim_whitespace=True, header=0)
atoMEC_df
# Out:
#         T[eV]    rs     P[AU]
# 0     0.17235  1.05  0.046682
# 1     0.41796  1.05  0.046722
# 2     1.01360  1.05  0.046956
# 3     2.45810  1.05  0.048324
# 4     5.96100  1.05  0.056139
# 5    14.45600  1.05  0.094099
# 6    35.05700  1.05  0.225690
# 7    85.01800  1.05  0.586500
# 8   206.18000  1.05  1.492800
# 9   500.00000  1.05  3.710600
# 10    0.17235  1.10  0.033502
# 11    0.41796  1.10  0.033540
# 12    1.01360  1.10  0.033763
# 13    2.45810  1.10  0.035067
# 14    5.96100  1.10  0.042467
# 15   14.45600  1.10  0.077305
# 16   35.05700  1.10  0.194140
# 17   85.01800  1.10  0.509710
# 18  206.18000  1.10  1.299400
# 19  500.00000  1.10  3.229000
# 20    0.17235  1.15  0.024025
# 21    0.41796  1.15  0.024062
# 22    1.01360  1.15  0.024275
# 23    2.45810  1.15  0.025521
# 24    5.96100  1.15  0.032532
# 25   14.45600  1.15  0.064504
# 26   35.05700  1.15  0.168570
# 27   85.01800  1.15  0.446320
# 28  206.18000  1.15  1.138200
# 29  500.00000  1.15  2.826700
# 30    0.17235  1.25  0.012138
# 31    0.41796  1.25  0.012172
# 32    1.01360  1.25  0.012368
# 33    2.45810  1.25  0.013511
# 34    5.96100  1.25  0.019808
# 35   14.45600  1.25  0.046754
# 36   35.05700  1.25  0.130080
# 37   85.01800  1.25  0.348110
# 38  206.18000  1.25  0.888020
# 39  500.00000  1.25  2.203900
# 40    0.17235  1.40  0.003733
# 41    0.41796  1.40  0.003763
# 42    1.01360  1.40  0.003938
# 43    2.45810  1.40  0.004952
# 44    5.96100  1.40  0.010311
# 45   14.45600  1.40  0.031255
# 46   35.05700  1.40  0.092317
# 47   85.01800  1.40  0.248780
# 48  206.18000  1.40  0.633890
# 49  500.00000  1.40  1.570800
# 50    0.17235  1.55  0.000343
# 51    0.41796  1.55  0.000370
# 52    1.01360  1.55  0.000527
# 53    2.45810  1.55  0.001434
# 54    5.96100  1.55  0.005986
# 55   14.45600  1.55  0.022405
# 56   35.05700  1.55  0.068281
# 57   85.01800  1.55  0.184190
# 58  206.18000  1.55  0.468340
# 59  500.00000  1.55  1.158700

# %% [markdown]
# ### Set Parameters in Paper and Plot

# %%
name = 'Hydrogen'
Z, A = 1,1 

Te_eV_list = np.geomspace(0.172347, 1e3, num=10) #np.array(GP_Te_eV) # eV
Ti_eV_list = Te_eV_list

# ri_cm = rs_from_n(ni_cc)  # cm
ri_AU_list = np.sort(np.array(list(set(CEIMC_rs))))    # AU 
ri_AU_list
# Out:
# array([1.05, 1.1 , 1.15, 1.25, 1.4 , 1.55])

# %% [markdown]
# #### Run Ornstein-Zernike Closure

# %%
def plasma_output(plasma):
    plasma.run_hnc()
    try: 
        plasma.hnc.βu_r_matrix[1,1] -= plasma.βP_ee
    except:
        plasma.hnc.βu_r_matrix[1,1] -= plasma.qsp.βv_Pauli(plasma.hnc.r_array, plasma.qsp.Λee)
    Pe_hnc_id, Pe_hnc_ex   = plasma.hnc.rho[1]*plasma.hnc.Temp_list[1],  np.sum( plasma.hnc.excess_pressure_matrix(),axis=1 )[1] 
    try: 
        plasma.hnc.βu_r_matrix[1,1] += plasma.βP_ee
    except:
        plasma.hnc.βu_r_matrix[1,1] += plasma.qsp.βv_Pauli(plasma.hnc.r_array, plasma.qsp.Λee)
    
    Pe_Mbar_id, Pe_Mbar_ex = P_hnc_to_Mbar(Pe_hnc_id, plasma.qsp.ri), P_hnc_to_Mbar(Pe_hnc_ex, plasma.qsp.ri)
    Pe_Mbar = Pe_Mbar_id + Pe_Mbar_ex
    return Pe_Mbar_id, Pe_Mbar_ex, Pe_Mbar

name1 = 'OZ - g'
plasma1 = lambda T_eV, ni_cc: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0,'which_Tij':'geometric'},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
name2 = 'OZ - th'
plasma2 = lambda T_eV, ni_cc: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0,'which_Tij':'thermal'},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
name3 = 'OZ - th  Pauli'
plasma3 = lambda T_eV, ni_cc: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z, find_βuee=True,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0,'which_Tij':'thermal'},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
name4 = 'SVT - th'
plasma4 =  lambda T_eV, ni_cc: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'svt'},
                 hnc_solve_options={'alpha_Picard':0.5,'num_iterations':1e4})

P_hnc_to_bar = lambda P_hnc, ri: (P_hnc/ri**3) *  AU_to_bar 
P_hnc_to_Mbar = lambda P_hnc, ri: 1e-6*P_hnc_to_bar(P_hnc, ri)
P_hnc_to_GPa = lambda P_hnc, ri:  P_hnc_to_bar(P_hnc, ri) * 1e5 / 1e9

# %% [markdown]
# ####  Investigate Pressure

# %%
# print("P = {0:.3e} [Mbar]".format(P_hnc_to_Mbar(Pid)))
# print("P = {0:.3e} [GPa]".format(P_hnc_to_GPa(Pid)))

# %% [markdown]
# ### Compute all plasma models for list of densities

# %%
P_list_1 = []
P_list_2 = []
P_list_3 = []
P_list_4 = []

for T_eV in Te_eV_list:
    for rs in ri_AU_list:
        ni_cc = n_from_rs(rs)*cm_to_AU**3
        #1
        # plasma = plasma1(T_eV, ni_cc)
        # Pe_id, Pe_ex, Pe = plasma_output(plasma)
        # P_list_1.append( [Pe_id, Pe_ex, Pe] )
        #2
        # plasma = plasma2(T_eV, ni_cc)
        # Pe_id, Pe_ex, Pe = plasma_output(plasma)
        # P_list_2.append( [Pe_id, Pe_ex, Pe] )
        #3
        plasma = plasma3(T_eV, ni_cc)
        Pe_id, Pe_ex, Pe = plasma_output(plasma)
        P_list_3.append( [Pe_id, Pe_ex, Pe] )
        #4
        # plasma = plasma4(T_eV, ni_cc)
        # Pe_id, Pe_ex, Pe = plasma_output(plasma)
        # P_list_4.append( [Pe_id, Pe_ex, Pe] )
# Out:
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# /home/zach/plasma/hnc/hnc/PIE.py:181: RuntimeWarning: overflow encountered in exp
#   integrand = lambda t: t*np.sin(sin_arg*t)/(1+np.exp(t**2-η))
# /home/zach/plasma/hnc/hnc/PIE.py:188: RuntimeWarning: overflow encountered in exp
#   f_of_k = 1/(  1+np.exp((dense_hnc.k_array/self.qsp.ri)**2/(2*m_e*self.qsp.Te) - η) )
# 0: Initial condition Total Error: 1.283e+01
# Exiting status 0, reverting to best index so far: 1036
# Final iter:1037, Total Error: 9.874e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.244e+01
# Exiting status 0, reverting to best index so far: 993
# Final iter:994, Total Error: 9.969e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.208e+01
# Exiting status 0, reverting to best index so far: 954
# Final iter:955, Total Error: 9.998e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.143e+01
# Exiting status 0, reverting to best index so far: 886
# Final iter:887, Total Error: 9.877e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.060e+01
# Exiting status 0, reverting to best index so far: 801
# Final iter:802, Total Error: 9.841e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 9.900e+00
# Exiting status 0, reverting to best index so far: 732
# Final iter:733, Total Error: 9.775e-09
# Te_in_eV: 0.451
# Ti_in_eV: 0.451
# 0: Initial condition Total Error: 6.681e+00
# Exiting status 0, reverting to best index so far: 449
# Final iter:450, Total Error: 9.844e-09
# Te_in_eV: 0.451
# Ti_in_eV: 0.451
# 0: Initial condition Total Error: 6.467e+00
# Exiting status 0, reverting to best index so far: 432
# Final iter:433, Total Error: 9.739e-09
# Te_in_eV: 0.451
# Ti_in_eV: 0.451
# 0: Initial condition Total Error: 6.269e+00
# Exiting status 0, reverting to best index so far: 416
# Final iter:417, Total Error: 9.797e-09
# Te_in_eV: 0.451
# Ti_in_eV: 0.451
# 0: Initial condition Total Error: 5.912e+00
# Exiting status 0, reverting to best index so far: 388
# Final iter:389, Total Error: 9.746e-09
# Te_in_eV: 0.451
# Ti_in_eV: 0.451
# 0: Initial condition Total Error: 5.457e+00
# Exiting status 0, reverting to best index so far: 353
# Final iter:354, Total Error: 9.687e-09
# Te_in_eV: 0.451
# Ti_in_eV: 0.451
# 0: Initial condition Total Error: 5.076e+00
# Exiting status 0, reverting to best index so far: 324
# Final iter:325, Total Error: 9.775e-09
# Te_in_eV: 1.182
# Ti_in_eV: 1.182
# 0: Initial condition Total Error: 3.337e+00
# Exiting status 0, reverting to best index so far: 208
# Final iter:209, Total Error: 9.712e-09
# Te_in_eV: 1.182
# Ti_in_eV: 1.182
# 0: Initial condition Total Error: 3.223e+00
# Exiting status 0, reverting to best index so far: 201
# Final iter:202, Total Error: 9.380e-09
# Te_in_eV: 1.182
# Ti_in_eV: 1.182
# 0: Initial condition Total Error: 3.118e+00
# Exiting status 0, reverting to best index so far: 194
# Final iter:195, Total Error: 9.511e-09
# Te_in_eV: 1.182
# Ti_in_eV: 1.182
# 0: Initial condition Total Error: 2.929e+00
# Exiting status 0, reverting to best index so far: 182
# Final iter:183, Total Error: 9.313e-09
# Te_in_eV: 1.182
# Ti_in_eV: 1.182
# 0: Initial condition Total Error: 2.689e+00
# Exiting status 0, reverting to best index so far: 166
# Final iter:167, Total Error: 9.821e-09
# Te_in_eV: 1.182
# Ti_in_eV: 1.182
# 0: Initial condition Total Error: 2.490e+00
# Exiting status 0, reverting to best index so far: 153
# Final iter:154, Total Error: 9.946e-09
# Te_in_eV: 3.097
# Ti_in_eV: 3.097
# 0: Initial condition Total Error: 1.583e+00
# Exiting status 0, reverting to best index so far: 104
# Final iter:105, Total Error: 9.297e-09
# Te_in_eV: 3.097
# Ti_in_eV: 3.097
# 0: Initial condition Total Error: 1.525e+00
# Exiting status 0, reverting to best index so far: 101
# Final iter:102, Total Error: 8.599e-09
# Te_in_eV: 3.097
# Ti_in_eV: 3.097
# 0: Initial condition Total Error: 1.472e+00
# Exiting status 0, reverting to best index so far: 97
# Final iter:98, Total Error: 9.819e-09
# Te_in_eV: 3.097
# Ti_in_eV: 3.097
# 0: Initial condition Total Error: 1.377e+00
# Exiting status 0, reverting to best index so far: 92
# Final iter:93, Total Error: 8.451e-09
# Te_in_eV: 3.097
# Ti_in_eV: 3.097
# 0: Initial condition Total Error: 1.260e+00
# Exiting status 0, reverting to best index so far: 84
# Final iter:85, Total Error: 9.200e-09
# Te_in_eV: 3.097
# Ti_in_eV: 3.097
# 0: Initial condition Total Error: 1.165e+00
# Exiting status 0, reverting to best index so far: 78
# Final iter:79, Total Error: 8.371e-09
# Te_in_eV: 8.112
# Ti_in_eV: 8.112
# 0: Initial condition Total Error: 7.060e-01
# Exiting status 0, reverting to best index so far: 56
# Final iter:57, Total Error: 9.379e-09
# Te_in_eV: 8.112
# Ti_in_eV: 8.112
# 0: Initial condition Total Error: 6.796e-01
# Exiting status 0, reverting to best index so far: 55
# Final iter:56, Total Error: 7.426e-09
# Te_in_eV: 8.112
# Ti_in_eV: 8.112
# 0: Initial condition Total Error: 6.558e-01
# Exiting status 0, reverting to best index so far: 53
# Final iter:54, Total Error: 8.201e-09
# Te_in_eV: 8.112
# Ti_in_eV: 8.112
# 0: Initial condition Total Error: 6.147e-01
# Exiting status 0, reverting to best index so far: 50
# Final iter:51, Total Error: 8.087e-09
# Te_in_eV: 8.112
# Ti_in_eV: 8.112
# 0: Initial condition Total Error: 5.676e-01
# Exiting status 0, reverting to best index so far: 46
# Final iter:47, Total Error: 8.278e-09
# Te_in_eV: 8.112
# Ti_in_eV: 8.112
# 0: Initial condition Total Error: 5.350e-01
# Exiting status 0, reverting to best index so far: 43
# Final iter:44, Total Error: 7.372e-09
# Te_in_eV: 21.247
# Ti_in_eV: 21.247
# /home/zach/plasma/hnc/hnc/PIE.py:182: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   κ = 3*(2*self.qsp.Te*m_e) / (self.qsp.k_F**3 * r) *quad(integrand, 0, t_max)[0]
# 0: Initial condition Total Error: 2.989e-01
# Exiting status 0, reverting to best index so far: 34
# Final iter:35, Total Error: 7.434e-09
# Te_in_eV: 21.247
# Ti_in_eV: 21.247
# 0: Initial condition Total Error: 2.899e-01
# Exiting status 0, reverting to best index so far: 33
# Final iter:34, Total Error: 7.809e-09
# Te_in_eV: 21.247
# Ti_in_eV: 21.247
# 0: Initial condition Total Error: 2.823e-01
# Exiting status 0, reverting to best index so far: 32
# Final iter:33, Total Error: 8.510e-09
# Te_in_eV: 21.247
# Ti_in_eV: 21.247
# 0: Initial condition Total Error: 2.707e-01
# Exiting status 0, reverting to best index so far: 31
# Final iter:32, Total Error: 6.772e-09
# Te_in_eV: 21.247
# Ti_in_eV: 21.247
# 0: Initial condition Total Error: 2.605e-01
# Exiting status 0, reverting to best index so far: 29
# Final iter:30, Total Error: 7.548e-09
# Te_in_eV: 21.247
# Ti_in_eV: 21.247
# 0: Initial condition Total Error: 2.565e-01
# Exiting status 0, reverting to best index so far: 28
# Final iter:29, Total Error: 6.072e-09
# Te_in_eV: 55.650
# Ti_in_eV: 55.650
# /home/zach/plasma/hnc/hnc/PIE.py:182: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   κ = 3*(2*self.qsp.Te*m_e) / (self.qsp.k_F**3 * r) *quad(integrand, 0, t_max)[0]
# 0: Initial condition Total Error: 1.256e-01
# Exiting status 0, reverting to best index so far: 25
# Final iter:26, Total Error: 6.025e-09
# Te_in_eV: 55.650
# Ti_in_eV: 55.650
# 0: Initial condition Total Error: 1.237e-01
# Exiting status 0, reverting to best index so far: 25
# Final iter:26, Total Error: 5.157e-09
# Te_in_eV: 55.650
# Ti_in_eV: 55.650
# 0: Initial condition Total Error: 1.222e-01
# Exiting status 0, reverting to best index so far: 24
# Final iter:25, Total Error: 8.958e-09
# Te_in_eV: 55.650
# Ti_in_eV: 55.650
# 0: Initial condition Total Error: 1.200e-01
# Exiting status 0, reverting to best index so far: 24
# Final iter:25, Total Error: 7.410e-09
# Te_in_eV: 55.650
# Ti_in_eV: 55.650
# 0: Initial condition Total Error: 1.179e-01
# Exiting status 0, reverting to best index so far: 24
# Final iter:25, Total Error: 6.177e-09
# Te_in_eV: 55.650
# Ti_in_eV: 55.650
# 0: Initial condition Total Error: 1.166e-01
# Exiting status 0, reverting to best index so far: 24
# Final iter:25, Total Error: 5.562e-09
# Te_in_eV: 145.762
# Ti_in_eV: 145.762
# 0: Initial condition Total Error: 5.365e-02
# Exiting status 0, reverting to best index so far: 23
# Final iter:24, Total Error: 5.876e-09
# Te_in_eV: 145.762
# Ti_in_eV: 145.762
# 0: Initial condition Total Error: 5.321e-02
# Exiting status 0, reverting to best index so far: 23
# Final iter:24, Total Error: 5.780e-09
# Te_in_eV: 145.762
# Ti_in_eV: 145.762
# 0: Initial condition Total Error: 5.281e-02
# Exiting status 0, reverting to best index so far: 23
# Final iter:24, Total Error: 5.705e-09
# Te_in_eV: 145.762
# Ti_in_eV: 145.762
# 0: Initial condition Total Error: 5.208e-02
# Exiting status 0, reverting to best index so far: 23
# Final iter:24, Total Error: 5.600e-09
# Te_in_eV: 145.762
# Ti_in_eV: 145.762
# 0: Initial condition Total Error: 5.110e-02
# Exiting status 0, reverting to best index so far: 23
# Final iter:24, Total Error: 5.502e-09
# Te_in_eV: 145.762
# Ti_in_eV: 145.762
# 0: Initial condition Total Error: 5.019e-02
# Exiting status 0, reverting to best index so far: 23
# Final iter:24, Total Error: 5.434e-09
# Te_in_eV: 381.788
# Ti_in_eV: 381.788
# 0: Initial condition Total Error: 2.754e-02
# Exiting status 0, reverting to best index so far: 22
# Final iter:23, Total Error: 6.430e-09
# Te_in_eV: 381.788
# Ti_in_eV: 381.788
# 0: Initial condition Total Error: 2.739e-02
# Exiting status 0, reverting to best index so far: 22
# Final iter:23, Total Error: 6.405e-09
# Te_in_eV: 381.788
# Ti_in_eV: 381.788
# 0: Initial condition Total Error: 2.722e-02
# Exiting status 0, reverting to best index so far: 22
# Final iter:23, Total Error: 6.378e-09
# Te_in_eV: 381.788
# Ti_in_eV: 381.788
# 0: Initial condition Total Error: 2.688e-02
# Exiting status 0, reverting to best index so far: 22
# Final iter:23, Total Error: 6.315e-09
# Te_in_eV: 381.788
# Ti_in_eV: 381.788
# 0: Initial condition Total Error: 2.633e-02
# Exiting status 0, reverting to best index so far: 22
# Final iter:23, Total Error: 6.206e-09
# Te_in_eV: 381.788
# Ti_in_eV: 381.788
# 0: Initial condition Total Error: 2.576e-02
# Exiting status 0, reverting to best index so far: 22
# Final iter:23, Total Error: 6.084e-09
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 1.701e-02
# Exiting status 0, reverting to best index so far: 21
# Final iter:22, Total Error: 8.136e-09
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 1.674e-02
# Exiting status 0, reverting to best index so far: 21
# Final iter:22, Total Error: 8.005e-09
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 1.647e-02
# Exiting status 0, reverting to best index so far: 21
# Final iter:22, Total Error: 7.874e-09
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 1.594e-02
# Exiting status 0, reverting to best index so far: 21
# Final iter:22, Total Error: 7.616e-09
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 1.516e-02
# Exiting status 0, reverting to best index so far: 21
# Final iter:22, Total Error: 7.237e-09
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 1.441e-02
# Exiting status 0, reverting to best index so far: 21
# Final iter:22, Total Error: 6.877e-09

# %% [markdown]
# Now Plot

# %%
P_list_1 = np.array(P_list_1)
P_list_2 = np.array(P_list_2)
P_list_3 = np.array(P_list_3)
P_list_4 = np.array(P_list_4)

# %%
atoMEC_df[atoMEC_df['rs'] == ri_AU_list[1] ]['P[AU]']*AU_to_bar/1e6
# Out:
# 10      9.856627
# 11      9.867807
# 12      9.933416
# 13     10.317066
# 14     12.494221
# 15     22.743912
# 16     57.117950
# 17    149.961834
# 18    382.296615
# 19    950.004439
# Name: P[AU], dtype: float64

# %%
from hnc.hnc.misc import P_Ideal_Fermi_Gas

fig, axs = plt.subplots(2,3, figsize=(16,8))
axs = axs.flatten()

for i, ax in enumerate(axs):
    rs = ri_AU_list[i]
    ni_AU = n_from_rs(rs)
    #Plot CEIMC data
    CEIMC_PMbar = CEIMC_df[CEIMC_df['rs'] == ri_AU_list[i] ]['P[GPa]']*1e-2
    CEIMC_TeV = CEIMC_df[CEIMC_df['rs'] == ri_AU_list[i] ]['T[K]']/eV_to_K
    ax.plot(CEIMC_TeV, CEIMC_PMbar, '+', label='Morales (CEIMC)')

    #Plot BOMD data
    BOMD_PMbar = BOMD_df[BOMD_df['rs'] == ri_AU_list[i] ]['P[GPa]']*1e-2
    BOMD_TeV = BOMD_df[BOMD_df['rs'] == ri_AU_list[i] ]['T[K]']/eV_to_K
    ax.plot(BOMD_TeV, BOMD_PMbar, '.', label='Morales (BOMD)')

    #Plot atoMEC data
    atoMEC_PMbar = atoMEC_df[atoMEC_df['rs'] == ri_AU_list[i] ]['P[AU]']*AU_to_bar/1e6
    atoMEC_TeV = atoMEC_df[atoMEC_df['rs'] == ri_AU_list[i] ]['T[eV]']
    ax.plot(atoMEC_TeV, atoMEC_PMbar, '^', label='atoMEC (AA)')

    # Plot Pressure ratio
    # axs[0].plot(GP_Te_eV, P_list_1[:,2], label=name1)
    # axs[0].plot(Te_eV_list, P_list_2[:,2], label=name2)
    # ax.plot(Te_eV_list, P_list_3.reshape( 10,len(ri_AU_list), 3)[:,i,2],'--', label=name3)
    ax.plot(Te_eV_list, P_list_3.reshape( 10,len(ri_AU_list), 3)[:,i,2],'--', label="CMHNC")
    # axs[0].plot(Te_eV_list, P_list_4[:,2],'--.', label=name4)

    # Plot Fermi Pressure
    ax.plot(Te_eV_list, [P_Ideal_Fermi_Gas(Te_eV*eV_to_AU, ni_AU)*AU_to_bar/1e6 for Te_eV in Te_eV_list],'k-', label="Ideal Fermi Gas"  ) 

    ax.set_title(r"$r_i$={}".format(rs), fontsize=20)
    
    ax.legend(fontsize=12, loc='upper left')
    ax.set_xscale('log')
    # ax.set_yscale('symlog', linthresh=1)
    ax.set_yscale('log')
    # ax.set_ylim(0, 1e4)
    ax.set_ylabel(r"$P_e$ [Mbar]", fontsize=15)
    ax.set_xlabel(r"$T$ [eV]", fontsize=15)
    ax.tick_params(labelsize=15)
    
    plt.tight_layout(pad=0.1)
# Out:
# /tmp/ipykernel_228794/66035246.py:45: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0.1)
# /tmp/ipykernel_228794/66035246.py:45: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0.1)
# /tmp/ipykernel_228794/66035246.py:45: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0.1)
# /tmp/ipykernel_228794/66035246.py:45: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0.1)
# /tmp/ipykernel_228794/66035246.py:45: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0.1)

# %%
CEIMC_df[]
