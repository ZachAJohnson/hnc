# %% [markdown]
# # Integral Equation Model Comparisons
# Purpose of this notebook is to EOS calculations for comparisons to George Petrov's Average Atom model, and Morales EOS Hydrogen paper
#
# [https://journals.aps.org/pre/abstract/10.1103/PhysRevE.81.021202](https://journals.aps.org/pre/abstract/10.1103/PhysRevE.81.021202)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

from hnc.hnc.PIE import Plasma_of_Ions_and_Electrons as PLASMA

from hnc.hnc.constants import *
from hnc.hnc.misc import n_from_rs, rs_from_n

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
                
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# ModuleNotFoundError: No module named 'mendeleev'
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %% [markdown]
# ### Set Parameters in Paper and Plot

# %%
name = 'Hydrogen'
Z, A = 1,1 

Te_eV_list = [0.172347, 1.000000 ]
Ti_eV_list = Te_eV_list
# ni_cc = 5.98e23
# ni_AU = ni_cc/cm_to_AU**3

# ri_cm = rs_from_n(ni_cc)  # cm
# ri_AU = ri_cm*cm_to_AU    # AU 

ri_AU = 1.3914542638521432
ni_cc = n_from_rs(ri_AU/cm_to_AU)

# %%
ri_AU
# Out:
# 1.3914542638521432

# %% [markdown]
# #### Load atoMEC data

# %%
from scipy.integrate import simpson
atoMEC_files = ["H_rs1.391_T0.17234656eV.csv","H_rs1.391_T1eV.csv"]

def get_atoMEC_gei(file, ri): 
    
    atoMEC_df = read_csv(file, delim_whitespace=True, header=0)
    ne = atoMEC_df['n(bound)'] + atoMEC_df['n(unbound)']
    r_array = np.array(atoMEC_df['r[a_0]'])
    N_electrons = simpson(4*π*ne*r_array**2, x=r_array)
    print(f"Num electrons total: {N_electrons:0.6f}")
    # nbar_f = (Z-AA_Zbar)/( 4/3*π*ri**3 )
    # nbar_b = AA_Zbar/ (  4/3*π*ri**3 )
    nbar_tot = Z/( 4/3*π*ri**3 )
    
    # unbound_h = np.array( (AA_data['n[unbound]'])/nbar_f )
    # bound_h = np.array((AA_data['n[bound]'])/nbar_b)/2
    total_gei = ne/nbar_tot
    return np.array([r_array, total_gei])

# [get_atoMEC_gei(file, ri_AU) for file in atoMEC_files]
AA_data1, AA_data2 = [get_atoMEC_gei(file, ri_AU) for file in atoMEC_files]
# Out:
# Num electrons total: 1.000000
# Num electrons total: 1.000000

# %% [markdown]
# #### Run Ornstein-Zernike Closure

# %%
name1 = 'OZ - g'
plasma1 = lambda T_eV: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0,'which_Tij':'geometric'},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
name2 = 'OZ - th'
plasma2 = lambda T_eV: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0,'which_Tij':'thermal'},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
name3 = 'OZ - g - 2'
plasma3= lambda T_eV: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0,'which_Tij':'geometric'},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
# name3 = 'OZ - th  Pauli'
# plasma3 = lambda T_eV: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z, find_βuee=True,
#                  βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
#                  qsp_options= {'r_c':0,'which_Tij':'thermal'},
#                  hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
#                                'h_max':2e2,'oz_method':'standard'},
#                  hnc_solve_options={'alpha_Picard':0.5, 'num_iterations':1e4})
name4 = 'SVT - th'
plasma4 =  lambda T_eV: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Z,
                 βu_options = {'add_bridge':False,'bridge':'ocp', 'pseudopotential':False}, 
                 qsp_options= {'r_c':0},
                 hnc_options= {'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 
                               'h_max':2e2,'oz_method':'svt'},
                 hnc_solve_options={'alpha_Picard':0.5,'num_iterations':1e4})

P_hnc_to_AU   = lambda P_hnc: (P_hnc/ri_AU**3) 
P_hnc_to_bar  = lambda P_hnc: P_hnc_to_AU(P_hnc) *  AU_to_bar 
P_hnc_to_Mbar = lambda P_hnc: 1e-6*P_hnc_to_bar(P_hnc)
P_hnc_to_GPa  = lambda P_hnc: P_hnc_to_bar(P_hnc) * 1e5 / 1e9

# %% [markdown]
# ### Compute all plasma models for list of densities

# %%
P_list_1 = []
P_list_2 = []
P_list_3 = []
P_list_4 = []

for T_eV in Te_eV_list:
    """
    """
    #1
    plasma = plasma1(T_eV)
    plasma.run_hnc()
    P_list_1.append( plasma )
    #2
    plasma = plasma2(T_eV)
    plasma.run_hnc()
    P_list_2.append( plasma )
    #3
    plasma = plasma3(T_eV)
    plasma.hnc.set_βu_matrix(plasma.hnc.βu_r_matrix*np.array([[1,0.049094638798413345/0.3803294873670104],[0.049094638798413345/0.3803294873670104,1]])[:,:,np.newaxis])
    plasma.run_hnc()
    P_list_3.append( plasma )
    #4
    # plasma = plasma4(T_eV)
    # Pe_id, Pe_ex, Pe = plasma_output(plasma)
    # P_list_4.append( [Pe_id, Pe_ex, Pe] )
# Out:
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.070e+01
# Exiting status 0, reverting to best index so far: 806
# Final iter:807, Total Error: 9.810e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.064e+01
# Exiting status 0, reverting to best index so far: 804
# Final iter:805, Total Error: 9.972e-09
# Te_in_eV: 0.172
# Ti_in_eV: 0.172
# 0: Initial condition Total Error: 1.064e+01
# Exiting status 0, reverting to best index so far: 808
# Final iter:809, Total Error: 9.846e-09
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# 0: Initial condition Total Error: 3.076e+00
# Exiting status 0, reverting to best index so far: 188
# Final iter:189, Total Error: 9.195e-09
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# 0: Initial condition Total Error: 3.065e+00
# Exiting status 0, reverting to best index so far: 188
# Final iter:189, Total Error: 9.597e-09
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# 0: Initial condition Total Error: 3.062e+00
# ...

# %% [markdown]
# Now Plot

# %%
fig, ax  = plt.subplots(figsize=(10,6))

# plot atoMEC curves
ax.plot(AA_data1[0], np.gradient(np.log(AA_data1[1]), AA_data1[0]), label=r"$atoMEC$")
# ax.plot(AA_data1[0], AA_data1[1], label=r"$T_1$")
# ax.plot(AA_data2[0], AA_data2[1], label=r"$T_2$")

# plot cmHNC curves
# plasma = 
ddx = lambda f: np.gradient(f, plasma.hnc.r_array*plasma.qsp.ri)
ax.plot(plasma.hnc.r_array*plasma.qsp.ri, ddx(np.log(P_list_1[0].hnc.h_r_matrix[0,1]+1)), label=r'cmHNC $T_1$')
# ax.plot(plasma.hnc.r_array*plasma.qsp.ri, ddx(np.log(P_list_1[0].hnc.h_r_matrix[0,1]+1)), label=r'cmHNC $T_1$')

# Kato cusp
ax.plot(AA_data1[0], -2*Z*np.ones_like(AA_data1[0]), label='Kato cusp' )

# Configure plot
ax.set_xscale('log')
ax.set_yscale('symlog',linthresh=1)

ax.set_ylim(-1e2,1e0)

ax.set_ylabel(r"$ d \ln (g_{ei})/dr$", fontsize=20)
ax.set_xlabel(r"$r$ [AU]", fontsize=20)
ax.legend(fontsize=14)

# %%
ddx(P_list_3[0].hnc.βu_r_matrix[0,1])[:5], -ddx(np.log(P_list_3[0].hnc.h_r_matrix[0,1]+1))[:5]
# Out:
# (array([0.01827313, 0.01827212, 0.01826959, 0.01826606, 0.01826153]),
#  array([1.76424514, 1.74314133, 1.70091243, 1.65865241, 1.61638407]))

# %%
(Z/(π*plasma.qsp.Λei**2*plasma.qsp.ri**2) * (np.sqrt(2)-0.5)*plasma.qsp.βie_c)
# Out:
# 1.8274303123153615

# %%
ddx(P_list_3[0].qsp.βvei(P_list_3[0].hnc.r_array))[:5]
# Out:
# array([1.82731259, 1.8272117 , 1.82695949, 1.82660647, 1.82615271])

# %%
ddx(P_list_3[0].qsp.βv_Kelbg(P_list_3[0].qsp.Γei,P_list_3[0].hnc.r_array,P_list_3[0].qsp.Λei))[:5]
# Out:
# array([1.82731259, 1.8272117 , 1.82695949, 1.82660647, 1.82615271])

# %%
ddx(P_list_3[0].qsp.βv_Kelbg(P_list_3[0].qsp.Γei,P_list_3[0].hnc.r_array,P_list_3[0].qsp.Λei))[:5]
# Out:
# array([1.82731259, 1.8272117 , 1.82695949, 1.82660647, 1.82615271])

# %% [markdown]
# The hell is atomec doing

# %% [markdown]
# ### Improved Improved Kelbg

# %%
from scipy.special import erfc

fig, ax  = plt.subplots(figsize=(10,6))

def Kelbg(Γ, r, Λ): 
    return Γ/r*( 1 - np.exp(-r**2/(Λ**2*2*π)) + r/Λ*erfc(r/Λ/np.sqrt(2*π)) )

def IIKelbg(Γ, r, Λ): 
    a = 1
    b = (0.5 + plasma.qsp.βie_c/plasma.qsp.μ)/np.sqrt(2)
    print(f"b={b:0.3f}")
    return Γ/r*( 1 - np.exp(-r**2/(Λ**2*2*π)) + r/(Λ*a)*erfc(r*b/Λ/np.sqrt(2*π)) )

def IIKelbg(Γ, r, Λ): 
    a = np.sqrt(2)/(0.5 + plasma.qsp.βie_c/plasma.qsp.μ)
    b = 1
    print(f"b={b:0.3f}")
    return Γ/r*( 1 - np.exp(-r**2/(Λ**2*2*π)) + r/(Λ*a)*erfc(r*b/Λ/np.sqrt(2*π)) )

plasma = P_list_1[0]
# ax.plot(plasma.hnc.r_array*plasma.qsp.ri, -Kelbg(plasma.qsp.Γei, plasma.hnc.r_array, plasma.qsp.Λei) , label=r'Kelbg')
# ax.plot(plasma.hnc.r_array*plasma.qsp.ri, -IIKelbg(plasma.qsp.Γei, plasma.hnc.r_array, plasma.qsp.Λei) , label=r'II-Kelbg')


# plot derivatives curves
ddx = lambda f: np.gradient(f, plasma.hnc.r_array*plasma.qsp.ri)
ax.plot(plasma.hnc.r_array*plasma.qsp.ri, ddx(Kelbg(plasma.qsp.Γei, plasma.hnc.r_array, plasma.qsp.Λei)) , label=r'Kelbg')
ax.plot(plasma.hnc.r_array*plasma.qsp.ri, ddx(IIKelbg(plasma.qsp.Γei, plasma.hnc.r_array, plasma.qsp.Λei) ), label=r'II-Kelbg')

# Kato cusp
ax.plot(AA_data1[0], 2*plasma.qsp.βie_c*Z*np.ones_like(AA_data1[0]), label='Kato cusp' )

# Configure plot
ax.set_xscale('log')
ax.set_yscale('log')
# ax.set_yscale('symlog',linthresh=1)

# ax.set_ylim(-1e2,1e0)

# ax.set_ylabel(r"$ d \ln (g_{ei})/dr$", fontsize=20)
ax.set_xlabel(r"$r$ [AU]", fontsize=20)
ax.legend(fontsize=14)
# Out:
# b=1.000

# %% [markdown]
# ## Compare Guassian and Thermal $T_{ei}$

# %%
[plasma.qsp.Tie_c for plasma in P_list_1], [plasma.qsp.Tie_c for plasma in P_list_2]
# Out:
# ([0.049094638798413345, 0.11860929074240928],
#  [0.3803294873670104, 0.3826060259926246])

# %%
[plasma.qsp.Λei for plasma in P_list_1], [plasma.qsp.Λei for plasma in P_list_2]
# Out:
# ([1.2943225296278416, 0.8327222920269645],
#  [0.4650284745370329, 0.4636429308090445])

# %%
[plasma.qsp.Te for plasma in P_list_1], [plasma.qsp.Te_c for plasma in P_list_2]
# Out:
# ([0.006333959066399999, 0.0367512], [0.3805334915302182, 0.3827946801850654])

# %%
fig, axs  = plt.subplots(2,2)

indx = 0
for i in range(2):
    for j in range(2):
        # g_ij(r)
        axs[i,j].plot(P_list_1[0].hnc.r_array, P_list_1[0].hnc.h_r_matrix[i,j] + 1, label='Guassian')
        axs[i,j].plot(P_list_2[0].hnc.r_array, P_list_2[0].hnc.h_r_matrix[i,j] + 1, label='Thermal')
        # axs[i,j].plot(P_list_3[0].hnc.r_array, P_list_3[0].hnc.h_r_matrix[i,j] + 1, label=r'Thermal $\beta u$, gaussian $\Lambda$')
        
        # derivatives
        # axs[i,j].plot(P_list_1[0].hnc.r_array*P_list_1[0].qsp.ri, ddx(np.log(P_list_1[0].hnc.h_r_matrix[i,j]+1)), label='Guassian')
        # axs[i,j].plot(P_list_2[0].hnc.r_array*P_list_2[0].qsp.ri, ddx(np.log(P_list_2[0].hnc.h_r_matrix[i,j]+1)), label='Thermal')
        
        # Kato cusp
        # axs[i,j].plot(AA_data1[0], -2*Z*np.ones_like(AA_data1[0]), label='Kato cusp' )

        axs[i,j].set_xlim(0,3)
        axs[i,j].set_yscale('symlog', linthresh=1)
        
axs[0,0].legend(fontsize=14)

# %%
fig, axs  = plt.subplots(2,2)

indx = 0
for i in range(2):
    for j in range(2):
        # g_ij(r)
        axs[i,j].plot(P_list_1[0].hnc.r_array, P_list_1[0].hnc.c_r_matrix[i,j]*P_list_1[0].hnc.Temp_matrix[i,j],color=colors[0],linestyle='-' , label='c-Guassian')
        axs[i,j].plot(P_list_2[0].hnc.r_array, P_list_2[0].hnc.c_r_matrix[i,j]*P_list_2[0].hnc.Temp_matrix[i,j],color=colors[1],linestyle='-' , label='c-Thermal')
        
        # axs[i,j].plot(P_list_1[0].hnc.r_array, P_list_1[0].hnc.c_r_matrix[i,j]*P_list_1[0].hnc.Temp_matrix[i,j],color=colors[0],linestyle='-' , label='c-Guassian')
        # axs[i,j].plot(P_list_2[0].hnc.r_array, P_list_2[0].hnc.c_r_matrix[i,j]*P_list_2[0].hnc.Temp_matrix[i,j],color=colors[1],linestyle='-' , label='c-Thermal')
        
#         axs[i,j].plot(P_list_1[0].hnc.r_array, P_list_1[0].hnc.h_r_matrix[i,j]*P_list_1[0].hnc.Temp_matrix[i,j],color=colors[0],linestyle='--' , label='h-Guassian')
#         axs[i,j].plot(P_list_2[0].hnc.r_array, P_list_2[0].hnc.h_r_matrix[i,j]*P_list_2[0].hnc.Temp_matrix[i,j],color=colors[1],linestyle='--' , label='h-Thermal')
        
        # derivatives
        # axs[i,j].plot(P_list_1[0].hnc.r_array*P_list_1[0].qsp.ri, ddx(np.log(P_list_1[0].hnc.h_r_matrix[i,j]+1)), label='Guassian')
        # axs[i,j].plot(P_list_2[0].hnc.r_array*P_list_2[0].qsp.ri, ddx(np.log(P_list_2[0].hnc.h_r_matrix[i,j]+1)), label='Thermal')
        
        # Kato cusp
        # axs[i,j].plot(AA_data1[0], -2*Z*np.ones_like(AA_data1[0]), label='Kato cusp' )

        axs[i,j].set_xlim(0,3)
        # axs[i,j].set_yscale('symlog', linthresh=1)
        
axs[0,0].legend(fontsize=14)
# Out:
# /tmp/ipykernel_248806/377242402.py:14: RuntimeWarning: divide by zero encountered in log
#   axs[i,j].plot(P_list_1[0].hnc.r_array*P_list_1[0].qsp.ri, ddx(np.log(P_list_1[0].hnc.h_r_matrix[i,j]+1)), label='Guassian')
# /home/zach/anaconda3/envs/zplasma/lib/python3.10/site-packages/numpy/lib/function_base.py:1250: RuntimeWarning: invalid value encountered in multiply
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /home/zach/anaconda3/envs/zplasma/lib/python3.10/site-packages/numpy/lib/function_base.py:1250: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# /home/zach/anaconda3/envs/zplasma/lib/python3.10/site-packages/numpy/lib/function_base.py:1259: RuntimeWarning: invalid value encountered in scalar subtract
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_0
# ...

# %%
[plasma.hnc.total_pressure() for plasma in P_list_1]
# Out:
# [0.1981960571584094, 0.12241427407373094]

# %%
[plasma.hnc.total_pressure() for plasma in P_list_2]
# Out:
# [0.06262476640907669, 0.07337755292476188]

# %%
[plasma.hnc.total_pressure() for plasma in P_list_3]
# Out:
# [29.975211067993847, 29.973876755463632]
