# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

from hnc.hnc.PIE import Plasma_of_Ions_and_Electrons as PLASMA

from hnc.hnc.constants import *
from hnc.hnc.misc import n_from_rs, rs_from_n

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
                
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")

import matplotlib as mpl
from cycler import cycler


plt.style.use('../hnc_paper_MM.mplstyle')

# %% [markdown]
# # Function that sets up HNC QSP

# %%
Element_name = 'Aluminum'
Al_file = "data/Al-rho=2,70-2023-09-03.dat"

Z, A = 13, 26
ni_cc = 6.03e22
Al_df = read_csv(Al_file, delim_whitespace = True, header=0)

Al_Zbars = Al_df['Z_bar'][3:] 
Al_TeVs = Al_df['Te(eV)'][3:]
Al_Zbars, Al_TeVs

# TCCW Submission Data point
tccw_nicc = ni_cc
tccw_TeV = 1
tccw_η_cgs = 1.068e-02	 
tccw_η_cgs_err = 1.018e-03

# %%
r_c = 0.6

# %%
plasma_svt_func = lambda T_eV, ni_cc, Zbar: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Zbar, 
                 βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':True}, 
                 qsp_options={'r_c':r_c},
                 hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':250},
                 hnc_solve_options={'alpha_Picard':0.1},
                 root_options={'options':{'maxfev':50000,'xtol':1e-14}})

# %%
plasma_oz_func = lambda T_eV, ni_cc, Zbar: PLASMA(Z, A, ni_cc, T_eV, T_eV, Zbar=Zbar, 
                 βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':True}, 
                 qsp_options={'r_c':r_c},
                 hnc_options={'kappa_multiscale':10, 'R_max':20,'N_bins':1000, 'oz_method':'standard'},
                 hnc_solve_options={'alpha_Picard':0.25,'num_iterations':10000})

# %% [markdown]
# ## Born Green Viscosity
# See [Morioka 2004](https://www.sciencedirect.com/science/article/pii/S0022309304003692)
#
# \begin{align}
# η = f_{BG} \frac{2 \pi}{15} \left(\frac{M}{RT} \right)^{1/2} \frac{n^2}{N_a} \int^\infty_0 g(r) \frac{d\phi}{dr}r^4 dr
# \end{align}
# Resulting units is Pa s

# %%
from scipy.integrate import simpson

def get_ηBG(plasma, units = 'SI', plot = False):
    plasma.hnc.invert_HNC_OZ([1])
    fBG = -1
    n_AU = n_from_rs(plasma.qsp.ri)
    r_array = plasma.hnc.r_array*plasma.qsp.ri
    gii = plasma.hnc.h_r_matrix[0,0]+1
    dφdr = plasma.qsp.Ti*np.gradient(plasma.hnc.βueff_r_matrix[0,0], r_array)

    integrand = r_array**4 * gii * dφdr
    ##
    if plot==True:
        fig, ax = plt.subplots()
        ax.plot(r_array, dφdr*r_array**4)
    ###
    integral = simpson(integrand, x=r_array)
    η = fBG* 2*π/15 * (plasma.qsp.βi*plasma.qsp.m_i)**0.5*n_AU**2*integral
    η_SI = η*AU_to_Pa*AU_to_s # Pa s = kg m^-1 s^-1 
    η_cgs = η_SI * 1000/100 # g cm^-1 s^-1
    
    # print and return only specified unit
    if units=='SI' or units=='si':
        print(f"SI: η = {η_SI:0.3e} [kg m^-1 s^-1] (or [Pa s])")
        return η_SI
    elif units=='cgs':
        print(f"CGS: η = {η_cgs:0.3e} [g cm^-1 s^-1]")
        return η_cgs
    elif units=='AU':
        return η

# %%
# Get list of viscosities

Al_η_cgs = np.zeros_like(Al_TeVs)

for i, (T_eV, Zbar) in enumerate(zip(  Al_TeVs, Al_Zbars  )):
    plasma = plasma_svt_func(T_eV, ni_cc, Zbar)
    plasma.run_hnc()
    Al_η_cgs[i] = get_ηBG(plasma, units='cgs')
# Out:
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# 0: Initial condition Total Error: 1.003e+01
# Warning: HNC_solver did not converge within the specified number of iterations.
# Exiting status 1, reverting to best index so far: 1001
# Final iter:1001, Total Error: 1.439e-03
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations. final err: 6.130e-11
# SI: η = 2.648e-03 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 2.648e-02 [g cm^-1 s^-1]
# Te_in_eV: 2.000
# Ti_in_eV: 2.000
# 0: Initial condition Total Error: 6.228e+00
# Warning: HNC_solver did not converge within the specified number of iterations.
# Exiting status 1, reverting to best index so far: 1001
# Final iter:1001, Total Error: 9.504e-06
#
# Root Finder:  False The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations. final err: 4.994e-12
# SI: η = 2.034e-03 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 2.034e-02 [g cm^-1 s^-1]
# Te_in_eV: 5.000
# Ti_in_eV: 5.000
# 0: Initial condition Total Error: 3.221e+00
# Exiting status 0, reverting to best index so far: 835
# Final iter:836, Total Error: 9.831e-09
# SI: η = 1.637e-03 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 1.637e-02 [g cm^-1 s^-1]
# Te_in_eV: 10.000
# Ti_in_eV: 10.000
# 0: Initial condition Total Error: 1.971e+00
# Exiting status 0, reverting to best index so far: 557
# Final iter:558, Total Error: 9.749e-09
# SI: η = 1.977e-03 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 1.977e-02 [g cm^-1 s^-1]
# Te_in_eV: 20.000
# Ti_in_eV: 20.000
# 0: Initial condition Total Error: 1.678e+00
# Exiting status 0, reverting to best index so far: 498
# Final iter:499, Total Error: 9.872e-09
# SI: η = 3.614e-03 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 3.614e-02 [g cm^-1 s^-1]
# Te_in_eV: 50.000
# Ti_in_eV: 50.000
# 0: Initial condition Total Error: 1.684e+00
# Exiting status 0, reverting to best index so far: 505
# Final iter:506, Total Error: 9.930e-09
# SI: η = 9.609e-03 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 9.609e-02 [g cm^-1 s^-1]
# Te_in_eV: 100.000
# Ti_in_eV: 100.000
# 0: Initial condition Total Error: 1.625e+00
# Exiting status 0, reverting to best index so far: 491
# Final iter:492, Total Error: 9.715e-09
# SI: η = 1.980e-02 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 1.980e-01 [g cm^-1 s^-1]
# Te_in_eV: 200.000
# Ti_in_eV: 200.000
# 0: Initial condition Total Error: 1.251e+00
# Exiting status 0, reverting to best index so far: 405
# Final iter:406, Total Error: 9.599e-09
# SI: η = 3.706e-02 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 3.706e-01 [g cm^-1 s^-1]
# Te_in_eV: 500.000
# Ti_in_eV: 500.000
# 0: Initial condition Total Error: 7.737e-01
# Exiting status 0, reverting to best index so far: 304
# Final iter:305, Total Error: 9.519e-09
# SI: η = 8.261e-02 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 8.261e-01 [g cm^-1 s^-1]
# Te_in_eV: 1000.000
# Ti_in_eV: 1000.000
# 0: Initial condition Total Error: 4.451e-01
# Exiting status 0, reverting to best index so far: 237
# Final iter:238, Total Error: 9.559e-09
# SI: η = 1.353e-01 [kg m^-1 s^-1] (or [Pa s])
# CGS: η = 1.353e+00 [g cm^-1 s^-1]

# %% [markdown]
# ## Plot viscocities

# %%
def sci_notation(num, decimal_digits=1, precision=None, exponent=None):
    """
    Returns a string representation of the scientific
    notation of the given number formatted for use with
    LaTeX or Mathtext, with specified number of significant
    decimal digits and precision (number of decimal digits
    to show). The exponent to be used can also be specified
    explicitly.
    """
    if exponent is None:
        exponent = int(np.floor(np.log10(abs(num))))
    coeff = round(num / float(10**exponent), decimal_digits)
    if not precision:
        precision = decimal_digits

    return r"${0:.{2}f} \times 10^{{{1:d}}}$".format(coeff, exponent, precision)

# %%
fig, ax = plt.subplots( facecolor='white')

ax.plot(Al_TeVs, Al_η_cgs, label='Born Green')

ax.set_ylabel(r"$\eta $[g cm$^{-1}$ s$^{-1}$]")
ax.set_xlabel(r"$T$ [eV]")

# Inset Text Box
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{Element_name}\n {sci_notation(ni_cc,3)} [cc$^{{-1}}$]" 
ax.text(0.35, 0.95, inset_text, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.errorbar([tccw_TeV],[tccw_η_cgs], yerr=[tccw_η_cgs_err], barsabove=True, capsize=5, marker='.', label='MD Simulation')

# Scales
ax.set_yscale('log')
ax.set_xscale('log')

# Legend
ax.legend()

# %%
fig, ax = plt.subplots( facecolor='white')

cgs_to_mPas = 1/10 * 1000
ax.plot(Al_TeVs, Al_η_cgs*cgs_to_mPas, label='Born Green')

ax.set_ylabel(r"$\eta$ [m Pa s]")
ax.set_xlabel(r"$T$ [eV]")

# Inset Text Box
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{Element_name}\n {sci_notation(ni_cc,3)} [cc$^{{-1}}$]" 
ax.text(0.35, 0.95, inset_text, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

ax.errorbar([tccw_TeV],[tccw_η_cgs*cgs_to_mPas], yerr=[tccw_η_cgs_err], barsabove=True, capsize=5, marker='.', label='MD Simulation')

# Scales
# ax.set_yscale('log')
ax.set_xscale('log')

# Legend
ax.legend()
