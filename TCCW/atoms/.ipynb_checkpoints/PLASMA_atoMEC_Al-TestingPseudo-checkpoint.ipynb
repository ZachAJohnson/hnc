# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

from hnc.hnc.PIE import Plasma_of_Ions_and_Electrons as PLASMA

from hnc.hnc.constants import *
from hnc.hnc.misc import n_from_rs, rs_from_n

from pandas import read_csv

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
                
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %% [markdown]
# # Function that sets up HNC QSP

# %% [markdown]
# ### Create and run plasma

# %%
name='Al'
Z, A = 13, 27
mi = m_p * A
ρ_gpercc =  2.7 
ni_cc = ρ_gpercc/(mi*AU_to_g)
ri_cm = rs_from_n(ni_cc)
ri_AU = ri_cm*cm_to_AU

Te_eV = 1
Ti_eV = 1

ri_AU
# Out:
# 2.99645749925308

# %% [markdown]
# ### Make βu_ii, βu_fi from using bound density from AA
# If we assume the bound state does not deform at all, then we can calculate potentials based on it easily via integration

# %%
from scipy.integrate import simpson

bound_file = "~/plasma/hnc/TCCW/data/Al_rs_3.000_T_1.000e+00eV.csv"
AA_data = read_csv(bound_file, delim_whitespace=True, header=0)
AA_r_AU_full = np.array(AA_data['r[a_0]'])
AA_nb_AU_full = np.array(AA_data['n(bound)'])

# Get Zbar
Zbar = Z - simpson(4*π*AA_nb_AU_full*AA_r_AU_full**2,  AA_r_AU_full)
print(f"Total Zbar from integration: {Zbar:.3f}")
# Out:
# Total Zbar from integration: 3.000

# %%
atom = PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, find_βuee=True,
                 βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':False}, 
                 hnc_options={'kappa_multiscale':0, 'R_max':10,'N_bins':1000},
                 hnc_solve_options={'alpha_Picard':0.1},
                 root_options={'options':{'maxfev':50000,'xtol':1e-14}})
# Out:
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# /home/zach/plasma/hnc/hnc/PIE.py:163: RuntimeWarning: overflow encountered in exp
#   f_of_k = 1/(  1+np.exp((dense_hnc.k_array/self.qsp.ri)**2/(2*m_e*self.qsp.Te) - η) )

# %%
# Only use some values for speed
min_r_to_use = 0.2*atom.hnc.r_array[0]*atom.qsp.ri # in AU
indcs = np.where(AA_r_AU_full > min_r_to_use)
AA_r_AU = AA_r_AU_full[indcs]
AA_nb_AU = AA_nb_AU_full[indcs]

# Plot bound states
fig, ax = plt.subplots(figsize=(8,6))

ax.plot(AA_r_AU_full/atom.qsp.ri, 4*π*AA_nb_AU_full*AA_r_AU_full**2)
ax.axvspan(AA_r_AU_full[0]/atom.qsp.ri, min_r_to_use/atom.qsp.ri, color='k', alpha=0.1)
ax.set_xlabel(r'$r/r_i$')
ax.set_ylabel(r'$4 \pi n_b r^2$ [AU]')
# ax.set_xscale('log')
ax.set_xlim(np.min(AA_r_AU_full/atom.qsp.ri), np.max(AA_r_AU_full/atom.qsp.ri))
ax.set_ylim(0, None)
# Out:
# (0.0, 15.17911784559138)

# %%
from scipy.integrate import dblquad, simpson
from scipy.interpolate import RegularGridInterpolator

def new_δβuei(r_sep_in_AU, verbose = False, only_Pauli=True, HNC_Pauli=True):
    r_array = AA_r_AU #AU
    rs = atom.qsp.ri
    cosφ_array = np.linspace(-1,1,num=100)
    r_mesh, cosφ_mesh = np.meshgrid(r_array,cosφ_array, indexing='ij')

    nb_mesh = AA_nb_AU[:,np.newaxis] * np.ones_like(r_mesh)
    ree_mesh = np.sqrt( r_sep_in_AU**2 + r_mesh**2 + 2*r_mesh*r_sep_in_AU*cosφ_mesh  )
    
    if only_Pauli:
        # βu_ee_mesh = atom.qsp.βv_Pauli(ree_mesh/rs, atom.qsp.Λee)
        if HNC_Pauli:
            βu_ee_mesh = atom.βP_ee_func(ree_mesh/rs)
        else:
            βu_ee_mesh = atom.qsp.βv_Pauli(ree_mesh/rs, type='Lado')
    else:
        βu_ee_mesh = atom.qsp.βvee( ree_mesh/rs  ) + atom.βP_ee_func(ree_mesh/rs) - atom.qsp.βv_Pauli(ree_mesh/rs)
    
    integrand_mesh = 2*π* r_mesh**2 * nb_mesh*βu_ee_mesh
    
    if verbose:
        fig, axs = plt.subplots(1,3)
        extent = [-1,1, r_array[0]/atom.qsp.ri, r_array[-1]/atom.qsp.ri]
        print(extent)
        axs[0].imshow(r_mesh**2 * nb_mesh*βu_ee_mesh, origin='lower', extent=extent)
        axs[1].imshow(βu_ee_mesh, origin='lower', extent=extent)
        axs[2].imshow(r_mesh**2 * nb_mesh, origin='lower', extent=extent)
        for ax in axs:
            ax.set_ylabel(r'$r/r_i$')
            ax.set_xlabel(r'$\cos \theta$')
            ax.set_yscale('log')
            ax.plot(cosφ_array, np.ones_like(cosφ_array) * r_sep_in_AU/atom.qsp.ri ,'r')

        plt.tight_layout()
        plt.show()
    δβuei_simpson = simpson(simpson(integrand_mesh, axis=0, x=r_array), axis=0, x=cosφ_array)
    
#     δβuei_interp = RegularGridInterpolator( (r_array, cosφ_array), integrand_mesh  )
#     δβuei_integrand = lambda y, x : δβuei_interp((x, y)) # Weird convention, flipping not a mistake...
#     δβuei = dblquad(δβuei_integrand, r_array[0], r_array[-1], -1, 1)
    
    return δβuei_simpson#, δβuei
    
new_δβuei(1, verbose=True, HNC_Pauli=False)
# Out:
# [-1, 1, 0.00200166563400118, 1.0011822295987198]
# 3.834981587471398

# %%
δβuei = np.array([new_δβuei(r_hnc*atom.qsp.ri, only_Pauli=False) for r_hnc in atom.hnc.r_array])
δβuei_Pauli_HNC = np.array([new_δβuei(r_hnc*atom.qsp.ri) for r_hnc in atom.hnc.r_array])
δβuei_Pauli_Lado = np.array([new_δβuei(r_hnc*atom.qsp.ri, HNC_Pauli=False) for r_hnc in atom.hnc.r_array])

δβuei_Pauli_pointlike = (Z-Zbar)*atom.βP_ee_func(atom.hnc.r_array)
δβuii_Pauli_pointlike = (Z-Zbar)**2 *atom.βP_ee_func(atom.hnc.r_array)

# %%
fig, ax = plt.subplots(figsize=(10,8))


ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1] * Z/(atom.hnc.r_array*atom.qsp.ri),'--', label=r'Coulomb: $ Z$')
ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1] * (Z-Zbar)/(atom.hnc.r_array*atom.qsp.ri),'--', label=r'Coulomb: $ Z-\langle Z \rangle$')
ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1] * Zbar/(atom.hnc.r_array*atom.qsp.ri),'--', label=r'Coulomb: $\langle Z \rangle$')
ax.plot(atom.hnc.r_array, atom.hnc.βu_r_matrix[0,1], 'k-',label=r'OLD $-\beta u_{ei}$')
ax.plot(atom.hnc.r_array, -δβuei, label=r' $\int n_b u_{ee}$ ')
ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1]* Z/(atom.hnc.r_array*atom.qsp.ri) + δβuei,'k--' , label=r' NEW1: $-\beta Z/r + \int n_b u_{ee}$ ')
ax.plot(atom.hnc.r_array,  Z/Zbar*atom.hnc.βu_r_matrix[0,1] + δβuei,'k-.' , label=r' NEW2: $-\beta u_{ei}(Z) + \int n_b u_{ee}$ ')
ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,1] + δβuei_Pauli_HNC,'k--.' , label=r' NEW3: $-\beta u_{ei}(\langle Z \rangle) + \int n_b u^P_{ee}(HNC)$ ')
ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,1] + δβuei_Pauli_Lado,'k.' , label=r' NEW4: $-\beta u_{ei}(\langle Z \rangle) + \int n_b u^P_{ee}(Lado)$ ')
ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,1] + δβuei_Pauli_pointlike,'k:' , label=r' NEW4: $-\beta u_{ei}(\langle Z \rangle) + u^P_{ee}(HNC, origin)$ ')

ax.legend(fontsize=14)
ax.set_yscale('symlog', linthresh=1)
ax.set_xscale('log')

ax.set_ylabel(r"$\beta u$", fontsize=20)
ax.set_xlabel(r"$r/r_i$", fontsize=20)

ax.set_ylim(-1e4,1e2)
# Out:
# (-10000.0, 100.0)

# %%
fig, ax = plt.subplots(figsize=(10,8))


ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,0],'--', label=r'Coulomb: $ Z$')
ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,0] + δβuii_Pauli_pointlike,'--', label=r'Coulomb: $ Z$')

ax.legend(fontsize=14)
ax.set_yscale('symlog', linthresh=1)
ax.set_xscale('log')

ax.set_ylabel(r"$\beta u$", fontsize=20)
ax.set_xlabel(r"$r/r_i$", fontsize=20)

# ax.set_ylim(-1e4,1e2)
# Out:
# Text(0.5, 0, '$r/r_i$')

# %% [markdown]
# ### Solving

# %%
from scipy.optimize import least_squares
from scipy.interpolate import interp1d

def custom_flat(hnc_matrix):
    hnc_flat = np.concatenate([hnc_matrix[0,0],hnc_matrix[0,1],hnc_matrix[1,1]])
    return hnc_flat

def custom_unflat(hnc_flat):
    hnc00, hnc01, hnc11 = np.split(hnc_flat,3)
    hnc_matrix = np.zeros((2,2,len(hnc00)))
    hnc_matrix[0,0] = hnc00
    hnc_matrix[1,0] = hnc01
    hnc_matrix[0,1] = hnc01
    hnc_matrix[1,1] = hnc11
    return hnc_matrix

def solve_least_squares(plasma, sparse_k_array, c_s_k_guess=None, ftol=1e-8):
    if c_s_k_guess is None:
        c_s_k_guess = plasma.hnc.c_s_k_matrix

    # Create functions for converting between sparse, not sparse and flattened versions of c_s_k
    get_sparse_csk = lambda c_s_k_flat: np.concatenate([interp1d(plasma.hnc.k_array, c_s_k)(sparse_k_array) for c_s_k in np.split(c_s_k_flat,3) ])
    get_csk = lambda sparse_hnc_csk: interp1d(sparse_k_array, sparse_hnc_csk, kind='linear')(plasma.hnc.k_array)
    get_csk_matrix_from_sparse_csk_flat =  lambda sparse_c_s_k_flat: custom_unflat(np.concatenate([get_csk(sparse_csk) for sparse_csk in np.split(sparse_c_s_k_flat,3)]))
    
    def min_function(sparse_c_s_k_flat):
        c_s_k_matrix = get_csk_matrix_from_sparse_csk_flat(sparse_c_s_k_flat)
        new_c_s_k_matrix = plasma.hnc.guess_c_s_k_matrix(c_s_k_matrix)
        plasma.hnc.c_s_k_matrix = new_c_s_k_matrix.copy()
        new_c_s_k_flat = custom_flat(new_c_s_k_matrix)
        return sparse_c_s_k_flat - get_sparse_csk(new_c_s_k_flat)
    
    c_s_k_flat_guess = custom_flat(c_s_k_guess)
    c_s_k_sparse_guess = get_sparse_csk(c_s_k_flat_guess)
    sol = least_squares(min_function, c_s_k_sparse_guess, verbose=2, ftol=ftol)#, bounds = c_s_k_bounds)
    plasma.hnc.c_s_k_matrix = get_csk_matrix_from_sparse_csk_flat(sol.x)
    plasma.hnc.set_all_matrices_from_csk(plasma.hnc.c_s_k_matrix)
    print(sol)

def best_shift(plasma, guess_c_s_k, ftol=1e-8, set=True):
    
    
    def min_function(multiplier_list):
        xii, xei, xee = multiplier_list
        multiplier_matrix = np.array([[xii,xei],[xei,xee]])
        c_s_k_matrix = multiplier_matrix[:,:,np.newaxis] * guess_c_s_k
        new_c_s_k_matrix = plasma.hnc.guess_c_s_k_matrix(c_s_k_matrix)
        
        return c_s_k_matrix.flatten() - new_c_s_k_matrix.flatten()
    
    sol = least_squares(min_function, np.ones((3)) , verbose=2, ftol=ftol)#, bounds = c_s_k_bounds)
    xii, xei, xee = sol.x
    multiplier_matrix = np.array([[xii,xei],[xei,xee]])
    
    plasma.hnc.c_s_k_matrix = multiplier_matrix[:,:,np.newaxis] * guess_c_s_k
    print(sol)
    return sol

# %%
# atom1 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, find_βuee=True,
#                  βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':False}, 
#                  hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000,'oz_method':'standard'},
#                  hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.1, 'verbose':False,'iters_to_wait':500},
#                  root_options={'options':{'maxfev':100,'xtol':1e-14}})

# atom2 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, find_βuee=True,
#                  βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':False}, 
#                  hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
#                  hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.11, 'verbose':False,'iters_to_wait':500},
#                  root_options={'options':{'maxfev':100,'xtol':1e-14}})

atom3 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar,find_βuee=True, 
                 βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':True}, 
                 hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                 qsp_options={'r_c':0.3, 'Te_c_type':'DMC'},
                 hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.1,'verbose':False, 'iters_to_wait':500},
                 root_options={'options':{'maxfev':100,'xtol':1e-14}})

# atom4 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar,find_βuee=True, 
#                  βu_options = {'add_bridge':False,'bridge':'yukawa', 'pseudopotential':False}, 
#                  hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000,'oz_method':'standard'},
#                  hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.1,'verbose':True},
#                  root_options={'options':{'maxfev':100,'xtol':1e-14}})


atom5 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar,find_βuee=True, 
                 βu_options = {'add_bridge':False,'bridge':'yukawa', 'pseudopotential':False}, 
                 hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                 hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.1,'verbose':True},
                 root_options={'options':{'maxfev':100,'xtol':1e-14}})

# Rc = 0.2
# k = atom1.hnc.k_array
# βvei = atom1.hnc.FT_k_2_r(  4*π*atom1.qsp.Γei*np.cos(k*Rc) * (1/k**2 - 1/(k**2 + 1/atom1.qsp.Λei**2))  )
# atom1.hnc.βu_r_matrix[0,1] = βvei
# atom1.hnc.βu_r_matrix[1,0] = βvei
# atom1.hnc.set_βu_matrix(atom1.hnc.βu_r_matrix)

# k = atom2.hnc.k_array
# βvei = atom2.hnc.FT_k_2_r(  4*π*atom2.qsp.Γei*np.cos(k*Rc) * (1/k**2 - 1/(k**2 + 1/atom2.qsp.Λei**2))  )
# atom2.hnc.βu_r_matrix[0,1] = βvei
# atom2.hnc.βu_r_matrix[1,0] = βvei
# atom2.hnc.set_βu_matrix(atom2.hnc.βu_r_matrix)

# k = atom3.hnc.k_array
# βvei = atom3.hnc.FT_k_2_r(  4*π*atom3.qsp.Γei*np.cos(k*Rc) * (1/k**2 - 1/(k**2 + 1/atom3.qsp.Λei**2))  )
# atom3.hnc.βu_r_matrix[0,1] = βvei
# atom3.hnc.βu_r_matrix[1,0] = βvei
# atom3.hnc.set_βu_matrix(atom3.hnc.βu_r_matrix)

# atom1.hnc.βu_r_matrix[0,1] += δβuei_Pauli_HNC
# atom1.hnc.βu_r_matrix[1,0] += δβuei_Pauli_HNC


# atom2.hnc.βu_r_matrix[0,1] += δβuei_Pauli_HNC
# atom2.hnc.βu_r_matrix[1,0] += δβuei_Pauli_HNC
# atom2.hnc.set_βu_matrix(atom2.hnc.βu_r_matrix)

# atom3.hnc.βu_r_matrix[0,1] += δβuei_Pauli_pointlike
# atom3.hnc.βu_r_matrix[1,0] += δβuei_Pauli_pointlike
# atom3.hnc.set_βu_matrix(atom3.hnc.βu_r_matrix)

# atom4.hnc.βu_r_matrix[0,1] += δβuei_Pauli_pointlike
# atom4.hnc.βu_r_matrix[1,0] += δβuei_Pauli_pointlike
# atom4.hnc.βu_r_matrix[0,0] += δβuii_Pauli_pointlike
# atom4.hnc.βu_r_matrix[0,0] += δβuii_Pauli_pointlike
# atom4.hnc.set_βu_matrix(atom4.hnc.βu_r_matrix)

# atom5.hnc.βu_r_matrix[0,1] += δβuei_Pauli_pointlike
# atom5.hnc.βu_r_matrix[1,0] += δβuei_Pauli_pointlike
# atom5.hnc.βu_r_matrix[0,0] += δβuii_Pauli_pointlike
# atom5.hnc.βu_r_matrix[0,0] += δβuii_Pauli_pointlike
# atom5.hnc.set_βu_matrix(atom5.hnc.βu_r_matrix)
# Out:
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# Te_in_eV: 1.000
# Ti_in_eV: 1.000
# /home/zach/plasma/hnc/hnc/PIE.py:163: RuntimeWarning: overflow encountered in exp
#   f_of_k = 1/(  1+np.exp((dense_hnc.k_array/self.qsp.ri)**2/(2*m_e*self.qsp.Te) - η) )

# %% [markdown]
# #### atom1

# %%
# interatom_list = []
# for i, x in enumerate(np.linspace(0.0, 1, num=20)):
#     atom =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar,
#                  βu_options = {'add_bridge':False,'bridge':'yukawa', 'pseudopotential':False}, 
#                  hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
#                  hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.01},
#                  root_options={'options':{'maxfev':100,'xtol':1e-14}})
#     δβuei_x = δβuei_Pauli_HNC*(1-x) + x*δβuei_Pauli_Lado
#     atom.hnc.βu_r_matrix[0,1] += δβuei_x
#     atom.hnc.βu_r_matrix[1,0] += δβuei_x
#     atom.hnc.set_βu_matrix(atom.hnc.βu_r_matrix)
#     if i==0:
#         c_s_k_guess = atom2.hnc.c_s_k_matrix.copy()
#     solve_least_squares(atom, np.linspace(atom.hnc.k_array[0], atom.hnc.k_array[-1], num=300), c_s_k_guess = c_s_k_guess.copy())
#     c_s_k_guess = atom.hnc.c_s_k_matrix.copy()
#     interatom_list.append(atom)

# %%
# saved_ck_guess = np.loadtxt("../data/dcf_data/Al_1eV_rs3_hnc_Pauli_c_s_k_matrix_part_Lado.csv").reshape(2,2,atom1.hnc.N_bins)
# saved_csk_guess = saved_ck_guess.copy() #+ atom3.hnc.βu_l_k_matrix

# %%
# best_shift(atom1, atom2.hnc.c_s_k_matrix.copy())
atom1.run_hnc(newton=False)#, c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
# solve_least_squares(atom2, np.linspace(atom2.hnc.k_array[0], atom2.hnc.k_array[-1], num=50))
# solve_least_squares(atom1, np.linspace(atom1.hnc.k_array[0], atom1.hnc.k_array[-1], num=300), c_s_k_guess = saved_csk_guess)
# solve_least_squares(atom1, np.linspace(atom1.hnc.k_array[0], atom1.hnc.k_array[-1], num=1000))#, c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
# Out:
# 0: Initial condition Total Error: 1.279e+01
# Starting Ng loop, using best index so far:  499
# |d_n|^2 =  [1.743914246416512, 1.75458917400599, 1.7653270674841903]
#  αs:  [ 12885.13282661 -25530.40660886  12646.27378225]
# |d_n|^2 =  [0.03499892893592615, 1.743914246416512, 1.75458917400599]
#  αs:  [  0.69387375  49.38022538 -49.07409913]
# |d_n|^2 =  [0.3705876769310614, 0.03499892893592615, 1.743914246416512]
#  αs:  [ 0.08103563  0.92325727 -0.0042929 ]
# |d_n|^2 =  [0.0224150400144487, 0.3705876769310614, 0.03499892893592615]
#  αs:  [ 0.75548081 -0.02155486  0.26607405]
# |d_n|^2 =  [0.010338043094378194, 0.0224150400144487, 0.3705876769310614]
#  αs:  [ 1.2245164 -0.2052455 -0.0192709]
# |d_n|^2 =  [0.013952673229304456, 0.010338043094378194, 0.0224150400144487]
#  αs:  [ 0.39472915  0.65137473 -0.04610388]
# |d_n|^2 =  [0.010262236036933063, 0.013952673229304456, 0.010338043094378194]
#  αs:  [ 1.90420213 -1.16641759  0.26221546]
# |d_n|^2 =  [0.007980763309691179, 0.010262236036933063, 0.013952673229304456]
#  αs:  [ 2.42322956 -0.49891671 -0.92431286]
# |d_n|^2 =  [0.009212398263947808, 0.007980763309691179, 0.010262236036933063]
#  αs:  [ 12.69186536  -1.62022763 -10.07163773]
# |d_n|^2 =  [0.007477617545103645, 0.009212398263947808, 0.007980763309691179]
#  αs:  [ 1.79939758 -5.3154382   4.51604062]
# |d_n|^2 =  [0.0008896327564875399, 0.007477617545103645, 0.009212398263947808]
#  αs:  [ 1.14857321 -0.21590842  0.06733521]
# |d_n|^2 =  [3.658308822956189e-05, 0.0008896327564875399, 0.007477617545103645]
#  αs:  [ 1.065768   -0.06890245  0.00313445]
# |d_n|^2 =  [1.602347735091711e-05, 3.658308822956189e-05, 0.0008896327564875399]
#  αs:  [ 0.89182144  0.12940211 -0.02122355]
# |d_n|^2 =  [3.2827085476786574e-07, 1.602347735091711e-05, 3.658308822956189e-05]
#  αs:  [ 1.0020317  -0.01280859  0.01077689]
# |d_n|^2 =  [7.631101725579805e-07, 3.2827085476786574e-07, 1.602347735091711e-05]
#  αs:  [ 1.1663476  -0.21771309  0.05136548]
# Exiting status 0, reverting to best index so far: 513
# Final iter:516, Total Error: 8.153e-09

# %%
atom1.hnc.plot_g_all_species()

# %% [markdown]
# #### atom2

# %%
atom2.run_hnc(newton=False)#, c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
# solve_least_squares(atom2, np.linspace(atom2.hnc.k_array[0], atom2.hnc.k_array[-1], num=400))
# solve_least_squares(atom2, np.linspace(atom2.hnc.k_array[0], atom2.hnc.k_array[-1], num=1000))
# Out:
# 0: Initial condition Total Error: 1.278e+01
# Starting Ng loop, using best index so far:  499
# |d_n|^2 =  [0.2258797135284285, 0.22876141915797993, 0.23167948497210286]
#  αs:  [ 3142.26860582 -6165.98958144  3024.72097561]
# |d_n|^2 =  [5.3893482417152924e-05, 0.2258797135284285, 0.22876141915797993]
#  αs:  [ 1.00419379 -0.31813594  0.31394215]
# |d_n|^2 =  [9.194838034062551e-05, 5.3893482417152924e-05, 0.2258797135284285]
#  αs:  [ 1.59161815e-01  8.40956727e-01 -1.18542641e-04]
# |d_n|^2 =  [5.4085340217449856e-05, 9.194838034062551e-05, 5.3893482417152924e-05]
#  αs:  [ 1.64177437 -0.80960375  0.16782938]
# |d_n|^2 =  [5.545176775944735e-05, 5.4085340217449856e-05, 9.194838034062551e-05]
#  αs:  [ 0.81535168 -0.66059266  0.84524098]
# |d_n|^2 =  [5.183954928944831e-05, 5.545176775944735e-05, 5.4085340217449856e-05]
#  αs:  [ 0.95932309 -0.45824997  0.49892688]
# |d_n|^2 =  [3.814524309262166e-06, 5.183954928944831e-05, 5.545176775944735e-05]
#  αs:  [ 1.06547979 -0.16184871  0.09636893]
# |d_n|^2 =  [3.8680305118077386e-06, 3.814524309262166e-06, 5.183954928944831e-05]
#  αs:  [ 4.30353391 -3.20990443 -0.09362948]
# |d_n|^2 =  [1.2653055704207885e-06, 3.8680305118077386e-06, 3.814524309262166e-06]
#  αs:  [ 1.46175567 -0.71589945  0.25414378]
# Exiting status 0, reverting to best index so far: 507
# Final iter:510, Total Error: 3.882e-09

# %%
atom2.hnc.plot_g_all_species()

# %% [markdown]
# #### atom3- Pointlike bound states

# %%
atom3.run_hnc(newton=False)#, c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
# solve_least_squares(atom2, np.linspace(atom2.hnc.k_array[0], atom2.hnc.k_array[-1], num=50))
# solve_least_squares(atom3, np.linspace(atom3.hnc.k_array[0], atom3.hnc.k_array[-1], num=400), c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
# Out:
# 0: Initial condition Total Error: 1.246e+01
# Starting Ng loop, using best index so far:  499
# |d_n|^2 =  [0.35016957361647894, 0.35422538078516036, 0.3583275713611296]
#  αs:  [ 3811.38824236 -7492.33400469  3681.94576233]
# |d_n|^2 =  [0.00020583515778842742, 0.35016957361647894, 0.35422538078516036]
#  αs:  [ 0.95161997  4.20675066 -4.15837063]
# |d_n|^2 =  [0.0007444695657383653, 0.00020583515778842742, 0.35016957361647894]
#  αs:  [ 2.53830615e-01  7.46402452e-01 -2.33067061e-04]
# |d_n|^2 =  [2.9573012293649832e-05, 0.0007444695657383653, 0.00020583515778842742]
#  αs:  [0.93875088 0.0308747  0.03037442]
# |d_n|^2 =  [0.00010852085362178674, 2.9573012293649832e-05, 0.0007444695657383653]
#  αs:  [0.13317465 0.86121246 0.00561289]
# |d_n|^2 =  [0.00010080083201637874, 0.00010852085362178674, 2.9573012293649832e-05]
#  αs:  [0.15751851 0.01586669 0.8266148 ]
# |d_n|^2 =  [9.309846731599782e-05, 0.00010080083201637874, 0.00010852085362178674]
#  αs:  [ 18.98657311 -24.64787658   6.66130346]
# |d_n|^2 =  [5.74653942721896e-05, 9.309846731599782e-05, 0.00010080083201637874]
#  αs:  [ 2.48325709 -0.88539906 -0.59785803]
# |d_n|^2 =  [2.4177046921972704e-06, 5.74653942721896e-05, 9.309846731599782e-05]
#  αs:  [ 0.69138986  0.76765263 -0.45904249]
# |d_n|^2 =  [2.0458055050944606e-06, 2.4177046921972704e-06, 5.74653942721896e-05]
#  αs:  [ 1.02406557  0.01195149 -0.03601707]
# Exiting status 0, reverting to best index so far: 508
# Final iter:511, Total Error: 8.259e-09

# %%
# solve_least_squares(atom3, np.linspace(atom3.hnc.k_array[0], atom3.hnc.k_array[-1], num=1000), c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())

# %%
atom3.hnc.plot_g_all_species()

# %% [markdown]
# #### atom4- OZ Pointlike bound states, with core-core

# %%
atom4.run_hnc(newton=False)#, c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
# Out:
# 0: Initial condition Total Error: 9.429e+00
# 1: Change in c_r: 3.060e-02, HNC Error: 1.067e+00, Total Error: 8.851e+00
# 2: Change in c_r: 3.051e-02, HNC Error: 7.570e-01, Total Error: 8.359e+00
# 3: Change in c_r: 3.048e-02, HNC Error: 5.687e-01, Total Error: 7.912e+00
# 4: Change in c_r: 3.048e-02, HNC Error: 4.438e-01, Total Error: 7.498e+00
# 5: Change in c_r: 3.051e-02, HNC Error: 3.564e-01, Total Error: 7.112e+00
# 6: Change in c_r: 3.057e-02, HNC Error: 2.930e-01, Total Error: 6.752e+00
# 7: Change in c_r: 3.065e-02, HNC Error: 2.459e-01, Total Error: 6.414e+00
# 8: Change in c_r: 3.076e-02, HNC Error: 2.105e-01, Total Error: 6.098e+00
# 9: Change in c_r: 3.087e-02, HNC Error: 1.836e-01, Total Error: 5.801e+00
# 10: Change in c_r: 3.100e-02, HNC Error: 1.632e-01, Total Error: 5.523e+00
# 11: Change in c_r: 3.114e-02, HNC Error: 1.478e-01, Total Error: 5.261e+00
# 12: Change in c_r: 3.127e-02, HNC Error: 1.363e-01, Total Error: 5.015e+00
# 13: Change in c_r: 3.141e-02, HNC Error: 1.279e-01, Total Error: 4.784e+00
# 14: Change in c_r: 3.154e-02, HNC Error: 1.219e-01, Total Error: 4.567e+00
# 15: Change in c_r: 3.166e-02, HNC Error: 1.179e-01, Total Error: 4.363e+00
# 16: Change in c_r: 3.177e-02, HNC Error: 1.153e-01, Total Error: 4.171e+00
# 17: Change in c_r: 3.187e-02, HNC Error: 1.140e-01, Total Error: 3.990e+00
# 18: Change in c_r: 3.196e-02, HNC Error: 1.135e-01, Total Error: 3.820e+00
# 19: Change in c_r: 3.204e-02, HNC Error: 1.137e-01, Total Error: 3.661e+00
# 20: Change in c_r: 3.210e-02, HNC Error: 1.145e-01, Total Error: 3.511e+00
# 21: Change in c_r: 3.216e-02, HNC Error: 1.156e-01, Total Error: 3.370e+00
# 22: Change in c_r: 3.220e-02, HNC Error: 1.170e-01, Total Error: 3.238e+00
# 23: Change in c_r: 3.223e-02, HNC Error: 1.186e-01, Total Error: 3.113e+00
# 24: Change in c_r: 3.226e-02, HNC Error: 1.203e-01, Total Error: 2.996e+00
# 25: Change in c_r: 3.227e-02, HNC Error: 1.220e-01, Total Error: 2.886e+00
# 26: Change in c_r: 3.228e-02, HNC Error: 1.238e-01, Total Error: 2.782e+00
# 27: Change in c_r: 3.228e-02, HNC Error: 1.255e-01, Total Error: 2.685e+00
# 28: Change in c_r: 3.227e-02, HNC Error: 1.272e-01, Total Error: 2.594e+00
# 29: Change in c_r: 3.225e-02, HNC Error: 1.288e-01, Total Error: 2.508e+00
# 30: Change in c_r: 3.223e-02, HNC Error: 1.303e-01, Total Error: 2.427e+00
# 31: Change in c_r: 3.221e-02, HNC Error: 1.317e-01, Total Error: 2.351e+00
# 32: Change in c_r: 3.218e-02, HNC Error: 1.330e-01, Total Error: 2.279e+00
# 33: Change in c_r: 3.215e-02, HNC Error: 1.341e-01, Total Error: 2.211e+00
# 34: Change in c_r: 3.211e-02, HNC Error: 1.352e-01, Total Error: 2.148e+00
# 35: Change in c_r: 3.207e-02, HNC Error: 1.362e-01, Total Error: 2.087e+00
# 36: Change in c_r: 3.202e-02, HNC Error: 1.371e-01, Total Error: 2.031e+00
# 37: Change in c_r: 3.198e-02, HNC Error: 1.378e-01, Total Error: 1.977e+00
# 38: Change in c_r: 3.193e-02, HNC Error: 1.386e-01, Total Error: 1.926e+00
# 39: Change in c_r: 3.187e-02, HNC Error: 1.392e-01, Total Error: 1.879e+00
# 40: Change in c_r: 3.182e-02, HNC Error: 1.397e-01, Total Error: 1.833e+00
# 41: Change in c_r: 3.176e-02, HNC Error: 1.401e-01, Total Error: 1.790e+00
# 42: Change in c_r: 3.170e-02, HNC Error: 1.405e-01, Total Error: 1.749e+00
# 43: Change in c_r: 3.164e-02, HNC Error: 1.407e-01, Total Error: 1.710e+00
# 44: Change in c_r: 3.158e-02, HNC Error: 1.409e-01, Total Error: 1.673e+00
# 45: Change in c_r: 3.151e-02, HNC Error: 1.410e-01, Total Error: 1.638e+00
# 46: Change in c_r: 3.145e-02, HNC Error: 1.411e-01, Total Error: 1.605e+00
# 47: Change in c_r: 3.138e-02, HNC Error: 1.410e-01, Total Error: 1.573e+00
# 48: Change in c_r: 3.131e-02, HNC Error: 1.410e-01, Total Error: 1.542e+00
# 49: Change in c_r: 3.125e-02, HNC Error: 1.408e-01, Total Error: 1.513e+00
# 50: Change in c_r: 3.118e-02, HNC Error: 1.406e-01, Total Error: 1.485e+00
# 51: Change in c_r: 3.111e-02, HNC Error: 1.404e-01, Total Error: 1.458e+00
# 52: Change in c_r: 3.104e-02, HNC Error: 1.401e-01, Total Error: 1.432e+00
# 53: Change in c_r: 3.097e-02, HNC Error: 1.398e-01, Total Error: 1.407e+00
# 54: Change in c_r: 3.090e-02, HNC Error: 1.394e-01, Total Error: 1.384e+00
# 55: Change in c_r: 3.083e-02, HNC Error: 1.391e-01, Total Error: 1.361e+00
# 56: Change in c_r: 3.076e-02, HNC Error: 1.387e-01, Total Error: 1.339e+00
# 57: Change in c_r: 3.069e-02, HNC Error: 1.383e-01, Total Error: 1.317e+00
# 58: Change in c_r: 3.061e-02, HNC Error: 1.379e-01, Total Error: 1.297e+00
# 59: Change in c_r: 3.054e-02, HNC Error: 1.375e-01, Total Error: 1.277e+00
# 60: Change in c_r: 3.047e-02, HNC Error: 1.372e-01, Total Error: 1.258e+00
# 61: Change in c_r: 3.040e-02, HNC Error: 1.368e-01, Total Error: 1.239e+00
# 62: Change in c_r: 3.033e-02, HNC Error: 1.364e-01, Total Error: 1.221e+00
# 63: Change in c_r: 3.026e-02, HNC Error: 1.360e-01, Total Error: 1.204e+00
# 64: Change in c_r: 3.018e-02, HNC Error: 1.357e-01, Total Error: 1.187e+00
# 65: Change in c_r: 3.011e-02, HNC Error: 1.353e-01, Total Error: 1.171e+00
# 66: Change in c_r: 3.004e-02, HNC Error: 1.350e-01, Total Error: 1.155e+00
# 67: Change in c_r: 2.997e-02, HNC Error: 1.347e-01, Total Error: 1.139e+00
# 68: Change in c_r: 2.989e-02, HNC Error: 1.344e-01, Total Error: 1.124e+00
# 69: Change in c_r: 2.982e-02, HNC Error: 1.341e-01, Total Error: 1.110e+00
# 70: Change in c_r: 2.975e-02, HNC Error: 1.338e-01, Total Error: 1.096e+00
# 71: Change in c_r: 2.968e-02, HNC Error: 1.334e-01, Total Error: 1.082e+00
# 72: Change in c_r: 2.961e-02, HNC Error: 1.331e-01, Total Error: 1.068e+00
# 73: Change in c_r: 2.954e-02, HNC Error: 1.328e-01, Total Error: 1.055e+00
# 74: Change in c_r: 2.946e-02, HNC Error: 1.325e-01, Total Error: 1.042e+00
# 75: Change in c_r: 2.939e-02, HNC Error: 1.322e-01, Total Error: 1.030e+00
# 76: Change in c_r: 2.932e-02, HNC Error: 1.319e-01, Total Error: 1.018e+00
# 77: Change in c_r: 2.925e-02, HNC Error: 1.316e-01, Total Error: 1.006e+00
# 78: Change in c_r: 2.918e-02, HNC Error: 1.313e-01, Total Error: 9.940e-01
# 79: Change in c_r: 2.911e-02, HNC Error: 1.309e-01, Total Error: 9.826e-01
# 80: Change in c_r: 2.904e-02, HNC Error: 1.306e-01, Total Error: 9.714e-01
# 81: Change in c_r: 2.897e-02, HNC Error: 1.303e-01, Total Error: 9.606e-01
# 82: Change in c_r: 2.890e-02, HNC Error: 1.300e-01, Total Error: 9.499e-01
# 83: Change in c_r: 2.883e-02, HNC Error: 1.296e-01, Total Error: 9.395e-01
# 84: Change in c_r: 2.876e-02, HNC Error: 1.293e-01, Total Error: 9.293e-01
# 85: Change in c_r: 2.870e-02, HNC Error: 1.290e-01, Total Error: 9.193e-01
# 86: Change in c_r: 2.863e-02, HNC Error: 1.287e-01, Total Error: 9.095e-01
# 87: Change in c_r: 2.856e-02, HNC Error: 1.284e-01, Total Error: 8.999e-01
# 88: Change in c_r: 2.849e-02, HNC Error: 1.280e-01, Total Error: 8.905e-01
# 89: Change in c_r: 2.843e-02, HNC Error: 1.277e-01, Total Error: 8.813e-01
# 90: Change in c_r: 2.836e-02, HNC Error: 1.274e-01, Total Error: 8.722e-01
# 91: Change in c_r: 2.829e-02, HNC Error: 1.271e-01, Total Error: 8.634e-01
# 92: Change in c_r: 2.823e-02, HNC Error: 1.268e-01, Total Error: 8.547e-01
# 93: Change in c_r: 2.816e-02, HNC Error: 1.265e-01, Total Error: 8.462e-01
# 94: Change in c_r: 2.810e-02, HNC Error: 1.262e-01, Total Error: 8.378e-01
# 95: Change in c_r: 2.803e-02, HNC Error: 1.259e-01, Total Error: 8.296e-01
# 96: Change in c_r: 2.797e-02, HNC Error: 1.256e-01, Total Error: 8.215e-01
# 97: Change in c_r: 2.790e-02, HNC Error: 1.252e-01, Total Error: 8.136e-01
# 98: Change in c_r: 2.784e-02, HNC Error: 1.249e-01, Total Error: 8.058e-01
# 99: Change in c_r: 2.777e-02, HNC Error: 1.246e-01, Total Error: 7.982e-01
# 100: Change in c_r: 2.771e-02, HNC Error: 1.243e-01, Total Error: 7.907e-01
# 101: Change in c_r: 2.765e-02, HNC Error: 1.240e-01, Total Error: 7.833e-01
# 102: Change in c_r: 2.758e-02, HNC Error: 1.237e-01, Total Error: 7.760e-01
# 103: Change in c_r: 2.752e-02, HNC Error: 1.234e-01, Total Error: 7.689e-01
# 104: Change in c_r: 2.746e-02, HNC Error: 1.231e-01, Total Error: 7.619e-01
# 105: Change in c_r: 2.740e-02, HNC Error: 1.227e-01, Total Error: 7.550e-01
# 106: Change in c_r: 2.734e-02, HNC Error: 1.224e-01, Total Error: 7.482e-01
# 107: Change in c_r: 2.728e-02, HNC Error: 1.221e-01, Total Error: 7.416e-01
# 108: Change in c_r: 2.722e-02, HNC Error: 1.217e-01, Total Error: 7.350e-01
# 109: Change in c_r: 2.716e-02, HNC Error: 1.214e-01, Total Error: 7.285e-01
# 110: Change in c_r: 2.710e-02, HNC Error: 1.210e-01, Total Error: 7.222e-01
# 111: Change in c_r: 2.704e-02, HNC Error: 1.206e-01, Total Error: 7.159e-01
# 112: Change in c_r: 2.698e-02, HNC Error: 1.202e-01, Total Error: 7.098e-01
# 113: Change in c_r: 2.692e-02, HNC Error: 1.199e-01, Total Error: 7.037e-01
# 114: Change in c_r: 2.687e-02, HNC Error: 1.195e-01, Total Error: 6.978e-01
# 115: Change in c_r: 2.681e-02, HNC Error: 1.191e-01, Total Error: 6.919e-01
# 116: Change in c_r: 2.675e-02, HNC Error: 1.187e-01, Total Error: 6.861e-01
# 117: Change in c_r: 2.670e-02, HNC Error: 1.182e-01, Total Error: 6.804e-01
# 118: Change in c_r: 2.664e-02, HNC Error: 1.178e-01, Total Error: 6.748e-01
# 119: Change in c_r: 2.658e-02, HNC Error: 1.174e-01, Total Error: 6.693e-01
# 120: Change in c_r: 2.653e-02, HNC Error: 1.169e-01, Total Error: 6.638e-01
# 121: Change in c_r: 2.647e-02, HNC Error: 1.165e-01, Total Error: 6.585e-01
# 122: Change in c_r: 2.642e-02, HNC Error: 1.160e-01, Total Error: 6.532e-01
# 123: Change in c_r: 2.636e-02, HNC Error: 1.156e-01, Total Error: 6.480e-01
# 124: Change in c_r: 2.631e-02, HNC Error: 1.151e-01, Total Error: 6.428e-01
# 125: Change in c_r: 2.626e-02, HNC Error: 1.146e-01, Total Error: 6.378e-01
# 126: Change in c_r: 2.620e-02, HNC Error: 1.141e-01, Total Error: 6.328e-01
# 127: Change in c_r: 2.615e-02, HNC Error: 1.137e-01, Total Error: 6.279e-01
# 128: Change in c_r: 2.610e-02, HNC Error: 1.132e-01, Total Error: 6.230e-01
# 129: Change in c_r: 2.605e-02, HNC Error: 1.127e-01, Total Error: 6.183e-01
# 130: Change in c_r: 2.599e-02, HNC Error: 1.122e-01, Total Error: 6.135e-01
# 131: Change in c_r: 2.594e-02, HNC Error: 1.116e-01, Total Error: 6.089e-01
# 132: Change in c_r: 2.589e-02, HNC Error: 1.111e-01, Total Error: 6.043e-01
# 133: Change in c_r: 2.584e-02, HNC Error: 1.106e-01, Total Error: 5.998e-01
# 134: Change in c_r: 2.579e-02, HNC Error: 1.101e-01, Total Error: 5.954e-01
# 135: Change in c_r: 2.574e-02, HNC Error: 1.095e-01, Total Error: 5.910e-01
# 136: Change in c_r: 2.569e-02, HNC Error: 1.090e-01, Total Error: 5.866e-01
# 137: Change in c_r: 2.564e-02, HNC Error: 1.084e-01, Total Error: 5.824e-01
# 138: Change in c_r: 2.559e-02, HNC Error: 1.079e-01, Total Error: 5.782e-01
# 139: Change in c_r: 2.554e-02, HNC Error: 1.073e-01, Total Error: 5.740e-01
# 140: Change in c_r: 2.549e-02, HNC Error: 1.068e-01, Total Error: 5.699e-01
# 141: Change in c_r: 2.545e-02, HNC Error: 1.062e-01, Total Error: 5.659e-01
# 142: Change in c_r: 2.540e-02, HNC Error: 1.056e-01, Total Error: 5.619e-01
# 143: Change in c_r: 2.535e-02, HNC Error: 1.051e-01, Total Error: 5.579e-01
# 144: Change in c_r: 2.530e-02, HNC Error: 1.045e-01, Total Error: 5.540e-01
# 145: Change in c_r: 2.526e-02, HNC Error: 1.039e-01, Total Error: 5.502e-01
# 146: Change in c_r: 2.521e-02, HNC Error: 1.033e-01, Total Error: 5.464e-01
# 147: Change in c_r: 2.516e-02, HNC Error: 1.027e-01, Total Error: 5.427e-01
# 148: Change in c_r: 2.512e-02, HNC Error: 1.021e-01, Total Error: 5.390e-01
# 149: Change in c_r: 2.507e-02, HNC Error: 1.015e-01, Total Error: 5.354e-01
# 150: Change in c_r: 2.502e-02, HNC Error: 1.009e-01, Total Error: 5.318e-01
# 151: Change in c_r: 2.498e-02, HNC Error: 1.003e-01, Total Error: 5.283e-01
# 152: Change in c_r: 2.493e-02, HNC Error: 9.965e-02, Total Error: 5.248e-01
# 153: Change in c_r: 2.489e-02, HNC Error: 9.904e-02, Total Error: 5.213e-01
# 154: Change in c_r: 2.484e-02, HNC Error: 9.841e-02, Total Error: 5.179e-01
# 155: Change in c_r: 2.480e-02, HNC Error: 9.777e-02, Total Error: 5.146e-01
# 156: Change in c_r: 2.475e-02, HNC Error: 9.714e-02, Total Error: 5.112e-01
# 157: Change in c_r: 2.471e-02, HNC Error: 9.650e-02, Total Error: 5.080e-01
# 158: Change in c_r: 2.466e-02, HNC Error: 9.585e-02, Total Error: 5.047e-01
# 159: Change in c_r: 2.462e-02, HNC Error: 9.520e-02, Total Error: 5.015e-01
# 160: Change in c_r: 2.457e-02, HNC Error: 9.455e-02, Total Error: 4.984e-01
# 161: Change in c_r: 2.453e-02, HNC Error: 9.390e-02, Total Error: 4.953e-01
# 162: Change in c_r: 2.449e-02, HNC Error: 9.324e-02, Total Error: 4.922e-01
# 163: Change in c_r: 2.444e-02, HNC Error: 9.257e-02, Total Error: 4.892e-01
# 164: Change in c_r: 2.440e-02, HNC Error: 9.191e-02, Total Error: 4.862e-01
# 165: Change in c_r: 2.436e-02, HNC Error: 9.124e-02, Total Error: 4.832e-01
# 166: Change in c_r: 2.431e-02, HNC Error: 9.058e-02, Total Error: 4.803e-01
# 167: Change in c_r: 2.427e-02, HNC Error: 8.990e-02, Total Error: 4.774e-01
# 168: Change in c_r: 2.423e-02, HNC Error: 8.923e-02, Total Error: 4.746e-01
# 169: Change in c_r: 2.419e-02, HNC Error: 8.856e-02, Total Error: 4.718e-01
# 170: Change in c_r: 2.414e-02, HNC Error: 8.788e-02, Total Error: 4.690e-01
# 171: Change in c_r: 2.410e-02, HNC Error: 8.721e-02, Total Error: 4.663e-01
# 172: Change in c_r: 2.406e-02, HNC Error: 8.654e-02, Total Error: 4.635e-01
# 173: Change in c_r: 2.402e-02, HNC Error: 8.586e-02, Total Error: 4.609e-01
# 174: Change in c_r: 2.397e-02, HNC Error: 8.518e-02, Total Error: 4.582e-01
# 175: Change in c_r: 2.393e-02, HNC Error: 8.451e-02, Total Error: 4.556e-01
# 176: Change in c_r: 2.389e-02, HNC Error: 8.384e-02, Total Error: 4.531e-01
# 177: Change in c_r: 2.385e-02, HNC Error: 8.317e-02, Total Error: 4.505e-01
# 178: Change in c_r: 2.381e-02, HNC Error: 8.250e-02, Total Error: 4.480e-01
# 179: Change in c_r: 2.376e-02, HNC Error: 8.182e-02, Total Error: 4.455e-01
# 180: Change in c_r: 2.372e-02, HNC Error: 8.115e-02, Total Error: 4.431e-01
# 181: Change in c_r: 2.368e-02, HNC Error: 8.048e-02, Total Error: 4.407e-01
# 182: Change in c_r: 2.364e-02, HNC Error: 7.982e-02, Total Error: 4.383e-01
# 183: Change in c_r: 2.360e-02, HNC Error: 7.916e-02, Total Error: 4.359e-01
# 184: Change in c_r: 2.356e-02, HNC Error: 7.850e-02, Total Error: 4.336e-01
# 185: Change in c_r: 2.352e-02, HNC Error: 7.784e-02, Total Error: 4.313e-01
# 186: Change in c_r: 2.348e-02, HNC Error: 7.718e-02, Total Error: 4.290e-01
# 187: Change in c_r: 2.344e-02, HNC Error: 7.653e-02, Total Error: 4.267e-01
# 188: Change in c_r: 2.339e-02, HNC Error: 7.587e-02, Total Error: 4.245e-01
# 189: Change in c_r: 2.335e-02, HNC Error: 7.523e-02, Total Error: 4.223e-01
# 190: Change in c_r: 2.331e-02, HNC Error: 7.458e-02, Total Error: 4.202e-01
# 191: Change in c_r: 2.327e-02, HNC Error: 7.395e-02, Total Error: 4.180e-01
# 192: Change in c_r: 2.323e-02, HNC Error: 7.331e-02, Total Error: 4.159e-01
# 193: Change in c_r: 2.319e-02, HNC Error: 7.268e-02, Total Error: 4.138e-01
# 194: Change in c_r: 2.315e-02, HNC Error: 7.205e-02, Total Error: 4.118e-01
# 195: Change in c_r: 2.311e-02, HNC Error: 7.142e-02, Total Error: 4.097e-01
# 196: Change in c_r: 2.307e-02, HNC Error: 7.079e-02, Total Error: 4.077e-01
# 197: Change in c_r: 2.303e-02, HNC Error: 7.018e-02, Total Error: 4.057e-01
# 198: Change in c_r: 2.299e-02, HNC Error: 6.956e-02, Total Error: 4.037e-01
# 199: Change in c_r: 2.295e-02, HNC Error: 6.895e-02, Total Error: 4.018e-01
# 200: Change in c_r: 2.291e-02, HNC Error: 6.835e-02, Total Error: 3.999e-01
# 201: Change in c_r: 2.287e-02, HNC Error: 6.775e-02, Total Error: 3.980e-01
# 202: Change in c_r: 2.283e-02, HNC Error: 6.716e-02, Total Error: 3.961e-01
# 203: Change in c_r: 2.279e-02, HNC Error: 6.656e-02, Total Error: 3.942e-01
# 204: Change in c_r: 2.275e-02, HNC Error: 6.597e-02, Total Error: 3.924e-01
# 205: Change in c_r: 2.271e-02, HNC Error: 6.539e-02, Total Error: 3.906e-01
# 206: Change in c_r: 2.267e-02, HNC Error: 6.481e-02, Total Error: 3.888e-01
# 207: Change in c_r: 2.263e-02, HNC Error: 6.423e-02, Total Error: 3.870e-01
# 208: Change in c_r: 2.259e-02, HNC Error: 6.367e-02, Total Error: 3.852e-01
# 209: Change in c_r: 2.255e-02, HNC Error: 6.310e-02, Total Error: 3.835e-01
# 210: Change in c_r: 2.251e-02, HNC Error: 6.255e-02, Total Error: 3.818e-01
# 211: Change in c_r: 2.247e-02, HNC Error: 6.200e-02, Total Error: 3.801e-01
# 212: Change in c_r: 2.243e-02, HNC Error: 6.145e-02, Total Error: 3.784e-01
# 213: Change in c_r: 2.239e-02, HNC Error: 6.090e-02, Total Error: 3.768e-01
# 214: Change in c_r: 2.236e-02, HNC Error: 6.036e-02, Total Error: 3.751e-01
# 215: Change in c_r: 2.232e-02, HNC Error: 5.982e-02, Total Error: 3.735e-01
# 216: Change in c_r: 2.228e-02, HNC Error: 5.929e-02, Total Error: 3.719e-01
# 217: Change in c_r: 2.224e-02, HNC Error: 5.876e-02, Total Error: 3.703e-01
# 218: Change in c_r: 2.220e-02, HNC Error: 5.824e-02, Total Error: 3.687e-01
# 219: Change in c_r: 2.216e-02, HNC Error: 5.773e-02, Total Error: 3.672e-01
# 220: Change in c_r: 2.212e-02, HNC Error: 5.722e-02, Total Error: 3.656e-01
# 221: Change in c_r: 2.208e-02, HNC Error: 5.672e-02, Total Error: 3.641e-01
# 222: Change in c_r: 2.204e-02, HNC Error: 5.622e-02, Total Error: 3.626e-01
# 223: Change in c_r: 2.200e-02, HNC Error: 5.573e-02, Total Error: 3.611e-01
# 224: Change in c_r: 2.197e-02, HNC Error: 5.523e-02, Total Error: 3.597e-01
# 225: Change in c_r: 2.193e-02, HNC Error: 5.474e-02, Total Error: 3.582e-01
# 226: Change in c_r: 2.189e-02, HNC Error: 5.426e-02, Total Error: 3.568e-01
# 227: Change in c_r: 2.185e-02, HNC Error: 5.378e-02, Total Error: 3.553e-01
# 228: Change in c_r: 2.181e-02, HNC Error: 5.330e-02, Total Error: 3.539e-01
# 229: Change in c_r: 2.177e-02, HNC Error: 5.283e-02, Total Error: 3.525e-01
# 230: Change in c_r: 2.174e-02, HNC Error: 5.236e-02, Total Error: 3.512e-01
# 231: Change in c_r: 2.170e-02, HNC Error: 5.190e-02, Total Error: 3.498e-01
# 232: Change in c_r: 2.166e-02, HNC Error: 5.143e-02, Total Error: 3.484e-01
# 233: Change in c_r: 2.162e-02, HNC Error: 5.098e-02, Total Error: 3.471e-01
# 234: Change in c_r: 2.158e-02, HNC Error: 5.053e-02, Total Error: 3.458e-01
# 235: Change in c_r: 2.155e-02, HNC Error: 5.008e-02, Total Error: 3.445e-01
# 236: Change in c_r: 2.151e-02, HNC Error: 4.964e-02, Total Error: 3.432e-01
# 237: Change in c_r: 2.147e-02, HNC Error: 4.920e-02, Total Error: 3.419e-01
# 238: Change in c_r: 2.143e-02, HNC Error: 4.876e-02, Total Error: 3.406e-01
# 239: Change in c_r: 2.140e-02, HNC Error: 4.832e-02, Total Error: 3.393e-01
# 240: Change in c_r: 2.136e-02, HNC Error: 4.789e-02, Total Error: 3.381e-01
# 241: Change in c_r: 2.132e-02, HNC Error: 4.747e-02, Total Error: 3.368e-01
# 242: Change in c_r: 2.129e-02, HNC Error: 4.705e-02, Total Error: 3.356e-01
# 243: Change in c_r: 2.125e-02, HNC Error: 4.664e-02, Total Error: 3.344e-01
# 244: Change in c_r: 2.121e-02, HNC Error: 4.623e-02, Total Error: 3.332e-01
# 245: Change in c_r: 2.117e-02, HNC Error: 4.582e-02, Total Error: 3.320e-01
# 246: Change in c_r: 2.114e-02, HNC Error: 4.541e-02, Total Error: 3.308e-01
# 247: Change in c_r: 2.110e-02, HNC Error: 4.500e-02, Total Error: 3.297e-01
# 248: Change in c_r: 2.106e-02, HNC Error: 4.460e-02, Total Error: 3.285e-01
# 249: Change in c_r: 2.103e-02, HNC Error: 4.421e-02, Total Error: 3.274e-01
# 250: Change in c_r: 2.099e-02, HNC Error: 4.382e-02, Total Error: 3.262e-01
# 251: Change in c_r: 2.095e-02, HNC Error: 4.343e-02, Total Error: 3.251e-01
# 252: Change in c_r: 2.092e-02, HNC Error: 4.305e-02, Total Error: 3.240e-01
# 253: Change in c_r: 2.088e-02, HNC Error: 4.268e-02, Total Error: 3.229e-01
# 254: Change in c_r: 2.085e-02, HNC Error: 4.230e-02, Total Error: 3.218e-01
# 255: Change in c_r: 2.081e-02, HNC Error: 4.193e-02, Total Error: 3.207e-01
# 256: Change in c_r: 2.077e-02, HNC Error: 4.156e-02, Total Error: 3.196e-01
# 257: Change in c_r: 2.074e-02, HNC Error: 4.119e-02, Total Error: 3.185e-01
# 258: Change in c_r: 2.070e-02, HNC Error: 4.083e-02, Total Error: 3.175e-01
# 259: Change in c_r: 2.067e-02, HNC Error: 4.047e-02, Total Error: 3.164e-01
# 260: Change in c_r: 2.063e-02, HNC Error: 4.011e-02, Total Error: 3.154e-01
# 261: Change in c_r: 2.059e-02, HNC Error: 3.976e-02, Total Error: 3.144e-01
# 262: Change in c_r: 2.056e-02, HNC Error: 3.942e-02, Total Error: 3.134e-01
# 263: Change in c_r: 2.052e-02, HNC Error: 3.908e-02, Total Error: 3.123e-01
# 264: Change in c_r: 2.049e-02, HNC Error: 3.874e-02, Total Error: 3.113e-01
# 265: Change in c_r: 2.045e-02, HNC Error: 3.840e-02, Total Error: 3.103e-01
# 266: Change in c_r: 2.042e-02, HNC Error: 3.806e-02, Total Error: 3.094e-01
# 267: Change in c_r: 2.038e-02, HNC Error: 3.773e-02, Total Error: 3.084e-01
# 268: Change in c_r: 2.035e-02, HNC Error: 3.740e-02, Total Error: 3.074e-01
# 269: Change in c_r: 2.031e-02, HNC Error: 3.707e-02, Total Error: 3.064e-01
# 270: Change in c_r: 2.028e-02, HNC Error: 3.675e-02, Total Error: 3.055e-01
# 271: Change in c_r: 2.024e-02, HNC Error: 3.643e-02, Total Error: 3.045e-01
# 272: Change in c_r: 2.021e-02, HNC Error: 3.612e-02, Total Error: 3.036e-01
# 273: Change in c_r: 2.017e-02, HNC Error: 3.581e-02, Total Error: 3.027e-01
# 274: Change in c_r: 2.014e-02, HNC Error: 3.550e-02, Total Error: 3.018e-01
# 275: Change in c_r: 2.010e-02, HNC Error: 3.519e-02, Total Error: 3.008e-01
# 276: Change in c_r: 2.007e-02, HNC Error: 3.489e-02, Total Error: 2.999e-01
# 277: Change in c_r: 2.003e-02, HNC Error: 3.459e-02, Total Error: 2.990e-01
# 278: Change in c_r: 2.000e-02, HNC Error: 3.429e-02, Total Error: 2.981e-01
# 279: Change in c_r: 1.996e-02, HNC Error: 3.400e-02, Total Error: 2.972e-01
# 280: Change in c_r: 1.993e-02, HNC Error: 3.370e-02, Total Error: 2.964e-01
# 281: Change in c_r: 1.990e-02, HNC Error: 3.341e-02, Total Error: 2.955e-01
# 282: Change in c_r: 1.986e-02, HNC Error: 3.313e-02, Total Error: 2.946e-01
# 283: Change in c_r: 1.983e-02, HNC Error: 3.284e-02, Total Error: 2.938e-01
# 284: Change in c_r: 1.979e-02, HNC Error: 3.256e-02, Total Error: 2.929e-01
# 285: Change in c_r: 1.976e-02, HNC Error: 3.229e-02, Total Error: 2.921e-01
# 286: Change in c_r: 1.973e-02, HNC Error: 3.201e-02, Total Error: 2.912e-01
# 287: Change in c_r: 1.969e-02, HNC Error: 3.174e-02, Total Error: 2.904e-01
# 288: Change in c_r: 1.966e-02, HNC Error: 3.147e-02, Total Error: 2.896e-01
# 289: Change in c_r: 1.963e-02, HNC Error: 3.121e-02, Total Error: 2.887e-01
# 290: Change in c_r: 1.959e-02, HNC Error: 3.095e-02, Total Error: 2.879e-01
# 291: Change in c_r: 1.956e-02, HNC Error: 3.069e-02, Total Error: 2.871e-01
# 292: Change in c_r: 1.952e-02, HNC Error: 3.043e-02, Total Error: 2.863e-01
# 293: Change in c_r: 1.949e-02, HNC Error: 3.017e-02, Total Error: 2.855e-01
# 294: Change in c_r: 1.946e-02, HNC Error: 2.991e-02, Total Error: 2.847e-01
# 295: Change in c_r: 1.943e-02, HNC Error: 2.966e-02, Total Error: 2.839e-01
# 296: Change in c_r: 1.939e-02, HNC Error: 2.941e-02, Total Error: 2.831e-01
# 297: Change in c_r: 1.936e-02, HNC Error: 2.916e-02, Total Error: 2.824e-01
# 298: Change in c_r: 1.933e-02, HNC Error: 2.892e-02, Total Error: 2.816e-01
# 299: Change in c_r: 1.929e-02, HNC Error: 2.868e-02, Total Error: 2.808e-01
# 300: Change in c_r: 1.926e-02, HNC Error: 2.844e-02, Total Error: 2.801e-01
# 301: Change in c_r: 1.923e-02, HNC Error: 2.820e-02, Total Error: 2.793e-01
# 302: Change in c_r: 1.920e-02, HNC Error: 2.797e-02, Total Error: 2.786e-01
# 303: Change in c_r: 1.916e-02, HNC Error: 2.774e-02, Total Error: 2.778e-01
# 304: Change in c_r: 1.913e-02, HNC Error: 2.751e-02, Total Error: 2.771e-01
# 305: Change in c_r: 1.910e-02, HNC Error: 2.729e-02, Total Error: 2.763e-01
# 306: Change in c_r: 1.907e-02, HNC Error: 2.707e-02, Total Error: 2.756e-01
# 307: Change in c_r: 1.903e-02, HNC Error: 2.684e-02, Total Error: 2.749e-01
# 308: Change in c_r: 1.900e-02, HNC Error: 2.662e-02, Total Error: 2.742e-01
# 309: Change in c_r: 1.897e-02, HNC Error: 2.640e-02, Total Error: 2.734e-01
# 310: Change in c_r: 1.894e-02, HNC Error: 2.618e-02, Total Error: 2.727e-01
# 311: Change in c_r: 1.891e-02, HNC Error: 2.596e-02, Total Error: 2.720e-01
# 312: Change in c_r: 1.887e-02, HNC Error: 2.575e-02, Total Error: 2.713e-01
# 313: Change in c_r: 1.884e-02, HNC Error: 2.554e-02, Total Error: 2.706e-01
# 314: Change in c_r: 1.881e-02, HNC Error: 2.533e-02, Total Error: 2.699e-01
# 315: Change in c_r: 1.878e-02, HNC Error: 2.512e-02, Total Error: 2.692e-01
# 316: Change in c_r: 1.875e-02, HNC Error: 2.492e-02, Total Error: 2.685e-01
# 317: Change in c_r: 1.872e-02, HNC Error: 2.472e-02, Total Error: 2.679e-01
# 318: Change in c_r: 1.869e-02, HNC Error: 2.452e-02, Total Error: 2.672e-01
# 319: Change in c_r: 1.866e-02, HNC Error: 2.432e-02, Total Error: 2.665e-01
# 320: Change in c_r: 1.862e-02, HNC Error: 2.413e-02, Total Error: 2.658e-01
# 321: Change in c_r: 1.859e-02, HNC Error: 2.394e-02, Total Error: 2.652e-01
# 322: Change in c_r: 1.856e-02, HNC Error: 2.375e-02, Total Error: 2.645e-01
# 323: Change in c_r: 1.853e-02, HNC Error: 2.356e-02, Total Error: 2.638e-01
# 324: Change in c_r: 1.850e-02, HNC Error: 2.338e-02, Total Error: 2.632e-01
# 325: Change in c_r: 1.847e-02, HNC Error: 2.319e-02, Total Error: 2.625e-01
# 326: Change in c_r: 1.844e-02, HNC Error: 2.300e-02, Total Error: 2.619e-01
# 327: Change in c_r: 1.841e-02, HNC Error: 2.281e-02, Total Error: 2.612e-01
# 328: Change in c_r: 1.838e-02, HNC Error: 2.263e-02, Total Error: 2.606e-01
# 329: Change in c_r: 1.835e-02, HNC Error: 2.244e-02, Total Error: 2.600e-01
# 330: Change in c_r: 1.832e-02, HNC Error: 2.226e-02, Total Error: 2.593e-01
# 331: Change in c_r: 1.829e-02, HNC Error: 2.209e-02, Total Error: 2.587e-01
# 332: Change in c_r: 1.826e-02, HNC Error: 2.191e-02, Total Error: 2.581e-01
# 333: Change in c_r: 1.823e-02, HNC Error: 2.174e-02, Total Error: 2.575e-01
# 334: Change in c_r: 1.820e-02, HNC Error: 2.156e-02, Total Error: 2.568e-01
# 335: Change in c_r: 1.817e-02, HNC Error: 2.139e-02, Total Error: 2.562e-01
# 336: Change in c_r: 1.814e-02, HNC Error: 2.123e-02, Total Error: 2.556e-01
# 337: Change in c_r: 1.811e-02, HNC Error: 2.106e-02, Total Error: 2.550e-01
# 338: Change in c_r: 1.808e-02, HNC Error: 2.089e-02, Total Error: 2.544e-01
# 339: Change in c_r: 1.805e-02, HNC Error: 2.073e-02, Total Error: 2.538e-01
# 340: Change in c_r: 1.802e-02, HNC Error: 2.057e-02, Total Error: 2.532e-01
# 341: Change in c_r: 1.799e-02, HNC Error: 2.041e-02, Total Error: 2.526e-01
# 342: Change in c_r: 1.797e-02, HNC Error: 2.025e-02, Total Error: 2.520e-01
# 343: Change in c_r: 1.794e-02, HNC Error: 2.010e-02, Total Error: 2.514e-01
# 344: Change in c_r: 1.791e-02, HNC Error: 1.994e-02, Total Error: 2.508e-01
# 345: Change in c_r: 1.788e-02, HNC Error: 1.979e-02, Total Error: 2.502e-01
# 346: Change in c_r: 1.785e-02, HNC Error: 1.963e-02, Total Error: 2.496e-01
# 347: Change in c_r: 1.782e-02, HNC Error: 1.948e-02, Total Error: 2.491e-01
# 348: Change in c_r: 1.779e-02, HNC Error: 1.932e-02, Total Error: 2.485e-01
# 349: Change in c_r: 1.777e-02, HNC Error: 1.917e-02, Total Error: 2.479e-01
# 350: Change in c_r: 1.774e-02, HNC Error: 1.902e-02, Total Error: 2.473e-01
# 351: Change in c_r: 1.771e-02, HNC Error: 1.887e-02, Total Error: 2.468e-01
# 352: Change in c_r: 1.768e-02, HNC Error: 1.872e-02, Total Error: 2.462e-01
# 353: Change in c_r: 1.765e-02, HNC Error: 1.857e-02, Total Error: 2.456e-01
# 354: Change in c_r: 1.763e-02, HNC Error: 1.842e-02, Total Error: 2.451e-01
# 355: Change in c_r: 1.760e-02, HNC Error: 1.828e-02, Total Error: 2.445e-01
# 356: Change in c_r: 1.757e-02, HNC Error: 1.814e-02, Total Error: 2.440e-01
# 357: Change in c_r: 1.754e-02, HNC Error: 1.800e-02, Total Error: 2.434e-01
# 358: Change in c_r: 1.752e-02, HNC Error: 1.785e-02, Total Error: 2.429e-01
# 359: Change in c_r: 1.749e-02, HNC Error: 1.771e-02, Total Error: 2.423e-01
# 360: Change in c_r: 1.746e-02, HNC Error: 1.756e-02, Total Error: 2.418e-01
# 361: Change in c_r: 1.743e-02, HNC Error: 1.742e-02, Total Error: 2.412e-01
# 362: Change in c_r: 1.741e-02, HNC Error: 1.728e-02, Total Error: 2.407e-01
# 363: Change in c_r: 1.738e-02, HNC Error: 1.714e-02, Total Error: 2.401e-01
# 364: Change in c_r: 1.735e-02, HNC Error: 1.700e-02, Total Error: 2.396e-01
# 365: Change in c_r: 1.733e-02, HNC Error: 1.687e-02, Total Error: 2.391e-01
# 366: Change in c_r: 1.730e-02, HNC Error: 1.673e-02, Total Error: 2.386e-01
# 367: Change in c_r: 1.727e-02, HNC Error: 1.660e-02, Total Error: 2.380e-01
# 368: Change in c_r: 1.725e-02, HNC Error: 1.647e-02, Total Error: 2.375e-01
# 369: Change in c_r: 1.722e-02, HNC Error: 1.634e-02, Total Error: 2.370e-01
# 370: Change in c_r: 1.719e-02, HNC Error: 1.621e-02, Total Error: 2.365e-01
# 371: Change in c_r: 1.717e-02, HNC Error: 1.608e-02, Total Error: 2.359e-01
# 372: Change in c_r: 1.714e-02, HNC Error: 1.595e-02, Total Error: 2.354e-01
# 373: Change in c_r: 1.711e-02, HNC Error: 1.581e-02, Total Error: 2.349e-01
# 374: Change in c_r: 1.709e-02, HNC Error: 1.568e-02, Total Error: 2.344e-01
# 375: Change in c_r: 1.706e-02, HNC Error: 1.555e-02, Total Error: 2.339e-01
# 376: Change in c_r: 1.704e-02, HNC Error: 1.542e-02, Total Error: 2.334e-01
# 377: Change in c_r: 1.701e-02, HNC Error: 1.530e-02, Total Error: 2.329e-01
# 378: Change in c_r: 1.699e-02, HNC Error: 1.517e-02, Total Error: 2.324e-01
# 379: Change in c_r: 1.696e-02, HNC Error: 1.504e-02, Total Error: 2.319e-01
# 380: Change in c_r: 1.693e-02, HNC Error: 1.492e-02, Total Error: 2.314e-01
# 381: Change in c_r: 1.691e-02, HNC Error: 1.480e-02, Total Error: 2.309e-01
# 382: Change in c_r: 1.688e-02, HNC Error: 1.468e-02, Total Error: 2.304e-01
# 383: Change in c_r: 1.686e-02, HNC Error: 1.456e-02, Total Error: 2.299e-01
# 384: Change in c_r: 1.683e-02, HNC Error: 1.444e-02, Total Error: 2.294e-01
# 385: Change in c_r: 1.681e-02, HNC Error: 1.432e-02, Total Error: 2.289e-01
# 386: Change in c_r: 1.678e-02, HNC Error: 1.420e-02, Total Error: 2.284e-01
# 387: Change in c_r: 1.676e-02, HNC Error: 1.409e-02, Total Error: 2.279e-01
# 388: Change in c_r: 1.673e-02, HNC Error: 1.397e-02, Total Error: 2.274e-01
# 389: Change in c_r: 1.671e-02, HNC Error: 1.385e-02, Total Error: 2.270e-01
# 390: Change in c_r: 1.668e-02, HNC Error: 1.373e-02, Total Error: 2.265e-01
# 391: Change in c_r: 1.666e-02, HNC Error: 1.361e-02, Total Error: 2.260e-01
# 392: Change in c_r: 1.663e-02, HNC Error: 1.350e-02, Total Error: 2.255e-01
# 393: Change in c_r: 1.661e-02, HNC Error: 1.338e-02, Total Error: 2.251e-01
# 394: Change in c_r: 1.659e-02, HNC Error: 1.327e-02, Total Error: 2.246e-01
# 395: Change in c_r: 1.656e-02, HNC Error: 1.316e-02, Total Error: 2.241e-01
# 396: Change in c_r: 1.654e-02, HNC Error: 1.304e-02, Total Error: 2.237e-01
# 397: Change in c_r: 1.651e-02, HNC Error: 1.293e-02, Total Error: 2.232e-01
# 398: Change in c_r: 1.649e-02, HNC Error: 1.282e-02, Total Error: 2.227e-01
# 399: Change in c_r: 1.646e-02, HNC Error: 1.272e-02, Total Error: 2.223e-01
# 400: Change in c_r: 1.644e-02, HNC Error: 1.261e-02, Total Error: 2.218e-01
# 401: Change in c_r: 1.642e-02, HNC Error: 1.250e-02, Total Error: 2.213e-01
# 402: Change in c_r: 1.639e-02, HNC Error: 1.240e-02, Total Error: 2.209e-01
# 403: Change in c_r: 1.637e-02, HNC Error: 1.229e-02, Total Error: 2.204e-01
# 404: Change in c_r: 1.634e-02, HNC Error: 1.219e-02, Total Error: 2.200e-01
# 405: Change in c_r: 1.632e-02, HNC Error: 1.209e-02, Total Error: 2.195e-01
# 406: Change in c_r: 1.630e-02, HNC Error: 1.198e-02, Total Error: 2.191e-01
# 407: Change in c_r: 1.627e-02, HNC Error: 1.188e-02, Total Error: 2.186e-01
# 408: Change in c_r: 1.625e-02, HNC Error: 1.177e-02, Total Error: 2.182e-01
# 409: Change in c_r: 1.622e-02, HNC Error: 1.167e-02, Total Error: 2.177e-01
# 410: Change in c_r: 1.620e-02, HNC Error: 1.156e-02, Total Error: 2.173e-01
# 411: Change in c_r: 1.618e-02, HNC Error: 1.146e-02, Total Error: 2.169e-01
# 412: Change in c_r: 1.615e-02, HNC Error: 1.136e-02, Total Error: 2.164e-01
# 413: Change in c_r: 1.613e-02, HNC Error: 1.126e-02, Total Error: 2.160e-01
# 414: Change in c_r: 1.611e-02, HNC Error: 1.116e-02, Total Error: 2.156e-01
# 415: Change in c_r: 1.608e-02, HNC Error: 1.106e-02, Total Error: 2.151e-01
# 416: Change in c_r: 1.606e-02, HNC Error: 1.096e-02, Total Error: 2.147e-01
# 417: Change in c_r: 1.604e-02, HNC Error: 1.087e-02, Total Error: 2.143e-01
# 418: Change in c_r: 1.601e-02, HNC Error: 1.077e-02, Total Error: 2.138e-01
# 419: Change in c_r: 1.599e-02, HNC Error: 1.068e-02, Total Error: 2.134e-01
# 420: Change in c_r: 1.597e-02, HNC Error: 1.059e-02, Total Error: 2.130e-01
# 421: Change in c_r: 1.595e-02, HNC Error: 1.049e-02, Total Error: 2.126e-01
# 422: Change in c_r: 1.592e-02, HNC Error: 1.040e-02, Total Error: 2.121e-01
# 423: Change in c_r: 1.590e-02, HNC Error: 1.031e-02, Total Error: 2.117e-01
# 424: Change in c_r: 1.588e-02, HNC Error: 1.022e-02, Total Error: 2.113e-01
# 425: Change in c_r: 1.585e-02, HNC Error: 1.013e-02, Total Error: 2.109e-01
# 426: Change in c_r: 1.583e-02, HNC Error: 1.005e-02, Total Error: 2.105e-01
# 427: Change in c_r: 1.581e-02, HNC Error: 9.958e-03, Total Error: 2.100e-01
# 428: Change in c_r: 1.579e-02, HNC Error: 9.866e-03, Total Error: 2.096e-01
# 429: Change in c_r: 1.576e-02, HNC Error: 9.775e-03, Total Error: 2.092e-01
# 430: Change in c_r: 1.574e-02, HNC Error: 9.684e-03, Total Error: 2.088e-01
# 431: Change in c_r: 1.572e-02, HNC Error: 9.595e-03, Total Error: 2.084e-01
# 432: Change in c_r: 1.570e-02, HNC Error: 9.507e-03, Total Error: 2.080e-01
# 433: Change in c_r: 1.567e-02, HNC Error: 9.419e-03, Total Error: 2.076e-01
# 434: Change in c_r: 1.565e-02, HNC Error: 9.333e-03, Total Error: 2.072e-01
# 435: Change in c_r: 1.563e-02, HNC Error: 9.248e-03, Total Error: 2.068e-01
# 436: Change in c_r: 1.561e-02, HNC Error: 9.163e-03, Total Error: 2.064e-01
# 437: Change in c_r: 1.558e-02, HNC Error: 9.080e-03, Total Error: 2.060e-01
# 438: Change in c_r: 1.556e-02, HNC Error: 8.998e-03, Total Error: 2.056e-01
# 439: Change in c_r: 1.554e-02, HNC Error: 8.917e-03, Total Error: 2.052e-01
# 440: Change in c_r: 1.552e-02, HNC Error: 8.836e-03, Total Error: 2.048e-01
# 441: Change in c_r: 1.549e-02, HNC Error: 8.757e-03, Total Error: 2.044e-01
# 442: Change in c_r: 1.547e-02, HNC Error: 8.678e-03, Total Error: 2.040e-01
# 443: Change in c_r: 1.545e-02, HNC Error: 8.601e-03, Total Error: 2.036e-01
# 444: Change in c_r: 1.543e-02, HNC Error: 8.525e-03, Total Error: 2.032e-01
# 445: Change in c_r: 1.540e-02, HNC Error: 8.449e-03, Total Error: 2.028e-01
# 446: Change in c_r: 1.538e-02, HNC Error: 8.375e-03, Total Error: 2.024e-01
# 447: Change in c_r: 1.536e-02, HNC Error: 8.301e-03, Total Error: 2.020e-01
# 448: Change in c_r: 1.534e-02, HNC Error: 8.229e-03, Total Error: 2.017e-01
# 449: Change in c_r: 1.532e-02, HNC Error: 8.157e-03, Total Error: 2.013e-01
# 450: Change in c_r: 1.529e-02, HNC Error: 8.087e-03, Total Error: 2.009e-01
# 451: Change in c_r: 1.527e-02, HNC Error: 8.013e-03, Total Error: 2.005e-01
# 452: Change in c_r: 1.525e-02, HNC Error: 7.937e-03, Total Error: 2.001e-01
# 453: Change in c_r: 1.523e-02, HNC Error: 7.862e-03, Total Error: 1.997e-01
# 454: Change in c_r: 1.521e-02, HNC Error: 7.788e-03, Total Error: 1.994e-01
# 455: Change in c_r: 1.518e-02, HNC Error: 7.715e-03, Total Error: 1.990e-01
# 456: Change in c_r: 1.516e-02, HNC Error: 7.643e-03, Total Error: 1.986e-01
# 457: Change in c_r: 1.514e-02, HNC Error: 7.572e-03, Total Error: 1.982e-01
# 458: Change in c_r: 1.512e-02, HNC Error: 7.502e-03, Total Error: 1.979e-01
# 459: Change in c_r: 1.510e-02, HNC Error: 7.432e-03, Total Error: 1.975e-01
# 460: Change in c_r: 1.508e-02, HNC Error: 7.364e-03, Total Error: 1.971e-01
# 461: Change in c_r: 1.505e-02, HNC Error: 7.297e-03, Total Error: 1.968e-01
# 462: Change in c_r: 1.503e-02, HNC Error: 7.231e-03, Total Error: 1.964e-01
# 463: Change in c_r: 1.501e-02, HNC Error: 7.166e-03, Total Error: 1.960e-01
# 464: Change in c_r: 1.499e-02, HNC Error: 7.102e-03, Total Error: 1.957e-01
# 465: Change in c_r: 1.497e-02, HNC Error: 7.039e-03, Total Error: 1.953e-01
# 466: Change in c_r: 1.495e-02, HNC Error: 6.977e-03, Total Error: 1.949e-01
# 467: Change in c_r: 1.492e-02, HNC Error: 6.916e-03, Total Error: 1.946e-01
# 468: Change in c_r: 1.490e-02, HNC Error: 6.856e-03, Total Error: 1.942e-01
# 469: Change in c_r: 1.488e-02, HNC Error: 6.797e-03, Total Error: 1.938e-01
# 470: Change in c_r: 1.486e-02, HNC Error: 6.739e-03, Total Error: 1.935e-01
# 471: Change in c_r: 1.484e-02, HNC Error: 6.681e-03, Total Error: 1.931e-01
# 472: Change in c_r: 1.482e-02, HNC Error: 6.625e-03, Total Error: 1.928e-01
# 473: Change in c_r: 1.480e-02, HNC Error: 6.570e-03, Total Error: 1.924e-01
# 474: Change in c_r: 1.477e-02, HNC Error: 6.516e-03, Total Error: 1.921e-01
# 475: Change in c_r: 1.475e-02, HNC Error: 6.463e-03, Total Error: 1.917e-01
# 476: Change in c_r: 1.473e-02, HNC Error: 6.411e-03, Total Error: 1.913e-01
# 477: Change in c_r: 1.471e-02, HNC Error: 6.360e-03, Total Error: 1.910e-01
# 478: Change in c_r: 1.469e-02, HNC Error: 6.307e-03, Total Error: 1.906e-01
# 479: Change in c_r: 1.467e-02, HNC Error: 6.250e-03, Total Error: 1.903e-01
# 480: Change in c_r: 1.465e-02, HNC Error: 6.194e-03, Total Error: 1.899e-01
# 481: Change in c_r: 1.463e-02, HNC Error: 6.139e-03, Total Error: 1.896e-01
# 482: Change in c_r: 1.460e-02, HNC Error: 6.085e-03, Total Error: 1.892e-01
# 483: Change in c_r: 1.458e-02, HNC Error: 6.032e-03, Total Error: 1.889e-01
# 484: Change in c_r: 1.456e-02, HNC Error: 5.980e-03, Total Error: 1.886e-01
# 485: Change in c_r: 1.454e-02, HNC Error: 5.929e-03, Total Error: 1.882e-01
# 486: Change in c_r: 1.452e-02, HNC Error: 5.879e-03, Total Error: 1.879e-01
# 487: Change in c_r: 1.450e-02, HNC Error: 5.830e-03, Total Error: 1.875e-01
# 488: Change in c_r: 1.448e-02, HNC Error: 5.782e-03, Total Error: 1.872e-01
# 489: Change in c_r: 1.446e-02, HNC Error: 5.736e-03, Total Error: 1.868e-01
# 490: Change in c_r: 1.444e-02, HNC Error: 5.690e-03, Total Error: 1.865e-01
# 491: Change in c_r: 1.442e-02, HNC Error: 5.645e-03, Total Error: 1.862e-01
# 492: Change in c_r: 1.439e-02, HNC Error: 5.602e-03, Total Error: 1.858e-01
# 493: Change in c_r: 1.437e-02, HNC Error: 5.559e-03, Total Error: 1.855e-01
# 494: Change in c_r: 1.435e-02, HNC Error: 5.518e-03, Total Error: 1.852e-01
# 495: Change in c_r: 1.433e-02, HNC Error: 5.477e-03, Total Error: 1.848e-01
# 496: Change in c_r: 1.431e-02, HNC Error: 5.438e-03, Total Error: 1.845e-01
# 497: Change in c_r: 1.429e-02, HNC Error: 5.400e-03, Total Error: 1.842e-01
# 498: Change in c_r: 1.427e-02, HNC Error: 5.362e-03, Total Error: 1.838e-01
# 499: Change in c_r: 1.425e-02, HNC Error: 5.326e-03, Total Error: 1.835e-01
# 500: Change in c_r: 1.423e-02, HNC Error: 5.291e-03, Total Error: 1.832e-01
# 501: Change in c_r: 1.421e-02, HNC Error: 5.257e-03, Total Error: 1.828e-01
# 502: Change in c_r: 1.419e-02, HNC Error: 5.224e-03, Total Error: 1.825e-01
# 503: Change in c_r: 1.417e-02, HNC Error: 5.192e-03, Total Error: 1.822e-01
# 504: Change in c_r: 1.415e-02, HNC Error: 5.161e-03, Total Error: 1.818e-01
# 505: Change in c_r: 1.413e-02, HNC Error: 5.131e-03, Total Error: 1.815e-01
# 506: Change in c_r: 1.410e-02, HNC Error: 5.102e-03, Total Error: 1.812e-01
# 507: Change in c_r: 1.408e-02, HNC Error: 5.074e-03, Total Error: 1.809e-01
# 508: Change in c_r: 1.406e-02, HNC Error: 5.047e-03, Total Error: 1.805e-01
# 509: Change in c_r: 1.404e-02, HNC Error: 5.017e-03, Total Error: 1.802e-01
# 510: Change in c_r: 1.402e-02, HNC Error: 4.983e-03, Total Error: 1.799e-01
# 511: Change in c_r: 1.400e-02, HNC Error: 4.951e-03, Total Error: 1.796e-01
# 512: Change in c_r: 1.398e-02, HNC Error: 4.919e-03, Total Error: 1.793e-01
# 513: Change in c_r: 1.396e-02, HNC Error: 4.889e-03, Total Error: 1.789e-01
# 514: Change in c_r: 1.394e-02, HNC Error: 4.860e-03, Total Error: 1.786e-01
# 515: Change in c_r: 1.392e-02, HNC Error: 4.832e-03, Total Error: 1.783e-01
# 516: Change in c_r: 1.390e-02, HNC Error: 4.805e-03, Total Error: 1.780e-01
# 517: Change in c_r: 1.388e-02, HNC Error: 4.779e-03, Total Error: 1.777e-01
# 518: Change in c_r: 1.386e-02, HNC Error: 4.754e-03, Total Error: 1.773e-01
# 519: Change in c_r: 1.384e-02, HNC Error: 4.730e-03, Total Error: 1.770e-01
# 520: Change in c_r: 1.382e-02, HNC Error: 4.707e-03, Total Error: 1.767e-01
# 521: Change in c_r: 1.380e-02, HNC Error: 4.685e-03, Total Error: 1.764e-01
# 522: Change in c_r: 1.378e-02, HNC Error: 4.665e-03, Total Error: 1.761e-01
# 523: Change in c_r: 1.376e-02, HNC Error: 4.645e-03, Total Error: 1.758e-01
# 524: Change in c_r: 1.374e-02, HNC Error: 4.626e-03, Total Error: 1.755e-01
# 525: Change in c_r: 1.372e-02, HNC Error: 4.608e-03, Total Error: 1.751e-01
# 526: Change in c_r: 1.370e-02, HNC Error: 4.592e-03, Total Error: 1.748e-01
# 527: Change in c_r: 1.368e-02, HNC Error: 4.576e-03, Total Error: 1.745e-01
# 528: Change in c_r: 1.366e-02, HNC Error: 4.561e-03, Total Error: 1.742e-01
# 529: Change in c_r: 1.364e-02, HNC Error: 4.548e-03, Total Error: 1.739e-01
# 530: Change in c_r: 1.362e-02, HNC Error: 4.535e-03, Total Error: 1.736e-01
# 531: Change in c_r: 1.360e-02, HNC Error: 4.523e-03, Total Error: 1.733e-01
# 532: Change in c_r: 1.358e-02, HNC Error: 4.512e-03, Total Error: 1.730e-01
# 533: Change in c_r: 1.356e-02, HNC Error: 4.502e-03, Total Error: 1.727e-01
# 534: Change in c_r: 1.354e-02, HNC Error: 4.493e-03, Total Error: 1.724e-01
# 535: Change in c_r: 1.352e-02, HNC Error: 4.485e-03, Total Error: 1.721e-01
# 536: Change in c_r: 1.350e-02, HNC Error: 4.478e-03, Total Error: 1.718e-01
# 537: Change in c_r: 1.348e-02, HNC Error: 4.472e-03, Total Error: 1.715e-01
# 538: Change in c_r: 1.346e-02, HNC Error: 4.466e-03, Total Error: 1.712e-01
# 539: Change in c_r: 1.344e-02, HNC Error: 4.462e-03, Total Error: 1.709e-01
# 540: Change in c_r: 1.343e-02, HNC Error: 4.458e-03, Total Error: 1.706e-01
# 541: Change in c_r: 1.341e-02, HNC Error: 4.455e-03, Total Error: 1.703e-01
# 542: Change in c_r: 1.339e-02, HNC Error: 4.453e-03, Total Error: 1.700e-01
# 543: Change in c_r: 1.337e-02, HNC Error: 4.452e-03, Total Error: 1.697e-01
# 544: Change in c_r: 1.335e-02, HNC Error: 4.448e-03, Total Error: 1.694e-01
# 545: Change in c_r: 1.333e-02, HNC Error: 4.440e-03, Total Error: 1.691e-01
# 546: Change in c_r: 1.331e-02, HNC Error: 4.433e-03, Total Error: 1.688e-01
# 547: Change in c_r: 1.329e-02, HNC Error: 4.427e-03, Total Error: 1.685e-01
# 548: Change in c_r: 1.327e-02, HNC Error: 4.422e-03, Total Error: 1.682e-01
# 549: Change in c_r: 1.325e-02, HNC Error: 4.417e-03, Total Error: 1.679e-01
# 550: Change in c_r: 1.323e-02, HNC Error: 4.414e-03, Total Error: 1.676e-01
# 551: Change in c_r: 1.321e-02, HNC Error: 4.411e-03, Total Error: 1.673e-01
# 552: Change in c_r: 1.319e-02, HNC Error: 4.410e-03, Total Error: 1.670e-01
# 553: Change in c_r: 1.317e-02, HNC Error: 4.409e-03, Total Error: 1.667e-01
# 554: Change in c_r: 1.316e-02, HNC Error: 4.408e-03, Total Error: 1.664e-01
# 555: Change in c_r: 1.314e-02, HNC Error: 4.409e-03, Total Error: 1.661e-01
# 556: Change in c_r: 1.312e-02, HNC Error: 4.410e-03, Total Error: 1.658e-01
# 557: Change in c_r: 1.310e-02, HNC Error: 4.412e-03, Total Error: 1.655e-01
# 558: Change in c_r: 1.308e-02, HNC Error: 4.415e-03, Total Error: 1.652e-01
# 559: Change in c_r: 1.306e-02, HNC Error: 4.418e-03, Total Error: 1.649e-01
# 560: Change in c_r: 1.304e-02, HNC Error: 4.423e-03, Total Error: 1.647e-01
# 561: Change in c_r: 1.302e-02, HNC Error: 4.427e-03, Total Error: 1.644e-01
# 562: Change in c_r: 1.300e-02, HNC Error: 4.433e-03, Total Error: 1.641e-01
# 563: Change in c_r: 1.299e-02, HNC Error: 4.439e-03, Total Error: 1.638e-01
# 564: Change in c_r: 1.297e-02, HNC Error: 4.446e-03, Total Error: 1.635e-01
# 565: Change in c_r: 1.295e-02, HNC Error: 4.453e-03, Total Error: 1.632e-01
# 566: Change in c_r: 1.293e-02, HNC Error: 4.461e-03, Total Error: 1.629e-01
# 567: Change in c_r: 1.291e-02, HNC Error: 4.470e-03, Total Error: 1.626e-01
# 568: Change in c_r: 1.289e-02, HNC Error: 4.479e-03, Total Error: 1.624e-01
# 569: Change in c_r: 1.287e-02, HNC Error: 4.489e-03, Total Error: 1.621e-01
# 570: Change in c_r: 1.286e-02, HNC Error: 4.499e-03, Total Error: 1.618e-01
# 571: Change in c_r: 1.284e-02, HNC Error: 4.510e-03, Total Error: 1.615e-01
# 572: Change in c_r: 1.282e-02, HNC Error: 4.521e-03, Total Error: 1.612e-01
# 573: Change in c_r: 1.280e-02, HNC Error: 4.533e-03, Total Error: 1.609e-01
# 574: Change in c_r: 1.278e-02, HNC Error: 4.545e-03, Total Error: 1.607e-01
# 575: Change in c_r: 1.276e-02, HNC Error: 4.558e-03, Total Error: 1.604e-01
# 576: Change in c_r: 1.274e-02, HNC Error: 4.571e-03, Total Error: 1.601e-01
# 577: Change in c_r: 1.273e-02, HNC Error: 4.585e-03, Total Error: 1.598e-01
# 578: Change in c_r: 1.271e-02, HNC Error: 4.599e-03, Total Error: 1.595e-01
# 579: Change in c_r: 1.269e-02, HNC Error: 4.613e-03, Total Error: 1.592e-01
# 580: Change in c_r: 1.267e-02, HNC Error: 4.628e-03, Total Error: 1.590e-01
# 581: Change in c_r: 1.265e-02, HNC Error: 4.643e-03, Total Error: 1.587e-01
# 582: Change in c_r: 1.264e-02, HNC Error: 4.659e-03, Total Error: 1.584e-01
# 583: Change in c_r: 1.262e-02, HNC Error: 4.675e-03, Total Error: 1.581e-01
# 584: Change in c_r: 1.260e-02, HNC Error: 4.686e-03, Total Error: 1.579e-01
# 585: Change in c_r: 1.258e-02, HNC Error: 4.697e-03, Total Error: 1.576e-01
# 586: Change in c_r: 1.256e-02, HNC Error: 4.707e-03, Total Error: 1.573e-01
# 587: Change in c_r: 1.255e-02, HNC Error: 4.718e-03, Total Error: 1.570e-01
# 588: Change in c_r: 1.253e-02, HNC Error: 4.730e-03, Total Error: 1.568e-01
# 589: Change in c_r: 1.251e-02, HNC Error: 4.742e-03, Total Error: 1.565e-01
# 590: Change in c_r: 1.249e-02, HNC Error: 4.754e-03, Total Error: 1.562e-01
# 591: Change in c_r: 1.247e-02, HNC Error: 4.767e-03, Total Error: 1.559e-01
# 592: Change in c_r: 1.246e-02, HNC Error: 4.780e-03, Total Error: 1.557e-01
# 593: Change in c_r: 1.244e-02, HNC Error: 4.794e-03, Total Error: 1.554e-01
# 594: Change in c_r: 1.242e-02, HNC Error: 4.807e-03, Total Error: 1.551e-01
# 595: Change in c_r: 1.240e-02, HNC Error: 4.822e-03, Total Error: 1.548e-01
# 596: Change in c_r: 1.238e-02, HNC Error: 4.836e-03, Total Error: 1.546e-01
# 597: Change in c_r: 1.237e-02, HNC Error: 4.851e-03, Total Error: 1.543e-01
# 598: Change in c_r: 1.235e-02, HNC Error: 4.866e-03, Total Error: 1.540e-01
# 599: Change in c_r: 1.233e-02, HNC Error: 4.882e-03, Total Error: 1.538e-01
# 600: Change in c_r: 1.231e-02, HNC Error: 4.898e-03, Total Error: 1.535e-01
# 601: Change in c_r: 1.230e-02, HNC Error: 4.914e-03, Total Error: 1.532e-01
# 602: Change in c_r: 1.228e-02, HNC Error: 4.930e-03, Total Error: 1.530e-01
# 603: Change in c_r: 1.226e-02, HNC Error: 4.947e-03, Total Error: 1.527e-01
# 604: Change in c_r: 1.224e-02, HNC Error: 4.964e-03, Total Error: 1.524e-01
# 605: Change in c_r: 1.223e-02, HNC Error: 4.981e-03, Total Error: 1.522e-01
# 606: Change in c_r: 1.221e-02, HNC Error: 4.998e-03, Total Error: 1.519e-01
# 607: Change in c_r: 1.219e-02, HNC Error: 5.016e-03, Total Error: 1.516e-01
# 608: Change in c_r: 1.217e-02, HNC Error: 5.033e-03, Total Error: 1.514e-01
# 609: Change in c_r: 1.216e-02, HNC Error: 5.051e-03, Total Error: 1.511e-01
# 610: Change in c_r: 1.214e-02, HNC Error: 5.069e-03, Total Error: 1.508e-01
# 611: Change in c_r: 1.212e-02, HNC Error: 5.084e-03, Total Error: 1.506e-01
# 612: Change in c_r: 1.211e-02, HNC Error: 5.098e-03, Total Error: 1.503e-01
# 613: Change in c_r: 1.209e-02, HNC Error: 5.112e-03, Total Error: 1.500e-01
# 614: Change in c_r: 1.207e-02, HNC Error: 5.126e-03, Total Error: 1.498e-01
# 615: Change in c_r: 1.205e-02, HNC Error: 5.140e-03, Total Error: 1.495e-01
# 616: Change in c_r: 1.204e-02, HNC Error: 5.155e-03, Total Error: 1.492e-01
# 617: Change in c_r: 1.202e-02, HNC Error: 5.170e-03, Total Error: 1.490e-01
# 618: Change in c_r: 1.200e-02, HNC Error: 5.185e-03, Total Error: 1.487e-01
# 619: Change in c_r: 1.199e-02, HNC Error: 5.200e-03, Total Error: 1.485e-01
# 620: Change in c_r: 1.197e-02, HNC Error: 5.216e-03, Total Error: 1.482e-01
# 621: Change in c_r: 1.195e-02, HNC Error: 5.231e-03, Total Error: 1.479e-01
# 622: Change in c_r: 1.193e-02, HNC Error: 5.247e-03, Total Error: 1.477e-01
# 623: Change in c_r: 1.192e-02, HNC Error: 5.263e-03, Total Error: 1.474e-01
# 624: Change in c_r: 1.190e-02, HNC Error: 5.280e-03, Total Error: 1.472e-01
# 625: Change in c_r: 1.188e-02, HNC Error: 5.296e-03, Total Error: 1.469e-01
# 626: Change in c_r: 1.187e-02, HNC Error: 5.313e-03, Total Error: 1.467e-01
# 627: Change in c_r: 1.185e-02, HNC Error: 5.330e-03, Total Error: 1.464e-01
# 628: Change in c_r: 1.183e-02, HNC Error: 5.347e-03, Total Error: 1.461e-01
# 629: Change in c_r: 1.182e-02, HNC Error: 5.364e-03, Total Error: 1.459e-01
# 630: Change in c_r: 1.180e-02, HNC Error: 5.381e-03, Total Error: 1.456e-01
# 631: Change in c_r: 1.178e-02, HNC Error: 5.398e-03, Total Error: 1.454e-01
# 632: Change in c_r: 1.177e-02, HNC Error: 5.416e-03, Total Error: 1.451e-01
# ...
# 7012: Change in c_r: 1.749e-09, HNC Error: 3.333e-09, Total Error: 1.701e-08
# 7013: Change in c_r: 1.745e-09, HNC Error: 3.324e-09, Total Error: 1.697e-08
# 7014: Change in c_r: 1.740e-09, HNC Error: 3.316e-09, Total Error: 1.692e-08
# 7015: Change in c_r: 1.736e-09, HNC Error: 3.307e-09, Total Error: 1.688e-08
# 7016: Change in c_r: 1.731e-09, HNC Error: 3.299e-09, Total Error: 1.684e-08
# 7017: Change in c_r: 1.727e-09, HNC Error: 3.290e-09, Total Error: 1.679e-08
# 7018: Change in c_r: 1.722e-09, HNC Error: 3.282e-09, Total Error: 1.675e-08
# 7019: Change in c_r: 1.718e-09, HNC Error: 3.273e-09, Total Error: 1.671e-08
# 7020: Change in c_r: 1.714e-09, HNC Error: 3.265e-09, Total Error: 1.666e-08
# 7021: Change in c_r: 1.709e-09, HNC Error: 3.257e-09, Total Error: 1.662e-08
# 7022: Change in c_r: 1.705e-09, HNC Error: 3.248e-09, Total Error: 1.658e-08
# 7023: Change in c_r: 1.700e-09, HNC Error: 3.240e-09, Total Error: 1.653e-08
# 7024: Change in c_r: 1.696e-09, HNC Error: 3.232e-09, Total Error: 1.649e-08
# 7025: Change in c_r: 1.691e-09, HNC Error: 3.223e-09, Total Error: 1.645e-08
# 7026: Change in c_r: 1.687e-09, HNC Error: 3.215e-09, Total Error: 1.641e-08
# 7027: Change in c_r: 1.683e-09, HNC Error: 3.207e-09, Total Error: 1.636e-08
# 7028: Change in c_r: 1.678e-09, HNC Error: 3.199e-09, Total Error: 1.632e-08
# 7029: Change in c_r: 1.674e-09, HNC Error: 3.191e-09, Total Error: 1.628e-08
# 7030: Change in c_r: 1.670e-09, HNC Error: 3.183e-09, Total Error: 1.624e-08
# 7031: Change in c_r: 1.665e-09, HNC Error: 3.174e-09, Total Error: 1.619e-08
# 7032: Change in c_r: 1.661e-09, HNC Error: 3.166e-09, Total Error: 1.615e-08
# 7033: Change in c_r: 1.657e-09, HNC Error: 3.158e-09, Total Error: 1.611e-08
# 7034: Change in c_r: 1.652e-09, HNC Error: 3.150e-09, Total Error: 1.607e-08
# 7035: Change in c_r: 1.648e-09, HNC Error: 3.142e-09, Total Error: 1.603e-08
# 7036: Change in c_r: 1.644e-09, HNC Error: 3.134e-09, Total Error: 1.599e-08
# 7037: Change in c_r: 1.640e-09, HNC Error: 3.126e-09, Total Error: 1.594e-08
# 7038: Change in c_r: 1.635e-09, HNC Error: 3.118e-09, Total Error: 1.590e-08
# 7039: Change in c_r: 1.631e-09, HNC Error: 3.110e-09, Total Error: 1.586e-08
# 7040: Change in c_r: 1.627e-09, HNC Error: 3.102e-09, Total Error: 1.582e-08
# 7041: Change in c_r: 1.623e-09, HNC Error: 3.094e-09, Total Error: 1.578e-08
# 7042: Change in c_r: 1.618e-09, HNC Error: 3.086e-09, Total Error: 1.574e-08
# 7043: Change in c_r: 1.614e-09, HNC Error: 3.078e-09, Total Error: 1.570e-08
# 7044: Change in c_r: 1.610e-09, HNC Error: 3.071e-09, Total Error: 1.566e-08
# 7045: Change in c_r: 1.606e-09, HNC Error: 3.063e-09, Total Error: 1.562e-08
# 7046: Change in c_r: 1.602e-09, HNC Error: 3.055e-09, Total Error: 1.558e-08
# 7047: Change in c_r: 1.598e-09, HNC Error: 3.047e-09, Total Error: 1.554e-08
# 7048: Change in c_r: 1.594e-09, HNC Error: 3.039e-09, Total Error: 1.550e-08
# 7049: Change in c_r: 1.589e-09, HNC Error: 3.032e-09, Total Error: 1.546e-08
# 7050: Change in c_r: 1.585e-09, HNC Error: 3.024e-09, Total Error: 1.542e-08
# 7051: Change in c_r: 1.581e-09, HNC Error: 3.016e-09, Total Error: 1.538e-08
# 7052: Change in c_r: 1.577e-09, HNC Error: 3.008e-09, Total Error: 1.534e-08
# 7053: Change in c_r: 1.573e-09, HNC Error: 3.001e-09, Total Error: 1.530e-08
# 7054: Change in c_r: 1.569e-09, HNC Error: 2.993e-09, Total Error: 1.526e-08
# 7055: Change in c_r: 1.565e-09, HNC Error: 2.985e-09, Total Error: 1.522e-08
# 7056: Change in c_r: 1.561e-09, HNC Error: 2.978e-09, Total Error: 1.518e-08
# 7057: Change in c_r: 1.557e-09, HNC Error: 2.970e-09, Total Error: 1.514e-08
# 7058: Change in c_r: 1.553e-09, HNC Error: 2.963e-09, Total Error: 1.510e-08
# 7059: Change in c_r: 1.549e-09, HNC Error: 2.955e-09, Total Error: 1.506e-08
# 7060: Change in c_r: 1.545e-09, HNC Error: 2.948e-09, Total Error: 1.502e-08
# 7061: Change in c_r: 1.541e-09, HNC Error: 2.940e-09, Total Error: 1.498e-08
# 7062: Change in c_r: 1.537e-09, HNC Error: 2.933e-09, Total Error: 1.494e-08
# 7063: Change in c_r: 1.533e-09, HNC Error: 2.925e-09, Total Error: 1.490e-08
# 7064: Change in c_r: 1.529e-09, HNC Error: 2.918e-09, Total Error: 1.487e-08
# 7065: Change in c_r: 1.525e-09, HNC Error: 2.910e-09, Total Error: 1.483e-08
# 7066: Change in c_r: 1.521e-09, HNC Error: 2.903e-09, Total Error: 1.479e-08
# 7067: Change in c_r: 1.517e-09, HNC Error: 2.895e-09, Total Error: 1.475e-08
# 7068: Change in c_r: 1.513e-09, HNC Error: 2.888e-09, Total Error: 1.471e-08
# 7069: Change in c_r: 1.509e-09, HNC Error: 2.881e-09, Total Error: 1.467e-08
# 7070: Change in c_r: 1.505e-09, HNC Error: 2.873e-09, Total Error: 1.464e-08
# 7071: Change in c_r: 1.501e-09, HNC Error: 2.866e-09, Total Error: 1.460e-08
# 7072: Change in c_r: 1.497e-09, HNC Error: 2.859e-09, Total Error: 1.456e-08
# 7073: Change in c_r: 1.493e-09, HNC Error: 2.851e-09, Total Error: 1.452e-08
# 7074: Change in c_r: 1.490e-09, HNC Error: 2.844e-09, Total Error: 1.449e-08
# 7075: Change in c_r: 1.486e-09, HNC Error: 2.837e-09, Total Error: 1.445e-08
# 7076: Change in c_r: 1.482e-09, HNC Error: 2.830e-09, Total Error: 1.441e-08
# 7077: Change in c_r: 1.478e-09, HNC Error: 2.822e-09, Total Error: 1.437e-08
# 7078: Change in c_r: 1.474e-09, HNC Error: 2.815e-09, Total Error: 1.434e-08
# 7079: Change in c_r: 1.470e-09, HNC Error: 2.808e-09, Total Error: 1.430e-08
# 7080: Change in c_r: 1.467e-09, HNC Error: 2.801e-09, Total Error: 1.426e-08
# 7081: Change in c_r: 1.463e-09, HNC Error: 2.794e-09, Total Error: 1.422e-08
# 7082: Change in c_r: 1.459e-09, HNC Error: 2.787e-09, Total Error: 1.419e-08
# 7083: Change in c_r: 1.455e-09, HNC Error: 2.780e-09, Total Error: 1.415e-08
# 7084: Change in c_r: 1.451e-09, HNC Error: 2.772e-09, Total Error: 1.411e-08
# 7085: Change in c_r: 1.448e-09, HNC Error: 2.765e-09, Total Error: 1.408e-08
# 7086: Change in c_r: 1.444e-09, HNC Error: 2.758e-09, Total Error: 1.404e-08
# 7087: Change in c_r: 1.440e-09, HNC Error: 2.751e-09, Total Error: 1.401e-08
# 7088: Change in c_r: 1.437e-09, HNC Error: 2.744e-09, Total Error: 1.397e-08
# 7089: Change in c_r: 1.433e-09, HNC Error: 2.737e-09, Total Error: 1.393e-08
# 7090: Change in c_r: 1.429e-09, HNC Error: 2.730e-09, Total Error: 1.390e-08
# 7091: Change in c_r: 1.425e-09, HNC Error: 2.723e-09, Total Error: 1.386e-08
# 7092: Change in c_r: 1.422e-09, HNC Error: 2.717e-09, Total Error: 1.382e-08
# 7093: Change in c_r: 1.418e-09, HNC Error: 2.710e-09, Total Error: 1.379e-08
# 7094: Change in c_r: 1.414e-09, HNC Error: 2.703e-09, Total Error: 1.375e-08
# 7095: Change in c_r: 1.411e-09, HNC Error: 2.696e-09, Total Error: 1.372e-08
# 7096: Change in c_r: 1.407e-09, HNC Error: 2.689e-09, Total Error: 1.368e-08
# 7097: Change in c_r: 1.403e-09, HNC Error: 2.682e-09, Total Error: 1.365e-08
# 7098: Change in c_r: 1.400e-09, HNC Error: 2.675e-09, Total Error: 1.361e-08
# 7099: Change in c_r: 1.396e-09, HNC Error: 2.669e-09, Total Error: 1.358e-08
# 7100: Change in c_r: 1.393e-09, HNC Error: 2.662e-09, Total Error: 1.354e-08
# 7101: Change in c_r: 1.389e-09, HNC Error: 2.655e-09, Total Error: 1.351e-08
# 7102: Change in c_r: 1.385e-09, HNC Error: 2.648e-09, Total Error: 1.347e-08
# 7103: Change in c_r: 1.382e-09, HNC Error: 2.642e-09, Total Error: 1.344e-08
# 7104: Change in c_r: 1.378e-09, HNC Error: 2.635e-09, Total Error: 1.340e-08
# 7105: Change in c_r: 1.375e-09, HNC Error: 2.628e-09, Total Error: 1.337e-08
# 7106: Change in c_r: 1.371e-09, HNC Error: 2.621e-09, Total Error: 1.333e-08
# 7107: Change in c_r: 1.367e-09, HNC Error: 2.615e-09, Total Error: 1.330e-08
# 7108: Change in c_r: 1.364e-09, HNC Error: 2.608e-09, Total Error: 1.326e-08
# 7109: Change in c_r: 1.360e-09, HNC Error: 2.602e-09, Total Error: 1.323e-08
# 7110: Change in c_r: 1.357e-09, HNC Error: 2.595e-09, Total Error: 1.319e-08
# 7111: Change in c_r: 1.353e-09, HNC Error: 2.588e-09, Total Error: 1.316e-08
# 7112: Change in c_r: 1.350e-09, HNC Error: 2.582e-09, Total Error: 1.313e-08
# 7113: Change in c_r: 1.346e-09, HNC Error: 2.575e-09, Total Error: 1.309e-08
# 7114: Change in c_r: 1.343e-09, HNC Error: 2.569e-09, Total Error: 1.306e-08
# 7115: Change in c_r: 1.339e-09, HNC Error: 2.562e-09, Total Error: 1.302e-08
# 7116: Change in c_r: 1.336e-09, HNC Error: 2.556e-09, Total Error: 1.299e-08
# 7117: Change in c_r: 1.332e-09, HNC Error: 2.549e-09, Total Error: 1.296e-08
# 7118: Change in c_r: 1.329e-09, HNC Error: 2.543e-09, Total Error: 1.292e-08
# 7119: Change in c_r: 1.326e-09, HNC Error: 2.536e-09, Total Error: 1.289e-08
# 7120: Change in c_r: 1.322e-09, HNC Error: 2.530e-09, Total Error: 1.286e-08
# 7121: Change in c_r: 1.319e-09, HNC Error: 2.523e-09, Total Error: 1.282e-08
# 7122: Change in c_r: 1.315e-09, HNC Error: 2.517e-09, Total Error: 1.279e-08
# 7123: Change in c_r: 1.312e-09, HNC Error: 2.511e-09, Total Error: 1.276e-08
# 7124: Change in c_r: 1.308e-09, HNC Error: 2.504e-09, Total Error: 1.272e-08
# 7125: Change in c_r: 1.305e-09, HNC Error: 2.498e-09, Total Error: 1.269e-08
# 7126: Change in c_r: 1.302e-09, HNC Error: 2.492e-09, Total Error: 1.266e-08
# 7127: Change in c_r: 1.298e-09, HNC Error: 2.485e-09, Total Error: 1.263e-08
# 7128: Change in c_r: 1.295e-09, HNC Error: 2.479e-09, Total Error: 1.259e-08
# 7129: Change in c_r: 1.292e-09, HNC Error: 2.473e-09, Total Error: 1.256e-08
# 7130: Change in c_r: 1.288e-09, HNC Error: 2.466e-09, Total Error: 1.253e-08
# 7131: Change in c_r: 1.285e-09, HNC Error: 2.460e-09, Total Error: 1.250e-08
# 7132: Change in c_r: 1.282e-09, HNC Error: 2.454e-09, Total Error: 1.246e-08
# 7133: Change in c_r: 1.278e-09, HNC Error: 2.448e-09, Total Error: 1.243e-08
# 7134: Change in c_r: 1.275e-09, HNC Error: 2.442e-09, Total Error: 1.240e-08
# 7135: Change in c_r: 1.272e-09, HNC Error: 2.435e-09, Total Error: 1.237e-08
# 7136: Change in c_r: 1.268e-09, HNC Error: 2.429e-09, Total Error: 1.233e-08
# 7137: Change in c_r: 1.265e-09, HNC Error: 2.423e-09, Total Error: 1.230e-08
# 7138: Change in c_r: 1.262e-09, HNC Error: 2.417e-09, Total Error: 1.227e-08
# 7139: Change in c_r: 1.259e-09, HNC Error: 2.411e-09, Total Error: 1.224e-08
# 7140: Change in c_r: 1.255e-09, HNC Error: 2.405e-09, Total Error: 1.221e-08
# 7141: Change in c_r: 1.252e-09, HNC Error: 2.399e-09, Total Error: 1.218e-08
# 7142: Change in c_r: 1.249e-09, HNC Error: 2.393e-09, Total Error: 1.214e-08
# 7143: Change in c_r: 1.246e-09, HNC Error: 2.386e-09, Total Error: 1.211e-08
# 7144: Change in c_r: 1.242e-09, HNC Error: 2.380e-09, Total Error: 1.208e-08
# 7145: Change in c_r: 1.239e-09, HNC Error: 2.374e-09, Total Error: 1.205e-08
# 7146: Change in c_r: 1.236e-09, HNC Error: 2.368e-09, Total Error: 1.202e-08
# 7147: Change in c_r: 1.233e-09, HNC Error: 2.362e-09, Total Error: 1.199e-08
# 7148: Change in c_r: 1.230e-09, HNC Error: 2.356e-09, Total Error: 1.196e-08
# 7149: Change in c_r: 1.226e-09, HNC Error: 2.350e-09, Total Error: 1.193e-08
# 7150: Change in c_r: 1.223e-09, HNC Error: 2.345e-09, Total Error: 1.189e-08
# 7151: Change in c_r: 1.220e-09, HNC Error: 2.339e-09, Total Error: 1.186e-08
# 7152: Change in c_r: 1.217e-09, HNC Error: 2.333e-09, Total Error: 1.183e-08
# 7153: Change in c_r: 1.214e-09, HNC Error: 2.327e-09, Total Error: 1.180e-08
# 7154: Change in c_r: 1.211e-09, HNC Error: 2.321e-09, Total Error: 1.177e-08
# 7155: Change in c_r: 1.207e-09, HNC Error: 2.315e-09, Total Error: 1.174e-08
# 7156: Change in c_r: 1.204e-09, HNC Error: 2.309e-09, Total Error: 1.171e-08
# 7157: Change in c_r: 1.201e-09, HNC Error: 2.303e-09, Total Error: 1.168e-08
# 7158: Change in c_r: 1.198e-09, HNC Error: 2.298e-09, Total Error: 1.165e-08
# 7159: Change in c_r: 1.195e-09, HNC Error: 2.292e-09, Total Error: 1.162e-08
# 7160: Change in c_r: 1.192e-09, HNC Error: 2.286e-09, Total Error: 1.159e-08
# 7161: Change in c_r: 1.189e-09, HNC Error: 2.280e-09, Total Error: 1.156e-08
# 7162: Change in c_r: 1.186e-09, HNC Error: 2.274e-09, Total Error: 1.153e-08
# 7163: Change in c_r: 1.183e-09, HNC Error: 2.269e-09, Total Error: 1.150e-08
# 7164: Change in c_r: 1.180e-09, HNC Error: 2.263e-09, Total Error: 1.147e-08
# 7165: Change in c_r: 1.177e-09, HNC Error: 2.257e-09, Total Error: 1.144e-08
# 7166: Change in c_r: 1.173e-09, HNC Error: 2.252e-09, Total Error: 1.141e-08
# 7167: Change in c_r: 1.170e-09, HNC Error: 2.246e-09, Total Error: 1.138e-08
# 7168: Change in c_r: 1.167e-09, HNC Error: 2.240e-09, Total Error: 1.135e-08
# 7169: Change in c_r: 1.164e-09, HNC Error: 2.235e-09, Total Error: 1.132e-08
# 7170: Change in c_r: 1.161e-09, HNC Error: 2.229e-09, Total Error: 1.129e-08
# 7171: Change in c_r: 1.158e-09, HNC Error: 2.223e-09, Total Error: 1.126e-08
# 7172: Change in c_r: 1.155e-09, HNC Error: 2.218e-09, Total Error: 1.123e-08
# 7173: Change in c_r: 1.152e-09, HNC Error: 2.212e-09, Total Error: 1.121e-08
# 7174: Change in c_r: 1.149e-09, HNC Error: 2.207e-09, Total Error: 1.118e-08
# 7175: Change in c_r: 1.146e-09, HNC Error: 2.201e-09, Total Error: 1.115e-08
# 7176: Change in c_r: 1.143e-09, HNC Error: 2.195e-09, Total Error: 1.112e-08
# 7177: Change in c_r: 1.140e-09, HNC Error: 2.190e-09, Total Error: 1.109e-08
# 7178: Change in c_r: 1.138e-09, HNC Error: 2.184e-09, Total Error: 1.106e-08
# 7179: Change in c_r: 1.135e-09, HNC Error: 2.179e-09, Total Error: 1.103e-08
# 7180: Change in c_r: 1.132e-09, HNC Error: 2.173e-09, Total Error: 1.100e-08
# 7181: Change in c_r: 1.129e-09, HNC Error: 2.168e-09, Total Error: 1.098e-08
# 7182: Change in c_r: 1.126e-09, HNC Error: 2.163e-09, Total Error: 1.095e-08
# 7183: Change in c_r: 1.123e-09, HNC Error: 2.157e-09, Total Error: 1.092e-08
# 7184: Change in c_r: 1.120e-09, HNC Error: 2.152e-09, Total Error: 1.089e-08
# 7185: Change in c_r: 1.117e-09, HNC Error: 2.146e-09, Total Error: 1.086e-08
# 7186: Change in c_r: 1.114e-09, HNC Error: 2.141e-09, Total Error: 1.083e-08
# 7187: Change in c_r: 1.111e-09, HNC Error: 2.135e-09, Total Error: 1.081e-08
# 7188: Change in c_r: 1.108e-09, HNC Error: 2.130e-09, Total Error: 1.078e-08
# 7189: Change in c_r: 1.106e-09, HNC Error: 2.125e-09, Total Error: 1.075e-08
# 7190: Change in c_r: 1.103e-09, HNC Error: 2.119e-09, Total Error: 1.072e-08
# 7191: Change in c_r: 1.100e-09, HNC Error: 2.114e-09, Total Error: 1.069e-08
# 7192: Change in c_r: 1.097e-09, HNC Error: 2.109e-09, Total Error: 1.067e-08
# 7193: Change in c_r: 1.094e-09, HNC Error: 2.103e-09, Total Error: 1.064e-08
# 7194: Change in c_r: 1.091e-09, HNC Error: 2.098e-09, Total Error: 1.061e-08
# 7195: Change in c_r: 1.088e-09, HNC Error: 2.093e-09, Total Error: 1.058e-08
# 7196: Change in c_r: 1.086e-09, HNC Error: 2.088e-09, Total Error: 1.056e-08
# 7197: Change in c_r: 1.083e-09, HNC Error: 2.082e-09, Total Error: 1.053e-08
# 7198: Change in c_r: 1.080e-09, HNC Error: 2.077e-09, Total Error: 1.050e-08
# 7199: Change in c_r: 1.077e-09, HNC Error: 2.072e-09, Total Error: 1.048e-08
# 7200: Change in c_r: 1.074e-09, HNC Error: 2.067e-09, Total Error: 1.045e-08
# 7201: Change in c_r: 1.072e-09, HNC Error: 2.062e-09, Total Error: 1.042e-08
# 7202: Change in c_r: 1.069e-09, HNC Error: 2.056e-09, Total Error: 1.039e-08
# 7203: Change in c_r: 1.066e-09, HNC Error: 2.051e-09, Total Error: 1.037e-08
# 7204: Change in c_r: 1.063e-09, HNC Error: 2.046e-09, Total Error: 1.034e-08
# 7205: Change in c_r: 1.061e-09, HNC Error: 2.041e-09, Total Error: 1.031e-08
# 7206: Change in c_r: 1.058e-09, HNC Error: 2.035e-09, Total Error: 1.029e-08
# 7207: Change in c_r: 1.055e-09, HNC Error: 2.030e-09, Total Error: 1.026e-08
# 7208: Change in c_r: 1.052e-09, HNC Error: 2.025e-09, Total Error: 1.023e-08
# 7209: Change in c_r: 1.050e-09, HNC Error: 2.020e-09, Total Error: 1.021e-08
# 7210: Change in c_r: 1.047e-09, HNC Error: 2.014e-09, Total Error: 1.018e-08
# 7211: Change in c_r: 1.044e-09, HNC Error: 2.009e-09, Total Error: 1.015e-08
# 7212: Change in c_r: 1.042e-09, HNC Error: 2.004e-09, Total Error: 1.013e-08
# 7213: Change in c_r: 1.039e-09, HNC Error: 1.999e-09, Total Error: 1.010e-08
# 7214: Change in c_r: 1.036e-09, HNC Error: 1.994e-09, Total Error: 1.008e-08
# 7215: Change in c_r: 1.033e-09, HNC Error: 1.989e-09, Total Error: 1.005e-08
# 7216: Change in c_r: 1.031e-09, HNC Error: 1.983e-09, Total Error: 1.002e-08
# 7217: Change in c_r: 1.028e-09, HNC Error: 1.978e-09, Total Error: 9.998e-09
# Exiting status 0, reverting to best index so far: 7217
# Final iter:7218, Total Error: 9.998e-09

# %%
# solve_least_squares(atom4, np.linspace(atom4.hnc.k_array[0], atom4.hnc.k_array[-1], num=300), c_s_k_guess = atom3.hnc.c_s_k_matrix.copy())
# solve_least_squares(atom4, np.linspace(atom4.hnc.k_array[0], atom4.hnc.k_array[-1], num=200))#, c_s_k_guess = atom3.hnc.c_s_k_matrix.copy())

# %%
# atom4_saved_csk = atom4.hnc.c_s_k_matrix.copy()

# %%
atom4.hnc.plot_g_all_species()

# %% [markdown]
# #### atom5- SVT Pointlike bound states, with core-core

# %%
# atom5.run_hnc(newton=False)#, c_s_k_guess = atom4.hnc.c_s_k_matrix.copy())
# solve_least_squares(atom5, np.linspace(atom5.hnc.k_array[0], atom5.hnc.k_array[-1], num=400))#, c_s_k_guess = atom4.hnc.c_s_k_matrix.copy())
solve_least_squares(atom5, np.linspace(atom5.hnc.k_array[0], atom5.hnc.k_array[-1], num=1000))#, c_s_k_guess = atom4.hnc.c_s_k_matrix.copy())
# Out:
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.8520e+06                                    1.32e+08
#        1              7         6.9840e+05      1.15e+06       9.42e-01       7.58e+07
#        2              8         1.5181e+05      5.47e+05       9.42e-01       1.74e+07
#        3              9         1.0292e+05      4.89e+04       1.88e+00       9.78e+06
#        4             10         6.1651e+04      4.13e+04       1.88e+00       8.01e+06
# KeyboardInterrupt

# %%
# atom5_save_csk = atom5.hnc.c_s_k_matrix.copy()

# %%
atom5.hnc.plot_g_all_species()

# %% [markdown]
# ### Plot and Comparison to QMD

# %%
atom1.run_ocp_hnc()
# Out:
# 0: Initial condition Total Error: 2.804e+01
# Starting Ng loop, using best index so far:  499
# |d_n|^2 =  [1.429463753732179, 1.438992691688904, 1.4485829574970757]
#  αs:  [ 10999.29957503 -21777.27476152  10778.97518648]
# |d_n|^2 =  [0.01669653692853746, 1.429463753732179, 1.438992691688904]
#  αs:  [  0.7667878   34.57333133 -34.34011913]
# |d_n|^2 =  [0.16031612260165587, 0.01669653692853746, 1.429463753732179]
#  αs:  [ 0.08674555  0.91501462 -0.00176017]
# |d_n|^2 =  [0.010411042207757838, 0.16031612260165587, 0.01669653692853746]
#  αs:  [ 0.92824919 -0.04917453  0.12092534]
# |d_n|^2 =  [0.002717470988982155, 0.010411042207757838, 0.16031612260165587]
#  αs:  [ 1.1490175  -0.17587257  0.02685507]
# |d_n|^2 =  [0.003025913540901326, 0.002717470988982155, 0.010411042207757838]
#  αs:  [ 3.1616272  -2.44851231  0.2868851 ]
# |d_n|^2 =  [0.002959753357899345, 0.003025913540901326, 0.002717470988982155]
#  αs:  [  7.35158243 -12.26599422   5.9144118 ]
# |d_n|^2 =  [0.0006373179772333259, 0.002959753357899345, 0.003025913540901326]
#  αs:  [ 0.83599649  1.1633008  -0.99929729]
# |d_n|^2 =  [8.484889178682323e-05, 0.0006373179772333259, 0.002959753357899345]
#  αs:  [ 1.1235588  -0.12848165  0.00492284]
# |d_n|^2 =  [1.8164067957137307e-05, 8.484889178682323e-05, 0.0006373179772333259]
#  αs:  [ 0.7553434   0.25809604 -0.01343944]
# |d_n|^2 =  [6.86057097795989e-06, 1.8164067957137307e-05, 8.484889178682323e-05]
#  αs:  [ 2.71984348 -1.58427237 -0.13557111]
# |d_n|^2 =  [3.265001782025796e-06, 6.86057097795989e-06, 1.8164067957137307e-05]
#  αs:  [ 4.4213493  -4.35054545  0.92919614]
# |d_n|^2 =  [4.1016674359089735e-07, 3.265001782025796e-06, 6.86057097795989e-06]
#  αs:  [ 1.2492237  -0.44996104  0.20073734]
# |d_n|^2 =  [2.374006408422089e-07, 4.1016674359089735e-07, 3.265001782025796e-06]
#  αs:  [ 0.76850654  0.28782287 -0.05632941]
# Exiting status 0, reverting to best index so far: 512
# Final iter:515, Total Error: 2.104e-09

# %%
MD_data = read_csv("/home/zach/plasma/datasets/RDFs/Al_1.0eV_rs3_VASP.txt",  header=1)
MD_data.columns=['r','g']
MD_data
# Out:
#            r         g
# 0   0.980066  0.004092
# 1   1.059801  0.009002
# 2   1.106312  0.031097
# 3   1.179402  0.134206
# 4   1.212625  0.247136
# 5   1.285714  0.576105
# 6   1.338870  0.892799
# 7   1.392027  1.145663
# 8   1.458472  1.413257
# 9   1.485050  1.481997
# 10  1.511628  1.565466
# 11  1.544850  1.587561
# 12  1.591362  1.567921
# 13  1.651163  1.501637
# 14  1.717608  1.420622
# 15  1.764120  1.339607
# 16  1.790698  1.278232
# 17  1.843854  1.209493
# 18  1.877076  1.157938
# 19  1.976744  1.025368
# 20  2.116279  0.900164
# 21  2.215947  0.870704
# 22  2.289037  0.855974
# 23  2.428571  0.887889
# 24  2.627907  0.966448
# 25  2.740864  1.000818
# 26  2.867110  1.035188
# 27  2.946844  1.052373
# 28  3.059801  1.049918
# 29  3.172757  1.020458

# %%
# AA_data = read_csv("/home/zach/plasma/atoMEC/examples/density.csv", delim_whitespace=True, header=0)

fig, ax = plt.subplots(figsize=(10,8))

# nf_0 = Zbar/(4/3*np.pi*atom.qsp.ri**3)
# ax.plot(AA_data['r[a_0]'], np.array(AA_data['n[unbound]'])/nf_0,'k.' ,label="AA" )
# ax.plot(atom_2e.hnc.r_array*atom_2e.qsp.ri, atom_2e.hnc.h_r_matrix[0,0]+1,'--', label='2 electron SVT ')
# ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,0]+1,'--', label='Ashcroft Pseudopotential')
ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,0]+1,'--', label='OZ - Fermi')
ax.plot(atom2.hnc.r_array, atom2.hnc.h_r_matrix[0,0]+1,'--', label='SVT- Fermi')
ax.plot(atom3.hnc.r_array, atom3.hnc.h_r_matrix[0,0]+1,'--', label='SVT- DMC')
# ax.plot(atom4.hnc.r_array, atom4.hnc.h_r_matrix[0,0]+1,'--', label='OZ- HNC Pauli (pointlike bound, core-core)')
# ax.plot(atom5.hnc.r_array, atom5.hnc.h_r_matrix[0,0]+1,'--', label='SVT- HNC Pauli (pointlike bound, core-core)')
# ax.plot(atom_long.hnc.r_array, atom_long.hnc.h_r_matrix[0,0]+1,'-.', label='1 electron SVT-long ')
# ax.plot(atom_oz.hnc.r_array, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='1 electron OZ ')
ax.plot(atom1.hnc.r_array, atom1.ocp_hnc.h_r_matrix[0,0]+1,'k--', label='Only Ion')
ax.plot(MD_data['r'], MD_data['g'], 'k',label='VASP')

# ax.plot(atom_oz.hnc.r_array*atom_oz.qsp.ri, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='my OZ CHNC')

ax.set_title(r"$R_c = {}$".format(Rc),fontsize=20)
ax.set_xlim(0,6)
ax.set_ylim(0,2)
ax.set_ylabel(r'$g_{ii}$',fontsize=20)
ax.set_xlabel(r'$r/r_i$ ',fontsize=20)
ax.tick_params(labelsize=20)
# ax.set_yscale('symlog', linthresh=2)

# [i.set_linewidth(0.1) for i in ax.spines.itervalues()]
ax.legend(fontsize=15)

# %% [markdown]
# ### Effective Potential

# %%
atom1.hnc.invert_HNC_OZ([1])
atom2.hnc.invert_HNC_OZ([1])
atom3.hnc.invert_HNC_OZ([1])
# atom4.hnc.invert_HNC_OZ([1])
# atom5.hnc.invert_HNC_OZ([1])
# atom6.hnc.invert_HNC_OZ([1])

fig, ax = plt.subplots(figsize=(10,8))

ax.plot(atom1.hnc.r_array, atom1.hnc.βu_r_matrix[0,0],'k-', label='Coulomb')
ax.plot(atom1.hnc.r_array, atom1.hnc.βueff_r_matrix[0,0],'--', label='OZ - Fermi')
ax.plot(atom2.hnc.r_array, atom2.hnc.βueff_r_matrix[0,0],'--', label='SVT- Fermi')
ax.plot(atom3.hnc.r_array, atom3.hnc.βueff_r_matrix[0,0],'--', label='SVT- DMC')
# ax.plot(atom4.hnc.r_array, atom4.hnc.βueff_r_matrix[0,0],'--', label='OZ- 0.1 Hartree')
# ax.plot(atom5.hnc.r_array, atom5.hnc.βueff_r_matrix[0,0],'--', label='OZ- 0.6 rc')
# ax.plot(atom6.hnc.r_array, atom6.hnc.βueff_r_matrix[0,0],'--', label='OZ- 0.6 rc Lado')
# ax.plot(atom1.ocp_hnc.r_array, atom1.ocp_hnc.h_r_matrix[0,0]+1,'k--', label='OCP')

# ax.plot(MD_data['r'], MD_data['g'], label='VASP')

ax.set_title(r"$R_c = {}$".format(Rc),fontsize=20)
ax.set_xlim(0,6)
ax.set_ylim(0,None)
ax.set_ylabel(r'$g_{ii}$',fontsize=20)
ax.set_xlabel(r'$r/r_i$ ',fontsize=20)
ax.tick_params(labelsize=20)
ax.set_yscale('symlog', linthresh=1)

# [i.set_linewidth(0.1) for i in ax.spines.itervalues()]
ax.legend(fontsize=15)

# %% [markdown]
# ### Large r oscillations

# %%
# AA_data = read_csv("/home/zach/plasma/atoMEC/examples/density.csv", delim_whitespace=True, header=0)

fig, ax = plt.subplots(figsize=(10,8))
# nf_0 = Zbar/(4/3*np.pi*atom.qsp.ri**3)
# ax.plot(AA_data['r[a_0]'], np.array(AA_data['n[unbound]'])/nf_0,'k.' ,label="AA" )
# ax.plot(atom_2e.hnc.r_array*atom_2e.qsp.ri, atom_2e.hnc.h_r_matrix[0,0]+1,'--', label='2 electron SVT ')
# ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,0]+1,'--', label='Ashcroft Pseudopotential')
ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,0],'--', label='OZ - HNC Pauli (AA bound)')
ax.plot(atom2.hnc.r_array, atom2.hnc.h_r_matrix[0,0],'--', label='SVT- HNC Pauli (AA bound)')
# ax.plot(atom3.hnc.r_array, atom3.hnc.h_r_matrix[0,0],'--', label='SVT- HNC Pauli (pointlike bound)')
# ax.plot(atom4.hnc.r_array, atom4.hnc.h_r_matrix[0,0]+1,'--', label='OZ- HNC Pauli (pointlike bound, core-core)')
# ax.plot(atom5.hnc.r_array, atom5.hnc.h_r_matrix[0,0]+1,'--', label='SVT- HNC Pauli (pointlike bound, core-core)')
# ax.plot(atom_long.hnc.r_array, atom_long.hnc.h_r_matrix[0,0]+1,'-.', label='1 electron SVT-long ')
# ax.plot(atom_oz.hnc.r_array, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='1 electron OZ ')
# ax.plot(atom.hnc.r_array, atom_oz.onlyion_hnc.h_r_matrix[0,0]+1,'--', label='Only Ion')
ax.plot(MD_data['r'], MD_data['g']-1, label='VASP')

# ax.plot(atom_oz.hnc.r_array*atom_oz.qsp.ri, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='my OZ CHNC')

ax.set_xlim(0,10)
ax.set_ylabel(r'$g_{ii}$',fontsize=20)
ax.set_xlabel(r'$r$ [A.U.]',fontsize=20)
ax.tick_params(labelsize=20)
ax.set_yscale('symlog', linthresh=0.0001)

# [i.set_linewidth(0.1) for i in ax.spines.itervalues()]
ax.legend(fontsize=15)

# %%
# np.savetxt(f"/home/zach/plasma/hnc/TCCW/data/dcf_data/{name}_{Ti_eV:0.2e}eV_rs{ri_AU:0.3f}_oz-hnc-Pauli-bound-dist_c_k_matrix.csv", atom1.hnc.c_k_matrix.reshape(4,atom1.hnc.N_bins))
# np.savetxt(f"/home/zach/plasma/hnc/TCCW/data/dcf_data/{name}_{Ti_eV:0.2e}eV_rs{ri_AU:0.3f}_svt-hnc-Pauli-bound-dist_c_k_matrix.csv", atom2.hnc.c_k_matrix.reshape(4,atom2.hnc.N_bins))
# np.savetxt(f"/home/zach/plasma/hnc/TCCW/data/dcf_data/{name}_{Ti_eV:0.2e}eV_rs{ri_AU:0.3f}_svt-hnc-Pauli-bound-point_c_k_matrix.csv", atom3.hnc.c_k_matrix.reshape(4,atom3.hnc.N_bins))

# %%
# AA_data = read_csv("/home/zach/plasma/atoMEC/examples/density.csv", delim_whitespace=True, header=0)

fig, ax = plt.subplots(figsize=(10,8))

ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,0]+1,'-', label='OZ - HNC Pauli (AA bound)')
ax.plot(atom2.hnc.r_array, atom2.hnc.h_r_matrix[0,0]+1,'-', label='SVT- HNC Pauli (AA bound)')
ax.plot(atom3.hnc.r_array, atom3.hnc.h_r_matrix[0,0]+1,'-', label='SVT- HNC Pauli (pointlike bound)')

ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,1]+1,'--')
ax.plot(atom2.hnc.r_array, atom2.hnc.h_r_matrix[0,1]+1,'--')
ax.plot(atom3.hnc.r_array, atom3.hnc.h_r_matrix[0,1]+1,'--')


ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[1,1]+1,':')
ax.plot(atom2.hnc.r_array, atom2.hnc.h_r_matrix[1,1]+1,':')
ax.plot(atom3.hnc.r_array, atom3.hnc.h_r_matrix[1,1]+1,':')

ax.plot(MD_data['r'], MD_data['g'], 'k-',label='VASP')

# ax.plot(atom_oz.hnc.r_array*atom_oz.qsp.ri, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='my OZ CHNC')

ax.set_xlim(0,3)
ax.set_ylabel(r'$g_{ii}$',fontsize=20)
ax.set_xlabel(r'$r$ [A.U.]',fontsize=20)
ax.tick_params(labelsize=20)
ax.set_yscale('symlog', linthresh=2)
ax.set_ylim(0,None)
# [i.set_linewidth(0.1) for i in ax.spines.itervalues()]
ax.legend(fontsize=15)

# %% [markdown]
# ### Bound and Free state Examination

# %%
bound_file = "/home/zach/plasma/hnc/TCCW/data/Al_rs_3.000_T_1.000e+00eV.csv"
AA_data = read_csv(bound_file, delim_whitespace=True, header=0)
AA_r_AU_full = np.array(AA_data['r[a_0]'])
AA_nb_AU_full = np.array(AA_data['n(bound)'])

# Only use some values for speed
min_r_to_use = 0.2*atom.hnc.r_array[0]*atom.qsp.ri # in AU
indcs = np.where(AA_r_AU_full > min_r_to_use)
AA_r_AU = AA_r_AU_full[indcs]
AA_nb_AU = AA_nb_AU_full[indcs]

# Plot bound states
fig, ax = plt.subplots(figsize=(8,6))

ax.plot(AA_r_AU_full/atom.qsp.ri*2, 4*π*AA_nb_AU_full*AA_r_AU_full**2)
# ax.plot(AA_r_AU_full/atom.qsp.ri, AA_nb_AU_full)
ax.plot(atom2.hnc.r_array, (atom2.hnc.h_r_matrix[0,0]+1) )
ax.plot(atom2.hnc.r_array*2, 4*π*atom2.hnc.r_array**2*(atom2.hnc.h_r_matrix[0,1]+1) )
# ax.plot(atom2.hnc.r_array, 4*π*(atom2.hnc.r_array*atom2.qsp.ri)**2*(atom2.hnc.h_r_matrix[0,1]+1)*(atom2.hnc.rho[1]/atom2.qsp.ri**3),'--', label='HNC bound Pauli')
ax.axvspan(AA_r_AU_full[0]/atom.qsp.ri, min_r_to_use/atom.qsp.ri, color='k', alpha=0.1)
ax.set_xlabel(r'$r/r_i$')
ax.set_ylabel(r'$4 \pi n_b r^2$ [AU]')
# ax.set_xscale('log')
ax.set_xlim(np.min(AA_r_AU_full/atom.qsp.ri), 2*np.max(AA_r_AU_full/atom.qsp.ri))
ax.set_ylim(0, 15)
# Out:
# (0.0, 15.0)

# %% [markdown]
# ## Born Green Viscocity
# See [Morioka 2004](https://www.sciencedirect.com/science/article/pii/S0022309304003692)
#
# \begin{align}
# η = f_{BG} \frac{2 \pi}{15} \left(\frac{M}{RT} \right)^{1/2} \frac{n^2}{N_a} \int^\infty_0 g(r) \frac{d\phi}{dr}r^4 dr
# \end{align}
# Resulting units is Pa s

# %%
from scipy.integrate import simpson

def get_ηBG(plasma):
    plasma.hnc.invert_HNC_OZ([1])
    fBG = -1
    n_AU = n_from_rs(plasma.qsp.ri)
    r_array = plasma.hnc.r_array*plasma.qsp.ri
    gii = plasma.hnc.h_r_matrix[0,0]+1
    dφdr = plasma.qsp.Ti*np.gradient(plasma.hnc.βueff_r_matrix[0,0], r_array)

    integrand = r_array**4 * gii * dφdr
    ##
    fig, ax = plt.subplots()
    ax.plot(r_array, dφdr*r_array**4)
    ###
    integral = simpson(integrand, x=r_array)
    η = fBG* 2*π/15 * (plasma.qsp.βi*plasma.qsp.m_i)**0.5*n_AU**2*integral
    return η

η_SI = get_ηBG(atom2)*AU_to_Pa*AU_to_s # Pa s = kg m^-1 s^-1 
print(f"SI: η = {η_SI:0.3e} [kg m^-1 s^-1] (or [Pa s])")
η_cgs = η_SI * 1000/100 # g cm^-1 s^-1
print(f"CGS: η = {η_cgs:0.3e} [g cm^-1 s^-1]")

# %% [markdown]
# # Plot Fixed Neutrality Issue βu_eff

# %%
plt.style.use('~/plasma/hnc/hnc_paper.mplstyle')

atom.hnc.invert_HNC_OZ([1])
βu_r_raw = atom.hnc.βueff_r_matrix[0,0]
βu_r_raw_fix1 = βu_r_raw - βu_r_raw[-1]
βu_r_raw_fix2 = βu_r_raw - (βu_r_raw[-1]*atom.hnc.r_array[-1])/atom.hnc.r_array
tapering_func = lambda r: np.exp( -0.02*r**2/(5-r))
βu_r_raw_fix3 = βu_r_raw*tapering_func(atom.hnc.r_array)
βu_r_raw_fix4 = βu_r_raw_fix1*tapering_func(atom.hnc.r_array)


fig, axs  = plt.subplots(1,2,figsize=(20,8))
yukawa_matrix = (atom_long.hnc.Gamma[:,:,np.newaxis]/atom_long.hnc.r_array * np.exp(-atom_long.hnc.r_array*atom_long.qsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]

axs[0].set_title(r"$\beta u$")
axs[0].plot(atom.hnc.r_array, βu_r_raw,'k--', label='Raw')
axs[0].plot(atom_long.hnc.r_array, atom_long.hnc.βueff_r_matrix[0,0],'k-.', label='Long')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix1, label=r'Constant Shift to $\beta u_{eff}$')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix2 , label=r'Subtraction of Coulomb directly')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix3, label=r'Tapered raw')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix4, label=r'Tapered shifted')
axs[0].plot(atom_long.hnc.r_array, yukawa_matrix[0,0],'-.', label='Yukawa')

axs[1].set_title(r"$F$")
dudx = lambda u: -(u[1:]-u[:-1])/atom.hnc.del_r
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw),'k--', label='Raw')
axs[1].plot(atom_long.hnc.r_array[1:], dudx(atom_long.hnc.βueff_r_matrix[0,0]),'k-.', label='Long')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix1), label=r'Constant Shift to $\beta u_{eff}$')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix2) , label=r'Subtraction of Coulomb directly')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix3), label=r'Tapered raw ')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix4), label=r'Tapered shifted')
βueff_r_header="r/r_i \t\t\t βuii_eff(r/r_i)"
np.savetxt("./fits/{0}_βu_eff_raw.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw]).T, header=βueff_r_header)
np.savetxt("./fits/{0}_βu_eff_shifted.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw_fix1]).T, header=βueff_r_header)
np.savetxt("./fits/{0}_βu_eff_tapered.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw_fix3]).T, header=βueff_r_header)
np.savetxt("./fits/{0}_βu_eff_shifted_tapered.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw_fix4]).T, header=βueff_r_header)

axs[1].set_xlim(4,10)

for ax in axs:
    ax.set_yscale('symlog',linthresh=1e-8)

    ax.legend(fontsize=15)

# %% [markdown]
# ### Plot $\beta u^{eff}$

# %%
plt.style.use('~/plasma/hnc/hnc_paper.mplstyle')
def make_gij(ax):
    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.h_r_matrix[0,0]+1,'-', label=r'$g_{ii}$')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.h_r_matrix[0,1]+1,'--', label=r'$g_{ei}$')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.h_r_matrix[1,1]+1,':', label=r'$g_{ee}$')

    # ax.set_yscale('symlog', linthresh=5)
    ax.set_xlim(0,10)
    ax.set_ylim(-0.05,5)

    ax.set_xlabel(r"$r$ [AU]")#, fontsize=25)
    ax.set_ylabel(r"$g_{ij}$")#, fontsize=25)
    ax.legend()

fig, ax = plt.subplots()
make_gij(ax)
plt.savefig("gij_Al1.png")

# %%
plt.style.use('~/plasma/hnc/hnc_paper.mplstyle')

atom.hnc.invert_HNC_OZ([1])
def make_βu(ax):
    yukawa_matrix = (atom.hnc.Gamma[:,:,np.newaxis]/atom.hnc.r_array * np.exp(-atom.hnc.r_array*atom.qsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]
    coulomb_matrix = (atom.hnc.Gamma[:,:,np.newaxis]/atom.hnc.r_array) [:-1,:-1]

    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.βueff_r_matrix[0,0],'-', label='HNC Inversion')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, yukawa_matrix[0,0],'-.', label='Yukawa')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, coulomb_matrix[0,0],'--', label='Coulomb')

    ax.set_yscale('symlog', linthresh=1)

    ax.set_xlabel(r"$r$ [AU]")#, fontsize=25)
    ax.set_ylabel(r"$\beta u_{\rm eff}$")#, fontsize=25)
    ax.legend()

fig, ax = plt.subplots()
make_βu(ax)
plt.savefig("βu_Al1.png")

# %% [markdown]
# ### Now Plot Both Together

# %%
plt.style.use('~/plasma/mpl_styles/paper.mplstyle')

fig, axs = plt.subplots(1,2, figsize=(18,8))

make_gij(axs[0])
make_βu(axs[1])
plt.tight_layout()
plt.savefig("βu_gij_Al1.png")

# %% [markdown]
# # Run Many Cases

# %%
for tccw_case in tccw_cases[6:]:
    α = 0.1
    case_converged=False
    case_attempts=0
    case_num= tccw_case[' ']
    case_id = tccw_case['Case ID']
    ni_cc = tccw_case['Number Density [N/cc]']
    Te_eV = tccw_case['Temperature [eV]']
    Ti_eV = Te_eV
    Z = tccw_case['Atomic Number']
    Zbar = tccw_case['Zbar (TFDW)']
    P_GP_AU  = tccw_case['p (Bar)']/AU_to_bar
    A = tccw_case['Atomic Weight [a.u.]']
    r_s_cc = tccw_case['Wigner-Seitz Radius [cm]']
    r_c = tccw_case['Average-Bound Radius [cm]']/r_s_cc
    if r_c>1:
        r_c=1e-5
    print('\n______________________________\nCase num: {0} Case ID: {1}'.format(case_num, case_id))
    print("Te = {0:.3e} eV, n_i = {1:.3e} 1/cc, r_c/r_s = {2:.3f}".format(Te_eV, ni_cc, r_c))
    print("Te = {0:.3e} K, ρ = {1:.3e} [g/cc] ".format(Te_eV*eV_to_K, 1e3*ni_cc*m_p*A ))
    print("P  = {0:.3e} [bar] = {1:.3e} [AU]".format(P_GP_AU*AU_to_bar, P_GP_AU))
    
    α = 1
    converged=False
    while not converged:
        atom = CMEP_Atom(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, 
                     βu_options = {'add_bridge':True}, 
                     qsp_options={'r_c':r_c},
                     hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                     hnc_solve_options={'alpha_Picard':α})
        atom.run_hnc()
        if atom.hnc.newton_succeed==True:
            converged=True
        else:
            α*=0.5
            
    atom.get_cp()

# %% [markdown]
# # Only Ion

# %%
atom.run_onlyion_hnc()

# %%
atom.onlyion_hnc.plot_species_convergence_g()

# %%
# c_s_k_guess = atom.hnc.c_s_k_matrix.copy()*0
c_s_k_guess[0,0] = atom.onlyion_hnc.c_s_k_matrix[0,0]*0.


atom.run_hnc(c_s_k_guess = c_s_k_guess)

# %% [markdown]
# # Make atom

# %%
Zbar_list  = np.linspace(3,Zbar, num=100)
# Zbar_list = [1,3]
atom_list= []
for i, Zbar_i in enumerate(Zbar_list):
    print("Zbar = {0:.3f}".format( Zbar_i ))
    
    atom = CMEP_Atom(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar_i, 
                 βu_options = {'add_bridge':True}, 
                 qsp_options={'r_c':r_c},
                 hnc_options={'kappa_multiscale':10},
                 hnc_solve_options={'alpha_Picard':0.5})
    if i>=1:
        Z2_matrix = [[Zbar_list[i]]]
        guess_2 = 
        c_s_k_guess = atom_list[-1].hnc.c_s_k_matrix
        c_s_k_guess[0,0] *= (Zbar_list[i]/Zbar_list[i-1])**2 
        c_s_k_guess[0,1] *= (Zbar_list[i]/Zbar_list[i-1])**1 
        c_s_k_guess[1,0] *= (Zbar_list[i]/Zbar_list[i-1])**1
#         c_s_k_guess[0,0] *= 0
    else:
        c_s_k_guess *=0
    atom.run_hnc(c_s_k_guess=c_s_k_guess)
    atom_list.append( atom )

# %%
fig, axs = plt.subplots(2, 2, facecolor='w', figsize=(10,8) )

atom3_guess = atom2.hnc.c_s_k_matrix + (atom2.hnc.c_s_k_matrix-atom1.hnc.c_s_k_matrix)/(2-1)*(3-2) 
atom3_guess = atom2.hnc.c_s_k_matrix + (atom2.hnc.c_s_k_matrix/atom1.hnc.c_s_k_matrix)/(2-1)*(3-2) 

for i in range(2):
    for j in range(2):
        for k, atom in enumerate(atom_list):
            color = plt.cm.viridis(k/len(atom_list))
            Z_factor = (Zbar_list[0]/Zbar_list[k])**-1
            axs[i, j].plot(atom.hnc.r_array, atom.hnc.c_s_k_matrix[i,j], '--',label= "Zbar", color= color)
            axs[i, j].plot(atom.hnc.r_array, Z_factor*atom_list[0].hnc.c_s_k_matrix[i,j],'.', label= "Zbar", color= color)
#             axs[i, j].plot(atom.hnc.r_array, atom2.hnc.c_s_k_matrix[i,j], label= "Zbar=2")
#             axs[i, j].plot(atom.hnc.r_array, atom6.hnc.c_s_k_matrix[i,j], label= "Zbar=6")
#         axs[i, j].plot(atom2.hnc.r_array, atom2.hnc.c_s_k_matrix[i,j]-atom1.hnc.c_s_k_matrix[i,j], label= "Zbar=2/1")
#         axs[i, j].plot(atom2.hnc.r_array, atom3.hnc.c_s_k_matrix[i,j]-atom2.hnc.c_s_k_matrix[i,j], label= "Zbar=3/2")
#         axs[i, j].plot(atom2.hnc.r_array, atom3_guess[i,j] , 'k--', label= "Zbar=3 (guess)")
        
#         axs[i, j].plot(atom3.hnc.r_array, atom3.hnc.c_s_k_matrix[i,j],'k', label= "Zbar=3")
#         axs[i, j].plot(atom100.hnc.r_array, atom80.hnc.c_s_k_matrix[i,j]-100/80*atom100.hnc.c_s_k_matrix[i,j], label= "80/100 eV")
#         axs[i, j].plot(atom100.hnc.r_array, atom60.hnc.c_s_k_matrix[i,j], label= "60 eV")
         
#         axs[i, j].plot(atom100.hnc.r_array, T_rescale[i,j]*atom100.hnc.c_s_k_matrix[i,j], label= "rescaled 100 eV")
        
        axs[i,j].set_xscale('log')
#         axs[i, j].set_yscale('symlog', linthresh=0.1)
#         axs[i, j].legend()
        
plt.tight_layout()

# %%
atom.get_cp(ε_derivative=1e-6, ε_table=1e-1, N_table= 2 )

# %%
fig, ax = plt.subplots()

# ax.plot(atom.hnc.r_array, atom.hnc.βueff_r_matrix[0,0])
ax.plot(atom.hnc.r_array, atom.hnc.h_r_matrix[0,0]+1)
# ax.set_yscale('symlog', linthresh=1)

# %% [markdown]
# ###### Hydrogen H1
#
# c_p = 1.667e+08 [J/m^3/K] = 1.667e+09 [erg/cc/K]
#
#
# c_p^ideal = 2.064e+07 [J/m^3/K] = 2.064e+08 [erg/cc/K]
#
# c_v = 1.229e+08 [J/m^3/K] = 1.229e+09 [erg/cc/K]
#
#
# γ = cp/cv = 1.357e+00
#
# ###### Aluminum Al1
#
# c_p = 5.560e+06 [J/m^3/K] = 5.560e+07 [erg/cc/K]
#
# c_p^ideal = 2.081e+06 [J/m^3/K] = 2.081e+07 [erg/cc/K]
#
# c_v = 3.559e+06 [J/m^3/K] = 3.559e+07 [erg/cc/K]
#
# c_p_over_nkB = 6.678
#
# c_v_over_nkB = 4.275
#
# γ = cp/cv = 1.562e+00
#
# ##### Carbon C1
#
# c_p = 1.005e+09 [J/m^3/K] = 1.005e+10 [erg/cc/K]
#
# c_p^ideal = 1.729e+07 [J/m^3/K] = 1.729e+08 [erg/cc/K]
#
# c_v = 7.410e+08 [J/m^3/K] = 7.410e+09 [erg/cc/K]
#
# γ = cp/cv = 1.357e+00
#
# ##### Copper Cu1
# c_p = 6.829e+07 [J/m^3/K] = 6.829e+08 [erg/cc/K]
#
# c_p^ideal = 2.930e+06 [J/m^3/K] = 2.930e+07 [erg/cc/K]
#
# c_v = 4.460e+07 [J/m^3/K] = 4.460e+08 [erg/cc/K]
#
# γ = cp/cv = 1.531e+00

# %%
# Compare to Ichimaru
n_AU = ni_cc * (1e2*aB)**3
E_over_nkBT = atom.U/( Te*N )
P_over_nkBT = atom.P/(Te*n_AU)
c_p_over_nkB = C_p_AU/N #c_p_SI_vol/k_B/(ni_cc*1e6)
E_over_nkBT, P_over_nkBT, c_p_over_nkB

# %%
# 2x2
#(16.078004224152146, 7.958852940677674, 20.391840227664225)
# 3x3
#(17.29156071613095, 9.41653222069282, 19.954770080816058)
# 4x4
#(17.29156071613095, 9.41653222069282, 20.31577883096223)
# 6x6
#(17.29156071613095, 9.41653222069282, 20.341775951597302)

# %%
#cp units are J/K/m^3

# %%
c_p_SI_vol *J_to_erg*1e-6 # from J/K/m^3 to erg/K/cc

# %%
(c_p_over_nkB*ni_cc * k_B*1e6)/1e8 # in erg/

# %%
# Ideal
# (1.503495387998133, 1.0020009999999997, 2.5033223241241656)

# %% [markdown]
# # βu_eff matching

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
# luke_file = '/home/zach/plasma/atomic_forces/data/Al_T0p5_tab.lammps.PAIR'
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
# luke_r, luke_βV = 1e-10/aB/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_r, luke_βV = 1e-8/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)

# %%
from scipy.optimize import curve_fit

class βu_fit():
    def __init__(self, func, r_array, y_data, initial_guess):
        self.r = r_array
        self.y = y_data
        self.y_vals = curve_fit(func, r_array, y_data, maxfev=int(1e5), p0=initial_guess)
        self.y_fit  = func(r_array, *self.y_vals[0])
        self.err = np.linalg.norm(self.y_fit-self.y)
        print(func.__name__ + " error: {0:.3e} ".format(self.err))

def yukawa_plus(r, a, b, c, d):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d)))

def yukawa_plus_gaussian(r, a ,b ,c, d ,e, f, g):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.exp(-(f-r)**2/g)

def yukawa_plus_cos(r, a ,b ,c, d , h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + h*np.cos((r-i)*j*np.exp(-k*r))*np.exp(-l*r)

def yukawa_plus_gaussian_cos(r, a ,b ,c, d ,e, f, g, h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.cos((r-f)*g*np.exp(-h*r))*np.exp(-i*r) + j*np.exp(-(k-r)**2/l)

# %%
atom = atom_highres

# %%
atom.invert_HNC_OZ([1])
fit1 = βu_fit(yukawa_plus, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[   atomqsp.Γii, atomqsp.get_κ(),2 , 1])
try: 
    fit2 = βu_fit(yukawa_plus_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit1.y_vals[0], 1, 0.01, 1 , 10, 2])
except:
    pass
try:
    fit3 = βu_fit(yukawa_plus_gaussian_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit2.y_vals[0], -1, 1.9, 1])
except:
    pass

# %%
luke_r

# %%
fig, ax = plt.subplots(figsize=(8,6),facecolor='w')
fig.suptitle(r"{0} $T=${1:.1f} eV, $r_i$={2:.2f}".format(case_id, Te/eV, atomqsp.ri), fontsize=20)


yukawa_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array * np.exp(-atom.r_array*atomqsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]
coulomb_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array) [:-1,:-1]

ax.plot(atom.r_array, atom.βu_r_matrix[0,0], 'k--',label='Initial')
ax.plot(atom.r_array, yukawa_matrix[0,0],'k-.', label="Yukawa")

ax.plot(atom.r_array, atom.βueff_r_matrix[0,0],color=colors[0], label='Effective')    
ax.plot(luke_r, luke_βV,'r-', label='Luke Force Match')

ax.set_ylim(np.min([-10, 2*np.min(atom.βueff_r_matrix[0,0])]), np.max([1e3, 2*np.max(atom.βueff_r_matrix[0,0])]))
ax.tick_params(labelsize=20)
ax.set_xlabel(r"$r/r_s$",fontsize=20)
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)

ax.set_xlim(0, 5)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=10)
fig.tight_layout()
