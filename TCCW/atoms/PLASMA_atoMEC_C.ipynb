# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

from hnc.hnc.PIE import Plasma_of_Ions_and_Electrons as PLASMA

from hnc.hnc.constants import *
from hnc.hnc.misc import n_from_rs, rs_from_n

from pandas import read_csv

prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
                
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# ModuleNotFoundError: No module named 'mendeleev'
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %% [markdown]
# # Function that sets up HNC QSP

# %% [markdown]
# ### Create and run plasma

# %%
Z, A = 6 , 12
mi = m_p * A
ρ_gpercc = 2.267
ni_cc = ρ_gpercc/(mi*AU_to_g)
ri_cm = rs_from_n(ni_cc)
ri_AU = ri_cm*cm_to_AU

Te_eV = 5
Ti_eV = 5

ri_AU
# Out:
# 2.4239185975523876

# %% [markdown]
# ### Make βu_ii, βu_fi from using bound density from AA
# If we assume the bound state does not deform at all, then we can calculate potentials based on it easily via integration

# %%
from scipy.integrate import simpson

bound_file = "../data/C_ri_2.424_T5.0eV.csv"
AA_data = read_csv(bound_file, delim_whitespace=True, header=0)
AA_r_AU_full = np.array(AA_data['r[a_0]'])
AA_nb_AU_full = np.array(AA_data['n[bound]'])

# Get Zbar
Zbar = Z - simpson(4*π*AA_nb_AU_full*AA_r_AU_full**2,  AA_r_AU_full)
print(f"Total Zbar from integration: {Zbar:.3f}")
# Out:
# Total Zbar from integration: 4.000

# %%
atom = PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, find_βuee=True,
                 βu_options = {'add_bridge':True,'bridge':'yukawa', 'pseudopotential':False}, 
                 hnc_options={'kappa_multiscale':0, 'R_max':10,'N_bins':1000},
                 hnc_solve_options={'alpha_Picard':0.1},
                 root_options={'options':{'maxfev':50000,'xtol':1e-14}})
# Out:
# Te_in_eV: 5.000
# Ti_in_eV: 5.000

# %%
# Only use some values for speed
min_r_to_use = 0.2*atom.hnc.r_array[0]*atom.qsp.ri # in AU
indcs = np.where(AA_r_AU_full > min_r_to_use)
AA_r_AU = AA_r_AU_full[indcs]
AA_nb_AU = AA_nb_AU_full[indcs]


# Plot bound states
fig, ax = plt.subplots(figsize=(8,6))

ax.plot(AA_r_AU_full/atom.qsp.ri, 4*π*AA_nb_AU_full*AA_r_AU_full**2)
ax.axvspan(AA_r_AU_full[0]/atom.qsp.ri, min_r_to_use/atom.qsp.ri, color='k', alpha=0.1)
ax.set_xlabel(r'$r/r_i$')
ax.set_ylabel(r'$4 \pi n_b r^2$ [AU]')
# ax.set_xscale('log')
ax.set_xlim(np.min(AA_r_AU_full/atom.qsp.ri), np.max(AA_r_AU_full/atom.qsp.ri))
ax.set_ylim(0, None)
# Out:
# (0.0, 6.194495172852935)

# %%
from scipy.integrate import dblquad, simpson
from scipy.interpolate import RegularGridInterpolator

def new_δβuei(r_sep_in_AU, verbose = False, only_Pauli=True, HNC_Pauli=True):
    r_array = AA_r_AU #AU
    rs = atom.qsp.ri
    cosφ_array = np.linspace(-1,1,num=100)
    r_mesh, cosφ_mesh = np.meshgrid(r_array,cosφ_array, indexing='ij')

    nb_mesh = AA_nb_AU[:,np.newaxis] * np.ones_like(r_mesh)
    ree_mesh = np.sqrt( r_sep_in_AU**2 + r_mesh**2 + 2*r_mesh*r_sep_in_AU*cosφ_mesh  )
    
    if only_Pauli:
        # βu_ee_mesh = atom.qsp.βv_Pauli(ree_mesh/rs, atom.qsp.Λee)
        if HNC_Pauli:
            βu_ee_mesh = atom.βP_ee_func(ree_mesh/rs)
        else:
            βu_ee_mesh = atom.qsp.βv_Pauli(ree_mesh/rs, type='Lado')
    else:
        βu_ee_mesh = atom.qsp.βvee( ree_mesh/rs  ) + atom.βP_ee_func(ree_mesh/rs) - atom.qsp.βv_Pauli(ree_mesh/rs)
    
    integrand_mesh = 2*π* r_mesh**2 * nb_mesh*βu_ee_mesh
    
    if verbose:
        fig, axs = plt.subplots(1,3)
        extent = [-1,1, r_array[0]/atom.qsp.ri, r_array[-1]/atom.qsp.ri]
        print(extent)
        axs[0].imshow(r_mesh**2 * nb_mesh*βu_ee_mesh, origin='lower', extent=extent)
        axs[1].imshow(βu_ee_mesh, origin='lower', extent=extent)
        axs[2].imshow(r_mesh**2 * nb_mesh, origin='lower', extent=extent)
        for ax in axs:
            ax.set_ylabel(r'$r/r_i$')
            ax.set_xlabel(r'$\cos \theta$')
            ax.set_yscale('log')
            ax.plot(cosφ_array, np.ones_like(cosφ_array) * r_sep_in_AU/atom.qsp.ri ,'r')

        plt.tight_layout()
        plt.show()
    δβuei_simpson = simpson(simpson(integrand_mesh, axis=0, x=r_array), axis=0, x=cosφ_array)
    
#     δβuei_interp = RegularGridInterpolator( (r_array, cosφ_array), integrand_mesh  )
#     δβuei_integrand = lambda y, x : δβuei_interp((x, y)) # Weird convention, flipping not a mistake...
#     δβuei = dblquad(δβuei_integrand, r_array[0], r_array[-1], -1, 1)
    
    return δβuei_simpson#, δβuei
    
new_δβuei(1, verbose=True, HNC_Pauli=False)
# Out:
# [-1, 1, 0.0020014913062257455, 1.0000001660318196]
# 0.7533305352365024

# %%
δβuei = np.array([new_δβuei(r_hnc*atom.qsp.ri, only_Pauli=False) for r_hnc in atom.hnc.r_array])
δβuei_Pauli_HNC = np.array([new_δβuei(r_hnc*atom.qsp.ri) for r_hnc in atom.hnc.r_array])
δβuei_Pauli_Lado = np.array([new_δβuei(r_hnc*atom.qsp.ri, HNC_Pauli=False) for r_hnc in atom.hnc.r_array])

# %%
fig, ax = plt.subplots(figsize=(10,8))


ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1] * Z/(atom.hnc.r_array*atom.qsp.ri),'--', label=r'Coulomb: $ Z$')
ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1] * (Z-Zbar)/(atom.hnc.r_array*atom.qsp.ri),'--', label=r'Coulomb: $ Z-\langle Z \rangle$')
ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1] * Zbar/(atom.hnc.r_array*atom.qsp.ri),'--', label=r'Coulomb: $\langle Z \rangle$')
ax.plot(atom.hnc.r_array, atom.hnc.βu_r_matrix[0,1], 'k-',label=r'OLD $-\beta u_{ei}$')
ax.plot(atom.hnc.r_array, -δβuei, label=r' $\int n_b u_{ee}$ ')
ax.plot(atom.hnc.r_array, -1/atom.hnc.Temp_matrix[0,1]* Z/(atom.hnc.r_array*atom.qsp.ri) + δβuei,'k--' , label=r' NEW1: $-\beta Z/r + \int n_b u_{ee}$ ')
ax.plot(atom.hnc.r_array,  Z/Zbar*atom.hnc.βu_r_matrix[0,1] + δβuei,'k-.' , label=r' NEW2: $-\beta u_{ei}(Z) + \int n_b u_{ee}$ ')
ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,1] + δβuei_Pauli_HNC,'k--.' , label=r' NEW3: $-\beta u_{ei}(\langle Z \rangle) + \int n_b u^P_{ee}(HNC)$ ')
ax.plot(atom.hnc.r_array,  atom.hnc.βu_r_matrix[0,1] + δβuei_Pauli_Lado,'k.' , label=r' NEW4: $-\beta u_{ei}(\langle Z \rangle) + \int n_b u^P_{ee}(Lado)$ ')

ax.legend(fontsize=14)
ax.set_yscale('symlog', linthresh=1)
ax.set_xscale('log')

ax.set_ylabel(r"$\beta u$", fontsize=20)
ax.set_xlabel(r"$r/r_i$", fontsize=20)

ax.set_ylim(-1e4,1e2)
# Out:
# (-10000.0, 100.0)

# %% [markdown]
# ### Solving

# %%
from scipy.optimize import least_squares
from scipy.interpolate import interp1d

def custom_flat(hnc_matrix):
    hnc_flat = np.concatenate([hnc_matrix[0,0],hnc_matrix[0,1],hnc_matrix[1,1]])
    return hnc_flat

def custom_unflat(hnc_flat):
    hnc00, hnc01, hnc11 = np.split(hnc_flat,3)
    hnc_matrix = np.zeros((2,2,len(hnc00)))
    hnc_matrix[0,0] = hnc00
    hnc_matrix[1,0] = hnc01
    hnc_matrix[0,1] = hnc01
    hnc_matrix[1,1] = hnc11
    return hnc_matrix

def solve_least_squares(plasma, sparse_k_array, c_s_k_guess=None, ftol=1e-8):
    if c_s_k_guess is None:
        c_s_k_guess = plasma.hnc.c_s_k_matrix

    # Create functions for converting between sparse, not sparse and flattened versions of c_s_k
    get_sparse_csk = lambda c_s_k_flat: np.concatenate([interp1d(plasma.hnc.k_array, c_s_k)(sparse_k_array) for c_s_k in np.split(c_s_k_flat,3) ])
    get_csk = lambda sparse_hnc_csk: interp1d(sparse_k_array, sparse_hnc_csk, kind='linear')(plasma.hnc.k_array)
    get_csk_matrix_from_sparse_csk_flat =  lambda sparse_c_s_k_flat: custom_unflat(np.concatenate([get_csk(sparse_csk) for sparse_csk in np.split(sparse_c_s_k_flat,3)]))
    
    def min_function(sparse_c_s_k_flat):
        c_s_k_matrix = get_csk_matrix_from_sparse_csk_flat(sparse_c_s_k_flat)
        new_c_s_k_matrix = plasma.hnc.guess_c_s_k_matrix(c_s_k_matrix)
        plasma.hnc.c_s_k_matrix = new_c_s_k_matrix.copy()
        new_c_s_k_flat = custom_flat(new_c_s_k_matrix)
        return sparse_c_s_k_flat - get_sparse_csk(new_c_s_k_flat)
    
    c_s_k_flat_guess = custom_flat(c_s_k_guess)
    c_s_k_sparse_guess = get_sparse_csk(c_s_k_flat_guess)
    sol = least_squares(min_function, c_s_k_sparse_guess, verbose=2, ftol=ftol)#, bounds = c_s_k_bounds)
    plasma.hnc.c_s_k_matrix = get_csk_matrix_from_sparse_csk_flat(sol.x)
    plasma.hnc.set_all_matrices_from_csk(plasma.hnc.c_s_k_matrix)
    print(sol)
    
def best_shift(plasma, guess_c_s_k, ftol=1e-8, set=True):
    
    
    def min_function(multiplier_list):
        xii, xei, xee = multiplier_list
        multiplier_matrix = np.array([[xii,xei],[xei,xee]])
        c_s_k_matrix = multiplier_matrix[:,:,np.newaxis] * guess_c_s_k
        new_c_s_k_matrix = plasma.hnc.guess_c_s_k_matrix(c_s_k_matrix)
        
        return c_s_k_matrix.flatten() - new_c_s_k_matrix.flatten()
    
    sol = least_squares(min_function, np.ones((3)) , verbose=2, ftol=ftol)#, bounds = c_s_k_bounds)
    xii, xei, xee = sol.x
    multiplier_matrix = np.array([[xii,xei],[xei,xee]])
    
    plasma.hnc.c_s_k_matrix = multiplier_matrix[:,:,np.newaxis] * guess_c_s_k
    print(sol)
    return sol

# %%
atom1 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, 
                 βu_options = {'add_bridge':False,'bridge':'yukawa', 'pseudopotential':False}, 
                 hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                 hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.01},
                 root_options={'options':{'maxfev':100,'xtol':1e-14}})

atom2 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, find_βuee=True,
                 βu_options = {'add_bridge':False,'bridge':'yukawa', 'pseudopotential':False}, 
                 hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                 hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.01, 'verbose':True},
                 root_options={'options':{'maxfev':100,'xtol':1e-14}})

atom3 =  PLASMA(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar,find_βuee=False, 
                 βu_options = {'add_bridge':False,'bridge':'yukawa', 'pseudopotential':False}, 
                 hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                 hnc_solve_options={'num_iterations':10000,'alpha_Picard':0.01,'verbose':False},
                 root_options={'options':{'maxfev':100,'xtol':1e-14}})


atom1.hnc.βu_r_matrix[0,1] = atom1.hnc.βu_r_matrix[0,1] + δβuei_Pauli_Lado
atom1.hnc.βu_r_matrix[1,0] = atom1.hnc.βu_r_matrix[1,0] + δβuei_Pauli_Lado
atom1.hnc.set_βu_matrix(atom1.hnc.βu_r_matrix)

atom2.hnc.βu_r_matrix[0,1] = atom2.hnc.βu_r_matrix[0,1] + δβuei_Pauli_HNC
atom2.hnc.βu_r_matrix[1,0] = atom2.hnc.βu_r_matrix[1,0] + δβuei_Pauli_HNC
atom2.hnc.set_βu_matrix(atom2.hnc.βu_r_matrix)

atom3.hnc.βu_r_matrix[0,1] = atom3.hnc.βu_r_matrix[0,1] #+ δβuei_Pauli_Lado
atom3.hnc.βu_r_matrix[1,0] = atom3.hnc.βu_r_matrix[1,0] #+ δβuei_Pauli_Lado
atom3.hnc.set_βu_matrix(atom3.hnc.βu_r_matrix)
# Out:
# Te_in_eV: 5.000
# Ti_in_eV: 5.000
# Te_in_eV: 5.000
# Ti_in_eV: 5.000
# Te_in_eV: 5.000
# Ti_in_eV: 5.000

# %% [markdown]
# #### atom1

# %%
# atom1.run_hnc(newton=False, c_s_k_guess = atom1.hnc.c_s_k_matrix.copy())
# solve_least_squares(atom1, np.linspace(atom1.hnc.k_array[0], atom1.hnc.k_array[-1], num=400))
# Out:
# 0: Initial condition Total Error: 1.896e+00

# %% [markdown]
# #### atom2

# %%
# atom2.hnc.c_s_k_matrix = np.loadtxt("../data/dcf_data/Al_1eV_rs3_hnc_Pauli_c_s_k_matrix.csv").reshape(2,2,atom2.hnc.N_bins)
saved_guess = np.loadtxt("../data/dcf_data/Al_1eV_rs3_hnc_Pauli_c_s_k_matrix.csv").reshape(2,2,atom3.hnc.N_bins)

# %%
# best_shift(atom2, saved_guess)
atom2.run_hnc(newton=False, c_s_k_guess = atom2.hnc.c_s_k_matrix.copy())
solve_least_squares(atom2, np.linspace(atom2.hnc.k_array[0], atom2.hnc.k_array[-1], num=300))
solve_least_squares(atom2, np.linspace(atom2.hnc.k_array[0], atom2.hnc.k_array[-1], num=1000))
# Out:
# 0: Initial condition Total Error: 5.964e+01
# 1: Change in c_r: 3.136e-03, HNC Error: 2.482e-01, Total Error: 5.912e+01
# 2: Change in c_r: 3.131e-03, HNC Error: 2.450e-01, Total Error: 5.860e+01
# 3: Change in c_r: 3.127e-03, HNC Error: 2.420e-01, Total Error: 5.809e+01
# 4: Change in c_r: 3.122e-03, HNC Error: 2.392e-01, Total Error: 5.759e+01
# 5: Change in c_r: 3.117e-03, HNC Error: 2.365e-01, Total Error: 5.708e+01
# 6: Change in c_r: 3.113e-03, HNC Error: 2.338e-01, Total Error: 5.659e+01
# 7: Change in c_r: 3.108e-03, HNC Error: 2.313e-01, Total Error: 5.609e+01
# 8: Change in c_r: 3.104e-03, HNC Error: 2.289e-01, Total Error: 5.560e+01
# 9: Change in c_r: 3.099e-03, HNC Error: 2.265e-01, Total Error: 5.512e+01
# 10: Change in c_r: 3.094e-03, HNC Error: 2.242e-01, Total Error: 5.464e+01
# 11: Change in c_r: 3.090e-03, HNC Error: 2.220e-01, Total Error: 5.416e+01
# 12: Change in c_r: 3.085e-03, HNC Error: 2.199e-01, Total Error: 5.369e+01
# 13: Change in c_r: 3.081e-03, HNC Error: 2.178e-01, Total Error: 5.322e+01
# 14: Change in c_r: 3.076e-03, HNC Error: 2.158e-01, Total Error: 5.275e+01
# 15: Change in c_r: 3.072e-03, HNC Error: 2.139e-01, Total Error: 5.229e+01
# 16: Change in c_r: 3.068e-03, HNC Error: 2.120e-01, Total Error: 5.183e+01
# 17: Change in c_r: 3.063e-03, HNC Error: 2.102e-01, Total Error: 5.138e+01
# 18: Change in c_r: 3.059e-03, HNC Error: 2.084e-01, Total Error: 5.093e+01
# 19: Change in c_r: 3.054e-03, HNC Error: 2.067e-01, Total Error: 5.049e+01
# 20: Change in c_r: 3.050e-03, HNC Error: 2.051e-01, Total Error: 5.004e+01
# 21: Change in c_r: 3.046e-03, HNC Error: 2.035e-01, Total Error: 4.961e+01
# 22: Change in c_r: 3.041e-03, HNC Error: 2.020e-01, Total Error: 4.917e+01
# 23: Change in c_r: 3.037e-03, HNC Error: 2.006e-01, Total Error: 4.874e+01
# 24: Change in c_r: 3.033e-03, HNC Error: 1.991e-01, Total Error: 4.832e+01
# 25: Change in c_r: 3.029e-03, HNC Error: 1.978e-01, Total Error: 4.789e+01
# 26: Change in c_r: 3.024e-03, HNC Error: 1.965e-01, Total Error: 4.747e+01
# 27: Change in c_r: 3.020e-03, HNC Error: 1.952e-01, Total Error: 4.706e+01
# 28: Change in c_r: 3.016e-03, HNC Error: 1.940e-01, Total Error: 4.665e+01
# 29: Change in c_r: 3.012e-03, HNC Error: 1.928e-01, Total Error: 4.624e+01
# 30: Change in c_r: 3.008e-03, HNC Error: 1.916e-01, Total Error: 4.583e+01
# 31: Change in c_r: 3.003e-03, HNC Error: 1.905e-01, Total Error: 4.543e+01
# 32: Change in c_r: 2.999e-03, HNC Error: 1.895e-01, Total Error: 4.503e+01
# 33: Change in c_r: 2.995e-03, HNC Error: 1.885e-01, Total Error: 4.464e+01
# 34: Change in c_r: 2.991e-03, HNC Error: 1.875e-01, Total Error: 4.425e+01
# 35: Change in c_r: 2.987e-03, HNC Error: 1.866e-01, Total Error: 4.386e+01
# 36: Change in c_r: 2.983e-03, HNC Error: 1.857e-01, Total Error: 4.347e+01
# 37: Change in c_r: 2.979e-03, HNC Error: 1.848e-01, Total Error: 4.309e+01
# 38: Change in c_r: 2.975e-03, HNC Error: 1.840e-01, Total Error: 4.272e+01
# 39: Change in c_r: 2.971e-03, HNC Error: 1.832e-01, Total Error: 4.234e+01
# 40: Change in c_r: 2.967e-03, HNC Error: 1.825e-01, Total Error: 4.197e+01
# 41: Change in c_r: 2.963e-03, HNC Error: 1.818e-01, Total Error: 4.160e+01
# 42: Change in c_r: 2.959e-03, HNC Error: 1.811e-01, Total Error: 4.124e+01
# 43: Change in c_r: 2.955e-03, HNC Error: 1.804e-01, Total Error: 4.087e+01
# 44: Change in c_r: 2.951e-03, HNC Error: 1.798e-01, Total Error: 4.052e+01
# 45: Change in c_r: 2.947e-03, HNC Error: 1.793e-01, Total Error: 4.016e+01
# 46: Change in c_r: 2.943e-03, HNC Error: 1.787e-01, Total Error: 3.981e+01
# 47: Change in c_r: 2.939e-03, HNC Error: 1.782e-01, Total Error: 3.946e+01
# 48: Change in c_r: 2.935e-03, HNC Error: 1.777e-01, Total Error: 3.911e+01
# 49: Change in c_r: 2.931e-03, HNC Error: 1.772e-01, Total Error: 3.877e+01
# 50: Change in c_r: 2.928e-03, HNC Error: 1.768e-01, Total Error: 3.843e+01
# 51: Change in c_r: 2.924e-03, HNC Error: 1.764e-01, Total Error: 3.809e+01
# 52: Change in c_r: 2.920e-03, HNC Error: 1.760e-01, Total Error: 3.776e+01
# 53: Change in c_r: 2.916e-03, HNC Error: 1.756e-01, Total Error: 3.743e+01
# 54: Change in c_r: 2.912e-03, HNC Error: 1.753e-01, Total Error: 3.710e+01
# 55: Change in c_r: 2.909e-03, HNC Error: 1.750e-01, Total Error: 3.677e+01
# 56: Change in c_r: 2.905e-03, HNC Error: 1.747e-01, Total Error: 3.645e+01
# 57: Change in c_r: 2.901e-03, HNC Error: 1.745e-01, Total Error: 3.613e+01
# 58: Change in c_r: 2.897e-03, HNC Error: 1.742e-01, Total Error: 3.581e+01
# 59: Change in c_r: 2.894e-03, HNC Error: 1.740e-01, Total Error: 3.550e+01
# 60: Change in c_r: 2.890e-03, HNC Error: 1.739e-01, Total Error: 3.519e+01
# 61: Change in c_r: 2.886e-03, HNC Error: 1.737e-01, Total Error: 3.488e+01
# 62: Change in c_r: 2.883e-03, HNC Error: 1.736e-01, Total Error: 3.457e+01
# 63: Change in c_r: 2.879e-03, HNC Error: 1.734e-01, Total Error: 3.427e+01
# 64: Change in c_r: 2.875e-03, HNC Error: 1.733e-01, Total Error: 3.397e+01
# 65: Change in c_r: 2.872e-03, HNC Error: 1.733e-01, Total Error: 3.367e+01
# 66: Change in c_r: 2.868e-03, HNC Error: 1.732e-01, Total Error: 3.337e+01
# 67: Change in c_r: 2.865e-03, HNC Error: 1.732e-01, Total Error: 3.308e+01
# 68: Change in c_r: 2.861e-03, HNC Error: 1.732e-01, Total Error: 3.279e+01
# 69: Change in c_r: 2.858e-03, HNC Error: 1.732e-01, Total Error: 3.250e+01
# 70: Change in c_r: 2.854e-03, HNC Error: 1.732e-01, Total Error: 3.221e+01
# 71: Change in c_r: 2.850e-03, HNC Error: 1.733e-01, Total Error: 3.193e+01
# 72: Change in c_r: 2.847e-03, HNC Error: 1.734e-01, Total Error: 3.165e+01
# 73: Change in c_r: 2.843e-03, HNC Error: 1.734e-01, Total Error: 3.137e+01
# 74: Change in c_r: 2.840e-03, HNC Error: 1.735e-01, Total Error: 3.110e+01
# 75: Change in c_r: 2.837e-03, HNC Error: 1.737e-01, Total Error: 3.082e+01
# 76: Change in c_r: 2.833e-03, HNC Error: 1.738e-01, Total Error: 3.055e+01
# 77: Change in c_r: 2.830e-03, HNC Error: 1.740e-01, Total Error: 3.028e+01
# 78: Change in c_r: 2.826e-03, HNC Error: 1.741e-01, Total Error: 3.002e+01
# 79: Change in c_r: 2.823e-03, HNC Error: 1.743e-01, Total Error: 2.975e+01
# 80: Change in c_r: 2.819e-03, HNC Error: 1.746e-01, Total Error: 2.949e+01
# 81: Change in c_r: 2.816e-03, HNC Error: 1.748e-01, Total Error: 2.923e+01
# 82: Change in c_r: 2.813e-03, HNC Error: 1.750e-01, Total Error: 2.898e+01
# 83: Change in c_r: 2.809e-03, HNC Error: 1.753e-01, Total Error: 2.872e+01
# 84: Change in c_r: 2.806e-03, HNC Error: 1.756e-01, Total Error: 2.847e+01
# 85: Change in c_r: 2.803e-03, HNC Error: 1.759e-01, Total Error: 2.822e+01
# 86: Change in c_r: 2.799e-03, HNC Error: 1.762e-01, Total Error: 2.797e+01
# 87: Change in c_r: 2.796e-03, HNC Error: 1.765e-01, Total Error: 2.773e+01
# 88: Change in c_r: 2.793e-03, HNC Error: 1.768e-01, Total Error: 2.748e+01
# 89: Change in c_r: 2.789e-03, HNC Error: 1.772e-01, Total Error: 2.724e+01
# 90: Change in c_r: 2.786e-03, HNC Error: 1.775e-01, Total Error: 2.700e+01
# 91: Change in c_r: 2.783e-03, HNC Error: 1.779e-01, Total Error: 2.676e+01
# 92: Change in c_r: 2.780e-03, HNC Error: 1.783e-01, Total Error: 2.653e+01
# 93: Change in c_r: 2.776e-03, HNC Error: 1.787e-01, Total Error: 2.630e+01
# 94: Change in c_r: 2.773e-03, HNC Error: 1.791e-01, Total Error: 2.607e+01
# 95: Change in c_r: 2.770e-03, HNC Error: 1.796e-01, Total Error: 2.584e+01
# 96: Change in c_r: 2.767e-03, HNC Error: 1.800e-01, Total Error: 2.561e+01
# 97: Change in c_r: 2.764e-03, HNC Error: 1.805e-01, Total Error: 2.538e+01
# 98: Change in c_r: 2.760e-03, HNC Error: 1.810e-01, Total Error: 2.516e+01
# 99: Change in c_r: 2.757e-03, HNC Error: 1.815e-01, Total Error: 2.494e+01
# 100: Change in c_r: 2.754e-03, HNC Error: 1.820e-01, Total Error: 2.472e+01
# 101: Change in c_r: 2.751e-03, HNC Error: 1.825e-01, Total Error: 2.450e+01
# 102: Change in c_r: 2.748e-03, HNC Error: 1.830e-01, Total Error: 2.429e+01
# 103: Change in c_r: 2.745e-03, HNC Error: 1.836e-01, Total Error: 2.408e+01
# 104: Change in c_r: 2.742e-03, HNC Error: 1.841e-01, Total Error: 2.387e+01
# 105: Change in c_r: 2.739e-03, HNC Error: 1.847e-01, Total Error: 2.366e+01
# 106: Change in c_r: 2.736e-03, HNC Error: 1.853e-01, Total Error: 2.345e+01
# 107: Change in c_r: 2.733e-03, HNC Error: 1.858e-01, Total Error: 2.324e+01
# 108: Change in c_r: 2.730e-03, HNC Error: 1.864e-01, Total Error: 2.304e+01
# 109: Change in c_r: 2.726e-03, HNC Error: 1.871e-01, Total Error: 2.284e+01
# 110: Change in c_r: 2.723e-03, HNC Error: 1.877e-01, Total Error: 2.264e+01
# 111: Change in c_r: 2.720e-03, HNC Error: 1.883e-01, Total Error: 2.244e+01
# 112: Change in c_r: 2.717e-03, HNC Error: 1.890e-01, Total Error: 2.224e+01
# 113: Change in c_r: 2.714e-03, HNC Error: 1.896e-01, Total Error: 2.205e+01
# 114: Change in c_r: 2.712e-03, HNC Error: 1.903e-01, Total Error: 2.185e+01
# 115: Change in c_r: 2.709e-03, HNC Error: 1.910e-01, Total Error: 2.166e+01
# 116: Change in c_r: 2.706e-03, HNC Error: 1.917e-01, Total Error: 2.147e+01
# 117: Change in c_r: 2.703e-03, HNC Error: 1.924e-01, Total Error: 2.128e+01
# 118: Change in c_r: 2.700e-03, HNC Error: 1.931e-01, Total Error: 2.110e+01
# 119: Change in c_r: 2.697e-03, HNC Error: 1.938e-01, Total Error: 2.091e+01
# 120: Change in c_r: 2.694e-03, HNC Error: 1.945e-01, Total Error: 2.073e+01
# 121: Change in c_r: 2.691e-03, HNC Error: 1.953e-01, Total Error: 2.055e+01
# 122: Change in c_r: 2.688e-03, HNC Error: 1.960e-01, Total Error: 2.037e+01
# 123: Change in c_r: 2.685e-03, HNC Error: 1.968e-01, Total Error: 2.019e+01
# 124: Change in c_r: 2.682e-03, HNC Error: 1.976e-01, Total Error: 2.001e+01
# 125: Change in c_r: 2.680e-03, HNC Error: 1.984e-01, Total Error: 1.984e+01
# 126: Change in c_r: 2.677e-03, HNC Error: 1.992e-01, Total Error: 1.966e+01
# 127: Change in c_r: 2.674e-03, HNC Error: 2.000e-01, Total Error: 1.949e+01
# 128: Change in c_r: 2.671e-03, HNC Error: 2.008e-01, Total Error: 1.932e+01
# 129: Change in c_r: 2.668e-03, HNC Error: 2.016e-01, Total Error: 1.915e+01
# 130: Change in c_r: 2.665e-03, HNC Error: 2.025e-01, Total Error: 1.898e+01
# 131: Change in c_r: 2.663e-03, HNC Error: 2.033e-01, Total Error: 1.882e+01
# 132: Change in c_r: 2.660e-03, HNC Error: 2.042e-01, Total Error: 1.865e+01
# 133: Change in c_r: 2.657e-03, HNC Error: 2.050e-01, Total Error: 1.849e+01
# 134: Change in c_r: 2.654e-03, HNC Error: 2.059e-01, Total Error: 1.833e+01
# 135: Change in c_r: 2.652e-03, HNC Error: 2.068e-01, Total Error: 1.817e+01
# 136: Change in c_r: 2.649e-03, HNC Error: 2.077e-01, Total Error: 1.801e+01
# 137: Change in c_r: 2.646e-03, HNC Error: 2.086e-01, Total Error: 1.785e+01
# 138: Change in c_r: 2.643e-03, HNC Error: 2.095e-01, Total Error: 1.769e+01
# 139: Change in c_r: 2.641e-03, HNC Error: 2.104e-01, Total Error: 1.754e+01
# 140: Change in c_r: 2.638e-03, HNC Error: 2.114e-01, Total Error: 1.739e+01
# 141: Change in c_r: 2.635e-03, HNC Error: 2.123e-01, Total Error: 1.724e+01
# 142: Change in c_r: 2.633e-03, HNC Error: 2.132e-01, Total Error: 1.708e+01
# 143: Change in c_r: 2.630e-03, HNC Error: 2.142e-01, Total Error: 1.694e+01
# 144: Change in c_r: 2.627e-03, HNC Error: 2.152e-01, Total Error: 1.679e+01
# 145: Change in c_r: 2.625e-03, HNC Error: 2.161e-01, Total Error: 1.664e+01
# 146: Change in c_r: 2.622e-03, HNC Error: 2.171e-01, Total Error: 1.650e+01
# 147: Change in c_r: 2.620e-03, HNC Error: 2.181e-01, Total Error: 1.635e+01
# 148: Change in c_r: 2.617e-03, HNC Error: 2.191e-01, Total Error: 1.621e+01
# 149: Change in c_r: 2.614e-03, HNC Error: 2.201e-01, Total Error: 1.607e+01
# 150: Change in c_r: 2.612e-03, HNC Error: 2.212e-01, Total Error: 1.593e+01
# 151: Change in c_r: 2.609e-03, HNC Error: 2.222e-01, Total Error: 1.579e+01
# 152: Change in c_r: 2.606e-03, HNC Error: 2.232e-01, Total Error: 1.565e+01
# 153: Change in c_r: 2.604e-03, HNC Error: 2.243e-01, Total Error: 1.552e+01
# 154: Change in c_r: 2.601e-03, HNC Error: 2.253e-01, Total Error: 1.538e+01
# 155: Change in c_r: 2.599e-03, HNC Error: 2.264e-01, Total Error: 1.525e+01
# 156: Change in c_r: 2.596e-03, HNC Error: 2.275e-01, Total Error: 1.511e+01
# 157: Change in c_r: 2.594e-03, HNC Error: 2.285e-01, Total Error: 1.498e+01
# 158: Change in c_r: 2.591e-03, HNC Error: 2.296e-01, Total Error: 1.485e+01
# 159: Change in c_r: 2.589e-03, HNC Error: 2.307e-01, Total Error: 1.472e+01
# 160: Change in c_r: 2.586e-03, HNC Error: 2.318e-01, Total Error: 1.459e+01
# 161: Change in c_r: 2.584e-03, HNC Error: 2.330e-01, Total Error: 1.447e+01
# 162: Change in c_r: 2.581e-03, HNC Error: 2.341e-01, Total Error: 1.434e+01
# 163: Change in c_r: 2.579e-03, HNC Error: 2.352e-01, Total Error: 1.422e+01
# 164: Change in c_r: 2.576e-03, HNC Error: 2.363e-01, Total Error: 1.409e+01
# 165: Change in c_r: 2.574e-03, HNC Error: 2.375e-01, Total Error: 1.397e+01
# 166: Change in c_r: 2.571e-03, HNC Error: 2.386e-01, Total Error: 1.385e+01
# 167: Change in c_r: 2.569e-03, HNC Error: 2.398e-01, Total Error: 1.373e+01
# 168: Change in c_r: 2.566e-03, HNC Error: 2.410e-01, Total Error: 1.361e+01
# 169: Change in c_r: 2.564e-03, HNC Error: 2.422e-01, Total Error: 1.349e+01
# 170: Change in c_r: 2.561e-03, HNC Error: 2.433e-01, Total Error: 1.338e+01
# 171: Change in c_r: 2.559e-03, HNC Error: 2.445e-01, Total Error: 1.326e+01
# 172: Change in c_r: 2.557e-03, HNC Error: 2.457e-01, Total Error: 1.315e+01
# 173: Change in c_r: 2.554e-03, HNC Error: 2.470e-01, Total Error: 1.303e+01
# 174: Change in c_r: 2.552e-03, HNC Error: 2.482e-01, Total Error: 1.292e+01
# 175: Change in c_r: 2.549e-03, HNC Error: 2.494e-01, Total Error: 1.281e+01
# 176: Change in c_r: 2.547e-03, HNC Error: 2.506e-01, Total Error: 1.270e+01
# 177: Change in c_r: 2.545e-03, HNC Error: 2.519e-01, Total Error: 1.259e+01
# 178: Change in c_r: 2.542e-03, HNC Error: 2.531e-01, Total Error: 1.248e+01
# 179: Change in c_r: 2.540e-03, HNC Error: 2.544e-01, Total Error: 1.237e+01
# 180: Change in c_r: 2.538e-03, HNC Error: 2.557e-01, Total Error: 1.226e+01
# 181: Change in c_r: 2.535e-03, HNC Error: 2.569e-01, Total Error: 1.216e+01
# 182: Change in c_r: 2.533e-03, HNC Error: 2.582e-01, Total Error: 1.205e+01
# 183: Change in c_r: 2.531e-03, HNC Error: 2.595e-01, Total Error: 1.195e+01
# 184: Change in c_r: 2.528e-03, HNC Error: 2.608e-01, Total Error: 1.184e+01
# 185: Change in c_r: 2.526e-03, HNC Error: 2.621e-01, Total Error: 1.174e+01
# 186: Change in c_r: 2.524e-03, HNC Error: 2.634e-01, Total Error: 1.164e+01
# 187: Change in c_r: 2.521e-03, HNC Error: 2.647e-01, Total Error: 1.154e+01
# 188: Change in c_r: 2.519e-03, HNC Error: 2.661e-01, Total Error: 1.144e+01
# 189: Change in c_r: 2.517e-03, HNC Error: 2.674e-01, Total Error: 1.134e+01
# 190: Change in c_r: 2.514e-03, HNC Error: 2.687e-01, Total Error: 1.125e+01
# 191: Change in c_r: 2.512e-03, HNC Error: 2.701e-01, Total Error: 1.115e+01
# 192: Change in c_r: 2.510e-03, HNC Error: 2.714e-01, Total Error: 1.105e+01
# 193: Change in c_r: 2.508e-03, HNC Error: 2.728e-01, Total Error: 1.096e+01
# 194: Change in c_r: 2.505e-03, HNC Error: 2.742e-01, Total Error: 1.086e+01
# 195: Change in c_r: 2.503e-03, HNC Error: 2.756e-01, Total Error: 1.077e+01
# 196: Change in c_r: 2.501e-03, HNC Error: 2.770e-01, Total Error: 1.068e+01
# 197: Change in c_r: 2.499e-03, HNC Error: 2.783e-01, Total Error: 1.059e+01
# 198: Change in c_r: 2.496e-03, HNC Error: 2.797e-01, Total Error: 1.050e+01
# 199: Change in c_r: 2.494e-03, HNC Error: 2.812e-01, Total Error: 1.041e+01
# 200: Change in c_r: 2.492e-03, HNC Error: 2.826e-01, Total Error: 1.032e+01
# 201: Change in c_r: 2.490e-03, HNC Error: 2.840e-01, Total Error: 1.023e+01
# 202: Change in c_r: 2.487e-03, HNC Error: 2.854e-01, Total Error: 1.014e+01
# 203: Change in c_r: 2.485e-03, HNC Error: 2.869e-01, Total Error: 1.005e+01
# 204: Change in c_r: 2.483e-03, HNC Error: 2.883e-01, Total Error: 9.967e+00
# 205: Change in c_r: 2.481e-03, HNC Error: 2.898e-01, Total Error: 9.882e+00
# 206: Change in c_r: 2.479e-03, HNC Error: 2.912e-01, Total Error: 9.798e+00
# 207: Change in c_r: 2.476e-03, HNC Error: 2.927e-01, Total Error: 9.714e+00
# 208: Change in c_r: 2.474e-03, HNC Error: 2.942e-01, Total Error: 9.631e+00
# 209: Change in c_r: 2.472e-03, HNC Error: 2.957e-01, Total Error: 9.549e+00
# 210: Change in c_r: 2.470e-03, HNC Error: 2.972e-01, Total Error: 9.467e+00
# 211: Change in c_r: 2.468e-03, HNC Error: 2.987e-01, Total Error: 9.386e+00
# 212: Change in c_r: 2.466e-03, HNC Error: 3.002e-01, Total Error: 9.306e+00
# 213: Change in c_r: 2.463e-03, HNC Error: 3.017e-01, Total Error: 9.227e+00
# 214: Change in c_r: 2.461e-03, HNC Error: 3.032e-01, Total Error: 9.149e+00
# 215: Change in c_r: 2.459e-03, HNC Error: 3.047e-01, Total Error: 9.071e+00
# 216: Change in c_r: 2.457e-03, HNC Error: 3.063e-01, Total Error: 8.994e+00
# 217: Change in c_r: 2.455e-03, HNC Error: 3.078e-01, Total Error: 8.917e+00
# 218: Change in c_r: 2.453e-03, HNC Error: 3.094e-01, Total Error: 8.841e+00
# 219: Change in c_r: 2.451e-03, HNC Error: 3.109e-01, Total Error: 8.766e+00
# 220: Change in c_r: 2.448e-03, HNC Error: 3.125e-01, Total Error: 8.692e+00
# 221: Change in c_r: 2.446e-03, HNC Error: 3.141e-01, Total Error: 8.618e+00
# 222: Change in c_r: 2.444e-03, HNC Error: 3.156e-01, Total Error: 8.545e+00
# 223: Change in c_r: 2.442e-03, HNC Error: 3.172e-01, Total Error: 8.473e+00
# 224: Change in c_r: 2.440e-03, HNC Error: 3.188e-01, Total Error: 8.401e+00
# 225: Change in c_r: 2.438e-03, HNC Error: 3.204e-01, Total Error: 8.330e+00
# 226: Change in c_r: 2.436e-03, HNC Error: 3.220e-01, Total Error: 8.259e+00
# 227: Change in c_r: 2.434e-03, HNC Error: 3.236e-01, Total Error: 8.190e+00
# 228: Change in c_r: 2.432e-03, HNC Error: 3.253e-01, Total Error: 8.120e+00
# 229: Change in c_r: 2.430e-03, HNC Error: 3.269e-01, Total Error: 8.052e+00
# 230: Change in c_r: 2.427e-03, HNC Error: 3.285e-01, Total Error: 7.984e+00
# 231: Change in c_r: 2.425e-03, HNC Error: 3.302e-01, Total Error: 7.916e+00
# 232: Change in c_r: 2.423e-03, HNC Error: 3.318e-01, Total Error: 7.850e+00
# 233: Change in c_r: 2.421e-03, HNC Error: 3.335e-01, Total Error: 7.784e+00
# 234: Change in c_r: 2.419e-03, HNC Error: 3.351e-01, Total Error: 7.718e+00
# 235: Change in c_r: 2.417e-03, HNC Error: 3.368e-01, Total Error: 7.653e+00
# 236: Change in c_r: 2.415e-03, HNC Error: 3.385e-01, Total Error: 7.589e+00
# 237: Change in c_r: 2.413e-03, HNC Error: 3.402e-01, Total Error: 7.525e+00
# 238: Change in c_r: 2.411e-03, HNC Error: 3.419e-01, Total Error: 7.462e+00
# 239: Change in c_r: 2.409e-03, HNC Error: 3.436e-01, Total Error: 7.399e+00
# 240: Change in c_r: 2.407e-03, HNC Error: 3.453e-01, Total Error: 7.337e+00
# 241: Change in c_r: 2.405e-03, HNC Error: 3.470e-01, Total Error: 7.276e+00
# 242: Change in c_r: 2.403e-03, HNC Error: 3.487e-01, Total Error: 7.215e+00
# 243: Change in c_r: 2.401e-03, HNC Error: 3.505e-01, Total Error: 7.154e+00
# 244: Change in c_r: 2.399e-03, HNC Error: 3.522e-01, Total Error: 7.095e+00
# 245: Change in c_r: 2.397e-03, HNC Error: 3.539e-01, Total Error: 7.035e+00
# 246: Change in c_r: 2.395e-03, HNC Error: 3.557e-01, Total Error: 6.977e+00
# 247: Change in c_r: 2.393e-03, HNC Error: 3.574e-01, Total Error: 6.918e+00
# 248: Change in c_r: 2.391e-03, HNC Error: 3.592e-01, Total Error: 6.861e+00
# 249: Change in c_r: 2.389e-03, HNC Error: 3.610e-01, Total Error: 6.804e+00
# 250: Change in c_r: 2.387e-03, HNC Error: 3.628e-01, Total Error: 6.747e+00
# 251: Change in c_r: 2.385e-03, HNC Error: 3.645e-01, Total Error: 6.691e+00
# 252: Change in c_r: 2.383e-03, HNC Error: 3.663e-01, Total Error: 6.635e+00
# 253: Change in c_r: 2.381e-03, HNC Error: 3.681e-01, Total Error: 6.580e+00
# 254: Change in c_r: 2.379e-03, HNC Error: 3.699e-01, Total Error: 6.525e+00
# 255: Change in c_r: 2.377e-03, HNC Error: 3.718e-01, Total Error: 6.471e+00
# 256: Change in c_r: 2.375e-03, HNC Error: 3.736e-01, Total Error: 6.418e+00
# 257: Change in c_r: 2.373e-03, HNC Error: 3.754e-01, Total Error: 6.365e+00
# 258: Change in c_r: 2.371e-03, HNC Error: 3.772e-01, Total Error: 6.312e+00
# 259: Change in c_r: 2.369e-03, HNC Error: 3.791e-01, Total Error: 6.260e+00
# 260: Change in c_r: 2.367e-03, HNC Error: 3.809e-01, Total Error: 6.208e+00
# 261: Change in c_r: 2.365e-03, HNC Error: 3.828e-01, Total Error: 6.157e+00
# 262: Change in c_r: 2.363e-03, HNC Error: 3.847e-01, Total Error: 6.106e+00
# 263: Change in c_r: 2.361e-03, HNC Error: 3.865e-01, Total Error: 6.056e+00
# 264: Change in c_r: 2.359e-03, HNC Error: 3.884e-01, Total Error: 6.006e+00
# 265: Change in c_r: 2.357e-03, HNC Error: 3.903e-01, Total Error: 5.957e+00
# 266: Change in c_r: 2.355e-03, HNC Error: 3.922e-01, Total Error: 5.908e+00
# 267: Change in c_r: 2.353e-03, HNC Error: 3.941e-01, Total Error: 5.859e+00
# 268: Change in c_r: 2.351e-03, HNC Error: 3.960e-01, Total Error: 5.811e+00
# 269: Change in c_r: 2.349e-03, HNC Error: 3.979e-01, Total Error: 5.763e+00
# 270: Change in c_r: 2.347e-03, HNC Error: 3.998e-01, Total Error: 5.716e+00
# 271: Change in c_r: 2.345e-03, HNC Error: 4.017e-01, Total Error: 5.669e+00
# 272: Change in c_r: 2.343e-03, HNC Error: 4.037e-01, Total Error: 5.623e+00
# 273: Change in c_r: 2.342e-03, HNC Error: 4.056e-01, Total Error: 5.577e+00
# 274: Change in c_r: 2.340e-03, HNC Error: 4.075e-01, Total Error: 5.532e+00
# 275: Change in c_r: 2.338e-03, HNC Error: 4.095e-01, Total Error: 5.487e+00
# 276: Change in c_r: 2.336e-03, HNC Error: 4.115e-01, Total Error: 5.442e+00
# 277: Change in c_r: 2.334e-03, HNC Error: 4.134e-01, Total Error: 5.398e+00
# 278: Change in c_r: 2.332e-03, HNC Error: 4.154e-01, Total Error: 5.354e+00
# 279: Change in c_r: 2.330e-03, HNC Error: 4.174e-01, Total Error: 5.310e+00
# 280: Change in c_r: 2.328e-03, HNC Error: 4.194e-01, Total Error: 5.267e+00
# 281: Change in c_r: 2.326e-03, HNC Error: 4.214e-01, Total Error: 5.225e+00
# 282: Change in c_r: 2.324e-03, HNC Error: 4.234e-01, Total Error: 5.182e+00
# 283: Change in c_r: 2.322e-03, HNC Error: 4.254e-01, Total Error: 5.140e+00
# 284: Change in c_r: 2.320e-03, HNC Error: 4.274e-01, Total Error: 5.099e+00
# 285: Change in c_r: 2.318e-03, HNC Error: 4.294e-01, Total Error: 5.058e+00
# 286: Change in c_r: 2.317e-03, HNC Error: 4.314e-01, Total Error: 5.017e+00
# 287: Change in c_r: 2.315e-03, HNC Error: 4.335e-01, Total Error: 4.977e+00
# 288: Change in c_r: 2.313e-03, HNC Error: 4.355e-01, Total Error: 4.937e+00
# 289: Change in c_r: 2.311e-03, HNC Error: 4.375e-01, Total Error: 4.897e+00
# 290: Change in c_r: 2.309e-03, HNC Error: 4.396e-01, Total Error: 4.858e+00
# 291: Change in c_r: 2.307e-03, HNC Error: 4.417e-01, Total Error: 4.819e+00
# 292: Change in c_r: 2.305e-03, HNC Error: 4.437e-01, Total Error: 4.780e+00
# 293: Change in c_r: 2.303e-03, HNC Error: 4.458e-01, Total Error: 4.742e+00
# 294: Change in c_r: 2.301e-03, HNC Error: 4.479e-01, Total Error: 4.704e+00
# 295: Change in c_r: 2.299e-03, HNC Error: 4.500e-01, Total Error: 4.667e+00
# 296: Change in c_r: 2.298e-03, HNC Error: 4.521e-01, Total Error: 4.629e+00
# 297: Change in c_r: 2.296e-03, HNC Error: 4.542e-01, Total Error: 4.593e+00
# 298: Change in c_r: 2.294e-03, HNC Error: 4.563e-01, Total Error: 4.556e+00
# 299: Change in c_r: 2.292e-03, HNC Error: 4.584e-01, Total Error: 4.520e+00
# 300: Change in c_r: 2.290e-03, HNC Error: 4.605e-01, Total Error: 4.484e+00
# 301: Change in c_r: 2.288e-03, HNC Error: 4.626e-01, Total Error: 4.449e+00
# 302: Change in c_r: 2.286e-03, HNC Error: 4.648e-01, Total Error: 4.413e+00
# 303: Change in c_r: 2.284e-03, HNC Error: 4.669e-01, Total Error: 4.379e+00
# 304: Change in c_r: 2.282e-03, HNC Error: 4.691e-01, Total Error: 4.344e+00
# 305: Change in c_r: 2.280e-03, HNC Error: 4.712e-01, Total Error: 4.310e+00
# 306: Change in c_r: 2.279e-03, HNC Error: 4.734e-01, Total Error: 4.276e+00
# 307: Change in c_r: 2.277e-03, HNC Error: 4.755e-01, Total Error: 4.242e+00
# 308: Change in c_r: 2.275e-03, HNC Error: 4.777e-01, Total Error: 4.209e+00
# 309: Change in c_r: 2.273e-03, HNC Error: 4.799e-01, Total Error: 4.176e+00
# 310: Change in c_r: 2.271e-03, HNC Error: 4.821e-01, Total Error: 4.143e+00
# 311: Change in c_r: 2.269e-03, HNC Error: 4.843e-01, Total Error: 4.111e+00
# 312: Change in c_r: 2.267e-03, HNC Error: 4.865e-01, Total Error: 4.079e+00
# 313: Change in c_r: 2.265e-03, HNC Error: 4.887e-01, Total Error: 4.047e+00
# 314: Change in c_r: 2.264e-03, HNC Error: 4.909e-01, Total Error: 4.016e+00
# 315: Change in c_r: 2.262e-03, HNC Error: 4.931e-01, Total Error: 3.985e+00
# 316: Change in c_r: 2.260e-03, HNC Error: 4.953e-01, Total Error: 3.954e+00
# 317: Change in c_r: 2.258e-03, HNC Error: 4.976e-01, Total Error: 3.923e+00
# 318: Change in c_r: 2.256e-03, HNC Error: 4.998e-01, Total Error: 3.893e+00
# 319: Change in c_r: 2.254e-03, HNC Error: 5.021e-01, Total Error: 3.863e+00
# 320: Change in c_r: 2.252e-03, HNC Error: 5.043e-01, Total Error: 3.833e+00
# 321: Change in c_r: 2.250e-03, HNC Error: 5.066e-01, Total Error: 3.803e+00
# 322: Change in c_r: 2.249e-03, HNC Error: 5.088e-01, Total Error: 3.774e+00
# 323: Change in c_r: 2.247e-03, HNC Error: 5.111e-01, Total Error: 3.745e+00
# 324: Change in c_r: 2.245e-03, HNC Error: 5.134e-01, Total Error: 3.717e+00
# 325: Change in c_r: 2.243e-03, HNC Error: 5.157e-01, Total Error: 3.688e+00
# 326: Change in c_r: 2.241e-03, HNC Error: 5.180e-01, Total Error: 3.660e+00
# 327: Change in c_r: 2.239e-03, HNC Error: 5.203e-01, Total Error: 3.632e+00
# 328: Change in c_r: 2.237e-03, HNC Error: 5.226e-01, Total Error: 3.605e+00
# 329: Change in c_r: 2.235e-03, HNC Error: 5.249e-01, Total Error: 3.577e+00
# 330: Change in c_r: 2.234e-03, HNC Error: 5.272e-01, Total Error: 3.550e+00
# 331: Change in c_r: 2.232e-03, HNC Error: 5.295e-01, Total Error: 3.523e+00
# 332: Change in c_r: 2.230e-03, HNC Error: 5.318e-01, Total Error: 3.497e+00
# 333: Change in c_r: 2.228e-03, HNC Error: 5.342e-01, Total Error: 3.470e+00
# 334: Change in c_r: 2.226e-03, HNC Error: 5.365e-01, Total Error: 3.444e+00
# 335: Change in c_r: 2.224e-03, HNC Error: 5.389e-01, Total Error: 3.418e+00
# 336: Change in c_r: 2.222e-03, HNC Error: 5.412e-01, Total Error: 3.393e+00
# 337: Change in c_r: 2.221e-03, HNC Error: 5.436e-01, Total Error: 3.367e+00
# 338: Change in c_r: 2.219e-03, HNC Error: 5.459e-01, Total Error: 3.342e+00
# 339: Change in c_r: 2.217e-03, HNC Error: 5.483e-01, Total Error: 3.317e+00
# 340: Change in c_r: 2.215e-03, HNC Error: 5.507e-01, Total Error: 3.293e+00
# 341: Change in c_r: 2.213e-03, HNC Error: 5.531e-01, Total Error: 3.268e+00
# 342: Change in c_r: 2.211e-03, HNC Error: 5.555e-01, Total Error: 3.244e+00
# 343: Change in c_r: 2.209e-03, HNC Error: 5.579e-01, Total Error: 3.220e+00
# 344: Change in c_r: 2.208e-03, HNC Error: 5.603e-01, Total Error: 3.196e+00
# 345: Change in c_r: 2.206e-03, HNC Error: 5.627e-01, Total Error: 3.173e+00
# 346: Change in c_r: 2.204e-03, HNC Error: 5.651e-01, Total Error: 3.150e+00
# 347: Change in c_r: 2.202e-03, HNC Error: 5.675e-01, Total Error: 3.127e+00
# 348: Change in c_r: 2.200e-03, HNC Error: 5.700e-01, Total Error: 3.104e+00
# 349: Change in c_r: 2.198e-03, HNC Error: 5.724e-01, Total Error: 3.081e+00
# 350: Change in c_r: 2.196e-03, HNC Error: 5.749e-01, Total Error: 3.059e+00
# 351: Change in c_r: 2.194e-03, HNC Error: 5.773e-01, Total Error: 3.037e+00
# 352: Change in c_r: 2.193e-03, HNC Error: 5.798e-01, Total Error: 3.015e+00
# 353: Change in c_r: 2.191e-03, HNC Error: 5.822e-01, Total Error: 2.993e+00
# 354: Change in c_r: 2.189e-03, HNC Error: 5.847e-01, Total Error: 2.971e+00
# 355: Change in c_r: 2.187e-03, HNC Error: 5.872e-01, Total Error: 2.950e+00
# 356: Change in c_r: 2.185e-03, HNC Error: 5.896e-01, Total Error: 2.929e+00
# 357: Change in c_r: 2.183e-03, HNC Error: 5.921e-01, Total Error: 2.908e+00
# 358: Change in c_r: 2.181e-03, HNC Error: 5.946e-01, Total Error: 2.887e+00
# 359: Change in c_r: 2.180e-03, HNC Error: 5.971e-01, Total Error: 2.866e+00
# 360: Change in c_r: 2.178e-03, HNC Error: 5.996e-01, Total Error: 2.846e+00
# 361: Change in c_r: 2.176e-03, HNC Error: 6.021e-01, Total Error: 2.826e+00
# 362: Change in c_r: 2.174e-03, HNC Error: 6.047e-01, Total Error: 2.806e+00
# 363: Change in c_r: 2.172e-03, HNC Error: 6.072e-01, Total Error: 2.786e+00
# 364: Change in c_r: 2.170e-03, HNC Error: 6.097e-01, Total Error: 2.767e+00
# 365: Change in c_r: 2.168e-03, HNC Error: 6.123e-01, Total Error: 2.747e+00
# 366: Change in c_r: 2.166e-03, HNC Error: 6.148e-01, Total Error: 2.728e+00
# 367: Change in c_r: 2.165e-03, HNC Error: 6.174e-01, Total Error: 2.709e+00
# 368: Change in c_r: 2.163e-03, HNC Error: 6.199e-01, Total Error: 2.690e+00
# 369: Change in c_r: 2.161e-03, HNC Error: 6.225e-01, Total Error: 2.672e+00
# 370: Change in c_r: 2.159e-03, HNC Error: 6.250e-01, Total Error: 2.653e+00
# 371: Change in c_r: 2.157e-03, HNC Error: 6.276e-01, Total Error: 2.635e+00
# 372: Change in c_r: 2.155e-03, HNC Error: 6.302e-01, Total Error: 2.617e+00
# 373: Change in c_r: 2.153e-03, HNC Error: 6.328e-01, Total Error: 2.599e+00
# 374: Change in c_r: 2.152e-03, HNC Error: 6.354e-01, Total Error: 2.581e+00
# 375: Change in c_r: 2.150e-03, HNC Error: 6.380e-01, Total Error: 2.564e+00
# 376: Change in c_r: 2.148e-03, HNC Error: 6.406e-01, Total Error: 2.547e+00
# 377: Change in c_r: 2.146e-03, HNC Error: 6.432e-01, Total Error: 2.529e+00
# 378: Change in c_r: 2.144e-03, HNC Error: 6.458e-01, Total Error: 2.512e+00
# 379: Change in c_r: 2.142e-03, HNC Error: 6.484e-01, Total Error: 2.496e+00
# 380: Change in c_r: 2.140e-03, HNC Error: 6.511e-01, Total Error: 2.479e+00
# 381: Change in c_r: 2.138e-03, HNC Error: 6.537e-01, Total Error: 2.462e+00
# 382: Change in c_r: 2.137e-03, HNC Error: 6.564e-01, Total Error: 2.446e+00
# 383: Change in c_r: 2.135e-03, HNC Error: 6.590e-01, Total Error: 2.430e+00
# 384: Change in c_r: 2.133e-03, HNC Error: 6.617e-01, Total Error: 2.414e+00
# 385: Change in c_r: 2.131e-03, HNC Error: 6.643e-01, Total Error: 2.398e+00
# 386: Change in c_r: 2.129e-03, HNC Error: 6.670e-01, Total Error: 2.382e+00
# 387: Change in c_r: 2.127e-03, HNC Error: 6.697e-01, Total Error: 2.367e+00
# 388: Change in c_r: 2.125e-03, HNC Error: 6.724e-01, Total Error: 2.352e+00
# 389: Change in c_r: 2.123e-03, HNC Error: 6.751e-01, Total Error: 2.336e+00
# 390: Change in c_r: 2.122e-03, HNC Error: 6.778e-01, Total Error: 2.321e+00
# 391: Change in c_r: 2.120e-03, HNC Error: 6.805e-01, Total Error: 2.307e+00
# 392: Change in c_r: 2.118e-03, HNC Error: 6.832e-01, Total Error: 2.292e+00
# 393: Change in c_r: 2.116e-03, HNC Error: 6.859e-01, Total Error: 2.277e+00
# 394: Change in c_r: 2.114e-03, HNC Error: 6.886e-01, Total Error: 2.263e+00
# 395: Change in c_r: 2.112e-03, HNC Error: 6.913e-01, Total Error: 2.249e+00
# 396: Change in c_r: 2.110e-03, HNC Error: 6.941e-01, Total Error: 2.235e+00
# 397: Change in c_r: 2.108e-03, HNC Error: 6.968e-01, Total Error: 2.221e+00
# 398: Change in c_r: 2.107e-03, HNC Error: 6.996e-01, Total Error: 2.207e+00
# 399: Change in c_r: 2.105e-03, HNC Error: 7.023e-01, Total Error: 2.193e+00
# 400: Change in c_r: 2.103e-03, HNC Error: 7.051e-01, Total Error: 2.180e+00
# 401: Change in c_r: 2.101e-03, HNC Error: 7.078e-01, Total Error: 2.166e+00
# 402: Change in c_r: 2.099e-03, HNC Error: 7.106e-01, Total Error: 2.153e+00
# 403: Change in c_r: 2.097e-03, HNC Error: 7.134e-01, Total Error: 2.140e+00
# 404: Change in c_r: 2.095e-03, HNC Error: 7.162e-01, Total Error: 2.127e+00
# 405: Change in c_r: 2.093e-03, HNC Error: 7.190e-01, Total Error: 2.114e+00
# 406: Change in c_r: 2.092e-03, HNC Error: 7.218e-01, Total Error: 2.102e+00
# 407: Change in c_r: 2.090e-03, HNC Error: 7.246e-01, Total Error: 2.089e+00
# 408: Change in c_r: 2.088e-03, HNC Error: 7.274e-01, Total Error: 2.077e+00
# 409: Change in c_r: 2.086e-03, HNC Error: 7.302e-01, Total Error: 2.065e+00
# 410: Change in c_r: 2.084e-03, HNC Error: 7.331e-01, Total Error: 2.053e+00
# 411: Change in c_r: 2.082e-03, HNC Error: 7.359e-01, Total Error: 2.041e+00
# 412: Change in c_r: 2.080e-03, HNC Error: 7.387e-01, Total Error: 2.029e+00
# 413: Change in c_r: 2.078e-03, HNC Error: 7.416e-01, Total Error: 2.017e+00
# 414: Change in c_r: 2.076e-03, HNC Error: 7.444e-01, Total Error: 2.006e+00
# 415: Change in c_r: 2.075e-03, HNC Error: 7.473e-01, Total Error: 1.994e+00
# 416: Change in c_r: 2.073e-03, HNC Error: 7.502e-01, Total Error: 1.983e+00
# 417: Change in c_r: 2.071e-03, HNC Error: 7.530e-01, Total Error: 1.972e+00
# 418: Change in c_r: 2.069e-03, HNC Error: 7.559e-01, Total Error: 1.961e+00
# 419: Change in c_r: 2.067e-03, HNC Error: 7.588e-01, Total Error: 1.950e+00
# 420: Change in c_r: 2.065e-03, HNC Error: 7.617e-01, Total Error: 1.939e+00
# 421: Change in c_r: 2.063e-03, HNC Error: 7.646e-01, Total Error: 1.929e+00
# 422: Change in c_r: 2.061e-03, HNC Error: 7.675e-01, Total Error: 1.918e+00
# 423: Change in c_r: 2.059e-03, HNC Error: 7.705e-01, Total Error: 1.908e+00
# 424: Change in c_r: 2.057e-03, HNC Error: 7.734e-01, Total Error: 1.897e+00
# 425: Change in c_r: 2.056e-03, HNC Error: 7.763e-01, Total Error: 1.887e+00
# 426: Change in c_r: 2.054e-03, HNC Error: 7.793e-01, Total Error: 1.877e+00
# 427: Change in c_r: 2.052e-03, HNC Error: 7.822e-01, Total Error: 1.868e+00
# 428: Change in c_r: 2.050e-03, HNC Error: 7.852e-01, Total Error: 1.858e+00
# 429: Change in c_r: 2.048e-03, HNC Error: 7.881e-01, Total Error: 1.848e+00
# 430: Change in c_r: 2.046e-03, HNC Error: 7.911e-01, Total Error: 1.839e+00
# 431: Change in c_r: 2.044e-03, HNC Error: 7.941e-01, Total Error: 1.829e+00
# 432: Change in c_r: 2.042e-03, HNC Error: 7.971e-01, Total Error: 1.820e+00
# 433: Change in c_r: 2.040e-03, HNC Error: 8.001e-01, Total Error: 1.811e+00
# 434: Change in c_r: 2.038e-03, HNC Error: 8.031e-01, Total Error: 1.802e+00
# 435: Change in c_r: 2.036e-03, HNC Error: 8.061e-01, Total Error: 1.793e+00
# 436: Change in c_r: 2.035e-03, HNC Error: 8.091e-01, Total Error: 1.784e+00
# 437: Change in c_r: 2.033e-03, HNC Error: 8.121e-01, Total Error: 1.775e+00
# 438: Change in c_r: 2.031e-03, HNC Error: 8.152e-01, Total Error: 1.767e+00
# 439: Change in c_r: 2.029e-03, HNC Error: 8.182e-01, Total Error: 1.758e+00
# 440: Change in c_r: 2.027e-03, HNC Error: 8.213e-01, Total Error: 1.750e+00
# 441: Change in c_r: 2.025e-03, HNC Error: 8.243e-01, Total Error: 1.742e+00
# 442: Change in c_r: 2.023e-03, HNC Error: 8.274e-01, Total Error: 1.734e+00
# 443: Change in c_r: 2.021e-03, HNC Error: 8.305e-01, Total Error: 1.726e+00
# 444: Change in c_r: 2.019e-03, HNC Error: 8.336e-01, Total Error: 1.718e+00
# 445: Change in c_r: 2.017e-03, HNC Error: 8.367e-01, Total Error: 1.710e+00
# 446: Change in c_r: 2.015e-03, HNC Error: 8.398e-01, Total Error: 1.703e+00
# 447: Change in c_r: 2.014e-03, HNC Error: 8.429e-01, Total Error: 1.695e+00
# 448: Change in c_r: 2.012e-03, HNC Error: 8.460e-01, Total Error: 1.688e+00
# 449: Change in c_r: 2.010e-03, HNC Error: 8.491e-01, Total Error: 1.680e+00
# 450: Change in c_r: 2.008e-03, HNC Error: 8.523e-01, Total Error: 1.673e+00
# 451: Change in c_r: 2.006e-03, HNC Error: 8.554e-01, Total Error: 1.666e+00
# 452: Change in c_r: 2.004e-03, HNC Error: 8.586e-01, Total Error: 1.659e+00
# 453: Change in c_r: 2.002e-03, HNC Error: 8.618e-01, Total Error: 1.652e+00
# 454: Change in c_r: 2.000e-03, HNC Error: 8.649e-01, Total Error: 1.645e+00
# 455: Change in c_r: 1.998e-03, HNC Error: 8.681e-01, Total Error: 1.639e+00
# 456: Change in c_r: 1.996e-03, HNC Error: 8.713e-01, Total Error: 1.632e+00
# 457: Change in c_r: 1.994e-03, HNC Error: 8.745e-01, Total Error: 1.626e+00
# 458: Change in c_r: 1.992e-03, HNC Error: 8.778e-01, Total Error: 1.619e+00
# 459: Change in c_r: 1.990e-03, HNC Error: 8.810e-01, Total Error: 1.613e+00
# 460: Change in c_r: 1.988e-03, HNC Error: 8.842e-01, Total Error: 1.607e+00
# 461: Change in c_r: 1.987e-03, HNC Error: 8.875e-01, Total Error: 1.601e+00
# 462: Change in c_r: 1.985e-03, HNC Error: 8.907e-01, Total Error: 1.595e+00
# 463: Change in c_r: 1.983e-03, HNC Error: 8.940e-01, Total Error: 1.589e+00
# 464: Change in c_r: 1.981e-03, HNC Error: 8.973e-01, Total Error: 1.583e+00
# 465: Change in c_r: 1.979e-03, HNC Error: 9.006e-01, Total Error: 1.578e+00
# 466: Change in c_r: 1.977e-03, HNC Error: 9.039e-01, Total Error: 1.572e+00
# 467: Change in c_r: 1.975e-03, HNC Error: 9.072e-01, Total Error: 1.567e+00
# 468: Change in c_r: 1.973e-03, HNC Error: 9.105e-01, Total Error: 1.561e+00
# 469: Change in c_r: 1.971e-03, HNC Error: 9.139e-01, Total Error: 1.556e+00
# 470: Change in c_r: 1.969e-03, HNC Error: 9.172e-01, Total Error: 1.551e+00
# 471: Change in c_r: 1.967e-03, HNC Error: 9.206e-01, Total Error: 1.546e+00
# 472: Change in c_r: 1.965e-03, HNC Error: 9.239e-01, Total Error: 1.541e+00
# 473: Change in c_r: 1.963e-03, HNC Error: 9.273e-01, Total Error: 1.536e+00
# 474: Change in c_r: 1.961e-03, HNC Error: 9.307e-01, Total Error: 1.531e+00
# 475: Change in c_r: 1.959e-03, HNC Error: 9.341e-01, Total Error: 1.526e+00
# 476: Change in c_r: 1.957e-03, HNC Error: 9.376e-01, Total Error: 1.522e+00
# 477: Change in c_r: 1.956e-03, HNC Error: 9.410e-01, Total Error: 1.517e+00
# 478: Change in c_r: 1.954e-03, HNC Error: 9.444e-01, Total Error: 1.513e+00
# 479: Change in c_r: 1.952e-03, HNC Error: 9.479e-01, Total Error: 1.509e+00
# 480: Change in c_r: 1.950e-03, HNC Error: 9.514e-01, Total Error: 1.504e+00
# 481: Change in c_r: 1.948e-03, HNC Error: 9.549e-01, Total Error: 1.500e+00
# 482: Change in c_r: 1.946e-03, HNC Error: 9.584e-01, Total Error: 1.496e+00
# 483: Change in c_r: 1.944e-03, HNC Error: 9.619e-01, Total Error: 1.492e+00
# 484: Change in c_r: 1.942e-03, HNC Error: 9.654e-01, Total Error: 1.489e+00
# 485: Change in c_r: 1.940e-03, HNC Error: 9.690e-01, Total Error: 1.485e+00
# 486: Change in c_r: 1.938e-03, HNC Error: 9.725e-01, Total Error: 1.481e+00
# 487: Change in c_r: 1.936e-03, HNC Error: 9.761e-01, Total Error: 1.478e+00
# 488: Change in c_r: 1.934e-03, HNC Error: 9.797e-01, Total Error: 1.474e+00
# 489: Change in c_r: 1.932e-03, HNC Error: 9.833e-01, Total Error: 1.471e+00
# 490: Change in c_r: 1.930e-03, HNC Error: 9.869e-01, Total Error: 1.468e+00
# 491: Change in c_r: 1.928e-03, HNC Error: 9.906e-01, Total Error: 1.464e+00
# 492: Change in c_r: 1.926e-03, HNC Error: 9.942e-01, Total Error: 1.461e+00
# 493: Change in c_r: 1.924e-03, HNC Error: 9.979e-01, Total Error: 1.458e+00
# 494: Change in c_r: 1.922e-03, HNC Error: 1.002e+00, Total Error: 1.455e+00
# 495: Change in c_r: 1.920e-03, HNC Error: 1.005e+00, Total Error: 1.453e+00
# 496: Change in c_r: 1.918e-03, HNC Error: 1.009e+00, Total Error: 1.450e+00
# 497: Change in c_r: 1.916e-03, HNC Error: 1.013e+00, Total Error: 1.447e+00
# 498: Change in c_r: 1.915e-03, HNC Error: 1.017e+00, Total Error: 1.445e+00
# 499: Change in c_r: 1.913e-03, HNC Error: 1.020e+00, Total Error: 1.442e+00
# 500: Change in c_r: 1.911e-03, HNC Error: 1.024e+00, Total Error: 1.440e+00
# 501: Change in c_r: 1.909e-03, HNC Error: 1.028e+00, Total Error: 1.437e+00
# 502: Change in c_r: 1.907e-03, HNC Error: 1.032e+00, Total Error: 1.435e+00
# 503: Change in c_r: 1.905e-03, HNC Error: 1.036e+00, Total Error: 1.433e+00
# 504: Change in c_r: 1.903e-03, HNC Error: 1.039e+00, Total Error: 1.431e+00
# 505: Change in c_r: 1.901e-03, HNC Error: 1.043e+00, Total Error: 1.429e+00
# 506: Change in c_r: 1.899e-03, HNC Error: 1.047e+00, Total Error: 1.427e+00
# 507: Change in c_r: 1.897e-03, HNC Error: 1.051e+00, Total Error: 1.425e+00
# 508: Change in c_r: 1.895e-03, HNC Error: 1.055e+00, Total Error: 1.424e+00
# 509: Change in c_r: 1.893e-03, HNC Error: 1.059e+00, Total Error: 1.422e+00
# 510: Change in c_r: 1.891e-03, HNC Error: 1.063e+00, Total Error: 1.421e+00
# 511: Change in c_r: 1.889e-03, HNC Error: 1.067e+00, Total Error: 1.419e+00
# 512: Change in c_r: 1.887e-03, HNC Error: 1.071e+00, Total Error: 1.418e+00
# 513: Change in c_r: 1.885e-03, HNC Error: 1.075e+00, Total Error: 1.417e+00
# 514: Change in c_r: 1.883e-03, HNC Error: 1.079e+00, Total Error: 1.415e+00
# 515: Change in c_r: 1.881e-03, HNC Error: 1.084e+00, Total Error: 1.414e+00
# 516: Change in c_r: 1.879e-03, HNC Error: 1.088e+00, Total Error: 1.413e+00
# 517: Change in c_r: 1.877e-03, HNC Error: 1.092e+00, Total Error: 1.412e+00
# 518: Change in c_r: 1.875e-03, HNC Error: 1.096e+00, Total Error: 1.412e+00
# 519: Change in c_r: 1.873e-03, HNC Error: 1.100e+00, Total Error: 1.411e+00
# 520: Change in c_r: 1.871e-03, HNC Error: 1.105e+00, Total Error: 1.410e+00
# 521: Change in c_r: 1.869e-03, HNC Error: 1.109e+00, Total Error: 1.410e+00
# 522: Change in c_r: 1.867e-03, HNC Error: 1.113e+00, Total Error: 1.409e+00
# 523: Change in c_r: 1.865e-03, HNC Error: 1.118e+00, Total Error: 1.409e+00
# 524: Change in c_r: 1.863e-03, HNC Error: 1.122e+00, Total Error: 1.409e+00
# 525: Change in c_r: 1.861e-03, HNC Error: 1.126e+00, Total Error: 1.408e+00
# 526: Change in c_r: 1.859e-03, HNC Error: 1.131e+00, Total Error: 1.408e+00
# 527: Change in c_r: 1.857e-03, HNC Error: 1.135e+00, Total Error: 1.408e+00
# 528: Change in c_r: 1.855e-03, HNC Error: 1.140e+00, Total Error: 1.408e+00
# 529: Change in c_r: 1.853e-03, HNC Error: 1.144e+00, Total Error: 1.408e+00
# 530: Change in c_r: 1.851e-03, HNC Error: 1.149e+00, Total Error: 1.409e+00
# 531: Change in c_r: 1.849e-03, HNC Error: 1.154e+00, Total Error: 1.409e+00
# 532: Change in c_r: 1.847e-03, HNC Error: 1.158e+00, Total Error: 1.409e+00
# 533: Change in c_r: 1.845e-03, HNC Error: 1.163e+00, Total Error: 1.410e+00
# 534: Change in c_r: 1.843e-03, HNC Error: 1.168e+00, Total Error: 1.411e+00
# 535: Change in c_r: 1.841e-03, HNC Error: 1.173e+00, Total Error: 1.411e+00
# 536: Change in c_r: 1.839e-03, HNC Error: 1.177e+00, Total Error: 1.412e+00
# QUIT: Last 10 iterations error has been increasing
# Exiting status 2, reverting to best index so far: 527
# Final iter:536, Total Error: 1.408e+00
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.2659e+01                                    8.93e+00
#        1              5         1.6771e+01      5.89e+00       5.07e-01       5.25e+00
#        2              7         1.4479e+01      2.29e+00       2.53e-01       5.33e+00
#        3              8         1.1209e+01      3.27e+00       5.07e-01       1.40e+01
#        4             10         9.3801e+00      1.83e+00       2.53e-01       6.07e+00
#        5             11         7.9265e+00      1.45e+00       2.53e-01       2.88e+00
#        6             12         5.5857e+00      2.34e+00       5.07e-01       1.88e+01
#        7             14         4.1238e+00      1.46e+00       2.53e-01       1.18e+01
#        8             16         3.6426e+00      4.81e-01       1.27e-01       8.88e+00
#        9             17         3.2941e+00      3.48e-01       1.27e-01       2.99e+00
#       10             19         3.1487e+00      1.45e-01       6.33e-02       2.61e+00
#       11             20         2.9072e+00      2.42e-01       1.27e-01       1.51e+00
#       12             21         2.7701e+00      1.37e-01       2.53e-01       2.26e+01
#       13             23         2.4996e+00      2.71e-01       6.33e-02       4.92e+00
#       14             24         2.3853e+00      1.14e-01       6.33e-02       6.93e-01
#       15             25         2.2280e+00      1.57e-01       1.27e-01       7.67e-01
#       16             26         1.9917e+00      2.36e-01       2.53e-01       6.52e+00
#       17             28         1.9192e+00      7.24e-02       1.27e-01       7.12e+00
#       18             30         1.8375e+00      8.17e-02       3.17e-02       1.23e+00
#       19             31         1.7783e+00      5.92e-02       6.33e-02       6.95e-01
#       20             32         1.6700e+00      1.08e-01       1.27e-01       6.22e-01
#       21             33         1.4914e+00      1.79e-01       2.53e-01       4.51e+00
#       22             34         1.2935e+00      1.98e-01       5.07e-01       1.28e+01
#       23             36         1.2146e+00      7.89e-02       1.27e-01       1.66e+01
#       24             37         1.0771e+00      1.37e-01       1.27e-01       4.07e+00
#       25             38         9.7397e-01      1.03e-01       2.53e-01       4.57e+00
#       26             39         8.4321e-01      1.31e-01       5.07e-01       4.69e+00
#       27             41         8.0967e-01      3.35e-02       2.53e-01       5.77e+00
#       28             43         7.9204e-01      1.76e-02       6.33e-02       1.08e+00
#       29             44         7.8568e-01      6.36e-03       6.33e-02       1.87e-01
#       30             45         7.8043e-01      5.25e-03       1.27e-01       5.16e-01
#       31             47         7.7536e-01      5.07e-03       3.17e-02       1.28e-01
#       32             48         7.7312e-01      2.24e-03       3.17e-02       5.71e-02
#       33             49         7.6929e-01      3.83e-03       6.33e-02       2.81e-02
#       34             50         7.6553e-01      3.76e-03       1.27e-01       4.15e-01
#       35             52         7.6179e-01      3.74e-03       3.17e-02       9.97e-02
#       36             53         7.6010e-01      1.69e-03       3.17e-02       2.80e-02
#       37             54         7.5699e-01      3.11e-03       6.33e-02       5.51e-02
#       38             55         7.5410e-01      2.89e-03       1.27e-01       2.45e-01
#       39             57         7.5064e-01      3.46e-03       3.17e-02       1.93e-01
#       40             58         7.4899e-01      1.65e-03       3.17e-02       3.34e-02
#       41             59         7.4603e-01      2.96e-03       6.33e-02       2.95e-02
#       42             60         7.4282e-01      3.21e-03       1.27e-01       4.15e-01
#       43             62         7.3967e-01      3.15e-03       3.17e-02       9.30e-02
#       44             63         7.3809e-01      1.58e-03       3.17e-02       2.90e-02
#       45             64         7.3505e-01      3.03e-03       6.33e-02       2.89e-02
#       46             65         7.2934e-01      5.71e-03       1.27e-01       2.86e-02
#       47             66         7.2716e-01      2.18e-03       2.53e-01       1.35e+00
#       48             67         7.1771e-01      9.45e-03       6.33e-02       6.18e-01
#       49             68         7.1471e-01      3.01e-03       6.33e-02       4.17e-02
#       50             69         7.1274e-01      1.97e-03       1.27e-01       3.31e-01
#       51             71         7.0893e-01      3.81e-03       3.17e-02       1.69e-01
#       52             72         7.0750e-01      1.43e-03       3.17e-02       4.73e-02
#       53             73         7.0516e-01      2.34e-03       6.33e-02       3.25e-02
#       54             74         7.0442e-01      7.36e-04       6.33e-02       3.64e-01
#       55             75         7.0259e-01      1.83e-03       1.58e-02       2.71e-02
#       56             76         7.0141e-01      1.18e-03       3.17e-02       3.07e-02
#       57             77         7.0024e-01      1.17e-03       3.17e-02       8.09e-02
#       58             78         6.9909e-01      1.15e-03       3.17e-02       2.73e-02
#       59             79         6.9795e-01      1.14e-03       3.17e-02       8.66e-02
#       60             80         6.9683e-01      1.12e-03       3.17e-02       3.35e-02
#       61             81         6.9572e-01      1.12e-03       3.17e-02       9.13e-02
#       62             82         6.9461e-01      1.11e-03       3.17e-02       3.58e-02
#       63             83         6.9351e-01      1.10e-03       3.17e-02       9.10e-02
#       64             84         6.9241e-01      1.10e-03       3.17e-02       3.91e-02
#       65             85         6.9131e-01      1.09e-03       3.17e-02       9.39e-02
#       66             86         6.9022e-01      1.09e-03       3.17e-02       4.06e-02
#       67             87         6.8914e-01      1.09e-03       3.17e-02       9.47e-02
#       68             88         6.8805e-01      1.08e-03       3.17e-02       4.07e-02
#       69             89         6.8697e-01      1.08e-03       3.17e-02       9.46e-02
#       70             90         6.8590e-01      1.08e-03       3.17e-02       4.25e-02
#       71             91         6.8482e-01      1.08e-03       3.17e-02       9.47e-02
#       72             92         6.8375e-01      1.07e-03       3.17e-02       4.17e-02
#       73             93         6.8268e-01      1.07e-03       3.17e-02       9.62e-02
#       74             94         6.8161e-01      1.07e-03       3.17e-02       4.24e-02
#       75             95         6.8055e-01      1.06e-03       3.17e-02       9.63e-02
#       76             96         6.7948e-01      1.06e-03       3.17e-02       4.28e-02
#       77             97         6.7843e-01      1.06e-03       3.17e-02       9.57e-02
#       78             98         6.7737e-01      1.06e-03       3.17e-02       4.25e-02
#       79             99         6.7631e-01      1.05e-03       3.17e-02       9.67e-02
#       80             100        6.7526e-01      1.05e-03       3.17e-02       4.34e-02
#       81             101        6.7421e-01      1.05e-03       3.17e-02       9.60e-02
#       82             102        6.7317e-01      1.05e-03       3.17e-02       4.28e-02
#       83             103        6.7212e-01      1.04e-03       3.17e-02       9.65e-02
#       84             104        6.7108e-01      1.04e-03       3.17e-02       4.27e-02
#       85             105        6.7004e-01      1.04e-03       3.17e-02       9.73e-02
#       86             106        6.6900e-01      1.04e-03       3.17e-02       4.22e-02
#       87             107        6.6797e-01      1.03e-03       3.17e-02       9.70e-02
#       88             108        6.6694e-01      1.03e-03       3.17e-02       4.31e-02
#       89             109        6.6591e-01      1.03e-03       3.17e-02       9.66e-02
#       90             110        6.6488e-01      1.03e-03       3.17e-02       4.35e-02
#       91             111        6.6386e-01      1.02e-03       3.17e-02       9.66e-02
#       92             112        6.6283e-01      1.02e-03       3.17e-02       4.26e-02
#       93             113        6.6182e-01      1.02e-03       3.17e-02       9.80e-02
#       94             114        6.6080e-01      1.02e-03       3.17e-02       4.22e-02
#       95             115        6.5978e-01      1.02e-03       3.17e-02       9.74e-02
#       96             116        6.5877e-01      1.01e-03       3.17e-02       4.35e-02
#       97             117        6.5776e-01      1.01e-03       3.17e-02       9.81e-02
#       98             118        6.5675e-01      1.01e-03       3.17e-02       4.36e-02
#       99             119        6.5575e-01      1.01e-03       3.17e-02       9.72e-02
#       100            120        6.5474e-01      1.00e-03       3.17e-02       4.39e-02
#       101            121        6.5374e-01      1.00e-03       3.17e-02       9.74e-02
#       102            122        6.5274e-01      1.00e-03       3.17e-02       4.23e-02
#       103            123        6.5174e-01      9.98e-04       3.17e-02       9.69e-02
#       104            124        6.5075e-01      9.96e-04       3.17e-02       4.40e-02
#       105            125        6.4975e-01      9.93e-04       3.17e-02       9.56e-02
#       106            126        6.4876e-01      9.91e-04       3.17e-02       4.35e-02
#       107            127        6.4777e-01      9.87e-04       3.17e-02       9.83e-02
#       108            128        6.4679e-01      9.86e-04       3.17e-02       4.36e-02
#       109            129        6.4581e-01      9.83e-04       3.17e-02       9.70e-02
#       110            130        6.4483e-01      9.80e-04       3.17e-02       4.43e-02
#       111            131        6.4385e-01      9.78e-04       3.17e-02       9.82e-02
#       112            132        6.4287e-01      9.77e-04       3.17e-02       4.47e-02
#       113            133        6.4190e-01      9.75e-04       3.17e-02       9.66e-02
#       114            134        6.4092e-01      9.72e-04       3.17e-02       4.47e-02
#       115            135        6.3995e-01      9.70e-04       3.17e-02       9.69e-02
#       116            136        6.3898e-01      9.68e-04       3.17e-02       4.34e-02
#       117            137        6.3802e-01      9.66e-04       3.17e-02       9.77e-02
#       118            138        6.3705e-01      9.64e-04       3.17e-02       4.40e-02
#       119            139        6.3609e-01      9.62e-04       3.17e-02       9.69e-02
#       120            140        6.3513e-01      9.59e-04       3.17e-02       4.45e-02
#       121            141        6.3418e-01      9.58e-04       3.17e-02       9.68e-02
#       122            142        6.3322e-01      9.55e-04       3.17e-02       4.43e-02
#       123            143        6.3227e-01      9.52e-04       3.17e-02       9.79e-02
#       124            144        6.3132e-01      9.50e-04       3.17e-02       4.48e-02
#       125            145        6.3037e-01      9.48e-04       3.17e-02       9.76e-02
#       126            146        6.2942e-01      9.47e-04       3.17e-02       4.49e-02
#       127            147        6.2848e-01      9.45e-04       3.17e-02       9.72e-02
#       128            148        6.2753e-01      9.43e-04       3.17e-02       4.46e-02
#       129            149        6.2659e-01      9.40e-04       3.17e-02       9.72e-02
#       130            150        6.2566e-01      9.38e-04       3.17e-02       4.37e-02
#       131            151        6.2472e-01      9.36e-04       3.17e-02       9.78e-02
#       132            152        6.2378e-01      9.35e-04       3.17e-02       4.43e-02
#       133            153        6.2285e-01      9.33e-04       3.17e-02       9.73e-02
#       134            154        6.2192e-01      9.31e-04       3.17e-02       4.41e-02
#       135            155        6.2099e-01      9.27e-04       3.17e-02       9.72e-02
#       136            156        6.2007e-01      9.26e-04       3.17e-02       4.57e-02
#       137            157        6.1914e-01      9.23e-04       3.17e-02       9.76e-02
#       138            158        6.1822e-01      9.22e-04       3.17e-02       4.45e-02
#       139            159        6.1730e-01      9.19e-04       3.17e-02       9.78e-02
#       140            160        6.1638e-01      9.19e-04       3.17e-02       4.44e-02
#       141            161        6.1547e-01      9.16e-04       3.17e-02       9.62e-02
#       142            162        6.1455e-01      9.15e-04       3.17e-02       4.41e-02
#       143            163        6.1364e-01      9.12e-04       3.17e-02       9.75e-02
#       144            164        6.1273e-01      9.12e-04       3.17e-02       4.41e-02
#       145            165        6.1182e-01      9.09e-04       3.17e-02       9.64e-02
#       146            166        6.1091e-01      9.07e-04       3.17e-02       4.51e-02
#       147            167        6.1001e-01      9.05e-04       3.17e-02       9.62e-02
#       148            168        6.0910e-01      9.03e-04       3.17e-02       4.46e-02
#       149            169        6.0820e-01      9.01e-04       3.17e-02       9.72e-02
#       150            170        6.0730e-01      8.99e-04       3.17e-02       4.43e-02
#       151            171        6.0641e-01      8.97e-04       3.17e-02       9.70e-02
#       152            172        6.0551e-01      8.95e-04       3.17e-02       4.50e-02
#       153            173        6.0462e-01      8.93e-04       3.17e-02       9.69e-02
#       154            174        6.0373e-01      8.92e-04       3.17e-02       4.45e-02
#       155            175        6.0284e-01      8.89e-04       3.17e-02       9.64e-02
#       156            176        6.0195e-01      8.87e-04       3.17e-02       4.54e-02
#       157            177        6.0107e-01      8.85e-04       3.17e-02       9.67e-02
#       158            178        6.0018e-01      8.84e-04       3.17e-02       4.53e-02
#       159            179        5.9930e-01      8.81e-04       3.17e-02       9.72e-02
#       160            180        5.9842e-01      8.81e-04       3.17e-02       4.50e-02
#       161            181        5.9754e-01      8.78e-04       3.17e-02       9.61e-02
#       162            182        5.9666e-01      8.77e-04       3.17e-02       4.50e-02
#       163            183        5.9579e-01      8.74e-04       3.17e-02       9.63e-02
#       164            184        5.9492e-01      8.74e-04       3.17e-02       4.42e-02
#       165            185        5.9405e-01      8.71e-04       3.17e-02       9.67e-02
#       166            186        5.9318e-01      8.71e-04       3.17e-02       4.37e-02
#       167            187        5.9231e-01      8.67e-04       3.17e-02       9.63e-02
#       168            188        5.9144e-01      8.64e-04       3.17e-02       4.50e-02
#       169            189        5.9058e-01      8.64e-04       3.17e-02       9.70e-02
#       170            190        5.8972e-01      8.63e-04       3.17e-02       4.47e-02
#       171            191        5.8886e-01      8.61e-04       3.17e-02       9.58e-02
#       172            192        5.8800e-01      8.59e-04       3.17e-02       4.56e-02
#       173            193        5.8714e-01      8.56e-04       3.17e-02       9.65e-02
#       174            194        5.8629e-01      8.55e-04       3.17e-02       4.53e-02
#       175            195        5.8543e-01      8.53e-04       3.17e-02       9.61e-02
#       176            196        5.8458e-01      8.51e-04       3.17e-02       4.44e-02
#       177            197        5.8373e-01      8.49e-04       3.17e-02       9.60e-02
#       178            198        5.8289e-01      8.48e-04       3.17e-02       4.47e-02
#       179            199        5.8204e-01      8.46e-04       3.17e-02       9.68e-02
#       180            200        5.8119e-01      8.45e-04       3.17e-02       4.48e-02
#       181            201        5.8035e-01      8.43e-04       3.17e-02       9.64e-02
#       182            202        5.7951e-01      8.42e-04       3.17e-02       4.51e-02
#       183            203        5.7867e-01      8.40e-04       3.17e-02       9.57e-02
#       184            204        5.7783e-01      8.39e-04       3.17e-02       4.47e-02
#       185            205        5.7700e-01      8.35e-04       3.17e-02       9.56e-02
#       186            206        5.7616e-01      8.35e-04       3.17e-02       4.48e-02
#       187            207        5.7533e-01      8.33e-04       3.17e-02       9.57e-02
#       188            208        5.7450e-01      8.32e-04       3.17e-02       4.55e-02
#       189            209        5.7367e-01      8.29e-04       3.17e-02       9.50e-02
#       190            210        5.7284e-01      8.28e-04       3.17e-02       4.57e-02
#       191            211        5.7201e-01      8.26e-04       3.17e-02       9.51e-02
#       192            212        5.7119e-01      8.25e-04       3.17e-02       4.43e-02
#       193            213        5.7036e-01      8.23e-04       3.17e-02       9.55e-02
#       194            214        5.6954e-01      8.22e-04       3.17e-02       4.49e-02
#       195            215        5.6872e-01      8.19e-04       3.17e-02       9.60e-02
#       196            216        5.6790e-01      8.19e-04       3.17e-02       4.47e-02
#       197            217        5.6709e-01      8.17e-04       3.17e-02       9.47e-02
#       198            218        5.6627e-01      8.16e-04       3.17e-02       4.40e-02
#       199            219        5.6546e-01      8.14e-04       3.17e-02       9.42e-02
#       200            220        5.6465e-01      8.11e-04       3.17e-02       4.45e-02
#       201            221        5.6384e-01      8.11e-04       3.17e-02       9.48e-02
#       202            222        5.6303e-01      8.08e-04       3.17e-02       4.51e-02
#       203            223        5.6222e-01      8.07e-04       3.17e-02       9.49e-02
#       204            224        5.6142e-01      8.06e-04       3.17e-02       4.52e-02
#       205            225        5.6061e-01      8.04e-04       3.17e-02       9.37e-02
#       206            226        5.5981e-01      8.03e-04       3.17e-02       4.49e-02
#       207            227        5.5901e-01      8.00e-04       3.17e-02       9.54e-02
#       208            228        5.5821e-01      7.99e-04       3.17e-02       4.49e-02
#       209            229        5.5741e-01      7.98e-04       3.17e-02       9.46e-02
#       210            230        5.5662e-01      7.96e-04       3.17e-02       4.57e-02
#       211            231        5.5582e-01      7.95e-04       3.17e-02       9.36e-02
#       212            232        5.5503e-01      7.94e-04       3.17e-02       4.48e-02
#       213            233        5.5424e-01      7.91e-04       3.17e-02       9.49e-02
#       214            234        5.5345e-01      7.92e-04       3.17e-02       4.39e-02
#       215            235        5.5266e-01      7.88e-04       3.17e-02       9.43e-02
#       216            236        5.5187e-01      7.87e-04       3.17e-02       4.50e-02

# %% [markdown]
# #### atom3

# %%
# saved_guess_2 = atom3.hnc.c_s_k_matrix.copy()

# %%
# saved_guess = c_s_k_guess.copy()

# %%
# np.savetxt("geuss.txt",saved_guess.reshape(4,atom.hnc.N_bins))
atom3.hnc.c_s_k_matrix = np.loadtxt("geuss.txt").reshape(2,2,atom3.hnc.N_bins)
saved_guess = np.loadtxt("geuss.txt").reshape(2,2,atom3.hnc.N_bins)

# %%
og_βu = atom3.hnc.βu_r_matrix.copy()
for i, x in enumerate(np.linspace(0.75, 1, num=3)):
    δβuei_x = δβuei_Pauli_HNC*(1-x) + x*δβuei_Pauli_Lado
    atom3.hnc.βu_r_matrix[0,1] = og_βu[0,1] + δβuei_x
    atom3.hnc.βu_r_matrix[1,0] = og_βu[1,0] + δβuei_x
    atom3.hnc.set_βu_matrix(atom3.hnc.βu_r_matrix)
    if i==0:
        c_s_k_guess = saved_guess
    else:
        c_s_k_guess = atom3.hnc.c_s_k_matrix.copy()
    solve_least_squares(atom3,np.linspace(atom3.hnc.k_array[0], atom3.hnc.k_array[-1], num=400), c_s_k_guess = c_s_k_guess.copy())
#atom.hnc.c_s_k_matrix.copy())#*np.array([[Z**2,Z/Zbar],[Z/Zbar,1]] )[:,:,np.newaxis] )
# Out:
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.4261e+04                                    1.98e+05
#        1              2         3.5706e+03      1.07e+04       7.21e+01       1.81e+04
#        2              7         1.7791e+03      1.79e+03       5.27e-01       2.68e+03
#        3              8         1.3240e+03      4.55e+02       5.27e-01       3.05e+03
#        4              9         1.2800e+03      4.40e+01       5.27e-01       7.14e+03

# %% [markdown]
# ### g(r) Plots

# %%
atom2.hnc.plot_g_all_species()

# %%
atom3.hnc.plot_g_all_species()

# %% [markdown]
# ### Comparison to QMD

# %%
MD_data = read_csv("../../RDFs/V_5.0eV_rs2.82_VASP.txt",  header=0, delim_whitespace=True)
MD_data.columns=['r','g']
MD_data
# Out:
#          r         g
# 0   1.4378  0.000000
# 1   1.4963  0.007183
# 2   1.5317  0.060301
# 3   1.6003  0.259140
# 4   1.6665  0.596870
# 5   1.7141  0.795780
# 6   1.7514  0.946120
# 7   1.7951  1.068700
# 8   1.8241  1.151900
# 9   1.8616  1.205000
# 10  1.8720  1.228100
# 11  1.9139  1.209400
# 12  1.9473  1.232500
# 13  1.9787  1.206900
# 14  2.0121  1.199800
# 15  2.0456  1.162700
# 16  2.0854  1.146400
# 17  2.1231  1.099900
# 18  2.1545  1.069700
# 19  2.1880  1.051100
# 20  2.2215  1.011600
# 21  2.2571  0.981410
# 22  2.2947  0.969700
# 23  2.3282  0.962640
# 24  2.3679  0.962500
# 25  2.4327  0.936820
# 26  2.4766  0.952870
# 27  2.5560  0.950280
# 28  2.6521  0.970780
# 29  2.7231  0.984420
# 30  2.7649  0.988910
# 31  2.8422  1.011800
# 32  2.9237  0.992990
# 33  3.0031  0.999660

# %%
# AA_data = read_csv("/home/zach/plasma/atoMEC/examples/density.csv", delim_whitespace=True, header=0)

fig, ax = plt.subplots(figsize=(10,8))
# nf_0 = Zbar/(4/3*np.pi*atom.qsp.ri**3)
# ax.plot(AA_data['r[a_0]'], np.array(AA_data['n[unbound]'])/nf_0,'k.' ,label="AA" )
# ax.plot(atom_2e.hnc.r_array*atom_2e.qsp.ri, atom_2e.hnc.h_r_matrix[0,0]+1,'--', label='2 electron SVT ')
# ax.plot(atom1.hnc.r_array, atom1.hnc.h_r_matrix[0,0]+1,'--', label='Ashcroft Pseudopotential')
ax.plot(atom2.hnc.r_array, atom2.hnc.h_r_matrix[0,0]+1,'--', label='HNC bound Pauli')
# ax.plot(atom3.hnc.r_array, atom3.hnc.h_r_matrix[0,0]+1,'--', label='Lado bound Paulo')
# ax.plot(atom_long.hnc.r_array, atom_long.hnc.h_r_matrix[0,0]+1,'-.', label='1 electron SVT-long ')
# ax.plot(atom_oz.hnc.r_array, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='1 electron OZ ')
# ax.plot(atom.hnc.r_array, atom_oz.onlyion_hnc.h_r_matrix[0,0]+1,'--', label='Only Ion')
ax.plot(MD_data['r'], MD_data['g'], label='VASP')

# ax.plot(atom_oz.hnc.r_array*atom_oz.qsp.ri, atom_oz.hnc.h_r_matrix[0,0]+1,'--', label='my OZ CHNC')

ax.set_xlim(0,6)
ax.set_ylabel(r'$g_{ii}$',fontsize=20)
ax.set_xlabel(r'$r/r_i$ ',fontsize=20)
ax.tick_params(labelsize=20)
# ax.set_yscale('symlog', linthresh=2)

# [i.set_linewidth(0.1) for i in ax.spines.itervalues()]
ax.legend(fontsize=15)

# %%
atom2.hnc.r_array[np.argmin( np.abs( atom2.hnc.h_r_matrix[0,0]+1 -0.0001 ))], atom2.hnc.r_array[np.argmax( atom2.hnc.h_r_matrix[0,0]+1)]
# Out:
# (0.86, 1.68)

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.plot(atom2.hnc.k_array, atom2.hnc.c_s_k_matrix[0,0],'-' )
ax.plot(atom2.hnc.k_array, atom2.hnc.c_s_k_matrix[1,0],'--' )
ax.plot(atom2.hnc.k_array, atom2.hnc.c_s_k_matrix[1,1],':' )

ax.set_yscale('symlog',linthresh=1)
ax.set_xscale('log')
ax.legend(fontsize=14)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
bound_file = "/home/zach/plasma/hnc/TCCW/data/Al_rs_3.000_T_1.000e+00eV.csv"
AA_data = read_csv(bound_file, delim_whitespace=True, header=0)
AA_r_AU_full = np.array(AA_data['r[a_0]'])
AA_nb_AU_full = np.array(AA_data['n(bound)'])

# Only use some values for speed
min_r_to_use = 0.2*atom.hnc.r_array[0]*atom.qsp.ri # in AU
indcs = np.where(AA_r_AU_full > min_r_to_use)
AA_r_AU = AA_r_AU_full[indcs]
AA_nb_AU = AA_nb_AU_full[indcs]

# Plot bound states
fig, ax = plt.subplots(figsize=(8,6))

ax.plot(AA_r_AU_full/atom.qsp.ri, 4*π*AA_nb_AU_full*AA_r_AU_full**2)
ax.plot(atom2.hnc.r_array, 4*π*(atom2.hnc.r_array*atom2.qsp.ri)**2*(atom2.hnc.h_r_matrix[0,1]+1)*(atom2.hnc.rho[1]/atom2.qsp.ri**3),'--', label='HNC bound Pauli')
ax.axvspan(AA_r_AU_full[0]/atom.qsp.ri, min_r_to_use/atom.qsp.ri, color='k', alpha=0.1)
ax.set_xlabel(r'$r/r_i$')
ax.set_ylabel(r'$4 \pi n_b r^2$ [AU]')
ax.set_xscale('log')
ax.set_xlim(np.min(AA_r_AU_full/atom.qsp.ri), 2*np.max(AA_r_AU_full/atom.qsp.ri))
ax.set_ylim(0, 20)
# Out:
# (0.0, 20.0)

# %% [markdown]
# ## Born Green Viscocity
# See [Morioka 2004](https://www.sciencedirect.com/science/article/pii/S0022309304003692)
#
# \begin{align}
# η = f_{BG} \frac{2 \pi}{15} \left(\frac{M}{RT} \right)^{1/2} \frac{n^2}{N_a} \int^\infty_0 g(r) \frac{d\phi}{dr}r^4 dr
# \end{align}
# Resulting units is Pa s

# %%
from scipy.integrate import simpson

def get_ηBG(plasma):
    plasma.hnc.invert_HNC_OZ([1])
    fBG = -1
    n_AU = n_from_rs(plasma.qsp.ri)
    r_array = plasma.hnc.r_array*plasma.qsp.ri
    gii = plasma.hnc.h_r_matrix[0,0]+1
    dφdr = plasma.qsp.Ti*np.gradient(plasma.hnc.βueff_r_matrix[0,0], r_array)

    integrand = r_array**4 * gii * dφdr
    ##
    fig, ax = plt.subplots()
    ax.plot(r_array, dφdr*r_array**4)
    ###
    integral = simpson(integrand, x=r_array)
    η = fBG* 2*π/15 * (plasma.qsp.βi*plasma.qsp.m_i)**0.5*n_AU**2*integral
    return η

η_SI = get_ηBG(atom2)*AU_to_Pa*AU_to_s # Pa s = kg m^-1 s^-1 
print(f"SI: η = {η_SI:0.3e} [kg m^-1 s^-1] (or [Pa s])")
η_cgs = η_SI * 1000/100 # g cm^-1 s^-1
print(f"CGS: η = {η_cgs:0.3e} [g cm^-1 s^-1]")

# %% [markdown]
# # Plot Fixed Neutrality Issue βu_eff

# %%
plt.style.use('~/plasma/hnc/hnc_paper.mplstyle')

atom.hnc.invert_HNC_OZ([1])
βu_r_raw = atom.hnc.βueff_r_matrix[0,0]
βu_r_raw_fix1 = βu_r_raw - βu_r_raw[-1]
βu_r_raw_fix2 = βu_r_raw - (βu_r_raw[-1]*atom.hnc.r_array[-1])/atom.hnc.r_array
tapering_func = lambda r: np.exp( -0.02*r**2/(5-r))
βu_r_raw_fix3 = βu_r_raw*tapering_func(atom.hnc.r_array)
βu_r_raw_fix4 = βu_r_raw_fix1*tapering_func(atom.hnc.r_array)


fig, axs  = plt.subplots(1,2,figsize=(20,8))
yukawa_matrix = (atom_long.hnc.Gamma[:,:,np.newaxis]/atom_long.hnc.r_array * np.exp(-atom_long.hnc.r_array*atom_long.qsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]

axs[0].set_title(r"$\beta u$")
axs[0].plot(atom.hnc.r_array, βu_r_raw,'k--', label='Raw')
axs[0].plot(atom_long.hnc.r_array, atom_long.hnc.βueff_r_matrix[0,0],'k-.', label='Long')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix1, label=r'Constant Shift to $\beta u_{eff}$')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix2 , label=r'Subtraction of Coulomb directly')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix3, label=r'Tapered raw')
axs[0].plot(atom.hnc.r_array, βu_r_raw_fix4, label=r'Tapered shifted')
axs[0].plot(atom_long.hnc.r_array, yukawa_matrix[0,0],'-.', label='Yukawa')

axs[1].set_title(r"$F$")
dudx = lambda u: -(u[1:]-u[:-1])/atom.hnc.del_r
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw),'k--', label='Raw')
axs[1].plot(atom_long.hnc.r_array[1:], dudx(atom_long.hnc.βueff_r_matrix[0,0]),'k-.', label='Long')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix1), label=r'Constant Shift to $\beta u_{eff}$')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix2) , label=r'Subtraction of Coulomb directly')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix3), label=r'Tapered raw ')
axs[1].plot(atom.hnc.r_array[1:], dudx(βu_r_raw_fix4), label=r'Tapered shifted')
βueff_r_header="r/r_i \t\t\t βuii_eff(r/r_i)"
np.savetxt("./fits/{0}_βu_eff_raw.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw]).T, header=βueff_r_header)
np.savetxt("./fits/{0}_βu_eff_shifted.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw_fix1]).T, header=βueff_r_header)
np.savetxt("./fits/{0}_βu_eff_tapered.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw_fix3]).T, header=βueff_r_header)
np.savetxt("./fits/{0}_βu_eff_shifted_tapered.txt".format(case_id), np.array([atom.hnc.r_array, βu_r_raw_fix4]).T, header=βueff_r_header)

axs[1].set_xlim(4,10)

for ax in axs:
    ax.set_yscale('symlog',linthresh=1e-8)

    ax.legend(fontsize=15)

# %% [markdown]
# ### Plot $\beta u^{eff}$

# %%
plt.style.use('~/plasma/hnc/hnc_paper.mplstyle')
def make_gij(ax):
    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.h_r_matrix[0,0]+1,'-', label=r'$g_{ii}$')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.h_r_matrix[0,1]+1,'--', label=r'$g_{ei}$')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.h_r_matrix[1,1]+1,':', label=r'$g_{ee}$')

    # ax.set_yscale('symlog', linthresh=5)
    ax.set_xlim(0,10)
    ax.set_ylim(-0.05,5)

    ax.set_xlabel(r"$r$ [AU]")#, fontsize=25)
    ax.set_ylabel(r"$g_{ij}$")#, fontsize=25)
    ax.legend()

fig, ax = plt.subplots()
make_gij(ax)
plt.savefig("gij_Al1.png")

# %%
plt.style.use('~/plasma/hnc/hnc_paper.mplstyle')

atom.hnc.invert_HNC_OZ([1])
def make_βu(ax):
    yukawa_matrix = (atom.hnc.Gamma[:,:,np.newaxis]/atom.hnc.r_array * np.exp(-atom.hnc.r_array*atom.qsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]
    coulomb_matrix = (atom.hnc.Gamma[:,:,np.newaxis]/atom.hnc.r_array) [:-1,:-1]

    ax.plot(atom.hnc.r_array*atom.qsp.ri, atom.hnc.βueff_r_matrix[0,0],'-', label='HNC Inversion')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, yukawa_matrix[0,0],'-.', label='Yukawa')
    ax.plot(atom.hnc.r_array*atom.qsp.ri, coulomb_matrix[0,0],'--', label='Coulomb')

    ax.set_yscale('symlog', linthresh=1)

    ax.set_xlabel(r"$r$ [AU]")#, fontsize=25)
    ax.set_ylabel(r"$\beta u_{\rm eff}$")#, fontsize=25)
    ax.legend()

fig, ax = plt.subplots()
make_βu(ax)
plt.savefig("βu_Al1.png")

# %% [markdown]
# ### Now Plot Both Together

# %%
plt.style.use('~/plasma/mpl_styles/paper.mplstyle')

fig, axs = plt.subplots(1,2, figsize=(18,8))

make_gij(axs[0])
make_βu(axs[1])
plt.tight_layout()
plt.savefig("βu_gij_Al1.png")

# %% [markdown]
# # Run Many Cases

# %%
for tccw_case in tccw_cases[6:]:
    α = 0.1
    case_converged=False
    case_attempts=0
    case_num= tccw_case[' ']
    case_id = tccw_case['Case ID']
    ni_cc = tccw_case['Number Density [N/cc]']
    Te_eV = tccw_case['Temperature [eV]']
    Ti_eV = Te_eV
    Z = tccw_case['Atomic Number']
    Zbar = tccw_case['Zbar (TFDW)']
    P_GP_AU  = tccw_case['p (Bar)']/AU_to_bar
    A = tccw_case['Atomic Weight [a.u.]']
    r_s_cc = tccw_case['Wigner-Seitz Radius [cm]']
    r_c = tccw_case['Average-Bound Radius [cm]']/r_s_cc
    if r_c>1:
        r_c=1e-5
    print('\n______________________________\nCase num: {0} Case ID: {1}'.format(case_num, case_id))
    print("Te = {0:.3e} eV, n_i = {1:.3e} 1/cc, r_c/r_s = {2:.3f}".format(Te_eV, ni_cc, r_c))
    print("Te = {0:.3e} K, ρ = {1:.3e} [g/cc] ".format(Te_eV*eV_to_K, 1e3*ni_cc*m_p*A ))
    print("P  = {0:.3e} [bar] = {1:.3e} [AU]".format(P_GP_AU*AU_to_bar, P_GP_AU))
    
    α = 1
    converged=False
    while not converged:
        atom = CMEP_Atom(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar, 
                     βu_options = {'add_bridge':True}, 
                     qsp_options={'r_c':r_c},
                     hnc_options={'kappa_multiscale':10, 'R_max':10,'N_bins':1000},
                     hnc_solve_options={'alpha_Picard':α})
        atom.run_hnc()
        if atom.hnc.newton_succeed==True:
            converged=True
        else:
            α*=0.5
            
    atom.get_cp()

# %% [markdown]
# # Only Ion

# %%
atom.run_onlyion_hnc()

# %%
atom.onlyion_hnc.plot_species_convergence_g()

# %%
# c_s_k_guess = atom.hnc.c_s_k_matrix.copy()*0
c_s_k_guess[0,0] = atom.onlyion_hnc.c_s_k_matrix[0,0]*0.


atom.run_hnc(c_s_k_guess = c_s_k_guess)

# %% [markdown]
# # Make atom

# %%
Zbar_list  = np.linspace(3,Zbar, num=100)
# Zbar_list = [1,3]
atom_list= []
for i, Zbar_i in enumerate(Zbar_list):
    print("Zbar = {0:.3f}".format( Zbar_i ))
    
    atom = CMEP_Atom(Z, A, ni_cc, Ti_eV, Te_eV, Zbar=Zbar_i, 
                 βu_options = {'add_bridge':True}, 
                 qsp_options={'r_c':r_c},
                 hnc_options={'kappa_multiscale':10},
                 hnc_solve_options={'alpha_Picard':0.5})
    if i>=1:
        Z2_matrix = [[Zbar_list[i]]]
        guess_2 = 
        c_s_k_guess = atom_list[-1].hnc.c_s_k_matrix
        c_s_k_guess[0,0] *= (Zbar_list[i]/Zbar_list[i-1])**2 
        c_s_k_guess[0,1] *= (Zbar_list[i]/Zbar_list[i-1])**1 
        c_s_k_guess[1,0] *= (Zbar_list[i]/Zbar_list[i-1])**1
#         c_s_k_guess[0,0] *= 0
    else:
        c_s_k_guess *=0
    atom.run_hnc(c_s_k_guess=c_s_k_guess)
    atom_list.append( atom )

# %%
fig, axs = plt.subplots(2, 2, facecolor='w', figsize=(10,8) )

atom3_guess = atom2.hnc.c_s_k_matrix + (atom2.hnc.c_s_k_matrix-atom1.hnc.c_s_k_matrix)/(2-1)*(3-2) 
atom3_guess = atom2.hnc.c_s_k_matrix + (atom2.hnc.c_s_k_matrix/atom1.hnc.c_s_k_matrix)/(2-1)*(3-2) 

for i in range(2):
    for j in range(2):
        for k, atom in enumerate(atom_list):
            color = plt.cm.viridis(k/len(atom_list))
            Z_factor = (Zbar_list[0]/Zbar_list[k])**-1
            axs[i, j].plot(atom.hnc.r_array, atom.hnc.c_s_k_matrix[i,j], '--',label= "Zbar", color= color)
            axs[i, j].plot(atom.hnc.r_array, Z_factor*atom_list[0].hnc.c_s_k_matrix[i,j],'.', label= "Zbar", color= color)
#             axs[i, j].plot(atom.hnc.r_array, atom2.hnc.c_s_k_matrix[i,j], label= "Zbar=2")
#             axs[i, j].plot(atom.hnc.r_array, atom6.hnc.c_s_k_matrix[i,j], label= "Zbar=6")
#         axs[i, j].plot(atom2.hnc.r_array, atom2.hnc.c_s_k_matrix[i,j]-atom1.hnc.c_s_k_matrix[i,j], label= "Zbar=2/1")
#         axs[i, j].plot(atom2.hnc.r_array, atom3.hnc.c_s_k_matrix[i,j]-atom2.hnc.c_s_k_matrix[i,j], label= "Zbar=3/2")
#         axs[i, j].plot(atom2.hnc.r_array, atom3_guess[i,j] , 'k--', label= "Zbar=3 (guess)")
        
#         axs[i, j].plot(atom3.hnc.r_array, atom3.hnc.c_s_k_matrix[i,j],'k', label= "Zbar=3")
#         axs[i, j].plot(atom100.hnc.r_array, atom80.hnc.c_s_k_matrix[i,j]-100/80*atom100.hnc.c_s_k_matrix[i,j], label= "80/100 eV")
#         axs[i, j].plot(atom100.hnc.r_array, atom60.hnc.c_s_k_matrix[i,j], label= "60 eV")
         
#         axs[i, j].plot(atom100.hnc.r_array, T_rescale[i,j]*atom100.hnc.c_s_k_matrix[i,j], label= "rescaled 100 eV")
        
        axs[i,j].set_xscale('log')
#         axs[i, j].set_yscale('symlog', linthresh=0.1)
#         axs[i, j].legend()
        
plt.tight_layout()

# %%
atom.get_cp(ε_derivative=1e-6, ε_table=1e-1, N_table= 2 )

# %%
fig, ax = plt.subplots()

# ax.plot(atom.hnc.r_array, atom.hnc.βueff_r_matrix[0,0])
ax.plot(atom.hnc.r_array, atom.hnc.h_r_matrix[0,0]+1)
# ax.set_yscale('symlog', linthresh=1)

# %% [markdown]
# ###### Hydrogen H1
#
# c_p = 1.667e+08 [J/m^3/K] = 1.667e+09 [erg/cc/K]
#
#
# c_p^ideal = 2.064e+07 [J/m^3/K] = 2.064e+08 [erg/cc/K]
#
# c_v = 1.229e+08 [J/m^3/K] = 1.229e+09 [erg/cc/K]
#
#
# γ = cp/cv = 1.357e+00
#
# ###### Aluminum Al1
#
# c_p = 5.560e+06 [J/m^3/K] = 5.560e+07 [erg/cc/K]
#
# c_p^ideal = 2.081e+06 [J/m^3/K] = 2.081e+07 [erg/cc/K]
#
# c_v = 3.559e+06 [J/m^3/K] = 3.559e+07 [erg/cc/K]
#
# c_p_over_nkB = 6.678
#
# c_v_over_nkB = 4.275
#
# γ = cp/cv = 1.562e+00
#
# ##### Carbon C1
#
# c_p = 1.005e+09 [J/m^3/K] = 1.005e+10 [erg/cc/K]
#
# c_p^ideal = 1.729e+07 [J/m^3/K] = 1.729e+08 [erg/cc/K]
#
# c_v = 7.410e+08 [J/m^3/K] = 7.410e+09 [erg/cc/K]
#
# γ = cp/cv = 1.357e+00
#
# ##### Copper Cu1
# c_p = 6.829e+07 [J/m^3/K] = 6.829e+08 [erg/cc/K]
#
# c_p^ideal = 2.930e+06 [J/m^3/K] = 2.930e+07 [erg/cc/K]
#
# c_v = 4.460e+07 [J/m^3/K] = 4.460e+08 [erg/cc/K]
#
# γ = cp/cv = 1.531e+00

# %%
# Compare to Ichimaru
n_AU = ni_cc * (1e2*aB)**3
E_over_nkBT = atom.U/( Te*N )
P_over_nkBT = atom.P/(Te*n_AU)
c_p_over_nkB = C_p_AU/N #c_p_SI_vol/k_B/(ni_cc*1e6)
E_over_nkBT, P_over_nkBT, c_p_over_nkB

# %%
# 2x2
#(16.078004224152146, 7.958852940677674, 20.391840227664225)
# 3x3
#(17.29156071613095, 9.41653222069282, 19.954770080816058)
# 4x4
#(17.29156071613095, 9.41653222069282, 20.31577883096223)
# 6x6
#(17.29156071613095, 9.41653222069282, 20.341775951597302)

# %%
#cp units are J/K/m^3

# %%
c_p_SI_vol *J_to_erg*1e-6 # from J/K/m^3 to erg/K/cc

# %%
(c_p_over_nkB*ni_cc * k_B*1e6)/1e8 # in erg/

# %%
# Ideal
# (1.503495387998133, 1.0020009999999997, 2.5033223241241656)

# %% [markdown]
# # βu_eff matching

# %%
from pandas import read_csv
from scipy.interpolate import interp1d
# luke_file = '/home/zach/plasma/atomic_forces/data/Al_T0p5_tab.lammps.PAIR'
luke_file = '/home/zach/plasma/atomic_forces/data/Al_T1_tab.lammps.PAIR'

luke_data = read_csv(luke_file ,delim_whitespace=True,header=3, names=['r [A]','V [eV]','F [eV/A]'])
# luke_r, luke_βV = 1e-10/aB/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_r, luke_βV = 1e-8/r_s*luke_data['r [A]'], 1/(Te/eV)*luke_data['V [eV]']
luke_βV_function = interp1d(luke_r, luke_βV,fill_value='extrapolate',bounds_error=False)

# %%
from scipy.optimize import curve_fit

class βu_fit():
    def __init__(self, func, r_array, y_data, initial_guess):
        self.r = r_array
        self.y = y_data
        self.y_vals = curve_fit(func, r_array, y_data, maxfev=int(1e5), p0=initial_guess)
        self.y_fit  = func(r_array, *self.y_vals[0])
        self.err = np.linalg.norm(self.y_fit-self.y)
        print(func.__name__ + " error: {0:.3e} ".format(self.err))

def yukawa_plus(r, a, b, c, d):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d)))

def yukawa_plus_gaussian(r, a ,b ,c, d ,e, f, g):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.exp(-(f-r)**2/g)

def yukawa_plus_cos(r, a ,b ,c, d , h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + h*np.cos((r-i)*j*np.exp(-k*r))*np.exp(-l*r)

def yukawa_plus_gaussian_cos(r, a ,b ,c, d ,e, f, g, h, i, j, k, l):
    return  a/r*np.exp(-b*r)/(1+np.exp(c*(r-d))) + e*np.cos((r-f)*g*np.exp(-h*r))*np.exp(-i*r) + j*np.exp(-(k-r)**2/l)

# %%
atom = atom_highres

# %%
atom.invert_HNC_OZ([1])
fit1 = βu_fit(yukawa_plus, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[   atomqsp.Γii, atomqsp.get_κ(),2 , 1])
try: 
    fit2 = βu_fit(yukawa_plus_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit1.y_vals[0], 1, 0.01, 1 , 10, 2])
except:
    pass
try:
    fit3 = βu_fit(yukawa_plus_gaussian_cos, atom.r_array, atom.βueff_r_matrix[0,0], initial_guess=[  *fit2.y_vals[0], -1, 1.9, 1])
except:
    pass

# %%
luke_r

# %%
fig, ax = plt.subplots(figsize=(8,6),facecolor='w')
fig.suptitle(r"{0} $T=${1:.1f} eV, $r_i$={2:.2f}".format(case_id, Te/eV, atomqsp.ri), fontsize=20)


yukawa_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array * np.exp(-atom.r_array*atomqsp.get_κ())[np.newaxis,np.newaxis,:] ) [:-1,:-1]
coulomb_matrix = (atom.Gamma[:,:,np.newaxis]/atom.r_array) [:-1,:-1]

ax.plot(atom.r_array, atom.βu_r_matrix[0,0], 'k--',label='Initial')
ax.plot(atom.r_array, yukawa_matrix[0,0],'k-.', label="Yukawa")

ax.plot(atom.r_array, atom.βueff_r_matrix[0,0],color=colors[0], label='Effective')    
ax.plot(luke_r, luke_βV,'r-', label='Luke Force Match')

ax.set_ylim(np.min([-10, 2*np.min(atom.βueff_r_matrix[0,0])]), np.max([1e3, 2*np.max(atom.βueff_r_matrix[0,0])]))
ax.tick_params(labelsize=20)
ax.set_xlabel(r"$r/r_s$",fontsize=20)
ax.set_ylabel(r'$\beta u(r/r_s)$',fontsize=20)
ax.set_xlabel(r'$r/r_s$',fontsize=20)

ax.set_xlim(0, 5)
ax.set_yscale('symlog',linthresh=1)
ax.tick_params(labelsize=15)
ax.legend(fontsize=10)
fig.tight_layout()
